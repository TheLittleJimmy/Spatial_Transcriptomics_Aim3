# %%
import torch
from torch_geometric.utils import (negative_sampling, remove_self_loops,
                                   add_self_loops)
EPS = 1e-15
MAX_LOGSTD = 10

class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""
    def forward(self, z, edge_index, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value


    def forward_all(self, z, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj



class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (Module): The encoder module.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        reset(self.encoder)
        reset(self.decoder)


    def encode(self, *args, **kwargs):
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)


    def decode(self, *args, **kwargs):
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)


    def recon_loss(self, z, pos_edge_index, neg_edge_index=None):
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :oenbj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to train against.
            neg_edge_index (LongTensor, optional): The negative edges to train
                against. If not given, uses negative sampling to calculate
                negative edges. (default: :obj:`None`)
        """

        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()

        # Do not include self-loops in negative samples
        pos_edge_index, _ = remove_self_loops(pos_edge_index)
        pos_edge_index, _ = add_self_loops(pos_edge_index)
        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index, sigmoid=True) +
                              EPS).mean()

        return pos_loss + neg_loss


    def test(self, z, pos_edge_index, neg_edge_index):
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        scores.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to evaluate
                against.
            neg_edge_index (LongTensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import roc_auc_score, average_precision_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)
        
        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)



class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (Module): The encoder module to compute :math:`\mu` and
            :math:`\log\sigma^2`.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(VGAE, self).__init__(encoder, decoder)

    def reparametrize(self, mu, logstd):
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs):
        """"""
        self.__mu__, self.__logstd__ = self.encoder(*args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z

    def kl_loss(self, mu=None, logstd=None):
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (Tensor, optional): The latent space for :math:`\mu`. If set to
                :obj:`None`, uses the last computation of :math:`mu`.
                (default: :obj:`None`)
            logstd (Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`.(default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch
from torch.autograd.grad_mode import F
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges
from torch_geometric.nn import VGAE

import scipy.sparse as sp
import numpy as np
import networkx as nx

class SimuData():
    """Simulate graph data"""
    def __init__(self, p=0.5, n_node=10, n_graph=30):
        self.n_node = n_node
        self.n_graph = n_graph
        self.p = p

    def simu_adj_wgh(self):
        adj_list = []

        for i in range(self.n_graph):
            ## zero matrix
            A = torch.zeros(self.n_node, self.n_node)

            # first five nodes weights: uniform(0,1)A[:5,:5] = W
            W = torch.rand(5,5)

            ## symmetric
            i, j = torch.triu_indices(5, 5)
            W[i, j] = W.T[i, j]

            A[:5,:5] = W
            adj_list.append(A)  

        return adj_list

    def simu_adj_diag(self):
        adj_list = []

        for i in range(self.n_graph):
            A = torch.eye(self.n_node)
            adj_list.append(A)  

        return adj_list

    def simu_adj_m(self):
        """generating adjacency matrix"""
        adj_wgh = self.simu_adj_wgh()
        #adj_wgh = self.simu_adj_diag()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>=1-self.p] = 1
            adj[adj<1-self.p] = 0
            for i in range(adj.shape[0]):
                adj[i, i] = 0
            adj_m_list.append(adj)    
        return adj_m_list

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.simu_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)

        return dataset

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)


class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=False) 
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=False)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=False)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)


transform = T.Compose([
            T.NormalizeFeatures(),
            T.RandomLinkSplit(num_val=0, num_test=0, is_undirected=True,
                            split_labels=True, add_negative_train_samples=False),])

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix


class LoadData():
    """Load graph data"""
    def __init__(self, file_path, samples, n_node=38):
        self.samples = samples
        self.file_path = file_path
        self.nSample = len(samples)
        self.n_node = n_node

    def get_adj_wgh(self):
        """generating adjacency matrix"""
        adj_orig_list =[]
        for sample in self.samples:
            f_name = self.file_path + ".".join([sample])
            adj   = np.asarray(pd.read_csv(f_name, index_col = 0, iterator = False))
            adj_orig_list.append(adj)    

        return adj_orig_list

    def get_adj_label(self):
        adj_m = self.get_adj_m()
        adj_label_list =[]
        
        for _, adj in enumerate(adj_m):
            adj_label = adj + sp.eye(adj.shape[0])
            adj_label = sparse_to_tuple(sp.coo_matrix(adj_label))
            #adj_label = sparse_to_tuple(adj_label)
            adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T), 
                            torch.FloatTensor(adj_label[1]), 
                            torch.Size(adj_label[2]))
            adj_label_list.append(adj_label)
        return adj_label_list

    def get_adj_norm(self):
        adj_m = self.get_adj_m()
        adj_norm_list =[]

        for _, adj in enumerate(adj_m):
            adj_norm = preprocess_graph(adj)
            adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T), 
                            torch.FloatTensor(adj_norm[1]), 
                            torch.Size(adj_norm[2]))
            adj_norm_list.append(adj_norm)

        return adj_norm_list

    def get_adj_m(self):
        adj_wgh = self.get_adj_wgh()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>0] = 1
            for i in range(38):
                adj[i, i] = 0
            for i in range(38):
                for j in range(38):
                    if adj[i, j] == 1:
                        adj[j, i] = 1
            adj_m_list.append(adj)    
        return adj_m_list

    def get_feature(self):
        """generating feature matrix X"""
        adj_wgh = self.get_adj_wgh()
        x_list = []
        for _, adj in enumerate(adj_wgh):
            x_feature  = adj
            x_feature  = csr_matrix(x_feature)
            x_feature  = sparse_to_tuple(x_feature)
            x_feature  = torch.sparse.FloatTensor(torch.LongTensor(x_feature[0].T), 
                            torch.FloatTensor(x_feature[1]), 
                            torch.Size(x_feature[2]))
            x_list.append(x_feature)
        return x_list

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)   

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.get_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)
        return dataset


def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    
    return sparse_to_tuple(adj_normalized)

from os import walk

def get_filename(mypath):
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        break
    return f

# %%
n_node = 10
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
simu_graph = SimuData(n_graph=30, p=0.8)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

# %%
out_channels = 2
n_node = 10
num_features = n_node

VGAE_Encoder = Encoder(num_features, out_channels)
model = VGAE(VGAE_Encoder)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
epochs = 1000

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 * model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))
# Out:
# 0tensor(22.0080, grad_fn=<DivBackward0>)
# 1tensor(19.8967, grad_fn=<DivBackward0>)
# 2tensor(20.9070, grad_fn=<DivBackward0>)
# 3tensor(18.9447, grad_fn=<DivBackward0>)
# 4tensor(20.1452, grad_fn=<DivBackward0>)
# 5tensor(18.2151, grad_fn=<DivBackward0>)
# 6tensor(18.9601, grad_fn=<DivBackward0>)
# 7tensor(18.2496, grad_fn=<DivBackward0>)
# 8tensor(18.8073, grad_fn=<DivBackward0>)
# 9tensor(18.4420, grad_fn=<DivBackward0>)
# 10tensor(16.2875, grad_fn=<DivBackward0>)
# 11tensor(16.0308, grad_fn=<DivBackward0>)
# 12tensor(16.4149, grad_fn=<DivBackward0>)
# 13tensor(15.9534, grad_fn=<DivBackward0>)
# 14tensor(15.6532, grad_fn=<DivBackward0>)
# 15tensor(16.8061, grad_fn=<DivBackward0>)
# 16tensor(16.5055, grad_fn=<DivBackward0>)
# 17tensor(15.5843, grad_fn=<DivBackward0>)
# 18tensor(15.8372, grad_fn=<DivBackward0>)
# 19tensor(15.7206, grad_fn=<DivBackward0>)
# 20tensor(15.3544, grad_fn=<DivBackward0>)
# 21tensor(17.1373, grad_fn=<DivBackward0>)
# 22tensor(15.1357, grad_fn=<DivBackward0>)
# 23tensor(15.0777, grad_fn=<DivBackward0>)
# 24tensor(16.0562, grad_fn=<DivBackward0>)
# 25tensor(15.2244, grad_fn=<DivBackward0>)
# 26tensor(16.0341, grad_fn=<DivBackward0>)
# 27tensor(15.1936, grad_fn=<DivBackward0>)
# 28tensor(14.3694, grad_fn=<DivBackward0>)
# 29tensor(14.5231, grad_fn=<DivBackward0>)
# 30tensor(15.0732, grad_fn=<DivBackward0>)
# 31tensor(15.0288, grad_fn=<DivBackward0>)
# 32tensor(14.9106, grad_fn=<DivBackward0>)
# 33tensor(14.0375, grad_fn=<DivBackward0>)
# 34tensor(14.8005, grad_fn=<DivBackward0>)
# 35tensor(14.5537, grad_fn=<DivBackward0>)
# 36tensor(14.0948, grad_fn=<DivBackward0>)
# 37tensor(14.6718, grad_fn=<DivBackward0>)
# 38tensor(14.9090, grad_fn=<DivBackward0>)
# 39tensor(14.1349, grad_fn=<DivBackward0>)
# 40tensor(14.6194, grad_fn=<DivBackward0>)
# 41tensor(14.3988, grad_fn=<DivBackward0>)
# 42tensor(14.0813, grad_fn=<DivBackward0>)
# 43tensor(14.4605, grad_fn=<DivBackward0>)
# 44tensor(14.2680, grad_fn=<DivBackward0>)
# 45tensor(14.2644, grad_fn=<DivBackward0>)
# 46tensor(14.0482, grad_fn=<DivBackward0>)
# 47tensor(14.3132, grad_fn=<DivBackward0>)
# 48tensor(14.4327, grad_fn=<DivBackward0>)
# 49tensor(13.9590, grad_fn=<DivBackward0>)
# 50tensor(13.9984, grad_fn=<DivBackward0>)
# 51tensor(13.6437, grad_fn=<DivBackward0>)
# 52tensor(13.6181, grad_fn=<DivBackward0>)
# 53tensor(13.6008, grad_fn=<DivBackward0>)
# 54tensor(13.8484, grad_fn=<DivBackward0>)
# 55tensor(13.2949, grad_fn=<DivBackward0>)
# 56tensor(13.9660, grad_fn=<DivBackward0>)
# 57tensor(13.5743, grad_fn=<DivBackward0>)
# 58tensor(13.6926, grad_fn=<DivBackward0>)
# 59tensor(13.6230, grad_fn=<DivBackward0>)
# 60tensor(13.2557, grad_fn=<DivBackward0>)
# 61tensor(13.0274, grad_fn=<DivBackward0>)
# 62tensor(12.9630, grad_fn=<DivBackward0>)
# 63tensor(13.1832, grad_fn=<DivBackward0>)
# 64tensor(12.9104, grad_fn=<DivBackward0>)
# 65tensor(12.8151, grad_fn=<DivBackward0>)
# 66tensor(12.5585, grad_fn=<DivBackward0>)
# 67tensor(12.6015, grad_fn=<DivBackward0>)
# 68tensor(12.9501, grad_fn=<DivBackward0>)
# 69tensor(12.0776, grad_fn=<DivBackward0>)
# 70tensor(11.7392, grad_fn=<DivBackward0>)
# 71tensor(11.9820, grad_fn=<DivBackward0>)
# 72tensor(11.7390, grad_fn=<DivBackward0>)
# 73tensor(11.7654, grad_fn=<DivBackward0>)
# 74tensor(11.4743, grad_fn=<DivBackward0>)
# 75tensor(11.6490, grad_fn=<DivBackward0>)
# 76tensor(11.7625, grad_fn=<DivBackward0>)
# 77tensor(11.2836, grad_fn=<DivBackward0>)
# 78tensor(10.7471, grad_fn=<DivBackward0>)
# 79tensor(10.9493, grad_fn=<DivBackward0>)
# 80tensor(10.5177, grad_fn=<DivBackward0>)
# 81tensor(10.0849, grad_fn=<DivBackward0>)
# 82tensor(10.7900, grad_fn=<DivBackward0>)
# 83tensor(10.5188, grad_fn=<DivBackward0>)
# 84tensor(10.7296, grad_fn=<DivBackward0>)
# 85tensor(10.1418, grad_fn=<DivBackward0>)
# 86tensor(9.9057, grad_fn=<DivBackward0>)
# 87tensor(9.8512, grad_fn=<DivBackward0>)
# 88tensor(9.2996, grad_fn=<DivBackward0>)
# 89tensor(9.7459, grad_fn=<DivBackward0>)
# 90tensor(9.4750, grad_fn=<DivBackward0>)
# 91tensor(9.3495, grad_fn=<DivBackward0>)
# 92tensor(9.4839, grad_fn=<DivBackward0>)
# 93tensor(9.7578, grad_fn=<DivBackward0>)
# 94tensor(9.1759, grad_fn=<DivBackward0>)
# 95tensor(9.1256, grad_fn=<DivBackward0>)
# 96tensor(8.8127, grad_fn=<DivBackward0>)
# 97tensor(8.8977, grad_fn=<DivBackward0>)
# 98tensor(8.5542, grad_fn=<DivBackward0>)
# 99tensor(8.2686, grad_fn=<DivBackward0>)
# 100tensor(8.3752, grad_fn=<DivBackward0>)
# 101tensor(8.4023, grad_fn=<DivBackward0>)
# 102tensor(8.3322, grad_fn=<DivBackward0>)
# 103tensor(8.1606, grad_fn=<DivBackward0>)
# 104tensor(8.1552, grad_fn=<DivBackward0>)
# 105tensor(8.1749, grad_fn=<DivBackward0>)
# 106tensor(8.7105, grad_fn=<DivBackward0>)
# 107tensor(8.5250, grad_fn=<DivBackward0>)
# 108tensor(8.6875, grad_fn=<DivBackward0>)
# 109tensor(8.1274, grad_fn=<DivBackward0>)
# 110tensor(7.9083, grad_fn=<DivBackward0>)
# 111tensor(7.8859, grad_fn=<DivBackward0>)
# 112tensor(7.9769, grad_fn=<DivBackward0>)
# 113tensor(8.2014, grad_fn=<DivBackward0>)
# 114tensor(8.6039, grad_fn=<DivBackward0>)
# 115tensor(8.1541, grad_fn=<DivBackward0>)
# 116tensor(8.2456, grad_fn=<DivBackward0>)
# 117tensor(7.9531, grad_fn=<DivBackward0>)
# 118tensor(8.2267, grad_fn=<DivBackward0>)
# 119tensor(7.7234, grad_fn=<DivBackward0>)
# 120tensor(7.8855, grad_fn=<DivBackward0>)
# 121tensor(7.7209, grad_fn=<DivBackward0>)
# 122tensor(7.8160, grad_fn=<DivBackward0>)
# 123tensor(8.0634, grad_fn=<DivBackward0>)
# 124tensor(7.9316, grad_fn=<DivBackward0>)
# 125tensor(8.2505, grad_fn=<DivBackward0>)
# 126tensor(7.8840, grad_fn=<DivBackward0>)
# 127tensor(8.1299, grad_fn=<DivBackward0>)
# 128tensor(7.6639, grad_fn=<DivBackward0>)
# 129tensor(8.4210, grad_fn=<DivBackward0>)
# 130tensor(7.8529, grad_fn=<DivBackward0>)
# 131tensor(8.2564, grad_fn=<DivBackward0>)
# 132tensor(7.8816, grad_fn=<DivBackward0>)
# 133tensor(7.9357, grad_fn=<DivBackward0>)
# 134tensor(8.2610, grad_fn=<DivBackward0>)
# 135tensor(8.6053, grad_fn=<DivBackward0>)
# 136tensor(7.9127, grad_fn=<DivBackward0>)
# 137tensor(8.1258, grad_fn=<DivBackward0>)
# 138tensor(7.8611, grad_fn=<DivBackward0>)
# 139tensor(8.3407, grad_fn=<DivBackward0>)
# 140tensor(8.0498, grad_fn=<DivBackward0>)
# 141tensor(7.6913, grad_fn=<DivBackward0>)
# 142tensor(7.8928, grad_fn=<DivBackward0>)
# 143tensor(8.2778, grad_fn=<DivBackward0>)
# 144tensor(7.3966, grad_fn=<DivBackward0>)
# 145tensor(8.4701, grad_fn=<DivBackward0>)
# 146tensor(8.1392, grad_fn=<DivBackward0>)
# 147tensor(7.7021, grad_fn=<DivBackward0>)
# 148tensor(8.0209, grad_fn=<DivBackward0>)
# 149tensor(8.1038, grad_fn=<DivBackward0>)
# 150tensor(7.8229, grad_fn=<DivBackward0>)
# 151tensor(7.8035, grad_fn=<DivBackward0>)
# 152tensor(7.8064, grad_fn=<DivBackward0>)
# 153tensor(7.7326, grad_fn=<DivBackward0>)
# 154tensor(8.0517, grad_fn=<DivBackward0>)
# 155tensor(7.6208, grad_fn=<DivBackward0>)
# 156tensor(7.8190, grad_fn=<DivBackward0>)
# 157tensor(7.8554, grad_fn=<DivBackward0>)
# 158tensor(7.8044, grad_fn=<DivBackward0>)
# 159tensor(7.8764, grad_fn=<DivBackward0>)
# 160tensor(7.7484, grad_fn=<DivBackward0>)
# 161tensor(7.5004, grad_fn=<DivBackward0>)
# 162tensor(8.3626, grad_fn=<DivBackward0>)
# 163tensor(7.7673, grad_fn=<DivBackward0>)
# 164tensor(7.7921, grad_fn=<DivBackward0>)
# 165tensor(7.9496, grad_fn=<DivBackward0>)
# 166tensor(8.1373, grad_fn=<DivBackward0>)
# 167tensor(8.0294, grad_fn=<DivBackward0>)
# 168tensor(7.7791, grad_fn=<DivBackward0>)
# 169tensor(8.0922, grad_fn=<DivBackward0>)
# 170tensor(7.7085, grad_fn=<DivBackward0>)
# 171tensor(8.3382, grad_fn=<DivBackward0>)
# 172tensor(7.6180, grad_fn=<DivBackward0>)
# 173tensor(7.8092, grad_fn=<DivBackward0>)
# 174tensor(7.3345, grad_fn=<DivBackward0>)
# 175tensor(7.7145, grad_fn=<DivBackward0>)
# 176tensor(8.2256, grad_fn=<DivBackward0>)
# 177tensor(8.0402, grad_fn=<DivBackward0>)
# 178tensor(8.0437, grad_fn=<DivBackward0>)
# 179tensor(7.6551, grad_fn=<DivBackward0>)
# 180tensor(7.9559, grad_fn=<DivBackward0>)
# 181tensor(7.6495, grad_fn=<DivBackward0>)
# 182tensor(8.2897, grad_fn=<DivBackward0>)
# 183tensor(8.0522, grad_fn=<DivBackward0>)
# 184tensor(7.8175, grad_fn=<DivBackward0>)
# 185tensor(7.9698, grad_fn=<DivBackward0>)
# 186tensor(7.7944, grad_fn=<DivBackward0>)
# 187tensor(8.1019, grad_fn=<DivBackward0>)
# 188tensor(7.9074, grad_fn=<DivBackward0>)
# 189tensor(8.3056, grad_fn=<DivBackward0>)
# 190tensor(8.5427, grad_fn=<DivBackward0>)
# 191tensor(8.0199, grad_fn=<DivBackward0>)
# 192tensor(7.7367, grad_fn=<DivBackward0>)
# 193tensor(8.1927, grad_fn=<DivBackward0>)
# 194tensor(7.7484, grad_fn=<DivBackward0>)
# 195tensor(7.4827, grad_fn=<DivBackward0>)
# 196tensor(7.8613, grad_fn=<DivBackward0>)
# 197tensor(7.7285, grad_fn=<DivBackward0>)
# 198tensor(7.6764, grad_fn=<DivBackward0>)
# 199tensor(7.8676, grad_fn=<DivBackward0>)
# 200tensor(7.9893, grad_fn=<DivBackward0>)
# 201tensor(7.6268, grad_fn=<DivBackward0>)
# 202tensor(7.8549, grad_fn=<DivBackward0>)
# 203tensor(7.9012, grad_fn=<DivBackward0>)
# 204tensor(7.6781, grad_fn=<DivBackward0>)
# 205tensor(7.5759, grad_fn=<DivBackward0>)
# 206tensor(8.2261, grad_fn=<DivBackward0>)
# 207tensor(7.9593, grad_fn=<DivBackward0>)
# 208tensor(7.5905, grad_fn=<DivBackward0>)
# 209tensor(8.3550, grad_fn=<DivBackward0>)
# 210tensor(8.2729, grad_fn=<DivBackward0>)
# 211tensor(7.7209, grad_fn=<DivBackward0>)
# 212tensor(7.5741, grad_fn=<DivBackward0>)
# 213tensor(7.7127, grad_fn=<DivBackward0>)
# 214tensor(7.8418, grad_fn=<DivBackward0>)
# 215tensor(8.2337, grad_fn=<DivBackward0>)
# 216tensor(8.1305, grad_fn=<DivBackward0>)
# 217tensor(8.1117, grad_fn=<DivBackward0>)
# 218tensor(7.9622, grad_fn=<DivBackward0>)
# 219tensor(7.5189, grad_fn=<DivBackward0>)
# 220tensor(7.7711, grad_fn=<DivBackward0>)
# 221tensor(7.3665, grad_fn=<DivBackward0>)
# 222tensor(8.2509, grad_fn=<DivBackward0>)
# 223tensor(7.4920, grad_fn=<DivBackward0>)
# 224tensor(7.7135, grad_fn=<DivBackward0>)
# 225tensor(7.5774, grad_fn=<DivBackward0>)
# 226tensor(7.8352, grad_fn=<DivBackward0>)
# 227tensor(7.8021, grad_fn=<DivBackward0>)
# 228tensor(8.0423, grad_fn=<DivBackward0>)
# 229tensor(7.5613, grad_fn=<DivBackward0>)
# 230tensor(7.7890, grad_fn=<DivBackward0>)
# 231tensor(7.9703, grad_fn=<DivBackward0>)
# 232tensor(8.1352, grad_fn=<DivBackward0>)
# 233tensor(7.8404, grad_fn=<DivBackward0>)
# 234tensor(7.5084, grad_fn=<DivBackward0>)
# 235tensor(7.9364, grad_fn=<DivBackward0>)
# 236tensor(8.0402, grad_fn=<DivBackward0>)
# 237tensor(7.7609, grad_fn=<DivBackward0>)
# 238tensor(7.8437, grad_fn=<DivBackward0>)
# 239tensor(8.0647, grad_fn=<DivBackward0>)
# 240tensor(7.4528, grad_fn=<DivBackward0>)
# 241tensor(7.4348, grad_fn=<DivBackward0>)
# 242tensor(7.5859, grad_fn=<DivBackward0>)
# 243tensor(7.9491, grad_fn=<DivBackward0>)
# 244tensor(8.0523, grad_fn=<DivBackward0>)
# 245tensor(7.7515, grad_fn=<DivBackward0>)
# 246tensor(7.8191, grad_fn=<DivBackward0>)
# 247tensor(7.6860, grad_fn=<DivBackward0>)
# 248tensor(7.6771, grad_fn=<DivBackward0>)
# 249tensor(7.8201, grad_fn=<DivBackward0>)
# 250tensor(8.0916, grad_fn=<DivBackward0>)
# 251tensor(7.6878, grad_fn=<DivBackward0>)
# 252tensor(7.2999, grad_fn=<DivBackward0>)
# 253tensor(7.6380, grad_fn=<DivBackward0>)
# 254tensor(8.2327, grad_fn=<DivBackward0>)
# 255tensor(7.5674, grad_fn=<DivBackward0>)
# 256tensor(7.6997, grad_fn=<DivBackward0>)
# 257tensor(7.6854, grad_fn=<DivBackward0>)
# 258tensor(7.4059, grad_fn=<DivBackward0>)
# 259tensor(7.1714, grad_fn=<DivBackward0>)
# 260tensor(7.5284, grad_fn=<DivBackward0>)
# 261tensor(7.3864, grad_fn=<DivBackward0>)
# 262tensor(7.5818, grad_fn=<DivBackward0>)
# 263tensor(7.0795, grad_fn=<DivBackward0>)
# 264tensor(8.6271, grad_fn=<DivBackward0>)
# 265tensor(7.8587, grad_fn=<DivBackward0>)
# 266tensor(7.4723, grad_fn=<DivBackward0>)
# 267tensor(7.8847, grad_fn=<DivBackward0>)
# 268tensor(7.8882, grad_fn=<DivBackward0>)
# 269tensor(7.9820, grad_fn=<DivBackward0>)
# 270tensor(7.2781, grad_fn=<DivBackward0>)
# 271tensor(7.8111, grad_fn=<DivBackward0>)
# 272tensor(8.0096, grad_fn=<DivBackward0>)
# 273tensor(7.3886, grad_fn=<DivBackward0>)
# 274tensor(7.6059, grad_fn=<DivBackward0>)
# 275tensor(7.6887, grad_fn=<DivBackward0>)
# 276tensor(7.4676, grad_fn=<DivBackward0>)
# 277tensor(7.3239, grad_fn=<DivBackward0>)
# 278tensor(7.6963, grad_fn=<DivBackward0>)
# 279tensor(7.6656, grad_fn=<DivBackward0>)
# 280tensor(8.0905, grad_fn=<DivBackward0>)
# 281tensor(7.9649, grad_fn=<DivBackward0>)
# 282tensor(8.1978, grad_fn=<DivBackward0>)
# 283tensor(7.7885, grad_fn=<DivBackward0>)
# 284tensor(7.4717, grad_fn=<DivBackward0>)
# 285tensor(7.5762, grad_fn=<DivBackward0>)
# 286tensor(7.8314, grad_fn=<DivBackward0>)
# 287tensor(7.8117, grad_fn=<DivBackward0>)
# 288tensor(7.5799, grad_fn=<DivBackward0>)
# 289tensor(7.4150, grad_fn=<DivBackward0>)
# 290tensor(8.1467, grad_fn=<DivBackward0>)
# 291tensor(7.5436, grad_fn=<DivBackward0>)
# 292tensor(7.8262, grad_fn=<DivBackward0>)
# 293tensor(8.0372, grad_fn=<DivBackward0>)
# 294tensor(7.1505, grad_fn=<DivBackward0>)
# 295tensor(7.7795, grad_fn=<DivBackward0>)
# 296tensor(7.4619, grad_fn=<DivBackward0>)
# 297tensor(7.2788, grad_fn=<DivBackward0>)
# 298tensor(7.7857, grad_fn=<DivBackward0>)
# 299tensor(7.4738, grad_fn=<DivBackward0>)
# 300tensor(7.2987, grad_fn=<DivBackward0>)
# 301tensor(7.7763, grad_fn=<DivBackward0>)
# 302tensor(7.3429, grad_fn=<DivBackward0>)
# 303tensor(7.3325, grad_fn=<DivBackward0>)
# 304tensor(8.4504, grad_fn=<DivBackward0>)
# 305tensor(7.6966, grad_fn=<DivBackward0>)
# 306tensor(7.6546, grad_fn=<DivBackward0>)
# 307tensor(7.2887, grad_fn=<DivBackward0>)
# 308tensor(7.5536, grad_fn=<DivBackward0>)
# 309tensor(7.4182, grad_fn=<DivBackward0>)
# 310tensor(7.8789, grad_fn=<DivBackward0>)
# 311tensor(7.2853, grad_fn=<DivBackward0>)
# 312tensor(7.3713, grad_fn=<DivBackward0>)
# 313tensor(7.3694, grad_fn=<DivBackward0>)
# 314tensor(7.4880, grad_fn=<DivBackward0>)
# 315tensor(7.6343, grad_fn=<DivBackward0>)
# 316tensor(7.4156, grad_fn=<DivBackward0>)
# 317tensor(7.6660, grad_fn=<DivBackward0>)
# 318tensor(7.7035, grad_fn=<DivBackward0>)
# 319tensor(7.9465, grad_fn=<DivBackward0>)
# 320tensor(7.3456, grad_fn=<DivBackward0>)
# 321tensor(7.4400, grad_fn=<DivBackward0>)
# 322tensor(7.3654, grad_fn=<DivBackward0>)
# 323tensor(7.7281, grad_fn=<DivBackward0>)
# 324tensor(7.2638, grad_fn=<DivBackward0>)
# 325tensor(7.7514, grad_fn=<DivBackward0>)
# 326tensor(7.1737, grad_fn=<DivBackward0>)
# 327tensor(7.6041, grad_fn=<DivBackward0>)
# 328tensor(7.0504, grad_fn=<DivBackward0>)
# 329tensor(8.2224, grad_fn=<DivBackward0>)
# 330tensor(7.5360, grad_fn=<DivBackward0>)
# 331tensor(7.8049, grad_fn=<DivBackward0>)
# 332tensor(7.4821, grad_fn=<DivBackward0>)
# 333tensor(8.4393, grad_fn=<DivBackward0>)
# 334tensor(7.2888, grad_fn=<DivBackward0>)
# 335tensor(7.3679, grad_fn=<DivBackward0>)
# 336tensor(8.0408, grad_fn=<DivBackward0>)
# 337tensor(7.7035, grad_fn=<DivBackward0>)
# 338tensor(7.6730, grad_fn=<DivBackward0>)
# 339tensor(7.4709, grad_fn=<DivBackward0>)
# 340tensor(7.4180, grad_fn=<DivBackward0>)
# 341tensor(7.6758, grad_fn=<DivBackward0>)
# 342tensor(7.6085, grad_fn=<DivBackward0>)
# 343tensor(7.7616, grad_fn=<DivBackward0>)
# 344tensor(7.9753, grad_fn=<DivBackward0>)
# 345tensor(7.6900, grad_fn=<DivBackward0>)
# 346tensor(7.5438, grad_fn=<DivBackward0>)
# 347tensor(7.5528, grad_fn=<DivBackward0>)
# 348tensor(7.4596, grad_fn=<DivBackward0>)
# 349tensor(7.3739, grad_fn=<DivBackward0>)
# 350tensor(7.7305, grad_fn=<DivBackward0>)
# 351tensor(7.3948, grad_fn=<DivBackward0>)
# 352tensor(7.6019, grad_fn=<DivBackward0>)
# 353tensor(7.3817, grad_fn=<DivBackward0>)
# 354tensor(7.6873, grad_fn=<DivBackward0>)
# 355tensor(7.5163, grad_fn=<DivBackward0>)
# 356tensor(7.7532, grad_fn=<DivBackward0>)
# 357tensor(7.4596, grad_fn=<DivBackward0>)
# 358tensor(7.7670, grad_fn=<DivBackward0>)
# 359tensor(7.6120, grad_fn=<DivBackward0>)
# 360tensor(7.5596, grad_fn=<DivBackward0>)
# 361tensor(7.4060, grad_fn=<DivBackward0>)
# 362tensor(7.9005, grad_fn=<DivBackward0>)
# 363tensor(7.6775, grad_fn=<DivBackward0>)
# 364tensor(7.6234, grad_fn=<DivBackward0>)
# 365tensor(7.7438, grad_fn=<DivBackward0>)
# 366tensor(7.5532, grad_fn=<DivBackward0>)
# 367tensor(8.0191, grad_fn=<DivBackward0>)
# 368tensor(7.6825, grad_fn=<DivBackward0>)
# 369tensor(7.7225, grad_fn=<DivBackward0>)
# 370tensor(7.2391, grad_fn=<DivBackward0>)
# 371tensor(7.7553, grad_fn=<DivBackward0>)
# 372tensor(7.9124, grad_fn=<DivBackward0>)
# 373tensor(7.6957, grad_fn=<DivBackward0>)
# 374tensor(7.8319, grad_fn=<DivBackward0>)
# 375tensor(7.0808, grad_fn=<DivBackward0>)
# 376tensor(7.8685, grad_fn=<DivBackward0>)
# 377tensor(7.5366, grad_fn=<DivBackward0>)
# 378tensor(7.6237, grad_fn=<DivBackward0>)
# 379tensor(7.6144, grad_fn=<DivBackward0>)
# 380tensor(7.8183, grad_fn=<DivBackward0>)
# 381tensor(7.5670, grad_fn=<DivBackward0>)
# 382tensor(7.5965, grad_fn=<DivBackward0>)
# 383tensor(7.9918, grad_fn=<DivBackward0>)
# 384tensor(7.2721, grad_fn=<DivBackward0>)
# 385tensor(7.2331, grad_fn=<DivBackward0>)
# 386tensor(7.4719, grad_fn=<DivBackward0>)
# 387tensor(7.9210, grad_fn=<DivBackward0>)
# 388tensor(7.2231, grad_fn=<DivBackward0>)
# 389tensor(7.6829, grad_fn=<DivBackward0>)
# 390tensor(7.6381, grad_fn=<DivBackward0>)
# 391tensor(7.9989, grad_fn=<DivBackward0>)
# 392tensor(7.5342, grad_fn=<DivBackward0>)
# 393tensor(7.7496, grad_fn=<DivBackward0>)
# 394tensor(7.5155, grad_fn=<DivBackward0>)
# 395tensor(7.6205, grad_fn=<DivBackward0>)
# 396tensor(7.1620, grad_fn=<DivBackward0>)
# 397tensor(7.3554, grad_fn=<DivBackward0>)
# 398tensor(7.4127, grad_fn=<DivBackward0>)
# 399tensor(7.7122, grad_fn=<DivBackward0>)
# 400tensor(7.3555, grad_fn=<DivBackward0>)
# 401tensor(7.7371, grad_fn=<DivBackward0>)
# 402tensor(7.4636, grad_fn=<DivBackward0>)
# 403tensor(7.5540, grad_fn=<DivBackward0>)
# 404tensor(7.2813, grad_fn=<DivBackward0>)
# 405tensor(7.2570, grad_fn=<DivBackward0>)
# 406tensor(8.1759, grad_fn=<DivBackward0>)
# 407tensor(7.5480, grad_fn=<DivBackward0>)
# 408tensor(7.9455, grad_fn=<DivBackward0>)
# 409tensor(7.3375, grad_fn=<DivBackward0>)
# 410tensor(7.2874, grad_fn=<DivBackward0>)
# 411tensor(7.6120, grad_fn=<DivBackward0>)
# 412tensor(7.3342, grad_fn=<DivBackward0>)
# 413tensor(7.3190, grad_fn=<DivBackward0>)
# 414tensor(7.1310, grad_fn=<DivBackward0>)
# 415tensor(7.7964, grad_fn=<DivBackward0>)
# 416tensor(8.0009, grad_fn=<DivBackward0>)
# 417tensor(7.6580, grad_fn=<DivBackward0>)
# 418tensor(8.0252, grad_fn=<DivBackward0>)
# 419tensor(7.1519, grad_fn=<DivBackward0>)
# 420tensor(7.6893, grad_fn=<DivBackward0>)
# 421tensor(7.5705, grad_fn=<DivBackward0>)
# 422tensor(7.5935, grad_fn=<DivBackward0>)
# 423tensor(7.6323, grad_fn=<DivBackward0>)
# 424tensor(7.5765, grad_fn=<DivBackward0>)
# 425tensor(7.8833, grad_fn=<DivBackward0>)
# 426tensor(7.3403, grad_fn=<DivBackward0>)
# 427tensor(7.0843, grad_fn=<DivBackward0>)
# 428tensor(7.5729, grad_fn=<DivBackward0>)
# 429tensor(7.6130, grad_fn=<DivBackward0>)
# 430tensor(7.0730, grad_fn=<DivBackward0>)
# 431tensor(7.4245, grad_fn=<DivBackward0>)
# 432tensor(7.5901, grad_fn=<DivBackward0>)
# 433tensor(7.6215, grad_fn=<DivBackward0>)
# 434tensor(7.6187, grad_fn=<DivBackward0>)
# 435tensor(6.7482, grad_fn=<DivBackward0>)
# 436tensor(7.5856, grad_fn=<DivBackward0>)
# 437tensor(7.2148, grad_fn=<DivBackward0>)
# 438tensor(7.6459, grad_fn=<DivBackward0>)
# 439tensor(7.7023, grad_fn=<DivBackward0>)
# 440tensor(7.1768, grad_fn=<DivBackward0>)
# 441tensor(7.4203, grad_fn=<DivBackward0>)
# 442tensor(7.4462, grad_fn=<DivBackward0>)
# 443tensor(7.4161, grad_fn=<DivBackward0>)
# 444tensor(7.4749, grad_fn=<DivBackward0>)
# 445tensor(7.5325, grad_fn=<DivBackward0>)
# 446tensor(7.6095, grad_fn=<DivBackward0>)
# 447tensor(7.2188, grad_fn=<DivBackward0>)
# 448tensor(7.3878, grad_fn=<DivBackward0>)
# 449tensor(7.4174, grad_fn=<DivBackward0>)
# 450tensor(7.8992, grad_fn=<DivBackward0>)
# 451tensor(7.6646, grad_fn=<DivBackward0>)
# 452tensor(7.2708, grad_fn=<DivBackward0>)
# 453tensor(7.4391, grad_fn=<DivBackward0>)
# 454tensor(8.1423, grad_fn=<DivBackward0>)
# 455tensor(7.6338, grad_fn=<DivBackward0>)
# 456tensor(7.7195, grad_fn=<DivBackward0>)
# 457tensor(7.7924, grad_fn=<DivBackward0>)
# 458tensor(7.6157, grad_fn=<DivBackward0>)
# 459tensor(6.8575, grad_fn=<DivBackward0>)
# 460tensor(8.0029, grad_fn=<DivBackward0>)
# 461tensor(7.3694, grad_fn=<DivBackward0>)
# 462tensor(7.2374, grad_fn=<DivBackward0>)
# 463tensor(7.2823, grad_fn=<DivBackward0>)
# 464tensor(7.4710, grad_fn=<DivBackward0>)
# 465tensor(7.5045, grad_fn=<DivBackward0>)
# 466tensor(7.2172, grad_fn=<DivBackward0>)
# 467tensor(7.4697, grad_fn=<DivBackward0>)
# 468tensor(7.6982, grad_fn=<DivBackward0>)
# 469tensor(7.1118, grad_fn=<DivBackward0>)
# 470tensor(7.2386, grad_fn=<DivBackward0>)
# 471tensor(7.0843, grad_fn=<DivBackward0>)
# 472tensor(8.2164, grad_fn=<DivBackward0>)
# 473tensor(7.4429, grad_fn=<DivBackward0>)
# 474tensor(7.7205, grad_fn=<DivBackward0>)
# 475tensor(7.6914, grad_fn=<DivBackward0>)
# 476tensor(7.2441, grad_fn=<DivBackward0>)
# 477tensor(7.7716, grad_fn=<DivBackward0>)
# 478tensor(7.2586, grad_fn=<DivBackward0>)
# 479tensor(7.7697, grad_fn=<DivBackward0>)
# 480tensor(7.4511, grad_fn=<DivBackward0>)
# 481tensor(7.5258, grad_fn=<DivBackward0>)
# 482tensor(7.6684, grad_fn=<DivBackward0>)
# 483tensor(7.5091, grad_fn=<DivBackward0>)
# 484tensor(7.5627, grad_fn=<DivBackward0>)
# 485tensor(7.2059, grad_fn=<DivBackward0>)
# 486tensor(7.7159, grad_fn=<DivBackward0>)
# 487tensor(7.5170, grad_fn=<DivBackward0>)
# 488tensor(7.3801, grad_fn=<DivBackward0>)
# 489tensor(7.8445, grad_fn=<DivBackward0>)
# 490tensor(7.7179, grad_fn=<DivBackward0>)
# 491tensor(7.7960, grad_fn=<DivBackward0>)
# 492tensor(7.6966, grad_fn=<DivBackward0>)
# 493tensor(7.3324, grad_fn=<DivBackward0>)
# 494tensor(7.4464, grad_fn=<DivBackward0>)
# 495tensor(7.4816, grad_fn=<DivBackward0>)
# 496tensor(7.3961, grad_fn=<DivBackward0>)
# 497tensor(7.4772, grad_fn=<DivBackward0>)
# 498tensor(7.4489, grad_fn=<DivBackward0>)
# 499tensor(7.6188, grad_fn=<DivBackward0>)
# 500tensor(7.4104, grad_fn=<DivBackward0>)
# 501tensor(7.6868, grad_fn=<DivBackward0>)
# 502tensor(7.1449, grad_fn=<DivBackward0>)
# 503tensor(7.1607, grad_fn=<DivBackward0>)
# 504tensor(7.7677, grad_fn=<DivBackward0>)
# 505tensor(7.2692, grad_fn=<DivBackward0>)
# 506tensor(7.7652, grad_fn=<DivBackward0>)
# 507tensor(7.6441, grad_fn=<DivBackward0>)
# 508tensor(7.7106, grad_fn=<DivBackward0>)
# 509tensor(7.7848, grad_fn=<DivBackward0>)
# 510tensor(7.2595, grad_fn=<DivBackward0>)
# 511tensor(7.4431, grad_fn=<DivBackward0>)
# 512tensor(7.4610, grad_fn=<DivBackward0>)
# 513tensor(7.3359, grad_fn=<DivBackward0>)
# 514tensor(7.5286, grad_fn=<DivBackward0>)
# 515tensor(7.7761, grad_fn=<DivBackward0>)
# 516tensor(7.5035, grad_fn=<DivBackward0>)
# 517tensor(7.3994, grad_fn=<DivBackward0>)
# 518tensor(7.4250, grad_fn=<DivBackward0>)
# 519tensor(7.0384, grad_fn=<DivBackward0>)
# 520tensor(7.3142, grad_fn=<DivBackward0>)
# 521tensor(7.2955, grad_fn=<DivBackward0>)
# 522tensor(7.5123, grad_fn=<DivBackward0>)
# 523tensor(7.3144, grad_fn=<DivBackward0>)
# 524tensor(7.4741, grad_fn=<DivBackward0>)
# 525tensor(7.4807, grad_fn=<DivBackward0>)
# 526tensor(7.3881, grad_fn=<DivBackward0>)
# 527tensor(7.7673, grad_fn=<DivBackward0>)
# 528tensor(7.3711, grad_fn=<DivBackward0>)
# 529tensor(7.0586, grad_fn=<DivBackward0>)
# 530tensor(7.6112, grad_fn=<DivBackward0>)
# 531tensor(7.6366, grad_fn=<DivBackward0>)
# 532tensor(7.7141, grad_fn=<DivBackward0>)
# 533tensor(7.6847, grad_fn=<DivBackward0>)
# 534tensor(7.2308, grad_fn=<DivBackward0>)
# 535tensor(7.3533, grad_fn=<DivBackward0>)
# 536tensor(7.1704, grad_fn=<DivBackward0>)
# 537tensor(7.3317, grad_fn=<DivBackward0>)
# 538tensor(7.3889, grad_fn=<DivBackward0>)
# 539tensor(7.3235, grad_fn=<DivBackward0>)
# 540tensor(7.9352, grad_fn=<DivBackward0>)
# 541tensor(7.0017, grad_fn=<DivBackward0>)
# 542tensor(7.2658, grad_fn=<DivBackward0>)
# 543tensor(6.7766, grad_fn=<DivBackward0>)
# 544tensor(7.2109, grad_fn=<DivBackward0>)
# 545tensor(7.0289, grad_fn=<DivBackward0>)
# 546tensor(7.7293, grad_fn=<DivBackward0>)
# 547tensor(7.5525, grad_fn=<DivBackward0>)
# 548tensor(7.3592, grad_fn=<DivBackward0>)
# 549tensor(7.5599, grad_fn=<DivBackward0>)
# 550tensor(7.6772, grad_fn=<DivBackward0>)
# 551tensor(7.0451, grad_fn=<DivBackward0>)
# 552tensor(7.4690, grad_fn=<DivBackward0>)
# 553tensor(8.1387, grad_fn=<DivBackward0>)
# 554tensor(7.8469, grad_fn=<DivBackward0>)
# 555tensor(7.6794, grad_fn=<DivBackward0>)
# 556tensor(7.4355, grad_fn=<DivBackward0>)
# 557tensor(7.6043, grad_fn=<DivBackward0>)
# 558tensor(7.4577, grad_fn=<DivBackward0>)
# 559tensor(7.5127, grad_fn=<DivBackward0>)
# 560tensor(6.9173, grad_fn=<DivBackward0>)
# 561tensor(7.3580, grad_fn=<DivBackward0>)
# 562tensor(7.5338, grad_fn=<DivBackward0>)
# 563tensor(7.7092, grad_fn=<DivBackward0>)
# 564tensor(7.1792, grad_fn=<DivBackward0>)
# 565tensor(7.4459, grad_fn=<DivBackward0>)
# 566tensor(7.4820, grad_fn=<DivBackward0>)
# 567tensor(7.7032, grad_fn=<DivBackward0>)
# 568tensor(7.3546, grad_fn=<DivBackward0>)
# 569tensor(7.3832, grad_fn=<DivBackward0>)
# 570tensor(7.8115, grad_fn=<DivBackward0>)
# 571tensor(7.8263, grad_fn=<DivBackward0>)
# 572tensor(7.2939, grad_fn=<DivBackward0>)
# 573tensor(6.8492, grad_fn=<DivBackward0>)
# 574tensor(7.4230, grad_fn=<DivBackward0>)
# 575tensor(7.8621, grad_fn=<DivBackward0>)
# 576tensor(7.5742, grad_fn=<DivBackward0>)
# 577tensor(7.5879, grad_fn=<DivBackward0>)
# 578tensor(7.2372, grad_fn=<DivBackward0>)
# 579tensor(7.4646, grad_fn=<DivBackward0>)
# 580tensor(7.4005, grad_fn=<DivBackward0>)
# 581tensor(6.9417, grad_fn=<DivBackward0>)
# 582tensor(7.7555, grad_fn=<DivBackward0>)
# 583tensor(7.6071, grad_fn=<DivBackward0>)
# 584tensor(7.7094, grad_fn=<DivBackward0>)
# 585tensor(7.3545, grad_fn=<DivBackward0>)
# 586tensor(7.5337, grad_fn=<DivBackward0>)
# 587tensor(7.4082, grad_fn=<DivBackward0>)
# 588tensor(7.4424, grad_fn=<DivBackward0>)
# 589tensor(7.5226, grad_fn=<DivBackward0>)
# 590tensor(7.2265, grad_fn=<DivBackward0>)
# 591tensor(7.2478, grad_fn=<DivBackward0>)
# 592tensor(7.7689, grad_fn=<DivBackward0>)
# 593tensor(6.7476, grad_fn=<DivBackward0>)
# 594tensor(7.4053, grad_fn=<DivBackward0>)
# 595tensor(7.6164, grad_fn=<DivBackward0>)
# 596tensor(7.5285, grad_fn=<DivBackward0>)
# 597tensor(7.0316, grad_fn=<DivBackward0>)
# 598tensor(7.5066, grad_fn=<DivBackward0>)
# 599tensor(7.7146, grad_fn=<DivBackward0>)
# 600tensor(7.2626, grad_fn=<DivBackward0>)
# 601tensor(7.2651, grad_fn=<DivBackward0>)
# 602tensor(7.2457, grad_fn=<DivBackward0>)
# 603tensor(6.9689, grad_fn=<DivBackward0>)
# 604tensor(7.5959, grad_fn=<DivBackward0>)
# 605tensor(7.7602, grad_fn=<DivBackward0>)
# 606tensor(7.0325, grad_fn=<DivBackward0>)
# 607tensor(7.3422, grad_fn=<DivBackward0>)
# 608tensor(7.7551, grad_fn=<DivBackward0>)
# 609tensor(7.4413, grad_fn=<DivBackward0>)
# 610tensor(7.7474, grad_fn=<DivBackward0>)
# 611tensor(7.6955, grad_fn=<DivBackward0>)
# 612tensor(7.4453, grad_fn=<DivBackward0>)
# 613tensor(7.8938, grad_fn=<DivBackward0>)
# 614tensor(7.4811, grad_fn=<DivBackward0>)
# 615tensor(7.4338, grad_fn=<DivBackward0>)
# 616tensor(7.4700, grad_fn=<DivBackward0>)
# 617tensor(7.5267, grad_fn=<DivBackward0>)
# 618tensor(7.5741, grad_fn=<DivBackward0>)
# 619tensor(7.5773, grad_fn=<DivBackward0>)
# 620tensor(7.6502, grad_fn=<DivBackward0>)
# 621tensor(7.6068, grad_fn=<DivBackward0>)
# 622tensor(7.9454, grad_fn=<DivBackward0>)
# 623tensor(7.3719, grad_fn=<DivBackward0>)
# 624tensor(7.4138, grad_fn=<DivBackward0>)
# 625tensor(7.8168, grad_fn=<DivBackward0>)
# 626tensor(7.2248, grad_fn=<DivBackward0>)
# 627tensor(7.0987, grad_fn=<DivBackward0>)
# 628tensor(7.1037, grad_fn=<DivBackward0>)
# 629tensor(7.4168, grad_fn=<DivBackward0>)
# 630tensor(7.6121, grad_fn=<DivBackward0>)
# 631tensor(7.5058, grad_fn=<DivBackward0>)
# 632tensor(7.6203, grad_fn=<DivBackward0>)
# 633tensor(7.4087, grad_fn=<DivBackward0>)
# 634tensor(7.2337, grad_fn=<DivBackward0>)
# 635tensor(7.3443, grad_fn=<DivBackward0>)
# 636tensor(7.7654, grad_fn=<DivBackward0>)
# 637tensor(7.4914, grad_fn=<DivBackward0>)
# 638tensor(7.7770, grad_fn=<DivBackward0>)
# 639tensor(7.6870, grad_fn=<DivBackward0>)
# 640tensor(7.3911, grad_fn=<DivBackward0>)
# 641tensor(7.7052, grad_fn=<DivBackward0>)
# 642tensor(7.3389, grad_fn=<DivBackward0>)
# 643tensor(7.0088, grad_fn=<DivBackward0>)
# 644tensor(7.0692, grad_fn=<DivBackward0>)
# 645tensor(7.3269, grad_fn=<DivBackward0>)
# 646tensor(7.8382, grad_fn=<DivBackward0>)
# 647tensor(7.4695, grad_fn=<DivBackward0>)
# 648tensor(7.3896, grad_fn=<DivBackward0>)
# 649tensor(7.5896, grad_fn=<DivBackward0>)
# 650tensor(7.9291, grad_fn=<DivBackward0>)
# 651tensor(7.6903, grad_fn=<DivBackward0>)
# 652tensor(7.1725, grad_fn=<DivBackward0>)
# 653tensor(7.5151, grad_fn=<DivBackward0>)
# 654tensor(7.0247, grad_fn=<DivBackward0>)
# 655tensor(7.5189, grad_fn=<DivBackward0>)
# 656tensor(7.4226, grad_fn=<DivBackward0>)
# 657tensor(7.1634, grad_fn=<DivBackward0>)
# 658tensor(7.3647, grad_fn=<DivBackward0>)
# 659tensor(7.2377, grad_fn=<DivBackward0>)
# 660tensor(7.5361, grad_fn=<DivBackward0>)
# 661tensor(7.2200, grad_fn=<DivBackward0>)
# 662tensor(7.2645, grad_fn=<DivBackward0>)
# 663tensor(7.3164, grad_fn=<DivBackward0>)
# 664tensor(7.4182, grad_fn=<DivBackward0>)
# 665tensor(7.8015, grad_fn=<DivBackward0>)
# 666tensor(7.3265, grad_fn=<DivBackward0>)
# 667tensor(7.3352, grad_fn=<DivBackward0>)
# 668tensor(6.7995, grad_fn=<DivBackward0>)
# 669tensor(7.3867, grad_fn=<DivBackward0>)
# 670tensor(7.3000, grad_fn=<DivBackward0>)
# 671tensor(7.3134, grad_fn=<DivBackward0>)
# 672tensor(7.4335, grad_fn=<DivBackward0>)
# 673tensor(7.2206, grad_fn=<DivBackward0>)
# 674tensor(7.0592, grad_fn=<DivBackward0>)
# 675tensor(7.0388, grad_fn=<DivBackward0>)
# 676tensor(6.9559, grad_fn=<DivBackward0>)
# 677tensor(7.2610, grad_fn=<DivBackward0>)
# 678tensor(7.0117, grad_fn=<DivBackward0>)
# 679tensor(7.3572, grad_fn=<DivBackward0>)
# 680tensor(7.2732, grad_fn=<DivBackward0>)
# 681tensor(7.3776, grad_fn=<DivBackward0>)
# 682tensor(7.0854, grad_fn=<DivBackward0>)
# 683tensor(7.1461, grad_fn=<DivBackward0>)
# 684tensor(7.1268, grad_fn=<DivBackward0>)
# 685tensor(7.2495, grad_fn=<DivBackward0>)
# 686tensor(7.4934, grad_fn=<DivBackward0>)
# 687tensor(7.1056, grad_fn=<DivBackward0>)
# 688tensor(7.2553, grad_fn=<DivBackward0>)
# 689tensor(7.6861, grad_fn=<DivBackward0>)
# 690tensor(7.3778, grad_fn=<DivBackward0>)
# 691tensor(7.0814, grad_fn=<DivBackward0>)
# 692tensor(7.2987, grad_fn=<DivBackward0>)
# 693tensor(7.2265, grad_fn=<DivBackward0>)
# 694tensor(7.3766, grad_fn=<DivBackward0>)
# 695tensor(7.2954, grad_fn=<DivBackward0>)
# 696tensor(7.4548, grad_fn=<DivBackward0>)
# 697tensor(7.1676, grad_fn=<DivBackward0>)
# 698tensor(6.9303, grad_fn=<DivBackward0>)
# 699tensor(7.4644, grad_fn=<DivBackward0>)
# 700tensor(7.0687, grad_fn=<DivBackward0>)
# 701tensor(7.3981, grad_fn=<DivBackward0>)
# 702tensor(7.3866, grad_fn=<DivBackward0>)
# 703tensor(7.3472, grad_fn=<DivBackward0>)
# 704tensor(7.6202, grad_fn=<DivBackward0>)
# 705tensor(7.4518, grad_fn=<DivBackward0>)
# 706tensor(7.1934, grad_fn=<DivBackward0>)
# 707tensor(7.1511, grad_fn=<DivBackward0>)
# 708tensor(7.3398, grad_fn=<DivBackward0>)
# 709tensor(7.3398, grad_fn=<DivBackward0>)
# 710tensor(7.0004, grad_fn=<DivBackward0>)
# 711tensor(7.5025, grad_fn=<DivBackward0>)
# 712tensor(7.0407, grad_fn=<DivBackward0>)
# 713tensor(7.0682, grad_fn=<DivBackward0>)
# 714tensor(7.0878, grad_fn=<DivBackward0>)
# 715tensor(6.6309, grad_fn=<DivBackward0>)
# 716tensor(6.7341, grad_fn=<DivBackward0>)
# 717tensor(6.9050, grad_fn=<DivBackward0>)
# 718tensor(7.4928, grad_fn=<DivBackward0>)
# 719tensor(7.5255, grad_fn=<DivBackward0>)
# 720tensor(6.9302, grad_fn=<DivBackward0>)
# 721tensor(6.9755, grad_fn=<DivBackward0>)
# 722tensor(6.9623, grad_fn=<DivBackward0>)
# 723tensor(7.1899, grad_fn=<DivBackward0>)
# 724tensor(7.2229, grad_fn=<DivBackward0>)
# 725tensor(7.2174, grad_fn=<DivBackward0>)
# 726tensor(7.2666, grad_fn=<DivBackward0>)
# 727tensor(7.0532, grad_fn=<DivBackward0>)
# 728tensor(6.9543, grad_fn=<DivBackward0>)
# 729tensor(7.3878, grad_fn=<DivBackward0>)
# 730tensor(7.2101, grad_fn=<DivBackward0>)
# 731tensor(7.2385, grad_fn=<DivBackward0>)
# 732tensor(7.2974, grad_fn=<DivBackward0>)
# 733tensor(7.1954, grad_fn=<DivBackward0>)
# 734tensor(7.2613, grad_fn=<DivBackward0>)
# 735tensor(7.3217, grad_fn=<DivBackward0>)
# 736tensor(7.5170, grad_fn=<DivBackward0>)
# 737tensor(7.3000, grad_fn=<DivBackward0>)
# 738tensor(7.3784, grad_fn=<DivBackward0>)
# 739tensor(7.2503, grad_fn=<DivBackward0>)
# 740tensor(7.2948, grad_fn=<DivBackward0>)
# 741tensor(6.8112, grad_fn=<DivBackward0>)
# 742tensor(7.1200, grad_fn=<DivBackward0>)
# 743tensor(7.3265, grad_fn=<DivBackward0>)
# 744tensor(6.8852, grad_fn=<DivBackward0>)
# 745tensor(7.2530, grad_fn=<DivBackward0>)
# 746tensor(7.0358, grad_fn=<DivBackward0>)
# 747tensor(7.3691, grad_fn=<DivBackward0>)
# 748tensor(6.9895, grad_fn=<DivBackward0>)
# 749tensor(6.9661, grad_fn=<DivBackward0>)
# 750tensor(7.1843, grad_fn=<DivBackward0>)
# 751tensor(6.6804, grad_fn=<DivBackward0>)
# 752tensor(7.3267, grad_fn=<DivBackward0>)
# 753tensor(6.9970, grad_fn=<DivBackward0>)
# 754tensor(7.3718, grad_fn=<DivBackward0>)
# 755tensor(7.8674, grad_fn=<DivBackward0>)
# 756tensor(7.1647, grad_fn=<DivBackward0>)
# 757tensor(6.8863, grad_fn=<DivBackward0>)
# 758tensor(6.9101, grad_fn=<DivBackward0>)
# 759tensor(7.6135, grad_fn=<DivBackward0>)
# 760tensor(6.9331, grad_fn=<DivBackward0>)
# 761tensor(6.8309, grad_fn=<DivBackward0>)
# 762tensor(7.2186, grad_fn=<DivBackward0>)
# 763tensor(7.4387, grad_fn=<DivBackward0>)
# 764tensor(7.1127, grad_fn=<DivBackward0>)
# 765tensor(7.0580, grad_fn=<DivBackward0>)
# 766tensor(7.6241, grad_fn=<DivBackward0>)
# 767tensor(7.1584, grad_fn=<DivBackward0>)
# 768tensor(7.5664, grad_fn=<DivBackward0>)
# 769tensor(7.2488, grad_fn=<DivBackward0>)
# 770tensor(7.0165, grad_fn=<DivBackward0>)
# 771tensor(7.5959, grad_fn=<DivBackward0>)
# 772tensor(7.2891, grad_fn=<DivBackward0>)
# 773tensor(7.1811, grad_fn=<DivBackward0>)
# 774tensor(6.7630, grad_fn=<DivBackward0>)
# 775tensor(7.4251, grad_fn=<DivBackward0>)
# 776tensor(6.9107, grad_fn=<DivBackward0>)
# 777tensor(7.1920, grad_fn=<DivBackward0>)
# 778tensor(7.1898, grad_fn=<DivBackward0>)
# 779tensor(7.2975, grad_fn=<DivBackward0>)
# 780tensor(6.7807, grad_fn=<DivBackward0>)
# 781tensor(7.0917, grad_fn=<DivBackward0>)
# 782tensor(6.9198, grad_fn=<DivBackward0>)
# 783tensor(7.5855, grad_fn=<DivBackward0>)
# 784tensor(7.4097, grad_fn=<DivBackward0>)
# 785tensor(7.4389, grad_fn=<DivBackward0>)
# 786tensor(7.1121, grad_fn=<DivBackward0>)
# 787tensor(7.0291, grad_fn=<DivBackward0>)
# 788tensor(7.0386, grad_fn=<DivBackward0>)
# 789tensor(6.6329, grad_fn=<DivBackward0>)
# 790tensor(7.4131, grad_fn=<DivBackward0>)
# 791tensor(7.3923, grad_fn=<DivBackward0>)
# 792tensor(7.2640, grad_fn=<DivBackward0>)
# 793tensor(7.2248, grad_fn=<DivBackward0>)
# 794tensor(7.4004, grad_fn=<DivBackward0>)
# 795tensor(7.1280, grad_fn=<DivBackward0>)
# 796tensor(7.0526, grad_fn=<DivBackward0>)
# 797tensor(6.9871, grad_fn=<DivBackward0>)
# 798tensor(7.5424, grad_fn=<DivBackward0>)
# 799tensor(7.3987, grad_fn=<DivBackward0>)
# 800tensor(6.9323, grad_fn=<DivBackward0>)
# 801tensor(6.8431, grad_fn=<DivBackward0>)
# 802tensor(7.2909, grad_fn=<DivBackward0>)
# 803tensor(7.1022, grad_fn=<DivBackward0>)
# 804tensor(6.9418, grad_fn=<DivBackward0>)
# 805tensor(6.7782, grad_fn=<DivBackward0>)
# 806tensor(7.3734, grad_fn=<DivBackward0>)
# 807tensor(7.1425, grad_fn=<DivBackward0>)
# 808tensor(7.1292, grad_fn=<DivBackward0>)
# 809tensor(6.9478, grad_fn=<DivBackward0>)
# 810tensor(7.4108, grad_fn=<DivBackward0>)
# 811tensor(7.3583, grad_fn=<DivBackward0>)
# 812tensor(6.7419, grad_fn=<DivBackward0>)
# 813tensor(7.0996, grad_fn=<DivBackward0>)
# 814tensor(7.4847, grad_fn=<DivBackward0>)
# 815tensor(7.1010, grad_fn=<DivBackward0>)
# 816tensor(6.6930, grad_fn=<DivBackward0>)
# 817tensor(7.1417, grad_fn=<DivBackward0>)
# 818tensor(7.0043, grad_fn=<DivBackward0>)
# 819tensor(6.8819, grad_fn=<DivBackward0>)
# 820tensor(7.3007, grad_fn=<DivBackward0>)
# 821tensor(7.3539, grad_fn=<DivBackward0>)
# 822tensor(7.5841, grad_fn=<DivBackward0>)
# 823tensor(7.0596, grad_fn=<DivBackward0>)
# 824tensor(7.3249, grad_fn=<DivBackward0>)
# 825tensor(6.8493, grad_fn=<DivBackward0>)
# 826tensor(7.1199, grad_fn=<DivBackward0>)
# 827tensor(7.2444, grad_fn=<DivBackward0>)
# 828tensor(7.6586, grad_fn=<DivBackward0>)
# 829tensor(7.5272, grad_fn=<DivBackward0>)
# 830tensor(7.3598, grad_fn=<DivBackward0>)
# 831tensor(7.1830, grad_fn=<DivBackward0>)
# 832tensor(6.9028, grad_fn=<DivBackward0>)
# 833tensor(7.5577, grad_fn=<DivBackward0>)
# 834tensor(7.1290, grad_fn=<DivBackward0>)
# 835tensor(7.4999, grad_fn=<DivBackward0>)
# 836tensor(6.9412, grad_fn=<DivBackward0>)
# 837tensor(7.0694, grad_fn=<DivBackward0>)
# 838tensor(7.1845, grad_fn=<DivBackward0>)
# 839tensor(7.2632, grad_fn=<DivBackward0>)
# 840tensor(6.7501, grad_fn=<DivBackward0>)
# 841tensor(7.3030, grad_fn=<DivBackward0>)
# 842tensor(7.0204, grad_fn=<DivBackward0>)
# 843tensor(7.2280, grad_fn=<DivBackward0>)
# 844tensor(7.1167, grad_fn=<DivBackward0>)
# 845tensor(7.5249, grad_fn=<DivBackward0>)
# 846tensor(7.0319, grad_fn=<DivBackward0>)
# 847tensor(7.2645, grad_fn=<DivBackward0>)
# 848tensor(6.9289, grad_fn=<DivBackward0>)
# 849tensor(7.0735, grad_fn=<DivBackward0>)
# 850tensor(6.9723, grad_fn=<DivBackward0>)
# 851tensor(7.4811, grad_fn=<DivBackward0>)
# 852tensor(7.1424, grad_fn=<DivBackward0>)
# 853tensor(7.3998, grad_fn=<DivBackward0>)
# 854tensor(7.4183, grad_fn=<DivBackward0>)
# 855tensor(7.0815, grad_fn=<DivBackward0>)
# 856tensor(7.0533, grad_fn=<DivBackward0>)
# 857tensor(6.9896, grad_fn=<DivBackward0>)
# 858tensor(7.2235, grad_fn=<DivBackward0>)
# 859tensor(6.5944, grad_fn=<DivBackward0>)
# 860tensor(7.3651, grad_fn=<DivBackward0>)
# 861tensor(7.7447, grad_fn=<DivBackward0>)
# 862tensor(7.1246, grad_fn=<DivBackward0>)
# 863tensor(7.0864, grad_fn=<DivBackward0>)
# 864tensor(6.9307, grad_fn=<DivBackward0>)
# 865tensor(7.2588, grad_fn=<DivBackward0>)
# 866tensor(6.8731, grad_fn=<DivBackward0>)
# 867tensor(7.1767, grad_fn=<DivBackward0>)
# 868tensor(7.0548, grad_fn=<DivBackward0>)
# 869tensor(7.3724, grad_fn=<DivBackward0>)
# 870tensor(6.9719, grad_fn=<DivBackward0>)
# 871tensor(6.8513, grad_fn=<DivBackward0>)
# 872tensor(6.9458, grad_fn=<DivBackward0>)
# 873tensor(7.2649, grad_fn=<DivBackward0>)
# 874tensor(7.2975, grad_fn=<DivBackward0>)
# 875tensor(7.1673, grad_fn=<DivBackward0>)
# 876tensor(6.9069, grad_fn=<DivBackward0>)
# 877tensor(7.1069, grad_fn=<DivBackward0>)
# 878tensor(6.7696, grad_fn=<DivBackward0>)
# 879tensor(7.7643, grad_fn=<DivBackward0>)
# 880tensor(6.9073, grad_fn=<DivBackward0>)
# 881tensor(6.7751, grad_fn=<DivBackward0>)
# 882tensor(6.9751, grad_fn=<DivBackward0>)
# 883tensor(6.8898, grad_fn=<DivBackward0>)
# 884tensor(7.2097, grad_fn=<DivBackward0>)
# 885tensor(6.7520, grad_fn=<DivBackward0>)
# 886tensor(6.8687, grad_fn=<DivBackward0>)
# 887tensor(7.3579, grad_fn=<DivBackward0>)
# 888tensor(6.8873, grad_fn=<DivBackward0>)
# 889tensor(6.7153, grad_fn=<DivBackward0>)
# 890tensor(7.0123, grad_fn=<DivBackward0>)
# 891tensor(7.0044, grad_fn=<DivBackward0>)
# 892tensor(6.9535, grad_fn=<DivBackward0>)
# 893tensor(6.8782, grad_fn=<DivBackward0>)
# 894tensor(7.4194, grad_fn=<DivBackward0>)
# 895tensor(7.5947, grad_fn=<DivBackward0>)
# 896tensor(6.6608, grad_fn=<DivBackward0>)
# 897tensor(6.9778, grad_fn=<DivBackward0>)
# 898tensor(7.3370, grad_fn=<DivBackward0>)
# 899tensor(7.2013, grad_fn=<DivBackward0>)
# 900tensor(7.2156, grad_fn=<DivBackward0>)
# 901tensor(6.8097, grad_fn=<DivBackward0>)
# 902tensor(7.2393, grad_fn=<DivBackward0>)
# 903tensor(7.1168, grad_fn=<DivBackward0>)
# 904tensor(7.0664, grad_fn=<DivBackward0>)
# 905tensor(7.1060, grad_fn=<DivBackward0>)
# 906tensor(7.0214, grad_fn=<DivBackward0>)
# 907tensor(6.8503, grad_fn=<DivBackward0>)
# 908tensor(7.3917, grad_fn=<DivBackward0>)
# 909tensor(7.2008, grad_fn=<DivBackward0>)
# 910tensor(7.1840, grad_fn=<DivBackward0>)
# 911tensor(7.0063, grad_fn=<DivBackward0>)
# 912tensor(6.4990, grad_fn=<DivBackward0>)
# 913tensor(7.1110, grad_fn=<DivBackward0>)
# 914tensor(6.9222, grad_fn=<DivBackward0>)
# 915tensor(7.0383, grad_fn=<DivBackward0>)
# 916tensor(7.3715, grad_fn=<DivBackward0>)
# 917tensor(6.9548, grad_fn=<DivBackward0>)
# 918tensor(6.9078, grad_fn=<DivBackward0>)
# 919tensor(7.6222, grad_fn=<DivBackward0>)
# 920tensor(6.8326, grad_fn=<DivBackward0>)
# 921tensor(6.9463, grad_fn=<DivBackward0>)
# 922tensor(6.9646, grad_fn=<DivBackward0>)
# 923tensor(7.0157, grad_fn=<DivBackward0>)
# 924tensor(6.9523, grad_fn=<DivBackward0>)
# 925tensor(6.7343, grad_fn=<DivBackward0>)
# 926tensor(7.2313, grad_fn=<DivBackward0>)
# 927tensor(6.7718, grad_fn=<DivBackward0>)
# 928tensor(6.6610, grad_fn=<DivBackward0>)
# 929tensor(7.1590, grad_fn=<DivBackward0>)
# 930tensor(7.0170, grad_fn=<DivBackward0>)
# 931tensor(7.2320, grad_fn=<DivBackward0>)
# 932tensor(6.8245, grad_fn=<DivBackward0>)
# 933tensor(6.9316, grad_fn=<DivBackward0>)
# 934tensor(7.3459, grad_fn=<DivBackward0>)
# 935tensor(7.0191, grad_fn=<DivBackward0>)
# 936tensor(6.8071, grad_fn=<DivBackward0>)
# 937tensor(6.6643, grad_fn=<DivBackward0>)
# 938tensor(7.1566, grad_fn=<DivBackward0>)
# 939tensor(7.2331, grad_fn=<DivBackward0>)
# 940tensor(7.2271, grad_fn=<DivBackward0>)
# 941tensor(7.3991, grad_fn=<DivBackward0>)
# 942tensor(6.7904, grad_fn=<DivBackward0>)
# 943tensor(6.9116, grad_fn=<DivBackward0>)
# 944tensor(6.9618, grad_fn=<DivBackward0>)
# 945tensor(7.1173, grad_fn=<DivBackward0>)
# 946tensor(6.9094, grad_fn=<DivBackward0>)
# 947tensor(6.5902, grad_fn=<DivBackward0>)
# 948tensor(7.2294, grad_fn=<DivBackward0>)
# 949tensor(7.1523, grad_fn=<DivBackward0>)
# 950tensor(7.0478, grad_fn=<DivBackward0>)
# 951tensor(6.8023, grad_fn=<DivBackward0>)
# 952tensor(6.5654, grad_fn=<DivBackward0>)
# 953tensor(6.9365, grad_fn=<DivBackward0>)
# 954tensor(7.2855, grad_fn=<DivBackward0>)
# 955tensor(6.6526, grad_fn=<DivBackward0>)
# 956tensor(7.4169, grad_fn=<DivBackward0>)
# 957tensor(7.5123, grad_fn=<DivBackward0>)
# 958tensor(6.8477, grad_fn=<DivBackward0>)
# 959tensor(6.9573, grad_fn=<DivBackward0>)
# 960tensor(7.1163, grad_fn=<DivBackward0>)
# 961tensor(7.1626, grad_fn=<DivBackward0>)
# 962tensor(6.7966, grad_fn=<DivBackward0>)
# 963tensor(7.4226, grad_fn=<DivBackward0>)
# 964tensor(6.9216, grad_fn=<DivBackward0>)
# 965tensor(7.3320, grad_fn=<DivBackward0>)
# 966tensor(7.0907, grad_fn=<DivBackward0>)
# 967tensor(6.8671, grad_fn=<DivBackward0>)
# 968tensor(7.2976, grad_fn=<DivBackward0>)
# 969tensor(6.8999, grad_fn=<DivBackward0>)
# 970tensor(7.0153, grad_fn=<DivBackward0>)
# 971tensor(7.0930, grad_fn=<DivBackward0>)
# 972tensor(7.2217, grad_fn=<DivBackward0>)
# 973tensor(7.1649, grad_fn=<DivBackward0>)
# 974tensor(6.6714, grad_fn=<DivBackward0>)
# 975tensor(6.9390, grad_fn=<DivBackward0>)
# 976tensor(7.0161, grad_fn=<DivBackward0>)
# 977tensor(7.2478, grad_fn=<DivBackward0>)
# 978tensor(7.5447, grad_fn=<DivBackward0>)
# 979tensor(7.0776, grad_fn=<DivBackward0>)
# 980tensor(6.8917, grad_fn=<DivBackward0>)
# 981tensor(7.2446, grad_fn=<DivBackward0>)
# 982tensor(6.8156, grad_fn=<DivBackward0>)
# 983tensor(7.1098, grad_fn=<DivBackward0>)
# 984tensor(7.0413, grad_fn=<DivBackward0>)
# 985tensor(6.5431, grad_fn=<DivBackward0>)
# 986tensor(7.3082, grad_fn=<DivBackward0>)
# 987tensor(7.4119, grad_fn=<DivBackward0>)
# 988tensor(6.7371, grad_fn=<DivBackward0>)
# 989tensor(6.5564, grad_fn=<DivBackward0>)
# 990tensor(6.7231, grad_fn=<DivBackward0>)
# 991tensor(7.2475, grad_fn=<DivBackward0>)
# 992tensor(7.0367, grad_fn=<DivBackward0>)
# 993tensor(6.7848, grad_fn=<DivBackward0>)
# 994tensor(7.3854, grad_fn=<DivBackward0>)
# 995tensor(7.0226, grad_fn=<DivBackward0>)
# 996tensor(6.7348, grad_fn=<DivBackward0>)
# 997tensor(6.9166, grad_fn=<DivBackward0>)
# 998tensor(6.9155, grad_fn=<DivBackward0>)
# 999tensor(6.7757, grad_fn=<DivBackward0>)

# %%
os.chdir('C:\\Users\\Ji Qi\\Documents\\GitHub\\ST-Aim3')
os.getcwd()
PATH = 'vgae_model_for_simulation_0.8.pth'
torch.save(model, PATH)

model = torch.load(PATH)
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder(
#     (conv1): GCNConv(10, 4)
#     (conv_mu): GCNConv(4, 2)
#     (conv_logstd): GCNConv(4, 2)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
for i in range(len(dataset)):
    train_data = dataset[i]
    print(VGAE_Encoder(train_data.x, train_data.edge_index))
# Out:
# (tensor([[-0.4229, -1.6986],
#         [-0.0724, -2.3531],
#         [-0.4229, -1.6986],
#         [-0.0724, -2.3531],
#         [ 0.0153, -1.4668],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.9452, -2.2311],
#         [-2.1773, -2.3118],
#         [-1.9452, -2.2311],
#         [-2.1773, -2.3118],
#         [-1.8976, -2.1639],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.7259, -2.1870],
#         [-0.1351, -1.9185],
#         [-0.9422, -1.0326],
#         [-0.1351, -1.9185],
#         [-0.7259, -2.1870],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0900, -2.2787],
#         [-2.0379, -2.2031],
#         [-1.6991, -2.1680],
#         [-2.0379, -2.2031],
#         [-2.0900, -2.2787],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.5343, -1.0602],
#         [-0.8461, -2.3250],
#         [-1.0761, -1.0762],
#         [ 0.9314, -1.4049],
#         [-1.5989, -1.4824],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.6783, -2.1543],
#         [-2.1182, -2.3953],
#         [-1.7029, -2.2089],
#         [-1.9204, -2.1955],
#         [-1.8068, -2.2661],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.2663, -1.6638],
#         [-1.4580, -1.0787],
#         [-0.0983, -1.8979],
#         [ 0.5881, -1.5774],
#         [-0.6316, -2.2450],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.8900, -2.2212],
#         [-1.6903, -2.1371],
#         [-2.0240, -2.2927],
#         [-1.9571, -2.2411],
#         [-2.1081, -2.3435],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.2384, -1.1450],
#         [-0.3911, -2.1699],
#         [-0.3911, -2.1699],
#         [ 0.3113, -1.8361],
#         [ 0.3113, -1.8361],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.7256, -2.1260],
#         [-2.0978, -2.3195],
#         [-2.0978, -2.3195],
#         [-2.0279, -2.2622],
#         [-2.0279, -2.2622],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4189, -2.1348],
#         [-0.3740, -1.7021],
#         [-0.4270, -1.6316],
#         [-0.4189, -2.1348],
#         [-0.4189, -2.1348],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0909, -2.2550],
#         [-1.9536, -2.1867],
#         [-1.9255, -2.2018],
#         [-2.0909, -2.2550],
#         [-2.0909, -2.2550],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.8607, -1.7997],
#         [-0.4451, -2.4534],
#         [-0.9391, -1.1917],
#         [ 0.1895, -2.1467],
#         [ 0.2192, -1.6734],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.9546, -2.2461],
#         [-2.1897, -2.3297],
#         [-1.7506, -2.1876],
#         [-2.1264, -2.2622],
#         [-1.9770, -2.1756],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.5055, -1.6836],
#         [-0.2112, -2.1321],
#         [-0.1663, -1.6427],
#         [-0.2112, -2.1321],
#         [-0.2112, -2.1321],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.9412, -2.1788],
#         [-2.0993, -2.2714],
#         [-1.9412, -2.2206],
#         [-2.0993, -2.2714],
#         [-2.0993, -2.2714],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4189, -2.1348],
#         [-0.3740, -1.7021],
#         [-0.4270, -1.6316],
#         [-0.4189, -2.1348],
#         [-0.4189, -2.1348],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0909, -2.2550],
#         [-1.9536, -2.1867],
#         [-1.9255, -2.2018],
#         [-2.0909, -2.2550],
#         [-2.0909, -2.2550],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.2607, -1.8873],
#         [-0.4639, -2.2168],
#         [-0.5382, -1.1037],
#         [-0.2607, -1.8873],
#         [-0.4639, -2.2168],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0213, -2.1972],
#         [-2.1123, -2.2961],
#         [-1.7423, -2.1915],
#         [-2.0213, -2.1972],
#         [-2.1123, -2.2961],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.6248, -2.2090],
#         [ 0.0365, -1.8760],
#         [ 0.0365, -1.8760],
#         [ 0.0365, -1.8760],
#         [-1.1905, -0.5486],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0939, -2.3622],
#         [-2.0248, -2.2737],
#         [-2.0248, -2.2737],
#         [-2.0248, -2.2737],
#         [-1.5273, -2.1231],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.2922, -2.3483],
#         [-0.3430, -1.8264],
#         [-0.2617, -1.3021],
#         [-0.2922, -2.3483],
#         [-0.3430, -1.8264],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.1660, -2.2900],
#         [-1.9962, -2.1990],
#         [-1.8242, -2.1846],
#         [-2.1660, -2.2900],
#         [-1.9962, -2.1990],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.7243, -0.8308],
#         [-0.5555, -2.1763],
#         [ 1.6601, -1.2981],
#         [ 1.3564, -2.5759],
#         [ 0.5400, -1.7768],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.5971, -2.0907],
#         [-2.0906, -2.3282],
#         [-1.9086, -2.3395],
#         [-2.3149, -2.4428],
#         [-2.0215, -2.2500],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.8045, -1.8708],
#         [-0.1658, -2.0695],
#         [-0.2086, -1.4135],
#         [ 0.3555, -2.2420],
#         [-0.8045, -1.8708],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.9852, -2.2175],
#         [-2.0807, -2.2647],
#         [-1.8594, -2.2362],
#         [-2.1651, -2.2806],
#         [-1.9852, -2.2175],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4946, -1.6473],
#         [-0.2079, -2.1044],
#         [-0.2079, -2.1044],
#         [-0.2079, -2.1044],
#         [-0.1910, -1.6606],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.9280, -2.1928],
#         [-2.0890, -2.2819],
#         [-2.0890, -2.2819],
#         [-2.0890, -2.2819],
#         [-1.9469, -2.2130],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4053, -2.1003],
#         [-0.3514, -1.6582],
#         [-0.4053, -2.1003],
#         [-0.4053, -2.1003],
#         [-0.4517, -1.6495],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0787, -2.2670],
#         [-1.9383, -2.2024],
#         [-2.0787, -2.2670],
#         [-2.0787, -2.2670],
#         [-1.9313, -2.1942],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.0132, -1.8263],
#         [-0.7257, -1.6440],
#         [-0.7257, -1.6440],
#         [ 0.6685, -1.7973],
#         [-0.7051, -1.8324],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.9568, -2.2355],
#         [-1.9066, -2.2728],
#         [-1.9066, -2.2728],
#         [-2.0365, -2.2296],
#         [-1.9734, -2.2572],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [-0.4728, -1.9715],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-2.0354, -2.2285],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-2.6980, -0.5034],
#         [ 0.8669, -2.3340],
#         [ 1.9303, -2.0306],
#         [ 1.9303, -2.0306],
#         [-1.7666, -1.2207],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.4342, -2.0947],
#         [-2.2087, -2.4178],
#         [-2.1666, -2.3735],
#         [-2.1666, -2.3735],
#         [-1.7121, -2.2365],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.5314, -1.0918],
#         [-1.5887, -1.5215],
#         [-1.0681, -1.1163],
#         [ 0.7653, -1.3592],
#         [-0.9462, -2.3248],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.6894, -2.1513],
#         [-1.8208, -2.2624],
#         [-1.7172, -2.2043],
#         [-1.8982, -2.1860],
#         [-2.1143, -2.3866],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.5343, -1.0602],
#         [-0.8461, -2.3250],
#         [-1.0761, -1.0762],
#         [ 0.9314, -1.4049],
#         [-1.5989, -1.4824],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.6783, -2.1543],
#         [-2.1182, -2.3953],
#         [-1.7029, -2.2089],
#         [-1.9204, -2.1955],
#         [-1.8068, -2.2661],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.6262, -2.0702],
#         [-0.0612, -1.8112],
#         [-0.6262, -2.0702],
#         [-0.0612, -1.8112],
#         [-0.9318, -1.0298],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0521, -2.3128],
#         [-2.0015, -2.2396],
#         [-2.0521, -2.3128],
#         [-2.0015, -2.2396],
#         [-1.6999, -2.1596],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-1.6207, -1.1202],
#         [-1.0008, -1.9205],
#         [-0.8400, -1.8092],
#         [ 1.1347, -1.9278],
#         [ 0.3479, -1.6553],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.6912, -2.1799],
#         [-1.9846, -2.2833],
#         [-1.9516, -2.3228],
#         [-2.0987, -2.3023],
#         [-1.9678, -2.2770],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.7753, -2.1695],
#         [-0.8944, -1.1803],
#         [-0.7753, -2.1695],
#         [-0.2468, -1.8123],
#         [-0.2468, -1.8123],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0804, -2.2893],
#         [-1.7534, -2.1477],
#         [-2.0804, -2.2893],
#         [-1.9944, -2.2220],
#         [-1.9944, -2.2220],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.6039, -1.3571],
#         [ 0.0993, -1.7796],
#         [-0.0049, -2.3061],
#         [-0.0049, -2.3061],
#         [ 0.0993, -1.7796],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-1.8290, -2.1434],
#         [-1.9984, -2.2542],
#         [-2.1633, -2.3290],
#         [-2.1633, -2.3290],
#         [-1.9984, -2.2542],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))
# (tensor([[-0.4053, -2.1003],
#         [-0.3514, -1.6582],
#         [-0.4053, -2.1003],
#         [-0.4053, -2.1003],
#         [-0.4517, -1.6495],
#         [ 0.2586,  0.6948],
#         [ 0.2524,  0.7212],
#         [ 0.0545,  0.7283],
#         [ 0.2493,  0.7344],
#         [ 0.2690,  0.6508]], grad_fn=<AddBackward0>), tensor([[-2.0787, -2.2670],
#         [-1.9383, -2.2024],
#         [-2.0787, -2.2670],
#         [-2.0787, -2.2670],
#         [-1.9313, -2.1942],
#         [-1.2136, -1.8160],
#         [-1.2047, -1.8131],
#         [-1.1910, -1.8212],
#         [-1.2002, -1.8116],
#         [-1.2286, -1.8209]], grad_fn=<AddBackward0>))

# %%
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))

mu_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))

# %%
# input data scatter 
import matplotlib.pyplot as plt
def plot_mu_graph(mu):
    
    n_node = mu.shape[0]
    annotations = [str(i+1) for i in range(n_node)]
    colors = plt.cm.rainbow(np.linspace(0, 1, n_node))
    plt.scatter(mu[:,0],mu[:,1],c=colors, s=100)
    
    for i, label in enumerate(annotations):
        plt.annotate(label, (mu[i,0], mu[i,1]), fontsize=14)

        
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list_in_data[graph_i])

# %%
# original data mu scatter
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*len(mu_list)
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
# original adj matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(10,10))
for i in range(30):
    plt.subplot(5, 6, i+1)
    plt.imshow(simu_graph.simu_adj_m()[i], cmap="Greys")

# %%
# original data first 5 vs. last 5
simu_graph = SimuData(n_graph=30)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

colors = ['#3DAE43', '#67E332','#008000', '#006400', '#228B22',
          '#CD5C5C','#C71585', '#FF4500', '#DB7093', '#FF0000']
mu_list = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list.append(np.asarray(mu.detach()))

plt.figure(figsize=(10,10))
for node_i in range(n_node):
    
    node_mu = np.empty((0, 2))
    for graph_i in range(len(mu_list)):
    
        node_mu = np.vstack((node_mu, mu_list[graph_i][node_i, :]))
    
    plt.scatter(node_mu[:,0],node_mu[:,1], c=colors[node_i],alpha=0.8)

plt.show()

# %%
# Gaussian distribution for generating mu

import scipy.stats as stats
data_mu = np.zeros((n, out_channels * n_node))
for i in range(n):
    data_mu[i, :] = mu_list_reshape[i]

from sklearn.mixture import GaussianMixture

gm_mu = GaussianMixture(n_components=1, random_state=0).fit(data_mu)
gm_mu.weights_[0] = 1
# Out:
# C:\Users\Ji Qi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# got mean and cov for mu generating distribution
means_normal = gm_mu.means_
cov_normal = gm_mu.covariances_
means_normal = np.asarray(means_normal.tolist()[0])
cov_normal = np.asarray(cov_normal.tolist()[0])

# %%
def compute_centrality(mat):
    return (np.sum(mat, axis=0)/mat.shape[0])

# %%
def sample_adj_mat(filter_value=0.75, filter_eye=True):
    model.__mu__ = torch.from_numpy((np.random.multivariate_normal(mean=means_normal,cov=cov_normal)).reshape((n_node,out_channels)))
    z = model.__mu__
    model.decode(z, edge_index)
    adj_mat = np.zeros((n_node, n_node))
    for i in range(n_node*n_node):
        adj_mat[int(edge_index[0, i]), int(edge_index[1, i])] = (model.decode(z, edge_index)[i].detach().numpy()).item()
    adj_mat[adj_mat < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat.shape[0]):
            adj_mat[i,i]=0
    return adj_mat, model.__mu__

# %%
# generate adjacency matrices

generated_from_simu = []
generated_simu_centrality = []

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(20,10))
adj_mat_list = []
mu_list = []
for i in range(30):
    plt.subplot(5, 6, i+1)
    adj_mat, mu_sample = sample_adj_mat(filter_value=0.5)
    generated_from_simu.append(adj_mat)
    generated_simu_centrality.append(compute_centrality(adj_mat))
    adj_mat_list.append(adj_mat)
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list[graph_i])

# %%
plot_scatter_for_mu(mu_list)

# %%
simu_adj_list = []
simu_centrality_list = []
for i in range(30):
    adj_mat = simu_graph.simu_adj_m()[i].detach().numpy()
    simu_adj_list.append(adj_mat)
    simu_centrality_list.append(compute_centrality(adj_mat))

# %%
from scipy import stats
res = stats.ttest_ind(generated_simu_centrality, simu_centrality_list, 
                      equal_var=True, axis=0)

display(res)
# Out:
# Ttest_indResult(statistic=array([ 10.10521206,  10.39396296,  10.96991984,   9.68567365,
#          9.89474008, 218.55229788, 214.96419847, 204.35509875,
#        213.86973983, 225.06475048]), pvalue=array([2.10311235e-14, 7.26991085e-15, 8.98687668e-16, 1.00004778e-13,
#        4.58764538e-14, 2.80882645e-86, 7.32816617e-86, 1.37473741e-84,
#        9.84940724e-86, 5.12577516e-87]))

# %%
np.mean(np.vstack(generated_simu_centrality), axis=0)
# Out:
# array([0.37821191, 0.38653071, 0.3805533 , 0.38057124, 0.38262799,
#        0.25323838, 0.2544636 , 0.25122335, 0.25505401, 0.25114142])

# %%
np.mean(np.vstack(simu_centrality_list), axis=0)
# Out:
# array([0.21      , 0.24      , 0.19333334, 0.16999997, 0.19333333,
#        0.        , 0.        , 0.        , 0.        , 0.        ],
#       dtype=float32)
