# %%
import torch
from torch_geometric.utils import (negative_sampling, remove_self_loops,
                                   add_self_loops)
EPS = 1e-15
MAX_LOGSTD = 10

class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""
    def forward(self, z, edge_index, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value


    def forward_all(self, z, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj



class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (Module): The encoder module.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        reset(self.encoder)
        reset(self.decoder)


    def encode(self, *args, **kwargs):
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)


    def decode(self, *args, **kwargs):
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)


    def recon_loss(self, z, pos_edge_index, neg_edge_index=None):
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :oenbj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to train against.
            neg_edge_index (LongTensor, optional): The negative edges to train
                against. If not given, uses negative sampling to calculate
                negative edges. (default: :obj:`None`)
        """

        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()

        # Do not include self-loops in negative samples
        pos_edge_index, _ = remove_self_loops(pos_edge_index)
        pos_edge_index, _ = add_self_loops(pos_edge_index)
        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index, sigmoid=True) +
                              EPS).mean()

        return pos_loss + neg_loss


    def test(self, z, pos_edge_index, neg_edge_index):
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        scores.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to evaluate
                against.
            neg_edge_index (LongTensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import roc_auc_score, average_precision_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)
        
        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)



class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (Module): The encoder module to compute :math:`\mu` and
            :math:`\log\sigma^2`.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(VGAE, self).__init__(encoder, decoder)

    def reparametrize(self, mu, logstd):
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs):
        """"""
        self.__mu__, self.__logstd__ = self.encoder(*args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z

    def kl_loss(self, mu=None, logstd=None):
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (Tensor, optional): The latent space for :math:`\mu`. If set to
                :obj:`None`, uses the last computation of :math:`mu`.
                (default: :obj:`None`)
            logstd (Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`.(default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch
from torch.autograd.grad_mode import F
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges
from torch_geometric.nn import VGAE

import scipy.sparse as sp
import numpy as np
import networkx as nx

class SimuData():
    """Simulate graph data"""
    def __init__(self, p=0.5, n_node=10, n_graph=30):
        self.n_node = n_node
        self.n_graph = n_graph
        self.p = p

    def simu_adj_wgh(self):
        adj_list = []

        for i in range(self.n_graph):
            ## zero matrix
            A = torch.zeros(self.n_node, self.n_node)

            # first five nodes weights: uniform(0,1)A[:5,:5] = W
            W = torch.rand(5,5)

            ## symmetric
            i, j = torch.triu_indices(5, 5)
            W[i, j] = W.T[i, j]

            A[:5,:5] = W
            adj_list.append(A)  

        return adj_list

    def simu_adj_diag(self):
        adj_list = []

        for i in range(self.n_graph):
            A = torch.eye(self.n_node)
            adj_list.append(A)  

        return adj_list

    def simu_adj_m(self):
        """generating adjacency matrix"""
        adj_wgh = self.simu_adj_wgh()
        #adj_wgh = self.simu_adj_diag()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>=1-self.p] = 1
            adj[adj<1-self.p] = 0
            for i in range(adj.shape[0]):
                adj[i, i] = 0
            adj_m_list.append(adj)    
        return adj_m_list

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.simu_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)

        return dataset

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)


class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True) 
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=True)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)


transform = T.Compose([
            T.NormalizeFeatures(),
            T.RandomLinkSplit(num_val=0, num_test=0, is_undirected=True,
                            split_labels=True, add_negative_train_samples=False),])

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix


class LoadData():
    """Load graph data"""
    def __init__(self, file_path, samples, n_node=38):
        self.samples = samples
        self.file_path = file_path
        self.nSample = len(samples)
        self.n_node = n_node

    def get_adj_wgh(self):
        """generating adjacency matrix"""
        adj_orig_list =[]
        for sample in self.samples:
            f_name = self.file_path + ".".join([sample])
            adj   = np.asarray(pd.read_csv(f_name, index_col = 0, iterator = False))
            adj_orig_list.append(adj)    

        return adj_orig_list

    def get_adj_label(self):
        adj_m = self.get_adj_m()
        adj_label_list =[]
        
        for _, adj in enumerate(adj_m):
            adj_label = adj + sp.eye(adj.shape[0])
            adj_label = sparse_to_tuple(sp.coo_matrix(adj_label))
            #adj_label = sparse_to_tuple(adj_label)
            adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T), 
                            torch.FloatTensor(adj_label[1]), 
                            torch.Size(adj_label[2]))
            adj_label_list.append(adj_label)
        return adj_label_list

    def get_adj_norm(self):
        adj_m = self.get_adj_m()
        adj_norm_list =[]

        for _, adj in enumerate(adj_m):
            adj_norm = preprocess_graph(adj)
            adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T), 
                            torch.FloatTensor(adj_norm[1]), 
                            torch.Size(adj_norm[2]))
            adj_norm_list.append(adj_norm)

        return adj_norm_list

    def get_adj_m(self):
        adj_wgh = self.get_adj_wgh()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>0] = 1
            for i in range(38):
                adj[i, i] = 0
            for i in range(38):
                for j in range(38):
                    if adj[i, j] == 1:
                        adj[j, i] = 1
            adj_m_list.append(adj)    
        return adj_m_list

    def get_feature(self):
        """generating feature matrix X"""
        adj_wgh = self.get_adj_wgh()
        x_list = []
        for _, adj in enumerate(adj_wgh):
            x_feature  = adj
            x_feature  = csr_matrix(x_feature)
            x_feature  = sparse_to_tuple(x_feature)
            x_feature  = torch.sparse.FloatTensor(torch.LongTensor(x_feature[0].T), 
                            torch.FloatTensor(x_feature[1]), 
                            torch.Size(x_feature[2]))
            x_list.append(x_feature)
        return x_list

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)   

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.get_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)
        return dataset


def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    
    return sparse_to_tuple(adj_normalized)

from os import walk

def get_filename(mypath):
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        break
    return f

# %%
n_node = 10
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
simu_graph = SimuData(n_graph=30, p=0.8)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node
out_channels = 2
n_node = 10
num_features = n_node

# %%
out_channels = 2
n_node = 10
num_features = n_node

model = VGAE(Encoder(num_features, out_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 1000

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 *model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))
# Out:
# 0tensor(28.5200, grad_fn=<DivBackward0>)
# 1tensor(23.9822, grad_fn=<DivBackward0>)
# 2tensor(23.8200, grad_fn=<DivBackward0>)
# 3tensor(27.1171, grad_fn=<DivBackward0>)
# 4tensor(24.8597, grad_fn=<DivBackward0>)
# 5tensor(25.7102, grad_fn=<DivBackward0>)
# 6tensor(26.2276, grad_fn=<DivBackward0>)
# 7tensor(26.4699, grad_fn=<DivBackward0>)
# 8tensor(23.6506, grad_fn=<DivBackward0>)
# 9tensor(25.8026, grad_fn=<DivBackward0>)
# 10tensor(23.3593, grad_fn=<DivBackward0>)
# 11tensor(22.5195, grad_fn=<DivBackward0>)
# 12tensor(21.7167, grad_fn=<DivBackward0>)
# 13tensor(25.0353, grad_fn=<DivBackward0>)
# 14tensor(22.5624, grad_fn=<DivBackward0>)
# 15tensor(23.4530, grad_fn=<DivBackward0>)
# 16tensor(21.7732, grad_fn=<DivBackward0>)
# 17tensor(21.0480, grad_fn=<DivBackward0>)
# 18tensor(22.3040, grad_fn=<DivBackward0>)
# 19tensor(22.3374, grad_fn=<DivBackward0>)
# 20tensor(20.9884, grad_fn=<DivBackward0>)
# 21tensor(22.1353, grad_fn=<DivBackward0>)
# 22tensor(25.8043, grad_fn=<DivBackward0>)
# 23tensor(19.8133, grad_fn=<DivBackward0>)
# 24tensor(22.9736, grad_fn=<DivBackward0>)
# 25tensor(23.0367, grad_fn=<DivBackward0>)
# 26tensor(22.2149, grad_fn=<DivBackward0>)
# 27tensor(23.1209, grad_fn=<DivBackward0>)
# 28tensor(21.4873, grad_fn=<DivBackward0>)
# 29tensor(23.6047, grad_fn=<DivBackward0>)
# 30tensor(22.8438, grad_fn=<DivBackward0>)
# 31tensor(22.7369, grad_fn=<DivBackward0>)
# 32tensor(23.2188, grad_fn=<DivBackward0>)
# 33tensor(24.2660, grad_fn=<DivBackward0>)
# 34tensor(20.7646, grad_fn=<DivBackward0>)
# 35tensor(20.2300, grad_fn=<DivBackward0>)
# 36tensor(24.7591, grad_fn=<DivBackward0>)
# 37tensor(19.7488, grad_fn=<DivBackward0>)
# 38tensor(21.3826, grad_fn=<DivBackward0>)
# 39tensor(20.2691, grad_fn=<DivBackward0>)
# 40tensor(21.7043, grad_fn=<DivBackward0>)
# 41tensor(20.4532, grad_fn=<DivBackward0>)
# 42tensor(21.7789, grad_fn=<DivBackward0>)
# 43tensor(21.3874, grad_fn=<DivBackward0>)
# 44tensor(20.9127, grad_fn=<DivBackward0>)
# 45tensor(24.4788, grad_fn=<DivBackward0>)
# 46tensor(17.9271, grad_fn=<DivBackward0>)
# 47tensor(20.6735, grad_fn=<DivBackward0>)
# 48tensor(19.2991, grad_fn=<DivBackward0>)
# 49tensor(21.3371, grad_fn=<DivBackward0>)
# 50tensor(16.7772, grad_fn=<DivBackward0>)
# 51tensor(24.1522, grad_fn=<DivBackward0>)
# 52tensor(19.2634, grad_fn=<DivBackward0>)
# 53tensor(21.9819, grad_fn=<DivBackward0>)
# 54tensor(18.7606, grad_fn=<DivBackward0>)
# 55tensor(19.5775, grad_fn=<DivBackward0>)
# 56tensor(18.4005, grad_fn=<DivBackward0>)
# 57tensor(19.8484, grad_fn=<DivBackward0>)
# 58tensor(19.6749, grad_fn=<DivBackward0>)
# 59tensor(20.8377, grad_fn=<DivBackward0>)
# 60tensor(19.8715, grad_fn=<DivBackward0>)
# 61tensor(19.6804, grad_fn=<DivBackward0>)
# 62tensor(19.6942, grad_fn=<DivBackward0>)
# 63tensor(19.1157, grad_fn=<DivBackward0>)
# 64tensor(18.5422, grad_fn=<DivBackward0>)
# 65tensor(21.7096, grad_fn=<DivBackward0>)
# 66tensor(21.0161, grad_fn=<DivBackward0>)
# 67tensor(18.0697, grad_fn=<DivBackward0>)
# 68tensor(19.4004, grad_fn=<DivBackward0>)
# 69tensor(16.9534, grad_fn=<DivBackward0>)
# 70tensor(18.4219, grad_fn=<DivBackward0>)
# 71tensor(17.4646, grad_fn=<DivBackward0>)
# 72tensor(18.0492, grad_fn=<DivBackward0>)
# 73tensor(18.5533, grad_fn=<DivBackward0>)
# 74tensor(18.5824, grad_fn=<DivBackward0>)
# 75tensor(19.1599, grad_fn=<DivBackward0>)
# 76tensor(21.7441, grad_fn=<DivBackward0>)
# 77tensor(19.9312, grad_fn=<DivBackward0>)
# 78tensor(17.9796, grad_fn=<DivBackward0>)
# 79tensor(19.4163, grad_fn=<DivBackward0>)
# 80tensor(17.8103, grad_fn=<DivBackward0>)
# 81tensor(19.7913, grad_fn=<DivBackward0>)
# 82tensor(18.9269, grad_fn=<DivBackward0>)
# 83tensor(19.2662, grad_fn=<DivBackward0>)
# 84tensor(17.5622, grad_fn=<DivBackward0>)
# 85tensor(17.8828, grad_fn=<DivBackward0>)
# 86tensor(17.0439, grad_fn=<DivBackward0>)
# 87tensor(19.3844, grad_fn=<DivBackward0>)
# 88tensor(17.6232, grad_fn=<DivBackward0>)
# 89tensor(17.4663, grad_fn=<DivBackward0>)
# 90tensor(16.7232, grad_fn=<DivBackward0>)
# 91tensor(19.2136, grad_fn=<DivBackward0>)
# 92tensor(18.0384, grad_fn=<DivBackward0>)
# 93tensor(16.5554, grad_fn=<DivBackward0>)
# 94tensor(16.8187, grad_fn=<DivBackward0>)
# 95tensor(21.0825, grad_fn=<DivBackward0>)
# 96tensor(17.4734, grad_fn=<DivBackward0>)
# 97tensor(19.8035, grad_fn=<DivBackward0>)
# 98tensor(17.1369, grad_fn=<DivBackward0>)
# 99tensor(19.5432, grad_fn=<DivBackward0>)
# 100tensor(18.2277, grad_fn=<DivBackward0>)
# 101tensor(17.0134, grad_fn=<DivBackward0>)
# 102tensor(18.7162, grad_fn=<DivBackward0>)
# 103tensor(17.5600, grad_fn=<DivBackward0>)
# 104tensor(16.7698, grad_fn=<DivBackward0>)
# 105tensor(17.2168, grad_fn=<DivBackward0>)
# 106tensor(19.8090, grad_fn=<DivBackward0>)
# 107tensor(18.6663, grad_fn=<DivBackward0>)
# 108tensor(17.7468, grad_fn=<DivBackward0>)
# 109tensor(19.2365, grad_fn=<DivBackward0>)
# 110tensor(17.4533, grad_fn=<DivBackward0>)
# 111tensor(17.3983, grad_fn=<DivBackward0>)
# 112tensor(19.7044, grad_fn=<DivBackward0>)
# 113tensor(17.2279, grad_fn=<DivBackward0>)
# 114tensor(17.9705, grad_fn=<DivBackward0>)
# 115tensor(17.9822, grad_fn=<DivBackward0>)
# 116tensor(16.6209, grad_fn=<DivBackward0>)
# 117tensor(17.2908, grad_fn=<DivBackward0>)
# 118tensor(17.9015, grad_fn=<DivBackward0>)
# 119tensor(17.6011, grad_fn=<DivBackward0>)
# 120tensor(16.8195, grad_fn=<DivBackward0>)
# 121tensor(18.4851, grad_fn=<DivBackward0>)
# 122tensor(19.3038, grad_fn=<DivBackward0>)
# 123tensor(16.7762, grad_fn=<DivBackward0>)
# 124tensor(15.5560, grad_fn=<DivBackward0>)
# 125tensor(17.8229, grad_fn=<DivBackward0>)
# 126tensor(16.0266, grad_fn=<DivBackward0>)
# 127tensor(15.7229, grad_fn=<DivBackward0>)
# 128tensor(18.1273, grad_fn=<DivBackward0>)
# 129tensor(17.5226, grad_fn=<DivBackward0>)
# 130tensor(17.0015, grad_fn=<DivBackward0>)
# 131tensor(19.3318, grad_fn=<DivBackward0>)
# 132tensor(16.7687, grad_fn=<DivBackward0>)
# 133tensor(16.6773, grad_fn=<DivBackward0>)
# 134tensor(18.2278, grad_fn=<DivBackward0>)
# 135tensor(16.2473, grad_fn=<DivBackward0>)
# 136tensor(17.2822, grad_fn=<DivBackward0>)
# 137tensor(17.5413, grad_fn=<DivBackward0>)
# 138tensor(17.6493, grad_fn=<DivBackward0>)
# 139tensor(17.4253, grad_fn=<DivBackward0>)
# 140tensor(17.3851, grad_fn=<DivBackward0>)
# 141tensor(17.8257, grad_fn=<DivBackward0>)
# 142tensor(18.5266, grad_fn=<DivBackward0>)
# 143tensor(18.4921, grad_fn=<DivBackward0>)
# 144tensor(16.7307, grad_fn=<DivBackward0>)
# 145tensor(17.8514, grad_fn=<DivBackward0>)
# 146tensor(15.8658, grad_fn=<DivBackward0>)
# 147tensor(15.3931, grad_fn=<DivBackward0>)
# 148tensor(16.4146, grad_fn=<DivBackward0>)
# 149tensor(16.5780, grad_fn=<DivBackward0>)
# 150tensor(18.1202, grad_fn=<DivBackward0>)
# 151tensor(17.5635, grad_fn=<DivBackward0>)
# 152tensor(16.0478, grad_fn=<DivBackward0>)
# 153tensor(15.9643, grad_fn=<DivBackward0>)
# 154tensor(17.9681, grad_fn=<DivBackward0>)
# 155tensor(18.2248, grad_fn=<DivBackward0>)
# 156tensor(18.9227, grad_fn=<DivBackward0>)
# 157tensor(17.4339, grad_fn=<DivBackward0>)
# 158tensor(16.4085, grad_fn=<DivBackward0>)
# 159tensor(16.2522, grad_fn=<DivBackward0>)
# 160tensor(17.1414, grad_fn=<DivBackward0>)
# 161tensor(17.4007, grad_fn=<DivBackward0>)
# 162tensor(16.4380, grad_fn=<DivBackward0>)
# 163tensor(15.6956, grad_fn=<DivBackward0>)
# 164tensor(15.4009, grad_fn=<DivBackward0>)
# 165tensor(16.5913, grad_fn=<DivBackward0>)
# 166tensor(15.8606, grad_fn=<DivBackward0>)
# 167tensor(16.7804, grad_fn=<DivBackward0>)
# 168tensor(16.9428, grad_fn=<DivBackward0>)
# 169tensor(15.6152, grad_fn=<DivBackward0>)
# 170tensor(15.6434, grad_fn=<DivBackward0>)
# 171tensor(15.9996, grad_fn=<DivBackward0>)
# 172tensor(16.8162, grad_fn=<DivBackward0>)
# 173tensor(16.7366, grad_fn=<DivBackward0>)
# 174tensor(16.6383, grad_fn=<DivBackward0>)
# 175tensor(16.5651, grad_fn=<DivBackward0>)
# 176tensor(16.3792, grad_fn=<DivBackward0>)
# 177tensor(15.8916, grad_fn=<DivBackward0>)
# 178tensor(15.9517, grad_fn=<DivBackward0>)
# 179tensor(16.7946, grad_fn=<DivBackward0>)
# 180tensor(15.5637, grad_fn=<DivBackward0>)
# 181tensor(16.1884, grad_fn=<DivBackward0>)
# 182tensor(15.7408, grad_fn=<DivBackward0>)
# 183tensor(16.3860, grad_fn=<DivBackward0>)
# 184tensor(15.9538, grad_fn=<DivBackward0>)
# 185tensor(16.1281, grad_fn=<DivBackward0>)
# 186tensor(16.1898, grad_fn=<DivBackward0>)
# 187tensor(16.0648, grad_fn=<DivBackward0>)
# 188tensor(15.7100, grad_fn=<DivBackward0>)
# 189tensor(17.6351, grad_fn=<DivBackward0>)
# 190tensor(16.0230, grad_fn=<DivBackward0>)
# 191tensor(17.2088, grad_fn=<DivBackward0>)
# 192tensor(16.0301, grad_fn=<DivBackward0>)
# 193tensor(16.3066, grad_fn=<DivBackward0>)
# 194tensor(15.7022, grad_fn=<DivBackward0>)
# 195tensor(15.5482, grad_fn=<DivBackward0>)
# 196tensor(15.7477, grad_fn=<DivBackward0>)
# 197tensor(16.2098, grad_fn=<DivBackward0>)
# 198tensor(15.6015, grad_fn=<DivBackward0>)
# 199tensor(17.7297, grad_fn=<DivBackward0>)
# 200tensor(15.6789, grad_fn=<DivBackward0>)
# 201tensor(16.9671, grad_fn=<DivBackward0>)
# 202tensor(15.5646, grad_fn=<DivBackward0>)
# 203tensor(16.2443, grad_fn=<DivBackward0>)
# 204tensor(16.6590, grad_fn=<DivBackward0>)
# 205tensor(15.6245, grad_fn=<DivBackward0>)
# 206tensor(15.6472, grad_fn=<DivBackward0>)
# 207tensor(16.9065, grad_fn=<DivBackward0>)
# 208tensor(15.8063, grad_fn=<DivBackward0>)
# 209tensor(16.4084, grad_fn=<DivBackward0>)
# 210tensor(16.2216, grad_fn=<DivBackward0>)
# 211tensor(15.4557, grad_fn=<DivBackward0>)
# 212tensor(15.2451, grad_fn=<DivBackward0>)
# 213tensor(16.4021, grad_fn=<DivBackward0>)
# 214tensor(16.9960, grad_fn=<DivBackward0>)
# 215tensor(16.5755, grad_fn=<DivBackward0>)
# 216tensor(15.3295, grad_fn=<DivBackward0>)
# 217tensor(16.0716, grad_fn=<DivBackward0>)
# 218tensor(16.2887, grad_fn=<DivBackward0>)
# 219tensor(15.9043, grad_fn=<DivBackward0>)
# 220tensor(16.3897, grad_fn=<DivBackward0>)
# 221tensor(15.4881, grad_fn=<DivBackward0>)
# 222tensor(16.1242, grad_fn=<DivBackward0>)
# 223tensor(16.3840, grad_fn=<DivBackward0>)
# 224tensor(16.9341, grad_fn=<DivBackward0>)
# 225tensor(16.5247, grad_fn=<DivBackward0>)
# 226tensor(15.4278, grad_fn=<DivBackward0>)
# 227tensor(15.5742, grad_fn=<DivBackward0>)
# 228tensor(16.1616, grad_fn=<DivBackward0>)
# 229tensor(15.3504, grad_fn=<DivBackward0>)
# 230tensor(16.4482, grad_fn=<DivBackward0>)
# 231tensor(15.6637, grad_fn=<DivBackward0>)
# 232tensor(15.6123, grad_fn=<DivBackward0>)
# 233tensor(15.8540, grad_fn=<DivBackward0>)
# 234tensor(15.2133, grad_fn=<DivBackward0>)
# 235tensor(15.9909, grad_fn=<DivBackward0>)
# 236tensor(16.4951, grad_fn=<DivBackward0>)
# 237tensor(15.2974, grad_fn=<DivBackward0>)
# 238tensor(16.5841, grad_fn=<DivBackward0>)
# 239tensor(16.8319, grad_fn=<DivBackward0>)
# 240tensor(16.0454, grad_fn=<DivBackward0>)
# 241tensor(15.5541, grad_fn=<DivBackward0>)
# 242tensor(15.4788, grad_fn=<DivBackward0>)
# 243tensor(15.1876, grad_fn=<DivBackward0>)
# 244tensor(15.4133, grad_fn=<DivBackward0>)
# 245tensor(15.7408, grad_fn=<DivBackward0>)
# 246tensor(15.7618, grad_fn=<DivBackward0>)
# 247tensor(16.0757, grad_fn=<DivBackward0>)
# 248tensor(15.9687, grad_fn=<DivBackward0>)
# 249tensor(16.1950, grad_fn=<DivBackward0>)
# 250tensor(16.7076, grad_fn=<DivBackward0>)
# 251tensor(16.0314, grad_fn=<DivBackward0>)
# 252tensor(15.0534, grad_fn=<DivBackward0>)
# 253tensor(14.3193, grad_fn=<DivBackward0>)
# 254tensor(15.0082, grad_fn=<DivBackward0>)
# 255tensor(15.1726, grad_fn=<DivBackward0>)
# 256tensor(15.5872, grad_fn=<DivBackward0>)
# 257tensor(15.7688, grad_fn=<DivBackward0>)
# 258tensor(15.9863, grad_fn=<DivBackward0>)
# 259tensor(14.5401, grad_fn=<DivBackward0>)
# 260tensor(16.2352, grad_fn=<DivBackward0>)
# 261tensor(15.9728, grad_fn=<DivBackward0>)
# 262tensor(15.7363, grad_fn=<DivBackward0>)
# 263tensor(15.1192, grad_fn=<DivBackward0>)
# 264tensor(15.5346, grad_fn=<DivBackward0>)
# 265tensor(15.9736, grad_fn=<DivBackward0>)
# 266tensor(17.3296, grad_fn=<DivBackward0>)
# 267tensor(14.7840, grad_fn=<DivBackward0>)
# 268tensor(15.8465, grad_fn=<DivBackward0>)
# 269tensor(15.3677, grad_fn=<DivBackward0>)
# 270tensor(16.2655, grad_fn=<DivBackward0>)
# 271tensor(15.6233, grad_fn=<DivBackward0>)
# 272tensor(15.9191, grad_fn=<DivBackward0>)
# 273tensor(15.0801, grad_fn=<DivBackward0>)
# 274tensor(16.3197, grad_fn=<DivBackward0>)
# 275tensor(16.2410, grad_fn=<DivBackward0>)
# 276tensor(15.9413, grad_fn=<DivBackward0>)
# 277tensor(15.0547, grad_fn=<DivBackward0>)
# 278tensor(14.9320, grad_fn=<DivBackward0>)
# 279tensor(15.4034, grad_fn=<DivBackward0>)
# 280tensor(15.1654, grad_fn=<DivBackward0>)
# 281tensor(15.7972, grad_fn=<DivBackward0>)
# 282tensor(15.4816, grad_fn=<DivBackward0>)
# 283tensor(15.0362, grad_fn=<DivBackward0>)
# 284tensor(15.4268, grad_fn=<DivBackward0>)
# 285tensor(15.7401, grad_fn=<DivBackward0>)
# 286tensor(15.6557, grad_fn=<DivBackward0>)
# 287tensor(15.1264, grad_fn=<DivBackward0>)
# 288tensor(14.8875, grad_fn=<DivBackward0>)
# 289tensor(15.0049, grad_fn=<DivBackward0>)
# 290tensor(16.0213, grad_fn=<DivBackward0>)
# 291tensor(16.4341, grad_fn=<DivBackward0>)
# 292tensor(16.0299, grad_fn=<DivBackward0>)
# 293tensor(15.2528, grad_fn=<DivBackward0>)
# 294tensor(15.7760, grad_fn=<DivBackward0>)
# 295tensor(15.2260, grad_fn=<DivBackward0>)
# 296tensor(14.8614, grad_fn=<DivBackward0>)
# 297tensor(15.0779, grad_fn=<DivBackward0>)
# 298tensor(14.8230, grad_fn=<DivBackward0>)
# 299tensor(14.9528, grad_fn=<DivBackward0>)
# 300tensor(15.3644, grad_fn=<DivBackward0>)
# 301tensor(16.2045, grad_fn=<DivBackward0>)
# 302tensor(14.0062, grad_fn=<DivBackward0>)
# 303tensor(14.9997, grad_fn=<DivBackward0>)
# 304tensor(15.0313, grad_fn=<DivBackward0>)
# 305tensor(14.7665, grad_fn=<DivBackward0>)
# 306tensor(14.5547, grad_fn=<DivBackward0>)
# 307tensor(14.8535, grad_fn=<DivBackward0>)
# 308tensor(15.4713, grad_fn=<DivBackward0>)
# 309tensor(14.9914, grad_fn=<DivBackward0>)
# 310tensor(14.7760, grad_fn=<DivBackward0>)
# 311tensor(15.1412, grad_fn=<DivBackward0>)
# 312tensor(14.4449, grad_fn=<DivBackward0>)
# 313tensor(15.1518, grad_fn=<DivBackward0>)
# 314tensor(14.8974, grad_fn=<DivBackward0>)
# 315tensor(14.5715, grad_fn=<DivBackward0>)
# 316tensor(14.5998, grad_fn=<DivBackward0>)
# 317tensor(14.7303, grad_fn=<DivBackward0>)
# 318tensor(14.9733, grad_fn=<DivBackward0>)
# 319tensor(14.8203, grad_fn=<DivBackward0>)
# 320tensor(15.0314, grad_fn=<DivBackward0>)
# 321tensor(15.7322, grad_fn=<DivBackward0>)
# 322tensor(15.1000, grad_fn=<DivBackward0>)
# 323tensor(14.7890, grad_fn=<DivBackward0>)
# 324tensor(14.5855, grad_fn=<DivBackward0>)
# 325tensor(14.8074, grad_fn=<DivBackward0>)
# 326tensor(14.7936, grad_fn=<DivBackward0>)
# 327tensor(16.2171, grad_fn=<DivBackward0>)
# 328tensor(14.6523, grad_fn=<DivBackward0>)
# 329tensor(14.6905, grad_fn=<DivBackward0>)
# 330tensor(15.4386, grad_fn=<DivBackward0>)
# 331tensor(15.0129, grad_fn=<DivBackward0>)
# 332tensor(15.6003, grad_fn=<DivBackward0>)
# 333tensor(15.0697, grad_fn=<DivBackward0>)
# 334tensor(15.1510, grad_fn=<DivBackward0>)
# 335tensor(14.3640, grad_fn=<DivBackward0>)
# 336tensor(14.3260, grad_fn=<DivBackward0>)
# 337tensor(14.9364, grad_fn=<DivBackward0>)
# 338tensor(15.8048, grad_fn=<DivBackward0>)
# 339tensor(15.3937, grad_fn=<DivBackward0>)
# 340tensor(14.5103, grad_fn=<DivBackward0>)
# 341tensor(15.2400, grad_fn=<DivBackward0>)
# 342tensor(14.4032, grad_fn=<DivBackward0>)
# 343tensor(14.8832, grad_fn=<DivBackward0>)
# 344tensor(15.3855, grad_fn=<DivBackward0>)
# 345tensor(15.1916, grad_fn=<DivBackward0>)
# 346tensor(15.2778, grad_fn=<DivBackward0>)
# 347tensor(14.7954, grad_fn=<DivBackward0>)
# 348tensor(14.6878, grad_fn=<DivBackward0>)
# 349tensor(15.5070, grad_fn=<DivBackward0>)
# 350tensor(14.1623, grad_fn=<DivBackward0>)
# 351tensor(15.0577, grad_fn=<DivBackward0>)
# 352tensor(14.1881, grad_fn=<DivBackward0>)
# 353tensor(13.9826, grad_fn=<DivBackward0>)
# 354tensor(14.5981, grad_fn=<DivBackward0>)
# 355tensor(14.1156, grad_fn=<DivBackward0>)
# 356tensor(14.6017, grad_fn=<DivBackward0>)
# 357tensor(14.9717, grad_fn=<DivBackward0>)
# 358tensor(15.5791, grad_fn=<DivBackward0>)
# 359tensor(14.5264, grad_fn=<DivBackward0>)
# 360tensor(14.1849, grad_fn=<DivBackward0>)
# 361tensor(15.1720, grad_fn=<DivBackward0>)
# 362tensor(14.8374, grad_fn=<DivBackward0>)
# 363tensor(14.4582, grad_fn=<DivBackward0>)
# 364tensor(14.5611, grad_fn=<DivBackward0>)
# 365tensor(14.2553, grad_fn=<DivBackward0>)
# 366tensor(14.2011, grad_fn=<DivBackward0>)
# 367tensor(15.3467, grad_fn=<DivBackward0>)
# 368tensor(14.3114, grad_fn=<DivBackward0>)
# 369tensor(14.5556, grad_fn=<DivBackward0>)
# 370tensor(14.3062, grad_fn=<DivBackward0>)
# 371tensor(14.3436, grad_fn=<DivBackward0>)
# 372tensor(14.2627, grad_fn=<DivBackward0>)
# 373tensor(14.1915, grad_fn=<DivBackward0>)
# 374tensor(14.3306, grad_fn=<DivBackward0>)
# 375tensor(14.1330, grad_fn=<DivBackward0>)
# 376tensor(14.4211, grad_fn=<DivBackward0>)
# 377tensor(14.3569, grad_fn=<DivBackward0>)
# 378tensor(14.6404, grad_fn=<DivBackward0>)
# 379tensor(14.0756, grad_fn=<DivBackward0>)
# 380tensor(13.8870, grad_fn=<DivBackward0>)
# 381tensor(15.2133, grad_fn=<DivBackward0>)
# 382tensor(13.7311, grad_fn=<DivBackward0>)
# 383tensor(13.8273, grad_fn=<DivBackward0>)
# 384tensor(14.8730, grad_fn=<DivBackward0>)
# 385tensor(14.5680, grad_fn=<DivBackward0>)
# 386tensor(14.3710, grad_fn=<DivBackward0>)
# 387tensor(14.3571, grad_fn=<DivBackward0>)
# 388tensor(14.3507, grad_fn=<DivBackward0>)
# 389tensor(14.0790, grad_fn=<DivBackward0>)
# 390tensor(14.8777, grad_fn=<DivBackward0>)
# 391tensor(14.2480, grad_fn=<DivBackward0>)
# 392tensor(13.5892, grad_fn=<DivBackward0>)
# 393tensor(13.8890, grad_fn=<DivBackward0>)
# 394tensor(14.1904, grad_fn=<DivBackward0>)
# 395tensor(14.6532, grad_fn=<DivBackward0>)
# 396tensor(15.2132, grad_fn=<DivBackward0>)
# 397tensor(14.9903, grad_fn=<DivBackward0>)
# 398tensor(14.1248, grad_fn=<DivBackward0>)
# 399tensor(13.7176, grad_fn=<DivBackward0>)
# 400tensor(14.0266, grad_fn=<DivBackward0>)
# 401tensor(14.7451, grad_fn=<DivBackward0>)
# 402tensor(14.0331, grad_fn=<DivBackward0>)
# 403tensor(14.1160, grad_fn=<DivBackward0>)
# 404tensor(14.1503, grad_fn=<DivBackward0>)
# 405tensor(13.2249, grad_fn=<DivBackward0>)
# 406tensor(13.6519, grad_fn=<DivBackward0>)
# 407tensor(13.9901, grad_fn=<DivBackward0>)
# 408tensor(14.5630, grad_fn=<DivBackward0>)
# 409tensor(13.8500, grad_fn=<DivBackward0>)
# 410tensor(13.7897, grad_fn=<DivBackward0>)
# 411tensor(14.3363, grad_fn=<DivBackward0>)
# 412tensor(13.7272, grad_fn=<DivBackward0>)
# 413tensor(14.0700, grad_fn=<DivBackward0>)
# 414tensor(13.9224, grad_fn=<DivBackward0>)
# 415tensor(14.0601, grad_fn=<DivBackward0>)
# 416tensor(14.3617, grad_fn=<DivBackward0>)
# 417tensor(14.1412, grad_fn=<DivBackward0>)
# 418tensor(13.7870, grad_fn=<DivBackward0>)
# 419tensor(13.8232, grad_fn=<DivBackward0>)
# 420tensor(13.7627, grad_fn=<DivBackward0>)
# 421tensor(13.9511, grad_fn=<DivBackward0>)
# 422tensor(13.6373, grad_fn=<DivBackward0>)
# 423tensor(14.0409, grad_fn=<DivBackward0>)
# 424tensor(13.4807, grad_fn=<DivBackward0>)
# 425tensor(14.0659, grad_fn=<DivBackward0>)
# 426tensor(13.5378, grad_fn=<DivBackward0>)
# 427tensor(13.4417, grad_fn=<DivBackward0>)
# 428tensor(13.7959, grad_fn=<DivBackward0>)
# 429tensor(13.7016, grad_fn=<DivBackward0>)
# 430tensor(13.7720, grad_fn=<DivBackward0>)
# 431tensor(14.0007, grad_fn=<DivBackward0>)
# 432tensor(14.2824, grad_fn=<DivBackward0>)
# 433tensor(13.7906, grad_fn=<DivBackward0>)
# 434tensor(13.9271, grad_fn=<DivBackward0>)
# 435tensor(13.5292, grad_fn=<DivBackward0>)
# 436tensor(13.3195, grad_fn=<DivBackward0>)
# 437tensor(13.6091, grad_fn=<DivBackward0>)
# 438tensor(13.2193, grad_fn=<DivBackward0>)
# 439tensor(14.5636, grad_fn=<DivBackward0>)
# 440tensor(13.2138, grad_fn=<DivBackward0>)
# 441tensor(13.4821, grad_fn=<DivBackward0>)
# 442tensor(13.5805, grad_fn=<DivBackward0>)
# 443tensor(13.6063, grad_fn=<DivBackward0>)
# 444tensor(13.3609, grad_fn=<DivBackward0>)
# 445tensor(14.3149, grad_fn=<DivBackward0>)
# 446tensor(13.7258, grad_fn=<DivBackward0>)
# 447tensor(13.6155, grad_fn=<DivBackward0>)
# 448tensor(13.0368, grad_fn=<DivBackward0>)
# 449tensor(12.7010, grad_fn=<DivBackward0>)
# 450tensor(13.1402, grad_fn=<DivBackward0>)
# 451tensor(13.3420, grad_fn=<DivBackward0>)
# 452tensor(13.1236, grad_fn=<DivBackward0>)
# 453tensor(13.3901, grad_fn=<DivBackward0>)
# 454tensor(13.4366, grad_fn=<DivBackward0>)
# 455tensor(12.9209, grad_fn=<DivBackward0>)
# 456tensor(13.1996, grad_fn=<DivBackward0>)
# 457tensor(12.8433, grad_fn=<DivBackward0>)
# 458tensor(12.7769, grad_fn=<DivBackward0>)
# 459tensor(13.2921, grad_fn=<DivBackward0>)
# 460tensor(12.9993, grad_fn=<DivBackward0>)
# 461tensor(13.5279, grad_fn=<DivBackward0>)
# 462tensor(13.1734, grad_fn=<DivBackward0>)
# 463tensor(12.6165, grad_fn=<DivBackward0>)
# 464tensor(13.6094, grad_fn=<DivBackward0>)
# 465tensor(13.5255, grad_fn=<DivBackward0>)
# 466tensor(13.0291, grad_fn=<DivBackward0>)
# 467tensor(12.9252, grad_fn=<DivBackward0>)
# 468tensor(13.0400, grad_fn=<DivBackward0>)
# 469tensor(13.1323, grad_fn=<DivBackward0>)
# 470tensor(13.0500, grad_fn=<DivBackward0>)
# 471tensor(13.8412, grad_fn=<DivBackward0>)
# 472tensor(12.8840, grad_fn=<DivBackward0>)
# 473tensor(13.0239, grad_fn=<DivBackward0>)
# 474tensor(13.1410, grad_fn=<DivBackward0>)
# 475tensor(12.5031, grad_fn=<DivBackward0>)
# 476tensor(12.6326, grad_fn=<DivBackward0>)
# 477tensor(13.1241, grad_fn=<DivBackward0>)
# 478tensor(12.9409, grad_fn=<DivBackward0>)
# 479tensor(12.4467, grad_fn=<DivBackward0>)
# 480tensor(13.2685, grad_fn=<DivBackward0>)
# 481tensor(11.9491, grad_fn=<DivBackward0>)
# 482tensor(13.5284, grad_fn=<DivBackward0>)
# 483tensor(12.9152, grad_fn=<DivBackward0>)
# 484tensor(13.1732, grad_fn=<DivBackward0>)
# 485tensor(13.3242, grad_fn=<DivBackward0>)
# 486tensor(12.3536, grad_fn=<DivBackward0>)
# 487tensor(12.8971, grad_fn=<DivBackward0>)
# 488tensor(12.6002, grad_fn=<DivBackward0>)
# 489tensor(13.2416, grad_fn=<DivBackward0>)
# 490tensor(13.4724, grad_fn=<DivBackward0>)
# 491tensor(12.2268, grad_fn=<DivBackward0>)
# 492tensor(12.6542, grad_fn=<DivBackward0>)
# 493tensor(12.9095, grad_fn=<DivBackward0>)
# 494tensor(13.3966, grad_fn=<DivBackward0>)
# 495tensor(12.9812, grad_fn=<DivBackward0>)
# 496tensor(12.8156, grad_fn=<DivBackward0>)
# 497tensor(13.1014, grad_fn=<DivBackward0>)
# 498tensor(12.4771, grad_fn=<DivBackward0>)
# 499tensor(13.4025, grad_fn=<DivBackward0>)
# 500tensor(13.3267, grad_fn=<DivBackward0>)
# 501tensor(12.5182, grad_fn=<DivBackward0>)
# 502tensor(12.4328, grad_fn=<DivBackward0>)
# 503tensor(12.5836, grad_fn=<DivBackward0>)
# 504tensor(12.2908, grad_fn=<DivBackward0>)
# 505tensor(12.1407, grad_fn=<DivBackward0>)
# 506tensor(11.9478, grad_fn=<DivBackward0>)
# 507tensor(12.6081, grad_fn=<DivBackward0>)
# 508tensor(12.6060, grad_fn=<DivBackward0>)
# 509tensor(12.6401, grad_fn=<DivBackward0>)
# 510tensor(12.2597, grad_fn=<DivBackward0>)
# 511tensor(12.6721, grad_fn=<DivBackward0>)
# 512tensor(12.1451, grad_fn=<DivBackward0>)
# 513tensor(11.9557, grad_fn=<DivBackward0>)
# 514tensor(12.0794, grad_fn=<DivBackward0>)
# 515tensor(12.9892, grad_fn=<DivBackward0>)
# 516tensor(12.2598, grad_fn=<DivBackward0>)
# 517tensor(12.4472, grad_fn=<DivBackward0>)
# 518tensor(12.5466, grad_fn=<DivBackward0>)
# 519tensor(12.5136, grad_fn=<DivBackward0>)
# 520tensor(12.3387, grad_fn=<DivBackward0>)
# 521tensor(13.2297, grad_fn=<DivBackward0>)
# 522tensor(12.8827, grad_fn=<DivBackward0>)
# 523tensor(12.2293, grad_fn=<DivBackward0>)
# 524tensor(11.5447, grad_fn=<DivBackward0>)
# 525tensor(12.7308, grad_fn=<DivBackward0>)
# 526tensor(12.0098, grad_fn=<DivBackward0>)
# 527tensor(11.9876, grad_fn=<DivBackward0>)
# 528tensor(11.7008, grad_fn=<DivBackward0>)
# 529tensor(12.2652, grad_fn=<DivBackward0>)
# 530tensor(12.0959, grad_fn=<DivBackward0>)
# 531tensor(12.3115, grad_fn=<DivBackward0>)
# 532tensor(12.1727, grad_fn=<DivBackward0>)
# 533tensor(13.0428, grad_fn=<DivBackward0>)
# 534tensor(11.7424, grad_fn=<DivBackward0>)
# 535tensor(12.2438, grad_fn=<DivBackward0>)
# 536tensor(12.5057, grad_fn=<DivBackward0>)
# 537tensor(12.2511, grad_fn=<DivBackward0>)
# 538tensor(12.0912, grad_fn=<DivBackward0>)
# 539tensor(12.0208, grad_fn=<DivBackward0>)
# 540tensor(11.8368, grad_fn=<DivBackward0>)
# 541tensor(11.8809, grad_fn=<DivBackward0>)
# 542tensor(12.3925, grad_fn=<DivBackward0>)
# 543tensor(11.8615, grad_fn=<DivBackward0>)
# 544tensor(12.2483, grad_fn=<DivBackward0>)
# 545tensor(12.2408, grad_fn=<DivBackward0>)
# 546tensor(11.8890, grad_fn=<DivBackward0>)
# 547tensor(12.6237, grad_fn=<DivBackward0>)
# 548tensor(11.5994, grad_fn=<DivBackward0>)
# 549tensor(11.6813, grad_fn=<DivBackward0>)
# 550tensor(11.6245, grad_fn=<DivBackward0>)
# 551tensor(11.7375, grad_fn=<DivBackward0>)
# 552tensor(11.7361, grad_fn=<DivBackward0>)
# 553tensor(12.0731, grad_fn=<DivBackward0>)
# 554tensor(11.8921, grad_fn=<DivBackward0>)
# 555tensor(11.7812, grad_fn=<DivBackward0>)
# 556tensor(11.7327, grad_fn=<DivBackward0>)
# 557tensor(11.3173, grad_fn=<DivBackward0>)
# 558tensor(11.7832, grad_fn=<DivBackward0>)
# 559tensor(12.6311, grad_fn=<DivBackward0>)
# 560tensor(11.8272, grad_fn=<DivBackward0>)
# 561tensor(11.5726, grad_fn=<DivBackward0>)
# 562tensor(11.3151, grad_fn=<DivBackward0>)
# 563tensor(11.4235, grad_fn=<DivBackward0>)
# 564tensor(11.5088, grad_fn=<DivBackward0>)
# 565tensor(11.8951, grad_fn=<DivBackward0>)
# 566tensor(11.5496, grad_fn=<DivBackward0>)
# 567tensor(11.5986, grad_fn=<DivBackward0>)
# 568tensor(11.1502, grad_fn=<DivBackward0>)
# 569tensor(11.7732, grad_fn=<DivBackward0>)
# 570tensor(12.7659, grad_fn=<DivBackward0>)
# 571tensor(11.9748, grad_fn=<DivBackward0>)
# 572tensor(11.9999, grad_fn=<DivBackward0>)
# 573tensor(11.4911, grad_fn=<DivBackward0>)
# 574tensor(11.7651, grad_fn=<DivBackward0>)
# 575tensor(11.3490, grad_fn=<DivBackward0>)
# 576tensor(11.4236, grad_fn=<DivBackward0>)
# 577tensor(11.4371, grad_fn=<DivBackward0>)
# 578tensor(11.6612, grad_fn=<DivBackward0>)
# 579tensor(11.9097, grad_fn=<DivBackward0>)
# 580tensor(11.6307, grad_fn=<DivBackward0>)
# 581tensor(11.5581, grad_fn=<DivBackward0>)
# 582tensor(11.4451, grad_fn=<DivBackward0>)
# 583tensor(11.7285, grad_fn=<DivBackward0>)
# 584tensor(11.9260, grad_fn=<DivBackward0>)
# 585tensor(11.7281, grad_fn=<DivBackward0>)
# 586tensor(11.4593, grad_fn=<DivBackward0>)
# 587tensor(11.8786, grad_fn=<DivBackward0>)
# 588tensor(11.7838, grad_fn=<DivBackward0>)
# 589tensor(10.3700, grad_fn=<DivBackward0>)
# 590tensor(11.3716, grad_fn=<DivBackward0>)
# 591tensor(11.1511, grad_fn=<DivBackward0>)
# 592tensor(11.5993, grad_fn=<DivBackward0>)
# 593tensor(11.5199, grad_fn=<DivBackward0>)
# 594tensor(11.5958, grad_fn=<DivBackward0>)
# 595tensor(11.9138, grad_fn=<DivBackward0>)
# 596tensor(11.0691, grad_fn=<DivBackward0>)
# 597tensor(11.8332, grad_fn=<DivBackward0>)
# 598tensor(11.0769, grad_fn=<DivBackward0>)
# 599tensor(11.4989, grad_fn=<DivBackward0>)
# 600tensor(11.2616, grad_fn=<DivBackward0>)
# 601tensor(11.3782, grad_fn=<DivBackward0>)
# 602tensor(11.6573, grad_fn=<DivBackward0>)
# 603tensor(11.5184, grad_fn=<DivBackward0>)
# 604tensor(11.7203, grad_fn=<DivBackward0>)
# 605tensor(11.1781, grad_fn=<DivBackward0>)
# 606tensor(11.0247, grad_fn=<DivBackward0>)
# 607tensor(11.5134, grad_fn=<DivBackward0>)
# 608tensor(10.9277, grad_fn=<DivBackward0>)
# 609tensor(11.5328, grad_fn=<DivBackward0>)
# 610tensor(11.0274, grad_fn=<DivBackward0>)
# 611tensor(11.1144, grad_fn=<DivBackward0>)
# 612tensor(11.2781, grad_fn=<DivBackward0>)
# 613tensor(10.9459, grad_fn=<DivBackward0>)
# 614tensor(11.6830, grad_fn=<DivBackward0>)
# 615tensor(11.1619, grad_fn=<DivBackward0>)
# 616tensor(11.3616, grad_fn=<DivBackward0>)
# 617tensor(11.0803, grad_fn=<DivBackward0>)
# 618tensor(10.8112, grad_fn=<DivBackward0>)
# 619tensor(11.8801, grad_fn=<DivBackward0>)
# 620tensor(10.5852, grad_fn=<DivBackward0>)
# 621tensor(10.9560, grad_fn=<DivBackward0>)
# 622tensor(11.2275, grad_fn=<DivBackward0>)
# 623tensor(11.2228, grad_fn=<DivBackward0>)
# 624tensor(11.6761, grad_fn=<DivBackward0>)
# 625tensor(11.5132, grad_fn=<DivBackward0>)
# 626tensor(10.7300, grad_fn=<DivBackward0>)
# 627tensor(10.8427, grad_fn=<DivBackward0>)
# 628tensor(10.5428, grad_fn=<DivBackward0>)
# 629tensor(11.4014, grad_fn=<DivBackward0>)
# 630tensor(11.1932, grad_fn=<DivBackward0>)
# 631tensor(10.6986, grad_fn=<DivBackward0>)
# 632tensor(11.1005, grad_fn=<DivBackward0>)
# 633tensor(11.1167, grad_fn=<DivBackward0>)
# 634tensor(10.8882, grad_fn=<DivBackward0>)
# 635tensor(10.5860, grad_fn=<DivBackward0>)
# 636tensor(11.6732, grad_fn=<DivBackward0>)
# 637tensor(11.0798, grad_fn=<DivBackward0>)
# 638tensor(11.0433, grad_fn=<DivBackward0>)
# 639tensor(10.6742, grad_fn=<DivBackward0>)
# 640tensor(10.7362, grad_fn=<DivBackward0>)
# 641tensor(10.7292, grad_fn=<DivBackward0>)
# 642tensor(10.9909, grad_fn=<DivBackward0>)
# 643tensor(11.1385, grad_fn=<DivBackward0>)
# 644tensor(10.6917, grad_fn=<DivBackward0>)
# 645tensor(11.2552, grad_fn=<DivBackward0>)
# 646tensor(11.2291, grad_fn=<DivBackward0>)
# 647tensor(11.2852, grad_fn=<DivBackward0>)
# 648tensor(10.6057, grad_fn=<DivBackward0>)
# 649tensor(10.7806, grad_fn=<DivBackward0>)
# 650tensor(10.8984, grad_fn=<DivBackward0>)
# 651tensor(10.8856, grad_fn=<DivBackward0>)
# 652tensor(10.6518, grad_fn=<DivBackward0>)
# 653tensor(10.9179, grad_fn=<DivBackward0>)
# 654tensor(10.1726, grad_fn=<DivBackward0>)
# 655tensor(10.6920, grad_fn=<DivBackward0>)
# 656tensor(11.1802, grad_fn=<DivBackward0>)
# 657tensor(10.9769, grad_fn=<DivBackward0>)
# 658tensor(10.5666, grad_fn=<DivBackward0>)
# 659tensor(10.6344, grad_fn=<DivBackward0>)
# 660tensor(11.2901, grad_fn=<DivBackward0>)
# 661tensor(10.7649, grad_fn=<DivBackward0>)
# 662tensor(10.6950, grad_fn=<DivBackward0>)
# 663tensor(10.8325, grad_fn=<DivBackward0>)
# 664tensor(11.2557, grad_fn=<DivBackward0>)
# 665tensor(11.0734, grad_fn=<DivBackward0>)
# 666tensor(10.7604, grad_fn=<DivBackward0>)
# 667tensor(10.8340, grad_fn=<DivBackward0>)
# 668tensor(10.0034, grad_fn=<DivBackward0>)
# 669tensor(10.7931, grad_fn=<DivBackward0>)
# 670tensor(10.2700, grad_fn=<DivBackward0>)
# 671tensor(11.0665, grad_fn=<DivBackward0>)
# 672tensor(10.9538, grad_fn=<DivBackward0>)
# 673tensor(10.5117, grad_fn=<DivBackward0>)
# 674tensor(10.9724, grad_fn=<DivBackward0>)
# 675tensor(10.5517, grad_fn=<DivBackward0>)
# 676tensor(10.2945, grad_fn=<DivBackward0>)
# 677tensor(11.3246, grad_fn=<DivBackward0>)
# 678tensor(10.2099, grad_fn=<DivBackward0>)
# 679tensor(10.9358, grad_fn=<DivBackward0>)
# 680tensor(10.0369, grad_fn=<DivBackward0>)
# 681tensor(10.5521, grad_fn=<DivBackward0>)
# 682tensor(10.5762, grad_fn=<DivBackward0>)
# 683tensor(11.3371, grad_fn=<DivBackward0>)
# 684tensor(10.6163, grad_fn=<DivBackward0>)
# 685tensor(10.8863, grad_fn=<DivBackward0>)
# 686tensor(9.9489, grad_fn=<DivBackward0>)
# 687tensor(10.9637, grad_fn=<DivBackward0>)
# 688tensor(10.3824, grad_fn=<DivBackward0>)
# 689tensor(10.6940, grad_fn=<DivBackward0>)
# 690tensor(10.7039, grad_fn=<DivBackward0>)
# 691tensor(10.6877, grad_fn=<DivBackward0>)
# 692tensor(10.2924, grad_fn=<DivBackward0>)
# 693tensor(10.6532, grad_fn=<DivBackward0>)
# 694tensor(10.6791, grad_fn=<DivBackward0>)
# 695tensor(10.6370, grad_fn=<DivBackward0>)
# 696tensor(10.5743, grad_fn=<DivBackward0>)
# 697tensor(10.5088, grad_fn=<DivBackward0>)
# 698tensor(10.2574, grad_fn=<DivBackward0>)
# 699tensor(10.0312, grad_fn=<DivBackward0>)
# 700tensor(10.6452, grad_fn=<DivBackward0>)
# 701tensor(10.8127, grad_fn=<DivBackward0>)
# 702tensor(11.1409, grad_fn=<DivBackward0>)
# 703tensor(10.2966, grad_fn=<DivBackward0>)
# 704tensor(11.1686, grad_fn=<DivBackward0>)
# 705tensor(10.8952, grad_fn=<DivBackward0>)
# 706tensor(9.8117, grad_fn=<DivBackward0>)
# 707tensor(10.7434, grad_fn=<DivBackward0>)
# 708tensor(10.4842, grad_fn=<DivBackward0>)
# 709tensor(10.2624, grad_fn=<DivBackward0>)
# 710tensor(10.2225, grad_fn=<DivBackward0>)
# 711tensor(10.4883, grad_fn=<DivBackward0>)
# 712tensor(11.1541, grad_fn=<DivBackward0>)
# 713tensor(11.0613, grad_fn=<DivBackward0>)
# 714tensor(11.1192, grad_fn=<DivBackward0>)
# 715tensor(10.7056, grad_fn=<DivBackward0>)
# 716tensor(10.3570, grad_fn=<DivBackward0>)
# 717tensor(10.9425, grad_fn=<DivBackward0>)
# 718tensor(10.1444, grad_fn=<DivBackward0>)
# 719tensor(9.8784, grad_fn=<DivBackward0>)
# 720tensor(10.1870, grad_fn=<DivBackward0>)
# 721tensor(10.4893, grad_fn=<DivBackward0>)
# 722tensor(10.8159, grad_fn=<DivBackward0>)
# 723tensor(10.5392, grad_fn=<DivBackward0>)
# 724tensor(10.1353, grad_fn=<DivBackward0>)
# 725tensor(11.1785, grad_fn=<DivBackward0>)
# 726tensor(10.7977, grad_fn=<DivBackward0>)
# 727tensor(11.1659, grad_fn=<DivBackward0>)
# 728tensor(9.9211, grad_fn=<DivBackward0>)
# 729tensor(10.9348, grad_fn=<DivBackward0>)
# 730tensor(10.9429, grad_fn=<DivBackward0>)
# 731tensor(10.4864, grad_fn=<DivBackward0>)
# 732tensor(10.5391, grad_fn=<DivBackward0>)
# 733tensor(10.4576, grad_fn=<DivBackward0>)
# 734tensor(10.0412, grad_fn=<DivBackward0>)
# 735tensor(10.6223, grad_fn=<DivBackward0>)
# 736tensor(10.1258, grad_fn=<DivBackward0>)
# 737tensor(10.0582, grad_fn=<DivBackward0>)
# 738tensor(10.4877, grad_fn=<DivBackward0>)
# 739tensor(10.6856, grad_fn=<DivBackward0>)
# 740tensor(10.8657, grad_fn=<DivBackward0>)
# 741tensor(10.5815, grad_fn=<DivBackward0>)
# 742tensor(10.6028, grad_fn=<DivBackward0>)
# 743tensor(10.3559, grad_fn=<DivBackward0>)
# 744tensor(9.8652, grad_fn=<DivBackward0>)
# 745tensor(10.3651, grad_fn=<DivBackward0>)
# 746tensor(10.3709, grad_fn=<DivBackward0>)
# 747tensor(9.4296, grad_fn=<DivBackward0>)
# 748tensor(9.5279, grad_fn=<DivBackward0>)
# 749tensor(10.3482, grad_fn=<DivBackward0>)
# 750tensor(10.3157, grad_fn=<DivBackward0>)
# 751tensor(10.7198, grad_fn=<DivBackward0>)
# 752tensor(10.2733, grad_fn=<DivBackward0>)
# 753tensor(10.0483, grad_fn=<DivBackward0>)
# 754tensor(10.3956, grad_fn=<DivBackward0>)
# 755tensor(10.2825, grad_fn=<DivBackward0>)
# 756tensor(10.5806, grad_fn=<DivBackward0>)
# 757tensor(10.9435, grad_fn=<DivBackward0>)
# 758tensor(10.4407, grad_fn=<DivBackward0>)
# 759tensor(10.2457, grad_fn=<DivBackward0>)
# 760tensor(10.3894, grad_fn=<DivBackward0>)
# 761tensor(9.8449, grad_fn=<DivBackward0>)
# 762tensor(10.2583, grad_fn=<DivBackward0>)
# 763tensor(10.7541, grad_fn=<DivBackward0>)
# 764tensor(9.8203, grad_fn=<DivBackward0>)
# 765tensor(10.2187, grad_fn=<DivBackward0>)
# 766tensor(10.6346, grad_fn=<DivBackward0>)
# 767tensor(11.1584, grad_fn=<DivBackward0>)
# 768tensor(10.2071, grad_fn=<DivBackward0>)
# 769tensor(9.6723, grad_fn=<DivBackward0>)
# 770tensor(10.2104, grad_fn=<DivBackward0>)
# 771tensor(10.1967, grad_fn=<DivBackward0>)
# 772tensor(10.6945, grad_fn=<DivBackward0>)
# 773tensor(10.2183, grad_fn=<DivBackward0>)
# 774tensor(10.0043, grad_fn=<DivBackward0>)
# 775tensor(10.4427, grad_fn=<DivBackward0>)
# 776tensor(10.6063, grad_fn=<DivBackward0>)
# 777tensor(10.0310, grad_fn=<DivBackward0>)
# 778tensor(10.5478, grad_fn=<DivBackward0>)
# 779tensor(10.5224, grad_fn=<DivBackward0>)
# 780tensor(10.6013, grad_fn=<DivBackward0>)
# 781tensor(10.0936, grad_fn=<DivBackward0>)
# 782tensor(9.1853, grad_fn=<DivBackward0>)
# 783tensor(9.8662, grad_fn=<DivBackward0>)
# 784tensor(9.8455, grad_fn=<DivBackward0>)
# 785tensor(10.3191, grad_fn=<DivBackward0>)
# 786tensor(10.3551, grad_fn=<DivBackward0>)
# 787tensor(10.0905, grad_fn=<DivBackward0>)
# 788tensor(9.8643, grad_fn=<DivBackward0>)
# 789tensor(10.0364, grad_fn=<DivBackward0>)
# 790tensor(10.3333, grad_fn=<DivBackward0>)
# 791tensor(10.9324, grad_fn=<DivBackward0>)
# 792tensor(10.2748, grad_fn=<DivBackward0>)
# 793tensor(10.6218, grad_fn=<DivBackward0>)
# 794tensor(10.6383, grad_fn=<DivBackward0>)
# 795tensor(10.5063, grad_fn=<DivBackward0>)
# 796tensor(10.2294, grad_fn=<DivBackward0>)
# 797tensor(10.5958, grad_fn=<DivBackward0>)
# 798tensor(10.3938, grad_fn=<DivBackward0>)
# 799tensor(9.8591, grad_fn=<DivBackward0>)
# 800tensor(10.5926, grad_fn=<DivBackward0>)
# 801tensor(10.2664, grad_fn=<DivBackward0>)
# 802tensor(9.7026, grad_fn=<DivBackward0>)
# 803tensor(10.1374, grad_fn=<DivBackward0>)
# 804tensor(9.1157, grad_fn=<DivBackward0>)
# 805tensor(9.8650, grad_fn=<DivBackward0>)
# 806tensor(10.4795, grad_fn=<DivBackward0>)
# 807tensor(10.2194, grad_fn=<DivBackward0>)
# 808tensor(9.2547, grad_fn=<DivBackward0>)
# 809tensor(10.2962, grad_fn=<DivBackward0>)
# 810tensor(10.0383, grad_fn=<DivBackward0>)
# 811tensor(10.4184, grad_fn=<DivBackward0>)
# 812tensor(10.1642, grad_fn=<DivBackward0>)
# 813tensor(10.7301, grad_fn=<DivBackward0>)
# 814tensor(9.8422, grad_fn=<DivBackward0>)
# 815tensor(9.9188, grad_fn=<DivBackward0>)
# 816tensor(10.2735, grad_fn=<DivBackward0>)
# 817tensor(9.9407, grad_fn=<DivBackward0>)
# 818tensor(10.1294, grad_fn=<DivBackward0>)
# 819tensor(10.5127, grad_fn=<DivBackward0>)
# 820tensor(9.8726, grad_fn=<DivBackward0>)
# 821tensor(10.6245, grad_fn=<DivBackward0>)
# 822tensor(10.3025, grad_fn=<DivBackward0>)
# 823tensor(10.1763, grad_fn=<DivBackward0>)
# 824tensor(9.8903, grad_fn=<DivBackward0>)
# 825tensor(10.0074, grad_fn=<DivBackward0>)
# 826tensor(10.1687, grad_fn=<DivBackward0>)
# 827tensor(11.0501, grad_fn=<DivBackward0>)
# 828tensor(10.2935, grad_fn=<DivBackward0>)
# 829tensor(9.5345, grad_fn=<DivBackward0>)
# 830tensor(10.6343, grad_fn=<DivBackward0>)
# 831tensor(10.1295, grad_fn=<DivBackward0>)
# 832tensor(9.9830, grad_fn=<DivBackward0>)
# 833tensor(10.1721, grad_fn=<DivBackward0>)
# 834tensor(9.6058, grad_fn=<DivBackward0>)
# 835tensor(9.7553, grad_fn=<DivBackward0>)
# 836tensor(11.2757, grad_fn=<DivBackward0>)
# 837tensor(9.4758, grad_fn=<DivBackward0>)
# 838tensor(10.3249, grad_fn=<DivBackward0>)
# 839tensor(10.9499, grad_fn=<DivBackward0>)
# 840tensor(9.5603, grad_fn=<DivBackward0>)
# 841tensor(10.1787, grad_fn=<DivBackward0>)
# 842tensor(10.6141, grad_fn=<DivBackward0>)
# 843tensor(9.5220, grad_fn=<DivBackward0>)
# 844tensor(10.6464, grad_fn=<DivBackward0>)
# 845tensor(9.3250, grad_fn=<DivBackward0>)
# 846tensor(9.8447, grad_fn=<DivBackward0>)
# 847tensor(9.7592, grad_fn=<DivBackward0>)
# 848tensor(10.0959, grad_fn=<DivBackward0>)
# 849tensor(10.0026, grad_fn=<DivBackward0>)
# 850tensor(9.9814, grad_fn=<DivBackward0>)
# 851tensor(10.0289, grad_fn=<DivBackward0>)
# 852tensor(9.3023, grad_fn=<DivBackward0>)
# 853tensor(10.9336, grad_fn=<DivBackward0>)
# 854tensor(9.7961, grad_fn=<DivBackward0>)
# 855tensor(10.2981, grad_fn=<DivBackward0>)
# 856tensor(10.1638, grad_fn=<DivBackward0>)
# 857tensor(10.0760, grad_fn=<DivBackward0>)
# 858tensor(10.1403, grad_fn=<DivBackward0>)
# 859tensor(10.8742, grad_fn=<DivBackward0>)
# 860tensor(10.1503, grad_fn=<DivBackward0>)
# 861tensor(10.1639, grad_fn=<DivBackward0>)
# 862tensor(9.7300, grad_fn=<DivBackward0>)
# 863tensor(10.1338, grad_fn=<DivBackward0>)
# 864tensor(9.9613, grad_fn=<DivBackward0>)
# 865tensor(10.1000, grad_fn=<DivBackward0>)
# 866tensor(10.1900, grad_fn=<DivBackward0>)
# 867tensor(10.1624, grad_fn=<DivBackward0>)
# 868tensor(9.5303, grad_fn=<DivBackward0>)
# 869tensor(9.9777, grad_fn=<DivBackward0>)
# 870tensor(9.7710, grad_fn=<DivBackward0>)
# 871tensor(9.8959, grad_fn=<DivBackward0>)
# 872tensor(10.1061, grad_fn=<DivBackward0>)
# 873tensor(10.4427, grad_fn=<DivBackward0>)
# 874tensor(10.2144, grad_fn=<DivBackward0>)
# 875tensor(9.6461, grad_fn=<DivBackward0>)
# 876tensor(10.0517, grad_fn=<DivBackward0>)
# 877tensor(10.7746, grad_fn=<DivBackward0>)
# 878tensor(9.5826, grad_fn=<DivBackward0>)
# 879tensor(10.0935, grad_fn=<DivBackward0>)
# 880tensor(9.5968, grad_fn=<DivBackward0>)
# 881tensor(10.2486, grad_fn=<DivBackward0>)
# 882tensor(10.0168, grad_fn=<DivBackward0>)
# 883tensor(10.0021, grad_fn=<DivBackward0>)
# 884tensor(9.7566, grad_fn=<DivBackward0>)
# 885tensor(10.3821, grad_fn=<DivBackward0>)
# 886tensor(10.1077, grad_fn=<DivBackward0>)
# 887tensor(9.4954, grad_fn=<DivBackward0>)
# 888tensor(9.7655, grad_fn=<DivBackward0>)
# 889tensor(10.5034, grad_fn=<DivBackward0>)
# 890tensor(10.4474, grad_fn=<DivBackward0>)
# 891tensor(10.3091, grad_fn=<DivBackward0>)
# 892tensor(10.2944, grad_fn=<DivBackward0>)
# 893tensor(10.0553, grad_fn=<DivBackward0>)
# 894tensor(9.9002, grad_fn=<DivBackward0>)
# 895tensor(10.2079, grad_fn=<DivBackward0>)
# 896tensor(10.3704, grad_fn=<DivBackward0>)
# 897tensor(9.9242, grad_fn=<DivBackward0>)
# 898tensor(9.9341, grad_fn=<DivBackward0>)
# 899tensor(9.4019, grad_fn=<DivBackward0>)
# 900tensor(10.0401, grad_fn=<DivBackward0>)
# 901tensor(10.2856, grad_fn=<DivBackward0>)
# 902tensor(10.1940, grad_fn=<DivBackward0>)
# 903tensor(10.0197, grad_fn=<DivBackward0>)
# 904tensor(10.0554, grad_fn=<DivBackward0>)
# 905tensor(10.5726, grad_fn=<DivBackward0>)
# 906tensor(10.4968, grad_fn=<DivBackward0>)
# 907tensor(9.7533, grad_fn=<DivBackward0>)
# 908tensor(9.9101, grad_fn=<DivBackward0>)
# 909tensor(9.7371, grad_fn=<DivBackward0>)
# 910tensor(9.7390, grad_fn=<DivBackward0>)
# 911tensor(10.7496, grad_fn=<DivBackward0>)
# 912tensor(9.5970, grad_fn=<DivBackward0>)
# 913tensor(9.8416, grad_fn=<DivBackward0>)
# 914tensor(9.7489, grad_fn=<DivBackward0>)
# 915tensor(10.5017, grad_fn=<DivBackward0>)
# 916tensor(10.6255, grad_fn=<DivBackward0>)
# 917tensor(9.8448, grad_fn=<DivBackward0>)
# 918tensor(10.3142, grad_fn=<DivBackward0>)
# 919tensor(9.6106, grad_fn=<DivBackward0>)
# 920tensor(9.9932, grad_fn=<DivBackward0>)
# 921tensor(10.4841, grad_fn=<DivBackward0>)
# 922tensor(9.7671, grad_fn=<DivBackward0>)
# 923tensor(10.0645, grad_fn=<DivBackward0>)
# 924tensor(10.0474, grad_fn=<DivBackward0>)
# 925tensor(9.4472, grad_fn=<DivBackward0>)
# 926tensor(9.9669, grad_fn=<DivBackward0>)
# 927tensor(9.9432, grad_fn=<DivBackward0>)
# 928tensor(9.2382, grad_fn=<DivBackward0>)
# 929tensor(9.5305, grad_fn=<DivBackward0>)
# 930tensor(10.0328, grad_fn=<DivBackward0>)
# 931tensor(9.4493, grad_fn=<DivBackward0>)
# 932tensor(9.7440, grad_fn=<DivBackward0>)
# 933tensor(9.6226, grad_fn=<DivBackward0>)
# 934tensor(9.5275, grad_fn=<DivBackward0>)
# 935tensor(10.2424, grad_fn=<DivBackward0>)
# 936tensor(10.0813, grad_fn=<DivBackward0>)
# 937tensor(9.6754, grad_fn=<DivBackward0>)
# 938tensor(9.0748, grad_fn=<DivBackward0>)
# 939tensor(10.5573, grad_fn=<DivBackward0>)
# 940tensor(9.9366, grad_fn=<DivBackward0>)
# 941tensor(9.8059, grad_fn=<DivBackward0>)
# 942tensor(10.1513, grad_fn=<DivBackward0>)
# 943tensor(9.5368, grad_fn=<DivBackward0>)
# 944tensor(9.4122, grad_fn=<DivBackward0>)
# 945tensor(10.0146, grad_fn=<DivBackward0>)
# 946tensor(9.5521, grad_fn=<DivBackward0>)
# 947tensor(9.6255, grad_fn=<DivBackward0>)
# 948tensor(9.2519, grad_fn=<DivBackward0>)
# 949tensor(10.1413, grad_fn=<DivBackward0>)
# 950tensor(10.2579, grad_fn=<DivBackward0>)
# 951tensor(9.7750, grad_fn=<DivBackward0>)
# 952tensor(9.8518, grad_fn=<DivBackward0>)
# 953tensor(9.5834, grad_fn=<DivBackward0>)
# 954tensor(9.5596, grad_fn=<DivBackward0>)
# 955tensor(9.5864, grad_fn=<DivBackward0>)
# 956tensor(10.2448, grad_fn=<DivBackward0>)
# 957tensor(10.2247, grad_fn=<DivBackward0>)
# 958tensor(9.7061, grad_fn=<DivBackward0>)
# 959tensor(9.8537, grad_fn=<DivBackward0>)
# 960tensor(9.6206, grad_fn=<DivBackward0>)
# 961tensor(10.5087, grad_fn=<DivBackward0>)
# 962tensor(9.0182, grad_fn=<DivBackward0>)
# 963tensor(9.7503, grad_fn=<DivBackward0>)
# 964tensor(9.8003, grad_fn=<DivBackward0>)
# 965tensor(9.7549, grad_fn=<DivBackward0>)
# 966tensor(9.7702, grad_fn=<DivBackward0>)
# 967tensor(9.8586, grad_fn=<DivBackward0>)
# 968tensor(9.5093, grad_fn=<DivBackward0>)
# 969tensor(10.1303, grad_fn=<DivBackward0>)
# 970tensor(9.6760, grad_fn=<DivBackward0>)
# 971tensor(10.2688, grad_fn=<DivBackward0>)
# 972tensor(9.9193, grad_fn=<DivBackward0>)
# 973tensor(10.4552, grad_fn=<DivBackward0>)
# 974tensor(10.2702, grad_fn=<DivBackward0>)
# 975tensor(9.8737, grad_fn=<DivBackward0>)
# 976tensor(9.8176, grad_fn=<DivBackward0>)
# 977tensor(10.0192, grad_fn=<DivBackward0>)
# 978tensor(9.9167, grad_fn=<DivBackward0>)
# 979tensor(9.8138, grad_fn=<DivBackward0>)
# 980tensor(9.8713, grad_fn=<DivBackward0>)
# 981tensor(10.3777, grad_fn=<DivBackward0>)
# 982tensor(9.3285, grad_fn=<DivBackward0>)
# 983tensor(9.2073, grad_fn=<DivBackward0>)
# 984tensor(9.6327, grad_fn=<DivBackward0>)
# 985tensor(10.2940, grad_fn=<DivBackward0>)
# 986tensor(9.8247, grad_fn=<DivBackward0>)
# 987tensor(10.1565, grad_fn=<DivBackward0>)
# 988tensor(10.6947, grad_fn=<DivBackward0>)
# 989tensor(9.7597, grad_fn=<DivBackward0>)
# 990tensor(10.0731, grad_fn=<DivBackward0>)
# 991tensor(9.6909, grad_fn=<DivBackward0>)
# 992tensor(9.3248, grad_fn=<DivBackward0>)
# 993tensor(9.7269, grad_fn=<DivBackward0>)
# 994tensor(10.1680, grad_fn=<DivBackward0>)
# 995tensor(9.8193, grad_fn=<DivBackward0>)
# 996tensor(10.1187, grad_fn=<DivBackward0>)
# 997tensor(9.6591, grad_fn=<DivBackward0>)
# 998tensor(9.3281, grad_fn=<DivBackward0>)
# 999tensor(9.2068, grad_fn=<DivBackward0>)

# %%
os.chdir('C:\\Users\\Ji Qi\\Documents\\GitHub\\ST-Aim3')
os.getcwd()
PATH = 'vgae_model_for_simulation.pth'
torch.save(model, PATH)

model = torch.load(PATH)
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder(
#     (conv1): GCNConv(10, 4)
#     (conv_mu): GCNConv(4, 2)
#     (conv_logstd): GCNConv(4, 2)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))

mu_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))

# %%
# input data scatter 
import matplotlib.pyplot as plt
def plot_mu_graph(mu):
    
    n_node = mu.shape[0]
    annotations = [str(i+1) for i in range(n_node)]
    colors = plt.cm.rainbow(np.linspace(0, 1, n_node))
    plt.scatter(mu[:,0],mu[:,1],c=colors, s=100)
    
    for i, label in enumerate(annotations):
        plt.annotate(label, (mu[i,0], mu[i,1]), fontsize=14)

        
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list_in_data[graph_i])

# %%
mu_list_in_data
# Out:
# [array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32),
#  array([[-1.4796917 , -1.091111  ],
#         [-1.451718  , -1.0538778 ],
#         [-0.9909379 , -0.621724  ],
#         [-1.091181  , -0.7488334 ],
#         [-1.1990753 , -0.8564589 ],
#         [ 0.56174   ,  0.4567092 ],
#         [ 0.16726035,  0.67126334],
#         [ 0.6913486 ,  0.38801128],
#         [ 0.6440252 ,  0.30504128],
#         [ 0.7506191 ,  0.12716141]], dtype=float32)]

# %%
# original data mu scatter
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*len(mu_list)
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
# original adj matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 5, figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(simu_graph.simu_adj_m()[i], cmap="Greys")

# %%
# original data first 5 vs. last 5
simu_graph = SimuData(n_graph=30)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

colors = ['#3DAE43', '#67E332','#008000', '#006400', '#228B22',
          '#CD5C5C','#C71585', '#FF4500', '#DB7093', '#FF0000']
mu_list = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list.append(np.asarray(mu.detach()))

plt.figure(figsize=(10,10))
for node_i in range(n_node):
    
    node_mu = np.empty((0, 2))
    for graph_i in range(len(mu_list)):
    
        node_mu = np.vstack((node_mu, mu_list[graph_i][node_i, :]))
    
    plt.scatter(node_mu[:,0],node_mu[:,1], c=colors[node_i],alpha=0.8)

plt.show()

# %%
# Gaussian distribution for generating mu

import scipy.stats as stats
data_mu = np.zeros((n, out_channels * n_node))
for i in range(n):
    data_mu[i, :] = mu_list_reshape[i]

from sklearn.mixture import GaussianMixture

gm_mu = GaussianMixture(n_components=1, random_state=0).fit(data_mu)
gm_mu.weights_[0] = 1
# Out:
# C:\Users\Ji Qi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# got mean and cov for mu generating distribution
means_normal = gm_mu.means_
cov_normal = gm_mu.covariances_
means_normal = np.asarray(means_normal.tolist()[0])
cov_normal = np.asarray(cov_normal.tolist()[0])

# %%
def sample_adj_mat(filter_value=0.75, filter_eye=True):
    model.__mu__ = torch.from_numpy((np.random.multivariate_normal(mean=means_normal,cov=cov_normal)).reshape((n_node,out_channels)))
    z = model.__mu__
    model.decode(z, edge_index)
    adj_mat = np.zeros((n_node, n_node))
    for i in range(n_node*n_node):
        adj_mat[int(edge_index[0, i]), int(edge_index[1, i])] = (model.decode(z, edge_index)[i].detach().numpy()).item()
    adj_mat[adj_mat < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat.shape[0]):
            adj_mat[i,i]=0
    return adj_mat, model.__mu__

# %%
# generate adjacency matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 5, figsize=(10,10))
adj_mat_list = []
mu_list = []
for i in range(25):
    plt.subplot(5, 5, i+1)
    adj_mat, mu_sample = sample_adj_mat(filter_value=0)
    adj_mat_list.append(adj_mat)
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
plt.subplots(figsize=(20,20))

for graph_i in range(25):
    plt.subplot(5, 5, graph_i+1)
    plot_mu_graph(mu_list[graph_i])

# %%
def compute_centrality(mat):
    return (np.sum(mat, axis=0)/mat.shape[0])

# %%
generated_from_simu = adj_mat_list
generated_simu_centrality = []

for i in range(30):
    train_data, val_data, test_data = transform(dataset[i])
    adj_mat,z = sample_adj_mat_1v1(filter_value=0.7, data=train_data)
    generated_from_simu.append(adj_mat)
    generated_simu_centrality.append(compute_centrality(adj_mat))

# %%
for k in range(30):
    plt.subplot(5,6,k+1)    
    plt.imshow(generated_from_simu[k], cmap="Greys")

# %%
simu_adj_list = []
simu_centrality_list = []
for i in range(30):
    adj_mat = simu_graph.simu_adj_m()[i].detach().numpy()
    simu_adj_list.append(adj_mat)
    simu_centrality_list.append(compute_centrality(adj_mat))

# %%
from scipy import stats
res = stats.ttest_ind(generated_simu_centrality, simu_centrality_list, 
                      equal_var=True, axis=0)

display(res)
# Out:
# Ttest_indResult(statistic=array([10.9626299 ,  7.72221656,  6.83576265, 10.90027879,  7.30782241,
#         5.06947448,  4.67625578,  5.46005156,  4.36472405,  3.67482036]), pvalue=array([9.22560262e-16, 1.79141975e-10, 5.52910643e-09, 1.15476003e-15,
#        8.90699386e-10, 4.36641318e-06, 1.79001177e-05, 1.03786335e-06,
#        5.30676393e-05, 5.21304751e-04]))

# %%
np.mean(np.vstack(generated_simu_centrality), axis=0)
# Out:
# array([0.3608369 , 0.36724798, 0.34949856, 0.37162413, 0.34025561,
#        0.07104433, 0.09292881, 0.09442856, 0.08354401, 0.04944068])

# %%
np.mean(np.vstack(simu_centrality_list), axis=0)
# Out:
# array([0.17999996, 0.19666664, 0.22333333, 0.16999999, 0.19666663,
#        0.        , 0.        , 0.        , 0.        , 0.        ],
#       dtype=float32)
