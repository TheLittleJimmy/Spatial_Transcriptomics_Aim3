# %%
import torch
from torch_geometric.utils import (negative_sampling, remove_self_loops,
                                   add_self_loops)
EPS = 1e-15
MAX_LOGSTD = 10

class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""
    def forward(self, z, edge_index, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value


    def forward_all(self, z, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj



class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (Module): The encoder module.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        reset(self.encoder)
        reset(self.decoder)


    def encode(self, *args, **kwargs):
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)


    def decode(self, *args, **kwargs):
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)


    def recon_loss(self, z, pos_edge_index, neg_edge_index=None):
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :oenbj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to train against.
            neg_edge_index (LongTensor, optional): The negative edges to train
                against. If not given, uses negative sampling to calculate
                negative edges. (default: :obj:`None`)
        """

        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()

        # Do not include self-loops in negative samples
        pos_edge_index, _ = remove_self_loops(pos_edge_index)
        pos_edge_index, _ = add_self_loops(pos_edge_index)
        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index, sigmoid=True) +
                              EPS).mean()

        return pos_loss + neg_loss


    def test(self, z, pos_edge_index, neg_edge_index):
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        scores.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to evaluate
                against.
            neg_edge_index (LongTensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import roc_auc_score, average_precision_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)
        
        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)



class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (Module): The encoder module to compute :math:`\mu` and
            :math:`\log\sigma^2`.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(VGAE, self).__init__(encoder, decoder)

    def reparametrize(self, mu, logstd):
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs):
        """"""
        self.__mu__, self.__logstd__ = self.encoder(*args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z

    def kl_loss(self, mu=None, logstd=None):
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (Tensor, optional): The latent space for :math:`\mu`. If set to
                :obj:`None`, uses the last computation of :math:`mu`.
                (default: :obj:`None`)
            logstd (Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`.(default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch
from torch.autograd.grad_mode import F
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges
from torch_geometric.nn import VGAE

import scipy.sparse as sp
import numpy as np
import networkx as nx

class SimuData():
    """Simulate graph data"""
    def __init__(self, p=0.5, n_node=10, n_graph=30):
        self.n_node = n_node
        self.n_graph = n_graph
        self.p = p

    def simu_adj_wgh(self):
        adj_list = []

        for i in range(self.n_graph):
            ## zero matrix
            A = torch.zeros(self.n_node, self.n_node)

            # first five nodes weights: uniform(0,1)A[:5,:5] = W
            W = torch.rand(5,5)

            ## symmetric
            i, j = torch.triu_indices(5, 5)
            W[i, j] = W.T[i, j]

            A[:5,:5] = W
            adj_list.append(A)  

        return adj_list

    def simu_adj_diag(self):
        adj_list = []

        for i in range(self.n_graph):
            A = torch.eye(self.n_node)
            adj_list.append(A)  

        return adj_list

    def simu_adj_m(self):
        """generating adjacency matrix"""
        adj_wgh = self.simu_adj_wgh()
        #adj_wgh = self.simu_adj_diag()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>=1-self.p] = 1
            adj[adj<1-self.p] = 0
            for i in range(adj.shape[0]):
                adj[i, i] = 0
            adj_m_list.append(adj)    
        return adj_m_list

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.simu_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)

        return dataset

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)


class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True) 
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=True)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)


transform = T.Compose([
            T.NormalizeFeatures(),
            T.RandomLinkSplit(num_val=0, num_test=0, is_undirected=True,
                            split_labels=True, add_negative_train_samples=False),])

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix


class LoadData():
    """Load graph data"""
    def __init__(self, file_path, samples, n_node=38):
        self.samples = samples
        self.file_path = file_path
        self.nSample = len(samples)
        self.n_node = n_node

    def get_adj_wgh(self):
        """generating adjacency matrix"""
        adj_orig_list =[]
        for sample in self.samples:
            f_name = self.file_path + ".".join([sample])
            adj   = np.asarray(pd.read_csv(f_name, index_col = 0, iterator = False))
            adj_orig_list.append(adj)    

        return adj_orig_list

    def get_adj_label(self):
        adj_m = self.get_adj_m()
        adj_label_list =[]
        
        for _, adj in enumerate(adj_m):
            adj_label = adj + sp.eye(adj.shape[0])
            adj_label = sparse_to_tuple(sp.coo_matrix(adj_label))
            #adj_label = sparse_to_tuple(adj_label)
            adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T), 
                            torch.FloatTensor(adj_label[1]), 
                            torch.Size(adj_label[2]))
            adj_label_list.append(adj_label)
        return adj_label_list

    def get_adj_norm(self):
        adj_m = self.get_adj_m()
        adj_norm_list =[]

        for _, adj in enumerate(adj_m):
            adj_norm = preprocess_graph(adj)
            adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T), 
                            torch.FloatTensor(adj_norm[1]), 
                            torch.Size(adj_norm[2]))
            adj_norm_list.append(adj_norm)

        return adj_norm_list

    def get_adj_m(self):
        adj_wgh = self.get_adj_wgh()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>0] = 1
            for i in range(38):
                adj[i, i] = 0
            for i in range(38):
                for j in range(38):
                    if adj[i, j] == 1:
                        adj[j, i] = 1
            adj_m_list.append(adj)    
        return adj_m_list

    def get_feature(self):
        """generating feature matrix X"""
        adj_wgh = self.get_adj_wgh()
        x_list = []
        for _, adj in enumerate(adj_wgh):
            x_feature  = adj
            x_feature  = csr_matrix(x_feature)
            x_feature  = sparse_to_tuple(x_feature)
            x_feature  = torch.sparse.FloatTensor(torch.LongTensor(x_feature[0].T), 
                            torch.FloatTensor(x_feature[1]), 
                            torch.Size(x_feature[2]))
            x_list.append(x_feature)
        return x_list

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)   

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.get_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)
        return dataset


def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    
    return sparse_to_tuple(adj_normalized)

from os import walk

def get_filename(mypath):
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        break
    return f

# %%
n_node = 10
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
simu_graph = SimuData(n_graph=30)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

out_channels = 10
num_features = n_node

model = VGAE(Encoder(num_features, out_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 10000

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 *model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))

# %%
out_channels = 2
n_node = 10
num_features = n_node

model = VGAE(Encoder(num_features, out_channels))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 1000

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 *model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))
# Out:
# 0tensor(17.0463, grad_fn=<DivBackward0>)
# 1tensor(17.5077, grad_fn=<DivBackward0>)
# 2tensor(18.0783, grad_fn=<DivBackward0>)
# 3tensor(17.8769, grad_fn=<DivBackward0>)
# 4tensor(17.4665, grad_fn=<DivBackward0>)
# 5tensor(17.1185, grad_fn=<DivBackward0>)
# 6tensor(17.1358, grad_fn=<DivBackward0>)
# 7tensor(18.3929, grad_fn=<DivBackward0>)
# 8tensor(16.4391, grad_fn=<DivBackward0>)
# 9tensor(17.9423, grad_fn=<DivBackward0>)
# 10tensor(17.4544, grad_fn=<DivBackward0>)
# 11tensor(16.8736, grad_fn=<DivBackward0>)
# 12tensor(19.4117, grad_fn=<DivBackward0>)
# 13tensor(18.1752, grad_fn=<DivBackward0>)
# 14tensor(16.1410, grad_fn=<DivBackward0>)
# 15tensor(16.9015, grad_fn=<DivBackward0>)
# 16tensor(18.0110, grad_fn=<DivBackward0>)
# 17tensor(18.5451, grad_fn=<DivBackward0>)
# 18tensor(17.3925, grad_fn=<DivBackward0>)
# 19tensor(15.8970, grad_fn=<DivBackward0>)
# 20tensor(18.0038, grad_fn=<DivBackward0>)
# 21tensor(17.1133, grad_fn=<DivBackward0>)
# 22tensor(17.5606, grad_fn=<DivBackward0>)
# 23tensor(16.9456, grad_fn=<DivBackward0>)
# 24tensor(17.1005, grad_fn=<DivBackward0>)
# 25tensor(16.6039, grad_fn=<DivBackward0>)
# 26tensor(17.7725, grad_fn=<DivBackward0>)
# 27tensor(17.6801, grad_fn=<DivBackward0>)
# 28tensor(17.3786, grad_fn=<DivBackward0>)
# 29tensor(15.9888, grad_fn=<DivBackward0>)
# 30tensor(15.9528, grad_fn=<DivBackward0>)
# 31tensor(16.7762, grad_fn=<DivBackward0>)
# 32tensor(18.1324, grad_fn=<DivBackward0>)
# 33tensor(17.4229, grad_fn=<DivBackward0>)
# 34tensor(16.9383, grad_fn=<DivBackward0>)
# 35tensor(18.5131, grad_fn=<DivBackward0>)
# 36tensor(17.2534, grad_fn=<DivBackward0>)
# 37tensor(17.7616, grad_fn=<DivBackward0>)
# 38tensor(16.6749, grad_fn=<DivBackward0>)
# 39tensor(19.2204, grad_fn=<DivBackward0>)
# 40tensor(17.0434, grad_fn=<DivBackward0>)
# 41tensor(17.6113, grad_fn=<DivBackward0>)
# 42tensor(17.4933, grad_fn=<DivBackward0>)
# 43tensor(14.7632, grad_fn=<DivBackward0>)
# 44tensor(17.4479, grad_fn=<DivBackward0>)
# 45tensor(16.4745, grad_fn=<DivBackward0>)
# 46tensor(16.7894, grad_fn=<DivBackward0>)
# 47tensor(16.2084, grad_fn=<DivBackward0>)
# 48tensor(16.9354, grad_fn=<DivBackward0>)
# 49tensor(15.7960, grad_fn=<DivBackward0>)
# 50tensor(16.4590, grad_fn=<DivBackward0>)
# 51tensor(16.5248, grad_fn=<DivBackward0>)
# 52tensor(17.1436, grad_fn=<DivBackward0>)
# 53tensor(16.7451, grad_fn=<DivBackward0>)
# 54tensor(15.2296, grad_fn=<DivBackward0>)
# 55tensor(15.8068, grad_fn=<DivBackward0>)
# 56tensor(17.3006, grad_fn=<DivBackward0>)
# 57tensor(17.7067, grad_fn=<DivBackward0>)
# 58tensor(16.7232, grad_fn=<DivBackward0>)
# 59tensor(15.9900, grad_fn=<DivBackward0>)
# 60tensor(17.5292, grad_fn=<DivBackward0>)
# 61tensor(17.3529, grad_fn=<DivBackward0>)
# 62tensor(16.1476, grad_fn=<DivBackward0>)
# 63tensor(16.0113, grad_fn=<DivBackward0>)
# 64tensor(17.1733, grad_fn=<DivBackward0>)
# 65tensor(17.0878, grad_fn=<DivBackward0>)
# 66tensor(16.3990, grad_fn=<DivBackward0>)
# 67tensor(16.5033, grad_fn=<DivBackward0>)
# 68tensor(17.0175, grad_fn=<DivBackward0>)
# 69tensor(16.9312, grad_fn=<DivBackward0>)
# 70tensor(15.9645, grad_fn=<DivBackward0>)
# 71tensor(16.6832, grad_fn=<DivBackward0>)
# 72tensor(16.4853, grad_fn=<DivBackward0>)
# 73tensor(15.5586, grad_fn=<DivBackward0>)
# 74tensor(16.7126, grad_fn=<DivBackward0>)
# 75tensor(14.8462, grad_fn=<DivBackward0>)
# 76tensor(16.0642, grad_fn=<DivBackward0>)
# 77tensor(17.4727, grad_fn=<DivBackward0>)
# 78tensor(15.8437, grad_fn=<DivBackward0>)
# 79tensor(16.4852, grad_fn=<DivBackward0>)
# 80tensor(16.3869, grad_fn=<DivBackward0>)
# 81tensor(15.6841, grad_fn=<DivBackward0>)
# 82tensor(16.4406, grad_fn=<DivBackward0>)
# 83tensor(16.7132, grad_fn=<DivBackward0>)
# 84tensor(17.5056, grad_fn=<DivBackward0>)
# 85tensor(15.7773, grad_fn=<DivBackward0>)
# 86tensor(16.5345, grad_fn=<DivBackward0>)
# 87tensor(15.3667, grad_fn=<DivBackward0>)
# 88tensor(15.0639, grad_fn=<DivBackward0>)
# 89tensor(15.1483, grad_fn=<DivBackward0>)
# 90tensor(15.9253, grad_fn=<DivBackward0>)
# 91tensor(16.2879, grad_fn=<DivBackward0>)
# 92tensor(15.7591, grad_fn=<DivBackward0>)
# 93tensor(16.9989, grad_fn=<DivBackward0>)
# 94tensor(15.2436, grad_fn=<DivBackward0>)
# 95tensor(16.2447, grad_fn=<DivBackward0>)
# 96tensor(16.5643, grad_fn=<DivBackward0>)
# 97tensor(16.0520, grad_fn=<DivBackward0>)
# 98tensor(15.2528, grad_fn=<DivBackward0>)
# 99tensor(16.5207, grad_fn=<DivBackward0>)
# 100tensor(15.5828, grad_fn=<DivBackward0>)
# 101tensor(16.3326, grad_fn=<DivBackward0>)
# 102tensor(15.2361, grad_fn=<DivBackward0>)
# 103tensor(16.7139, grad_fn=<DivBackward0>)
# 104tensor(15.8201, grad_fn=<DivBackward0>)
# 105tensor(14.5811, grad_fn=<DivBackward0>)
# 106tensor(15.6928, grad_fn=<DivBackward0>)
# 107tensor(15.6866, grad_fn=<DivBackward0>)
# 108tensor(16.3249, grad_fn=<DivBackward0>)
# 109tensor(15.5300, grad_fn=<DivBackward0>)
# 110tensor(15.6684, grad_fn=<DivBackward0>)
# 111tensor(17.0844, grad_fn=<DivBackward0>)
# 112tensor(16.0919, grad_fn=<DivBackward0>)
# 113tensor(15.3723, grad_fn=<DivBackward0>)
# 114tensor(15.8455, grad_fn=<DivBackward0>)
# 115tensor(15.3761, grad_fn=<DivBackward0>)
# 116tensor(15.3933, grad_fn=<DivBackward0>)
# 117tensor(15.5427, grad_fn=<DivBackward0>)
# 118tensor(15.4323, grad_fn=<DivBackward0>)
# 119tensor(14.8931, grad_fn=<DivBackward0>)
# 120tensor(16.7302, grad_fn=<DivBackward0>)
# 121tensor(15.1113, grad_fn=<DivBackward0>)
# 122tensor(16.1066, grad_fn=<DivBackward0>)
# 123tensor(15.0715, grad_fn=<DivBackward0>)
# 124tensor(16.2184, grad_fn=<DivBackward0>)
# 125tensor(15.4515, grad_fn=<DivBackward0>)
# 126tensor(15.3820, grad_fn=<DivBackward0>)
# 127tensor(14.9775, grad_fn=<DivBackward0>)
# 128tensor(15.2960, grad_fn=<DivBackward0>)
# 129tensor(14.6898, grad_fn=<DivBackward0>)
# 130tensor(15.4317, grad_fn=<DivBackward0>)
# 131tensor(15.5086, grad_fn=<DivBackward0>)
# 132tensor(14.6775, grad_fn=<DivBackward0>)
# 133tensor(15.4133, grad_fn=<DivBackward0>)
# 134tensor(15.9916, grad_fn=<DivBackward0>)
# 135tensor(15.6903, grad_fn=<DivBackward0>)
# 136tensor(15.6584, grad_fn=<DivBackward0>)
# 137tensor(15.3375, grad_fn=<DivBackward0>)
# 138tensor(15.6442, grad_fn=<DivBackward0>)
# 139tensor(14.0961, grad_fn=<DivBackward0>)
# 140tensor(15.7900, grad_fn=<DivBackward0>)
# 141tensor(15.6571, grad_fn=<DivBackward0>)
# 142tensor(15.8914, grad_fn=<DivBackward0>)
# 143tensor(15.2591, grad_fn=<DivBackward0>)
# 144tensor(15.1097, grad_fn=<DivBackward0>)
# 145tensor(15.2587, grad_fn=<DivBackward0>)
# 146tensor(14.4034, grad_fn=<DivBackward0>)
# 147tensor(15.6043, grad_fn=<DivBackward0>)
# 148tensor(15.6077, grad_fn=<DivBackward0>)
# 149tensor(15.7173, grad_fn=<DivBackward0>)
# 150tensor(15.3020, grad_fn=<DivBackward0>)
# 151tensor(16.6018, grad_fn=<DivBackward0>)
# 152tensor(15.2976, grad_fn=<DivBackward0>)
# 153tensor(15.6710, grad_fn=<DivBackward0>)
# 154tensor(15.6882, grad_fn=<DivBackward0>)
# 155tensor(15.4048, grad_fn=<DivBackward0>)
# 156tensor(14.6879, grad_fn=<DivBackward0>)
# 157tensor(14.8656, grad_fn=<DivBackward0>)
# 158tensor(15.0476, grad_fn=<DivBackward0>)
# 159tensor(15.1377, grad_fn=<DivBackward0>)
# 160tensor(14.3065, grad_fn=<DivBackward0>)
# 161tensor(15.4782, grad_fn=<DivBackward0>)
# 162tensor(15.0491, grad_fn=<DivBackward0>)
# 163tensor(15.0776, grad_fn=<DivBackward0>)
# 164tensor(15.4742, grad_fn=<DivBackward0>)
# 165tensor(14.8379, grad_fn=<DivBackward0>)
# 166tensor(15.0219, grad_fn=<DivBackward0>)
# 167tensor(14.8316, grad_fn=<DivBackward0>)
# 168tensor(15.7848, grad_fn=<DivBackward0>)
# 169tensor(15.0020, grad_fn=<DivBackward0>)
# 170tensor(15.2958, grad_fn=<DivBackward0>)
# 171tensor(14.4000, grad_fn=<DivBackward0>)
# 172tensor(14.4158, grad_fn=<DivBackward0>)
# 173tensor(14.2902, grad_fn=<DivBackward0>)
# 174tensor(14.2511, grad_fn=<DivBackward0>)
# 175tensor(15.2128, grad_fn=<DivBackward0>)
# 176tensor(14.4949, grad_fn=<DivBackward0>)
# 177tensor(15.1494, grad_fn=<DivBackward0>)
# 178tensor(15.6839, grad_fn=<DivBackward0>)
# 179tensor(14.2844, grad_fn=<DivBackward0>)
# 180tensor(15.8866, grad_fn=<DivBackward0>)
# 181tensor(14.7675, grad_fn=<DivBackward0>)
# 182tensor(14.5432, grad_fn=<DivBackward0>)
# 183tensor(15.0576, grad_fn=<DivBackward0>)
# 184tensor(15.6011, grad_fn=<DivBackward0>)
# 185tensor(14.9414, grad_fn=<DivBackward0>)
# 186tensor(15.9802, grad_fn=<DivBackward0>)
# 187tensor(14.7437, grad_fn=<DivBackward0>)
# 188tensor(14.1871, grad_fn=<DivBackward0>)
# 189tensor(14.5260, grad_fn=<DivBackward0>)
# 190tensor(14.5349, grad_fn=<DivBackward0>)
# 191tensor(14.4933, grad_fn=<DivBackward0>)
# 192tensor(14.3175, grad_fn=<DivBackward0>)
# 193tensor(14.6364, grad_fn=<DivBackward0>)
# 194tensor(14.4204, grad_fn=<DivBackward0>)
# 195tensor(15.2118, grad_fn=<DivBackward0>)
# 196tensor(14.4729, grad_fn=<DivBackward0>)
# 197tensor(15.4208, grad_fn=<DivBackward0>)
# 198tensor(13.8861, grad_fn=<DivBackward0>)
# 199tensor(14.6556, grad_fn=<DivBackward0>)
# 200tensor(14.8875, grad_fn=<DivBackward0>)
# 201tensor(14.2051, grad_fn=<DivBackward0>)
# 202tensor(14.6732, grad_fn=<DivBackward0>)
# 203tensor(15.0264, grad_fn=<DivBackward0>)
# 204tensor(14.6267, grad_fn=<DivBackward0>)
# 205tensor(15.2004, grad_fn=<DivBackward0>)
# 206tensor(14.7848, grad_fn=<DivBackward0>)
# 207tensor(14.5511, grad_fn=<DivBackward0>)
# 208tensor(14.7858, grad_fn=<DivBackward0>)
# 209tensor(14.6880, grad_fn=<DivBackward0>)
# 210tensor(15.2423, grad_fn=<DivBackward0>)
# 211tensor(14.7845, grad_fn=<DivBackward0>)
# 212tensor(15.1137, grad_fn=<DivBackward0>)
# 213tensor(14.2890, grad_fn=<DivBackward0>)
# 214tensor(14.1414, grad_fn=<DivBackward0>)
# 215tensor(14.2724, grad_fn=<DivBackward0>)
# 216tensor(14.8752, grad_fn=<DivBackward0>)
# 217tensor(14.0412, grad_fn=<DivBackward0>)
# 218tensor(14.3451, grad_fn=<DivBackward0>)
# 219tensor(13.6155, grad_fn=<DivBackward0>)
# 220tensor(13.7862, grad_fn=<DivBackward0>)
# 221tensor(14.3818, grad_fn=<DivBackward0>)
# 222tensor(14.3973, grad_fn=<DivBackward0>)
# 223tensor(14.6738, grad_fn=<DivBackward0>)
# 224tensor(14.4738, grad_fn=<DivBackward0>)
# 225tensor(14.1268, grad_fn=<DivBackward0>)
# 226tensor(14.0660, grad_fn=<DivBackward0>)
# 227tensor(13.7940, grad_fn=<DivBackward0>)
# 228tensor(14.5759, grad_fn=<DivBackward0>)
# 229tensor(14.4624, grad_fn=<DivBackward0>)
# 230tensor(14.7849, grad_fn=<DivBackward0>)
# 231tensor(13.7030, grad_fn=<DivBackward0>)
# 232tensor(14.8988, grad_fn=<DivBackward0>)
# 233tensor(14.6768, grad_fn=<DivBackward0>)
# 234tensor(14.2009, grad_fn=<DivBackward0>)
# 235tensor(13.8503, grad_fn=<DivBackward0>)
# 236tensor(14.2089, grad_fn=<DivBackward0>)
# 237tensor(13.2800, grad_fn=<DivBackward0>)
# 238tensor(13.5845, grad_fn=<DivBackward0>)
# 239tensor(14.8180, grad_fn=<DivBackward0>)
# 240tensor(14.4506, grad_fn=<DivBackward0>)
# 241tensor(14.1245, grad_fn=<DivBackward0>)
# 242tensor(14.2291, grad_fn=<DivBackward0>)
# 243tensor(14.2466, grad_fn=<DivBackward0>)
# 244tensor(13.4609, grad_fn=<DivBackward0>)
# 245tensor(13.6808, grad_fn=<DivBackward0>)
# 246tensor(14.2498, grad_fn=<DivBackward0>)
# 247tensor(13.7373, grad_fn=<DivBackward0>)
# 248tensor(14.1284, grad_fn=<DivBackward0>)
# 249tensor(14.1924, grad_fn=<DivBackward0>)
# 250tensor(14.3435, grad_fn=<DivBackward0>)
# 251tensor(14.4337, grad_fn=<DivBackward0>)
# 252tensor(14.1019, grad_fn=<DivBackward0>)
# 253tensor(14.0354, grad_fn=<DivBackward0>)
# 254tensor(14.1473, grad_fn=<DivBackward0>)
# 255tensor(14.4964, grad_fn=<DivBackward0>)
# 256tensor(14.1346, grad_fn=<DivBackward0>)
# 257tensor(13.7281, grad_fn=<DivBackward0>)
# 258tensor(14.2284, grad_fn=<DivBackward0>)
# 259tensor(13.6895, grad_fn=<DivBackward0>)
# 260tensor(13.8619, grad_fn=<DivBackward0>)
# 261tensor(13.8834, grad_fn=<DivBackward0>)
# 262tensor(13.5832, grad_fn=<DivBackward0>)
# 263tensor(12.8067, grad_fn=<DivBackward0>)
# 264tensor(13.8288, grad_fn=<DivBackward0>)
# 265tensor(14.5103, grad_fn=<DivBackward0>)
# 266tensor(14.4912, grad_fn=<DivBackward0>)
# 267tensor(14.0830, grad_fn=<DivBackward0>)
# 268tensor(13.8602, grad_fn=<DivBackward0>)
# 269tensor(14.4580, grad_fn=<DivBackward0>)
# 270tensor(13.3489, grad_fn=<DivBackward0>)
# 271tensor(13.0193, grad_fn=<DivBackward0>)
# 272tensor(14.1062, grad_fn=<DivBackward0>)
# 273tensor(13.4051, grad_fn=<DivBackward0>)
# 274tensor(13.9815, grad_fn=<DivBackward0>)
# 275tensor(13.2031, grad_fn=<DivBackward0>)
# 276tensor(13.6547, grad_fn=<DivBackward0>)
# 277tensor(13.4225, grad_fn=<DivBackward0>)
# 278tensor(14.0166, grad_fn=<DivBackward0>)
# 279tensor(13.9573, grad_fn=<DivBackward0>)
# 280tensor(14.3947, grad_fn=<DivBackward0>)
# 281tensor(13.5812, grad_fn=<DivBackward0>)
# 282tensor(13.3075, grad_fn=<DivBackward0>)
# 283tensor(13.4306, grad_fn=<DivBackward0>)
# 284tensor(13.1693, grad_fn=<DivBackward0>)
# 285tensor(14.0144, grad_fn=<DivBackward0>)
# 286tensor(12.9680, grad_fn=<DivBackward0>)
# 287tensor(13.3817, grad_fn=<DivBackward0>)
# 288tensor(13.2603, grad_fn=<DivBackward0>)
# 289tensor(13.3551, grad_fn=<DivBackward0>)
# 290tensor(12.8614, grad_fn=<DivBackward0>)
# 291tensor(13.3757, grad_fn=<DivBackward0>)
# 292tensor(13.0125, grad_fn=<DivBackward0>)
# 293tensor(12.8881, grad_fn=<DivBackward0>)
# 294tensor(13.0570, grad_fn=<DivBackward0>)
# 295tensor(13.3107, grad_fn=<DivBackward0>)
# 296tensor(13.3226, grad_fn=<DivBackward0>)
# 297tensor(13.1952, grad_fn=<DivBackward0>)
# 298tensor(13.3693, grad_fn=<DivBackward0>)
# 299tensor(13.1930, grad_fn=<DivBackward0>)
# 300tensor(13.4765, grad_fn=<DivBackward0>)
# 301tensor(13.9766, grad_fn=<DivBackward0>)
# 302tensor(12.9433, grad_fn=<DivBackward0>)
# 303tensor(13.6924, grad_fn=<DivBackward0>)
# 304tensor(13.4549, grad_fn=<DivBackward0>)
# 305tensor(12.6948, grad_fn=<DivBackward0>)
# 306tensor(12.8447, grad_fn=<DivBackward0>)
# 307tensor(13.0328, grad_fn=<DivBackward0>)
# 308tensor(12.7740, grad_fn=<DivBackward0>)
# 309tensor(13.1329, grad_fn=<DivBackward0>)
# 310tensor(12.7781, grad_fn=<DivBackward0>)
# 311tensor(12.5370, grad_fn=<DivBackward0>)
# 312tensor(13.0819, grad_fn=<DivBackward0>)
# 313tensor(13.2727, grad_fn=<DivBackward0>)
# 314tensor(12.9761, grad_fn=<DivBackward0>)
# 315tensor(12.9884, grad_fn=<DivBackward0>)
# 316tensor(12.3442, grad_fn=<DivBackward0>)
# 317tensor(12.2255, grad_fn=<DivBackward0>)
# 318tensor(13.1288, grad_fn=<DivBackward0>)
# 319tensor(12.9476, grad_fn=<DivBackward0>)
# 320tensor(13.5722, grad_fn=<DivBackward0>)
# 321tensor(12.7921, grad_fn=<DivBackward0>)
# 322tensor(12.4535, grad_fn=<DivBackward0>)
# 323tensor(12.3211, grad_fn=<DivBackward0>)
# 324tensor(12.8073, grad_fn=<DivBackward0>)
# 325tensor(13.7338, grad_fn=<DivBackward0>)
# 326tensor(13.2208, grad_fn=<DivBackward0>)
# 327tensor(12.7996, grad_fn=<DivBackward0>)
# 328tensor(12.5308, grad_fn=<DivBackward0>)
# 329tensor(12.3005, grad_fn=<DivBackward0>)
# 330tensor(12.5978, grad_fn=<DivBackward0>)
# 331tensor(13.0164, grad_fn=<DivBackward0>)
# 332tensor(12.8644, grad_fn=<DivBackward0>)
# 333tensor(12.3773, grad_fn=<DivBackward0>)
# 334tensor(13.0683, grad_fn=<DivBackward0>)
# 335tensor(12.6745, grad_fn=<DivBackward0>)
# 336tensor(11.5027, grad_fn=<DivBackward0>)
# 337tensor(11.9235, grad_fn=<DivBackward0>)
# 338tensor(12.3331, grad_fn=<DivBackward0>)
# 339tensor(12.5158, grad_fn=<DivBackward0>)
# 340tensor(12.5841, grad_fn=<DivBackward0>)
# 341tensor(12.2912, grad_fn=<DivBackward0>)
# 342tensor(12.0822, grad_fn=<DivBackward0>)
# 343tensor(12.3505, grad_fn=<DivBackward0>)
# 344tensor(11.9332, grad_fn=<DivBackward0>)
# 345tensor(12.2710, grad_fn=<DivBackward0>)
# 346tensor(12.1164, grad_fn=<DivBackward0>)
# 347tensor(11.6874, grad_fn=<DivBackward0>)
# 348tensor(11.7064, grad_fn=<DivBackward0>)
# 349tensor(12.5838, grad_fn=<DivBackward0>)
# 350tensor(12.1295, grad_fn=<DivBackward0>)
# 351tensor(11.8229, grad_fn=<DivBackward0>)
# 352tensor(12.1668, grad_fn=<DivBackward0>)
# 353tensor(12.1111, grad_fn=<DivBackward0>)
# 354tensor(11.7293, grad_fn=<DivBackward0>)
# 355tensor(12.0558, grad_fn=<DivBackward0>)
# 356tensor(12.7346, grad_fn=<DivBackward0>)
# 357tensor(12.6479, grad_fn=<DivBackward0>)
# 358tensor(11.7873, grad_fn=<DivBackward0>)
# 359tensor(12.2688, grad_fn=<DivBackward0>)
# 360tensor(11.7121, grad_fn=<DivBackward0>)
# 361tensor(11.8291, grad_fn=<DivBackward0>)
# 362tensor(12.0552, grad_fn=<DivBackward0>)
# 363tensor(12.5452, grad_fn=<DivBackward0>)
# 364tensor(11.6916, grad_fn=<DivBackward0>)
# 365tensor(12.3661, grad_fn=<DivBackward0>)
# 366tensor(11.8118, grad_fn=<DivBackward0>)
# 367tensor(11.7058, grad_fn=<DivBackward0>)
# 368tensor(11.8778, grad_fn=<DivBackward0>)
# 369tensor(11.9396, grad_fn=<DivBackward0>)
# 370tensor(11.9878, grad_fn=<DivBackward0>)
# 371tensor(11.4527, grad_fn=<DivBackward0>)
# 372tensor(11.5158, grad_fn=<DivBackward0>)
# 373tensor(11.4442, grad_fn=<DivBackward0>)
# 374tensor(11.9478, grad_fn=<DivBackward0>)
# 375tensor(11.5313, grad_fn=<DivBackward0>)
# 376tensor(11.8226, grad_fn=<DivBackward0>)
# 377tensor(11.7680, grad_fn=<DivBackward0>)
# 378tensor(12.2493, grad_fn=<DivBackward0>)
# 379tensor(11.6505, grad_fn=<DivBackward0>)
# 380tensor(12.0638, grad_fn=<DivBackward0>)
# 381tensor(11.3022, grad_fn=<DivBackward0>)
# 382tensor(11.6527, grad_fn=<DivBackward0>)
# 383tensor(11.3365, grad_fn=<DivBackward0>)
# 384tensor(11.3697, grad_fn=<DivBackward0>)
# 385tensor(11.4431, grad_fn=<DivBackward0>)
# 386tensor(11.5690, grad_fn=<DivBackward0>)
# 387tensor(11.3974, grad_fn=<DivBackward0>)
# 388tensor(11.7488, grad_fn=<DivBackward0>)
# 389tensor(11.7824, grad_fn=<DivBackward0>)
# 390tensor(11.4635, grad_fn=<DivBackward0>)
# 391tensor(11.5912, grad_fn=<DivBackward0>)
# 392tensor(11.6608, grad_fn=<DivBackward0>)
# 393tensor(11.5053, grad_fn=<DivBackward0>)
# 394tensor(11.5680, grad_fn=<DivBackward0>)
# 395tensor(11.0344, grad_fn=<DivBackward0>)
# 396tensor(11.1699, grad_fn=<DivBackward0>)
# 397tensor(11.7796, grad_fn=<DivBackward0>)
# 398tensor(11.2610, grad_fn=<DivBackward0>)
# 399tensor(10.9055, grad_fn=<DivBackward0>)
# 400tensor(11.8290, grad_fn=<DivBackward0>)
# 401tensor(11.0159, grad_fn=<DivBackward0>)
# 402tensor(11.5412, grad_fn=<DivBackward0>)
# 403tensor(11.3615, grad_fn=<DivBackward0>)
# 404tensor(11.2416, grad_fn=<DivBackward0>)
# 405tensor(11.4063, grad_fn=<DivBackward0>)
# 406tensor(11.6888, grad_fn=<DivBackward0>)
# 407tensor(11.6346, grad_fn=<DivBackward0>)
# 408tensor(11.5680, grad_fn=<DivBackward0>)
# 409tensor(11.1706, grad_fn=<DivBackward0>)
# 410tensor(11.5120, grad_fn=<DivBackward0>)
# 411tensor(11.4974, grad_fn=<DivBackward0>)
# 412tensor(12.2696, grad_fn=<DivBackward0>)
# 413tensor(11.7695, grad_fn=<DivBackward0>)
# 414tensor(10.7860, grad_fn=<DivBackward0>)
# 415tensor(10.9674, grad_fn=<DivBackward0>)
# 416tensor(11.1926, grad_fn=<DivBackward0>)
# 417tensor(11.1606, grad_fn=<DivBackward0>)
# 418tensor(10.9547, grad_fn=<DivBackward0>)
# 419tensor(11.8492, grad_fn=<DivBackward0>)
# 420tensor(11.7697, grad_fn=<DivBackward0>)
# 421tensor(11.3762, grad_fn=<DivBackward0>)
# 422tensor(11.1208, grad_fn=<DivBackward0>)
# 423tensor(11.0199, grad_fn=<DivBackward0>)
# 424tensor(11.0500, grad_fn=<DivBackward0>)
# 425tensor(10.6651, grad_fn=<DivBackward0>)
# 426tensor(11.3896, grad_fn=<DivBackward0>)
# 427tensor(11.2965, grad_fn=<DivBackward0>)
# 428tensor(11.1315, grad_fn=<DivBackward0>)
# 429tensor(10.8905, grad_fn=<DivBackward0>)
# 430tensor(11.1619, grad_fn=<DivBackward0>)
# 431tensor(11.0251, grad_fn=<DivBackward0>)
# 432tensor(11.8666, grad_fn=<DivBackward0>)
# 433tensor(11.5201, grad_fn=<DivBackward0>)
# 434tensor(11.0365, grad_fn=<DivBackward0>)
# 435tensor(11.1699, grad_fn=<DivBackward0>)
# 436tensor(9.8175, grad_fn=<DivBackward0>)
# 437tensor(11.0819, grad_fn=<DivBackward0>)
# 438tensor(11.1178, grad_fn=<DivBackward0>)
# 439tensor(10.8592, grad_fn=<DivBackward0>)
# 440tensor(11.1259, grad_fn=<DivBackward0>)
# 441tensor(11.0217, grad_fn=<DivBackward0>)
# 442tensor(10.0294, grad_fn=<DivBackward0>)
# 443tensor(10.9523, grad_fn=<DivBackward0>)
# 444tensor(10.8463, grad_fn=<DivBackward0>)
# 445tensor(10.4805, grad_fn=<DivBackward0>)
# 446tensor(11.0071, grad_fn=<DivBackward0>)
# 447tensor(10.7368, grad_fn=<DivBackward0>)
# 448tensor(10.9055, grad_fn=<DivBackward0>)
# 449tensor(10.8756, grad_fn=<DivBackward0>)
# 450tensor(10.6942, grad_fn=<DivBackward0>)
# 451tensor(11.1748, grad_fn=<DivBackward0>)
# 452tensor(11.0536, grad_fn=<DivBackward0>)
# 453tensor(10.7206, grad_fn=<DivBackward0>)
# 454tensor(10.7518, grad_fn=<DivBackward0>)
# 455tensor(11.1564, grad_fn=<DivBackward0>)
# 456tensor(10.6270, grad_fn=<DivBackward0>)
# 457tensor(10.6500, grad_fn=<DivBackward0>)
# 458tensor(10.4344, grad_fn=<DivBackward0>)
# 459tensor(11.0089, grad_fn=<DivBackward0>)
# 460tensor(10.8027, grad_fn=<DivBackward0>)
# 461tensor(10.8125, grad_fn=<DivBackward0>)
# 462tensor(11.6191, grad_fn=<DivBackward0>)
# 463tensor(10.4768, grad_fn=<DivBackward0>)
# 464tensor(10.4459, grad_fn=<DivBackward0>)
# 465tensor(10.9481, grad_fn=<DivBackward0>)
# 466tensor(11.4170, grad_fn=<DivBackward0>)
# 467tensor(10.4385, grad_fn=<DivBackward0>)
# 468tensor(10.7816, grad_fn=<DivBackward0>)
# 469tensor(10.1684, grad_fn=<DivBackward0>)
# 470tensor(11.3014, grad_fn=<DivBackward0>)
# 471tensor(11.3047, grad_fn=<DivBackward0>)
# 472tensor(11.3544, grad_fn=<DivBackward0>)
# 473tensor(11.0635, grad_fn=<DivBackward0>)
# 474tensor(10.7174, grad_fn=<DivBackward0>)
# 475tensor(10.3191, grad_fn=<DivBackward0>)
# 476tensor(10.6509, grad_fn=<DivBackward0>)
# 477tensor(10.5880, grad_fn=<DivBackward0>)
# 478tensor(10.7313, grad_fn=<DivBackward0>)
# 479tensor(10.9163, grad_fn=<DivBackward0>)
# 480tensor(10.5140, grad_fn=<DivBackward0>)
# 481tensor(11.0229, grad_fn=<DivBackward0>)
# 482tensor(10.5669, grad_fn=<DivBackward0>)
# 483tensor(9.7130, grad_fn=<DivBackward0>)
# 484tensor(10.2914, grad_fn=<DivBackward0>)
# 485tensor(10.9056, grad_fn=<DivBackward0>)
# 486tensor(10.3428, grad_fn=<DivBackward0>)
# 487tensor(10.7520, grad_fn=<DivBackward0>)
# 488tensor(11.0377, grad_fn=<DivBackward0>)
# 489tensor(11.2790, grad_fn=<DivBackward0>)
# 490tensor(10.7855, grad_fn=<DivBackward0>)
# 491tensor(10.4440, grad_fn=<DivBackward0>)
# 492tensor(10.2610, grad_fn=<DivBackward0>)
# 493tensor(10.1700, grad_fn=<DivBackward0>)
# 494tensor(9.9407, grad_fn=<DivBackward0>)
# 495tensor(11.1576, grad_fn=<DivBackward0>)
# 496tensor(10.4969, grad_fn=<DivBackward0>)
# 497tensor(10.0783, grad_fn=<DivBackward0>)
# 498tensor(11.2272, grad_fn=<DivBackward0>)
# 499tensor(10.4410, grad_fn=<DivBackward0>)
# 500tensor(11.3684, grad_fn=<DivBackward0>)
# 501tensor(9.4068, grad_fn=<DivBackward0>)
# 502tensor(9.7677, grad_fn=<DivBackward0>)
# 503tensor(10.8214, grad_fn=<DivBackward0>)
# 504tensor(10.5470, grad_fn=<DivBackward0>)
# 505tensor(10.4913, grad_fn=<DivBackward0>)
# 506tensor(11.0724, grad_fn=<DivBackward0>)
# 507tensor(10.8846, grad_fn=<DivBackward0>)
# 508tensor(10.7272, grad_fn=<DivBackward0>)
# 509tensor(10.4516, grad_fn=<DivBackward0>)
# 510tensor(10.7082, grad_fn=<DivBackward0>)
# 511tensor(10.6580, grad_fn=<DivBackward0>)
# 512tensor(10.2492, grad_fn=<DivBackward0>)
# 513tensor(9.7145, grad_fn=<DivBackward0>)
# 514tensor(10.1884, grad_fn=<DivBackward0>)
# 515tensor(10.8756, grad_fn=<DivBackward0>)
# 516tensor(11.0610, grad_fn=<DivBackward0>)
# 517tensor(10.4352, grad_fn=<DivBackward0>)
# 518tensor(11.4258, grad_fn=<DivBackward0>)
# 519tensor(10.1930, grad_fn=<DivBackward0>)
# 520tensor(11.4628, grad_fn=<DivBackward0>)
# 521tensor(10.6197, grad_fn=<DivBackward0>)
# 522tensor(10.3612, grad_fn=<DivBackward0>)
# 523tensor(9.6798, grad_fn=<DivBackward0>)
# 524tensor(10.6095, grad_fn=<DivBackward0>)
# 525tensor(10.3786, grad_fn=<DivBackward0>)
# 526tensor(10.4846, grad_fn=<DivBackward0>)
# 527tensor(9.8809, grad_fn=<DivBackward0>)
# 528tensor(10.1053, grad_fn=<DivBackward0>)
# 529tensor(10.5178, grad_fn=<DivBackward0>)
# 530tensor(10.7223, grad_fn=<DivBackward0>)
# 531tensor(10.2712, grad_fn=<DivBackward0>)
# 532tensor(9.8851, grad_fn=<DivBackward0>)
# 533tensor(10.4608, grad_fn=<DivBackward0>)
# 534tensor(10.4992, grad_fn=<DivBackward0>)
# 535tensor(11.1497, grad_fn=<DivBackward0>)
# 536tensor(10.6425, grad_fn=<DivBackward0>)
# 537tensor(10.7866, grad_fn=<DivBackward0>)
# 538tensor(10.1462, grad_fn=<DivBackward0>)
# 539tensor(10.9623, grad_fn=<DivBackward0>)
# 540tensor(10.6964, grad_fn=<DivBackward0>)
# 541tensor(11.0227, grad_fn=<DivBackward0>)
# 542tensor(10.0224, grad_fn=<DivBackward0>)
# 543tensor(10.3881, grad_fn=<DivBackward0>)
# 544tensor(10.6380, grad_fn=<DivBackward0>)
# 545tensor(10.4502, grad_fn=<DivBackward0>)
# 546tensor(10.9704, grad_fn=<DivBackward0>)
# 547tensor(10.1060, grad_fn=<DivBackward0>)
# 548tensor(10.4439, grad_fn=<DivBackward0>)
# 549tensor(10.4074, grad_fn=<DivBackward0>)
# 550tensor(10.3492, grad_fn=<DivBackward0>)
# 551tensor(11.0644, grad_fn=<DivBackward0>)
# 552tensor(10.2425, grad_fn=<DivBackward0>)
# 553tensor(10.3262, grad_fn=<DivBackward0>)
# 554tensor(10.3530, grad_fn=<DivBackward0>)
# 555tensor(9.9718, grad_fn=<DivBackward0>)
# 556tensor(10.1609, grad_fn=<DivBackward0>)
# 557tensor(10.2729, grad_fn=<DivBackward0>)
# 558tensor(10.3524, grad_fn=<DivBackward0>)
# 559tensor(9.5207, grad_fn=<DivBackward0>)
# 560tensor(10.2638, grad_fn=<DivBackward0>)
# 561tensor(10.8922, grad_fn=<DivBackward0>)
# 562tensor(10.6861, grad_fn=<DivBackward0>)
# 563tensor(9.8111, grad_fn=<DivBackward0>)
# 564tensor(10.6714, grad_fn=<DivBackward0>)
# 565tensor(10.2330, grad_fn=<DivBackward0>)
# 566tensor(9.5521, grad_fn=<DivBackward0>)
# 567tensor(10.4224, grad_fn=<DivBackward0>)
# 568tensor(10.1790, grad_fn=<DivBackward0>)
# 569tensor(10.0135, grad_fn=<DivBackward0>)
# 570tensor(10.2792, grad_fn=<DivBackward0>)
# 571tensor(10.0709, grad_fn=<DivBackward0>)
# 572tensor(9.9566, grad_fn=<DivBackward0>)
# 573tensor(9.7987, grad_fn=<DivBackward0>)
# 574tensor(10.2043, grad_fn=<DivBackward0>)
# 575tensor(10.2255, grad_fn=<DivBackward0>)
# 576tensor(10.4067, grad_fn=<DivBackward0>)
# 577tensor(10.2050, grad_fn=<DivBackward0>)
# 578tensor(10.3609, grad_fn=<DivBackward0>)
# 579tensor(9.9539, grad_fn=<DivBackward0>)
# 580tensor(11.0644, grad_fn=<DivBackward0>)
# 581tensor(9.8712, grad_fn=<DivBackward0>)
# 582tensor(10.1913, grad_fn=<DivBackward0>)
# 583tensor(10.5232, grad_fn=<DivBackward0>)
# 584tensor(9.7628, grad_fn=<DivBackward0>)
# 585tensor(9.8689, grad_fn=<DivBackward0>)
# 586tensor(10.4399, grad_fn=<DivBackward0>)
# 587tensor(10.0914, grad_fn=<DivBackward0>)
# 588tensor(10.0111, grad_fn=<DivBackward0>)
# 589tensor(9.8524, grad_fn=<DivBackward0>)
# 590tensor(10.2149, grad_fn=<DivBackward0>)
# 591tensor(9.8882, grad_fn=<DivBackward0>)
# 592tensor(9.9784, grad_fn=<DivBackward0>)
# 593tensor(9.8953, grad_fn=<DivBackward0>)
# 594tensor(10.2281, grad_fn=<DivBackward0>)
# 595tensor(10.2848, grad_fn=<DivBackward0>)
# 596tensor(10.0319, grad_fn=<DivBackward0>)
# 597tensor(9.5699, grad_fn=<DivBackward0>)
# 598tensor(10.1681, grad_fn=<DivBackward0>)
# 599tensor(10.7704, grad_fn=<DivBackward0>)
# 600tensor(10.0774, grad_fn=<DivBackward0>)
# 601tensor(9.9801, grad_fn=<DivBackward0>)
# 602tensor(10.5404, grad_fn=<DivBackward0>)
# 603tensor(10.2161, grad_fn=<DivBackward0>)
# 604tensor(10.1635, grad_fn=<DivBackward0>)
# 605tensor(10.4858, grad_fn=<DivBackward0>)
# 606tensor(10.5986, grad_fn=<DivBackward0>)
# 607tensor(11.3150, grad_fn=<DivBackward0>)
# 608tensor(10.2587, grad_fn=<DivBackward0>)
# 609tensor(9.7262, grad_fn=<DivBackward0>)
# 610tensor(9.9645, grad_fn=<DivBackward0>)
# 611tensor(10.9519, grad_fn=<DivBackward0>)
# 612tensor(10.0129, grad_fn=<DivBackward0>)
# 613tensor(10.1567, grad_fn=<DivBackward0>)
# 614tensor(10.2749, grad_fn=<DivBackward0>)
# 615tensor(10.3236, grad_fn=<DivBackward0>)
# 616tensor(9.6799, grad_fn=<DivBackward0>)
# 617tensor(10.2412, grad_fn=<DivBackward0>)
# 618tensor(9.3591, grad_fn=<DivBackward0>)
# 619tensor(10.8406, grad_fn=<DivBackward0>)
# 620tensor(9.8753, grad_fn=<DivBackward0>)
# 621tensor(9.8679, grad_fn=<DivBackward0>)
# 622tensor(10.2559, grad_fn=<DivBackward0>)
# 623tensor(9.7556, grad_fn=<DivBackward0>)
# 624tensor(10.0116, grad_fn=<DivBackward0>)
# 625tensor(10.5120, grad_fn=<DivBackward0>)
# 626tensor(9.9540, grad_fn=<DivBackward0>)
# 627tensor(10.0364, grad_fn=<DivBackward0>)
# 628tensor(10.9276, grad_fn=<DivBackward0>)
# 629tensor(9.7996, grad_fn=<DivBackward0>)
# 630tensor(10.1160, grad_fn=<DivBackward0>)
# 631tensor(9.7031, grad_fn=<DivBackward0>)
# 632tensor(9.6577, grad_fn=<DivBackward0>)
# 633tensor(10.0055, grad_fn=<DivBackward0>)
# 634tensor(10.1815, grad_fn=<DivBackward0>)
# 635tensor(9.3628, grad_fn=<DivBackward0>)
# 636tensor(9.6528, grad_fn=<DivBackward0>)
# 637tensor(9.4968, grad_fn=<DivBackward0>)
# 638tensor(10.5153, grad_fn=<DivBackward0>)
# 639tensor(9.9094, grad_fn=<DivBackward0>)
# 640tensor(10.3614, grad_fn=<DivBackward0>)
# 641tensor(9.6344, grad_fn=<DivBackward0>)
# 642tensor(9.9897, grad_fn=<DivBackward0>)
# 643tensor(9.0734, grad_fn=<DivBackward0>)
# 644tensor(9.7168, grad_fn=<DivBackward0>)
# 645tensor(9.8806, grad_fn=<DivBackward0>)
# 646tensor(9.7982, grad_fn=<DivBackward0>)
# 647tensor(10.3872, grad_fn=<DivBackward0>)
# 648tensor(10.5055, grad_fn=<DivBackward0>)
# 649tensor(10.0825, grad_fn=<DivBackward0>)
# 650tensor(10.2436, grad_fn=<DivBackward0>)
# 651tensor(9.5177, grad_fn=<DivBackward0>)
# 652tensor(9.5699, grad_fn=<DivBackward0>)
# 653tensor(10.2726, grad_fn=<DivBackward0>)
# 654tensor(10.0622, grad_fn=<DivBackward0>)
# 655tensor(10.3122, grad_fn=<DivBackward0>)
# 656tensor(9.7543, grad_fn=<DivBackward0>)
# 657tensor(9.3901, grad_fn=<DivBackward0>)
# 658tensor(9.6761, grad_fn=<DivBackward0>)
# 659tensor(10.3361, grad_fn=<DivBackward0>)
# 660tensor(9.4668, grad_fn=<DivBackward0>)
# 661tensor(9.4675, grad_fn=<DivBackward0>)
# 662tensor(10.3978, grad_fn=<DivBackward0>)
# 663tensor(9.1623, grad_fn=<DivBackward0>)
# 664tensor(10.6848, grad_fn=<DivBackward0>)
# 665tensor(10.1441, grad_fn=<DivBackward0>)
# 666tensor(10.1477, grad_fn=<DivBackward0>)
# 667tensor(10.3477, grad_fn=<DivBackward0>)
# 668tensor(9.5484, grad_fn=<DivBackward0>)
# 669tensor(10.4360, grad_fn=<DivBackward0>)
# 670tensor(10.3513, grad_fn=<DivBackward0>)
# 671tensor(9.7224, grad_fn=<DivBackward0>)
# 672tensor(10.0617, grad_fn=<DivBackward0>)
# 673tensor(10.4845, grad_fn=<DivBackward0>)
# 674tensor(10.0493, grad_fn=<DivBackward0>)
# 675tensor(9.7648, grad_fn=<DivBackward0>)
# 676tensor(9.7956, grad_fn=<DivBackward0>)
# 677tensor(10.0463, grad_fn=<DivBackward0>)
# 678tensor(10.7451, grad_fn=<DivBackward0>)
# 679tensor(10.3596, grad_fn=<DivBackward0>)
# 680tensor(10.2722, grad_fn=<DivBackward0>)
# 681tensor(10.3361, grad_fn=<DivBackward0>)
# 682tensor(9.7077, grad_fn=<DivBackward0>)
# 683tensor(10.5086, grad_fn=<DivBackward0>)
# 684tensor(9.8855, grad_fn=<DivBackward0>)
# 685tensor(9.5913, grad_fn=<DivBackward0>)
# 686tensor(10.2919, grad_fn=<DivBackward0>)
# 687tensor(10.4777, grad_fn=<DivBackward0>)
# 688tensor(9.7485, grad_fn=<DivBackward0>)
# 689tensor(10.2759, grad_fn=<DivBackward0>)
# 690tensor(9.8638, grad_fn=<DivBackward0>)
# 691tensor(10.4108, grad_fn=<DivBackward0>)
# 692tensor(9.4346, grad_fn=<DivBackward0>)
# 693tensor(9.8473, grad_fn=<DivBackward0>)
# 694tensor(10.7781, grad_fn=<DivBackward0>)
# 695tensor(10.6440, grad_fn=<DivBackward0>)
# 696tensor(10.2015, grad_fn=<DivBackward0>)
# 697tensor(9.5571, grad_fn=<DivBackward0>)
# 698tensor(10.3159, grad_fn=<DivBackward0>)
# 699tensor(10.0425, grad_fn=<DivBackward0>)
# 700tensor(9.9610, grad_fn=<DivBackward0>)
# 701tensor(9.9509, grad_fn=<DivBackward0>)
# 702tensor(10.5781, grad_fn=<DivBackward0>)
# 703tensor(10.1287, grad_fn=<DivBackward0>)
# 704tensor(9.7184, grad_fn=<DivBackward0>)
# 705tensor(9.7061, grad_fn=<DivBackward0>)
# 706tensor(9.6859, grad_fn=<DivBackward0>)
# 707tensor(9.7783, grad_fn=<DivBackward0>)
# 708tensor(9.7753, grad_fn=<DivBackward0>)
# 709tensor(10.0084, grad_fn=<DivBackward0>)
# 710tensor(10.1914, grad_fn=<DivBackward0>)
# 711tensor(9.6847, grad_fn=<DivBackward0>)
# 712tensor(10.1438, grad_fn=<DivBackward0>)
# 713tensor(10.2337, grad_fn=<DivBackward0>)
# 714tensor(9.8630, grad_fn=<DivBackward0>)
# 715tensor(10.0156, grad_fn=<DivBackward0>)
# 716tensor(9.9560, grad_fn=<DivBackward0>)
# 717tensor(9.2696, grad_fn=<DivBackward0>)
# 718tensor(9.8815, grad_fn=<DivBackward0>)
# 719tensor(9.4560, grad_fn=<DivBackward0>)
# 720tensor(10.1151, grad_fn=<DivBackward0>)
# 721tensor(9.4517, grad_fn=<DivBackward0>)
# 722tensor(10.3075, grad_fn=<DivBackward0>)
# 723tensor(9.3813, grad_fn=<DivBackward0>)
# 724tensor(9.7406, grad_fn=<DivBackward0>)
# 725tensor(9.9111, grad_fn=<DivBackward0>)
# 726tensor(10.4321, grad_fn=<DivBackward0>)
# 727tensor(9.9940, grad_fn=<DivBackward0>)
# 728tensor(9.3315, grad_fn=<DivBackward0>)
# 729tensor(9.4840, grad_fn=<DivBackward0>)
# 730tensor(9.8404, grad_fn=<DivBackward0>)
# 731tensor(10.0641, grad_fn=<DivBackward0>)
# 732tensor(9.4215, grad_fn=<DivBackward0>)
# 733tensor(9.8447, grad_fn=<DivBackward0>)
# 734tensor(9.1141, grad_fn=<DivBackward0>)
# 735tensor(10.0074, grad_fn=<DivBackward0>)
# 736tensor(9.6356, grad_fn=<DivBackward0>)
# 737tensor(9.3916, grad_fn=<DivBackward0>)
# 738tensor(9.7343, grad_fn=<DivBackward0>)
# 739tensor(9.1470, grad_fn=<DivBackward0>)
# 740tensor(11.0035, grad_fn=<DivBackward0>)
# 741tensor(9.6537, grad_fn=<DivBackward0>)
# 742tensor(9.4005, grad_fn=<DivBackward0>)
# 743tensor(9.5041, grad_fn=<DivBackward0>)
# 744tensor(9.6772, grad_fn=<DivBackward0>)
# 745tensor(10.2881, grad_fn=<DivBackward0>)
# 746tensor(9.6300, grad_fn=<DivBackward0>)
# 747tensor(9.4470, grad_fn=<DivBackward0>)
# 748tensor(9.3647, grad_fn=<DivBackward0>)
# 749tensor(10.2132, grad_fn=<DivBackward0>)
# 750tensor(9.7248, grad_fn=<DivBackward0>)
# 751tensor(9.8848, grad_fn=<DivBackward0>)
# 752tensor(9.7398, grad_fn=<DivBackward0>)
# 753tensor(9.7288, grad_fn=<DivBackward0>)
# 754tensor(10.0919, grad_fn=<DivBackward0>)
# 755tensor(10.2417, grad_fn=<DivBackward0>)
# 756tensor(10.3785, grad_fn=<DivBackward0>)
# 757tensor(10.3157, grad_fn=<DivBackward0>)
# 758tensor(9.5608, grad_fn=<DivBackward0>)
# 759tensor(10.2590, grad_fn=<DivBackward0>)
# 760tensor(9.5191, grad_fn=<DivBackward0>)
# 761tensor(9.7480, grad_fn=<DivBackward0>)
# 762tensor(9.9059, grad_fn=<DivBackward0>)
# 763tensor(9.9579, grad_fn=<DivBackward0>)
# 764tensor(10.2547, grad_fn=<DivBackward0>)
# 765tensor(9.8560, grad_fn=<DivBackward0>)
# 766tensor(10.3625, grad_fn=<DivBackward0>)
# 767tensor(10.3754, grad_fn=<DivBackward0>)
# 768tensor(9.4073, grad_fn=<DivBackward0>)
# 769tensor(9.7425, grad_fn=<DivBackward0>)
# 770tensor(9.9384, grad_fn=<DivBackward0>)
# 771tensor(9.2562, grad_fn=<DivBackward0>)
# 772tensor(9.4307, grad_fn=<DivBackward0>)
# 773tensor(10.1534, grad_fn=<DivBackward0>)
# 774tensor(10.3235, grad_fn=<DivBackward0>)
# 775tensor(10.0668, grad_fn=<DivBackward0>)
# 776tensor(9.8257, grad_fn=<DivBackward0>)
# 777tensor(9.6466, grad_fn=<DivBackward0>)
# 778tensor(9.2781, grad_fn=<DivBackward0>)
# 779tensor(9.7697, grad_fn=<DivBackward0>)
# 780tensor(9.2518, grad_fn=<DivBackward0>)
# 781tensor(9.8759, grad_fn=<DivBackward0>)
# 782tensor(9.4773, grad_fn=<DivBackward0>)
# 783tensor(10.0304, grad_fn=<DivBackward0>)
# 784tensor(10.2086, grad_fn=<DivBackward0>)
# 785tensor(9.5712, grad_fn=<DivBackward0>)
# 786tensor(9.8529, grad_fn=<DivBackward0>)
# 787tensor(10.1942, grad_fn=<DivBackward0>)
# 788tensor(9.5346, grad_fn=<DivBackward0>)
# 789tensor(10.1509, grad_fn=<DivBackward0>)
# 790tensor(10.3880, grad_fn=<DivBackward0>)
# 791tensor(9.8090, grad_fn=<DivBackward0>)
# 792tensor(9.4661, grad_fn=<DivBackward0>)
# 793tensor(9.6949, grad_fn=<DivBackward0>)
# 794tensor(9.6295, grad_fn=<DivBackward0>)
# 795tensor(9.8542, grad_fn=<DivBackward0>)
# 796tensor(9.5496, grad_fn=<DivBackward0>)
# 797tensor(9.7552, grad_fn=<DivBackward0>)
# 798tensor(9.4992, grad_fn=<DivBackward0>)
# 799tensor(9.4353, grad_fn=<DivBackward0>)
# 800tensor(10.5946, grad_fn=<DivBackward0>)
# 801tensor(10.2072, grad_fn=<DivBackward0>)
# 802tensor(9.7723, grad_fn=<DivBackward0>)
# 803tensor(9.9604, grad_fn=<DivBackward0>)
# 804tensor(9.5265, grad_fn=<DivBackward0>)
# 805tensor(9.1703, grad_fn=<DivBackward0>)
# 806tensor(9.3930, grad_fn=<DivBackward0>)
# 807tensor(9.3619, grad_fn=<DivBackward0>)
# 808tensor(10.2309, grad_fn=<DivBackward0>)
# 809tensor(10.4815, grad_fn=<DivBackward0>)
# 810tensor(9.7211, grad_fn=<DivBackward0>)
# 811tensor(9.8633, grad_fn=<DivBackward0>)
# 812tensor(9.7237, grad_fn=<DivBackward0>)
# 813tensor(10.2418, grad_fn=<DivBackward0>)
# 814tensor(10.3964, grad_fn=<DivBackward0>)
# 815tensor(10.0389, grad_fn=<DivBackward0>)
# 816tensor(10.0269, grad_fn=<DivBackward0>)
# 817tensor(9.5502, grad_fn=<DivBackward0>)
# 818tensor(9.4690, grad_fn=<DivBackward0>)
# 819tensor(10.1737, grad_fn=<DivBackward0>)
# 820tensor(9.9506, grad_fn=<DivBackward0>)
# 821tensor(9.5374, grad_fn=<DivBackward0>)
# 822tensor(9.0987, grad_fn=<DivBackward0>)
# 823tensor(9.8890, grad_fn=<DivBackward0>)
# 824tensor(9.4089, grad_fn=<DivBackward0>)
# 825tensor(9.9081, grad_fn=<DivBackward0>)
# 826tensor(10.6132, grad_fn=<DivBackward0>)
# 827tensor(10.4178, grad_fn=<DivBackward0>)
# 828tensor(9.5209, grad_fn=<DivBackward0>)
# 829tensor(9.4207, grad_fn=<DivBackward0>)
# 830tensor(9.6973, grad_fn=<DivBackward0>)
# 831tensor(10.1420, grad_fn=<DivBackward0>)
# 832tensor(9.9890, grad_fn=<DivBackward0>)
# 833tensor(10.3192, grad_fn=<DivBackward0>)
# 834tensor(10.1960, grad_fn=<DivBackward0>)
# 835tensor(9.8515, grad_fn=<DivBackward0>)
# 836tensor(9.8251, grad_fn=<DivBackward0>)
# 837tensor(9.7309, grad_fn=<DivBackward0>)
# 838tensor(9.3184, grad_fn=<DivBackward0>)
# 839tensor(9.6182, grad_fn=<DivBackward0>)
# 840tensor(9.9265, grad_fn=<DivBackward0>)
# 841tensor(9.6781, grad_fn=<DivBackward0>)
# 842tensor(9.9688, grad_fn=<DivBackward0>)
# 843tensor(9.4493, grad_fn=<DivBackward0>)
# 844tensor(9.9767, grad_fn=<DivBackward0>)
# 845tensor(10.1733, grad_fn=<DivBackward0>)
# 846tensor(9.2391, grad_fn=<DivBackward0>)
# 847tensor(9.5967, grad_fn=<DivBackward0>)
# 848tensor(9.8684, grad_fn=<DivBackward0>)
# 849tensor(9.8637, grad_fn=<DivBackward0>)
# 850tensor(9.8851, grad_fn=<DivBackward0>)
# 851tensor(10.0973, grad_fn=<DivBackward0>)
# 852tensor(9.5905, grad_fn=<DivBackward0>)
# 853tensor(10.2579, grad_fn=<DivBackward0>)
# 854tensor(9.7822, grad_fn=<DivBackward0>)
# 855tensor(10.2023, grad_fn=<DivBackward0>)
# 856tensor(10.2458, grad_fn=<DivBackward0>)
# 857tensor(9.8048, grad_fn=<DivBackward0>)
# 858tensor(9.3700, grad_fn=<DivBackward0>)
# 859tensor(9.8193, grad_fn=<DivBackward0>)
# 860tensor(9.1988, grad_fn=<DivBackward0>)
# 861tensor(10.2189, grad_fn=<DivBackward0>)
# 862tensor(9.9625, grad_fn=<DivBackward0>)
# 863tensor(10.4772, grad_fn=<DivBackward0>)
# 864tensor(9.9922, grad_fn=<DivBackward0>)
# 865tensor(9.5202, grad_fn=<DivBackward0>)
# 866tensor(9.5166, grad_fn=<DivBackward0>)
# 867tensor(10.3767, grad_fn=<DivBackward0>)
# 868tensor(9.4807, grad_fn=<DivBackward0>)
# 869tensor(9.8149, grad_fn=<DivBackward0>)
# 870tensor(9.8626, grad_fn=<DivBackward0>)
# 871tensor(9.9760, grad_fn=<DivBackward0>)
# 872tensor(9.3569, grad_fn=<DivBackward0>)
# 873tensor(9.5382, grad_fn=<DivBackward0>)
# 874tensor(10.1568, grad_fn=<DivBackward0>)
# 875tensor(9.3959, grad_fn=<DivBackward0>)
# 876tensor(9.4528, grad_fn=<DivBackward0>)
# 877tensor(9.8261, grad_fn=<DivBackward0>)
# 878tensor(9.9426, grad_fn=<DivBackward0>)
# 879tensor(10.4242, grad_fn=<DivBackward0>)
# 880tensor(10.4015, grad_fn=<DivBackward0>)
# 881tensor(9.0057, grad_fn=<DivBackward0>)
# 882tensor(9.5526, grad_fn=<DivBackward0>)
# 883tensor(10.0243, grad_fn=<DivBackward0>)
# 884tensor(10.0779, grad_fn=<DivBackward0>)
# 885tensor(9.6416, grad_fn=<DivBackward0>)
# 886tensor(9.5643, grad_fn=<DivBackward0>)
# 887tensor(10.2358, grad_fn=<DivBackward0>)
# 888tensor(10.3531, grad_fn=<DivBackward0>)
# 889tensor(9.2602, grad_fn=<DivBackward0>)
# 890tensor(9.3397, grad_fn=<DivBackward0>)
# 891tensor(9.7396, grad_fn=<DivBackward0>)
# 892tensor(9.3961, grad_fn=<DivBackward0>)
# 893tensor(9.8849, grad_fn=<DivBackward0>)
# 894tensor(10.1828, grad_fn=<DivBackward0>)
# 895tensor(9.1901, grad_fn=<DivBackward0>)
# 896tensor(9.1674, grad_fn=<DivBackward0>)
# 897tensor(9.9625, grad_fn=<DivBackward0>)
# 898tensor(9.1841, grad_fn=<DivBackward0>)
# 899tensor(9.9984, grad_fn=<DivBackward0>)
# 900tensor(9.9459, grad_fn=<DivBackward0>)
# 901tensor(9.1748, grad_fn=<DivBackward0>)
# 902tensor(10.2318, grad_fn=<DivBackward0>)
# 903tensor(9.5849, grad_fn=<DivBackward0>)
# 904tensor(9.8737, grad_fn=<DivBackward0>)
# 905tensor(9.2082, grad_fn=<DivBackward0>)
# 906tensor(10.2720, grad_fn=<DivBackward0>)
# 907tensor(9.6050, grad_fn=<DivBackward0>)
# 908tensor(9.4088, grad_fn=<DivBackward0>)
# 909tensor(9.3751, grad_fn=<DivBackward0>)
# 910tensor(9.4997, grad_fn=<DivBackward0>)
# 911tensor(9.9074, grad_fn=<DivBackward0>)
# 912tensor(8.7097, grad_fn=<DivBackward0>)
# 913tensor(9.8925, grad_fn=<DivBackward0>)
# 914tensor(9.5851, grad_fn=<DivBackward0>)
# 915tensor(9.7757, grad_fn=<DivBackward0>)
# 916tensor(10.1327, grad_fn=<DivBackward0>)
# 917tensor(9.8718, grad_fn=<DivBackward0>)
# 918tensor(9.5669, grad_fn=<DivBackward0>)
# 919tensor(10.2530, grad_fn=<DivBackward0>)
# 920tensor(10.2980, grad_fn=<DivBackward0>)
# 921tensor(9.1958, grad_fn=<DivBackward0>)
# 922tensor(9.7363, grad_fn=<DivBackward0>)
# 923tensor(9.7703, grad_fn=<DivBackward0>)
# 924tensor(9.1779, grad_fn=<DivBackward0>)
# 925tensor(9.7547, grad_fn=<DivBackward0>)
# 926tensor(9.5562, grad_fn=<DivBackward0>)
# 927tensor(9.8144, grad_fn=<DivBackward0>)
# 928tensor(8.4815, grad_fn=<DivBackward0>)
# 929tensor(9.9242, grad_fn=<DivBackward0>)
# 930tensor(9.2331, grad_fn=<DivBackward0>)
# 931tensor(9.9481, grad_fn=<DivBackward0>)
# 932tensor(9.8365, grad_fn=<DivBackward0>)
# 933tensor(10.0291, grad_fn=<DivBackward0>)
# 934tensor(9.4191, grad_fn=<DivBackward0>)
# 935tensor(9.7532, grad_fn=<DivBackward0>)
# 936tensor(11.0550, grad_fn=<DivBackward0>)
# 937tensor(9.4121, grad_fn=<DivBackward0>)
# 938tensor(9.1673, grad_fn=<DivBackward0>)
# 939tensor(9.9273, grad_fn=<DivBackward0>)
# 940tensor(9.4733, grad_fn=<DivBackward0>)
# 941tensor(10.1733, grad_fn=<DivBackward0>)
# 942tensor(9.9564, grad_fn=<DivBackward0>)
# 943tensor(8.8091, grad_fn=<DivBackward0>)
# 944tensor(9.1251, grad_fn=<DivBackward0>)
# 945tensor(9.3421, grad_fn=<DivBackward0>)
# 946tensor(9.4253, grad_fn=<DivBackward0>)
# 947tensor(9.5110, grad_fn=<DivBackward0>)
# 948tensor(9.8276, grad_fn=<DivBackward0>)
# 949tensor(10.5316, grad_fn=<DivBackward0>)
# 950tensor(9.3324, grad_fn=<DivBackward0>)
# 951tensor(8.9873, grad_fn=<DivBackward0>)
# 952tensor(9.6628, grad_fn=<DivBackward0>)
# 953tensor(9.8164, grad_fn=<DivBackward0>)
# 954tensor(9.5139, grad_fn=<DivBackward0>)
# 955tensor(9.3705, grad_fn=<DivBackward0>)
# 956tensor(9.6001, grad_fn=<DivBackward0>)
# 957tensor(9.2117, grad_fn=<DivBackward0>)
# 958tensor(10.4583, grad_fn=<DivBackward0>)
# 959tensor(9.7309, grad_fn=<DivBackward0>)
# 960tensor(10.0620, grad_fn=<DivBackward0>)
# 961tensor(10.1714, grad_fn=<DivBackward0>)
# 962tensor(9.7709, grad_fn=<DivBackward0>)
# 963tensor(9.8405, grad_fn=<DivBackward0>)
# 964tensor(9.3376, grad_fn=<DivBackward0>)
# 965tensor(9.7097, grad_fn=<DivBackward0>)
# 966tensor(10.0815, grad_fn=<DivBackward0>)
# 967tensor(9.9997, grad_fn=<DivBackward0>)
# 968tensor(9.3538, grad_fn=<DivBackward0>)
# 969tensor(9.7643, grad_fn=<DivBackward0>)
# 970tensor(10.0407, grad_fn=<DivBackward0>)
# 971tensor(9.5446, grad_fn=<DivBackward0>)
# 972tensor(9.2174, grad_fn=<DivBackward0>)
# 973tensor(9.5019, grad_fn=<DivBackward0>)
# 974tensor(9.7331, grad_fn=<DivBackward0>)
# 975tensor(8.8207, grad_fn=<DivBackward0>)
# 976tensor(9.8184, grad_fn=<DivBackward0>)
# 977tensor(9.5210, grad_fn=<DivBackward0>)
# 978tensor(9.8961, grad_fn=<DivBackward0>)
# 979tensor(9.9124, grad_fn=<DivBackward0>)
# 980tensor(9.7747, grad_fn=<DivBackward0>)
# 981tensor(9.4217, grad_fn=<DivBackward0>)
# 982tensor(10.0506, grad_fn=<DivBackward0>)
# 983tensor(10.1449, grad_fn=<DivBackward0>)
# 984tensor(9.7761, grad_fn=<DivBackward0>)
# 985tensor(10.1245, grad_fn=<DivBackward0>)
# 986tensor(9.4997, grad_fn=<DivBackward0>)
# 987tensor(8.8031, grad_fn=<DivBackward0>)
# 988tensor(9.5549, grad_fn=<DivBackward0>)
# 989tensor(9.5944, grad_fn=<DivBackward0>)
# 990tensor(9.6107, grad_fn=<DivBackward0>)
# 991tensor(9.4658, grad_fn=<DivBackward0>)
# 992tensor(10.1524, grad_fn=<DivBackward0>)
# 993tensor(9.9866, grad_fn=<DivBackward0>)
# 994tensor(9.5671, grad_fn=<DivBackward0>)
# 995tensor(9.9664, grad_fn=<DivBackward0>)
# 996tensor(9.2675, grad_fn=<DivBackward0>)
# 997tensor(9.3996, grad_fn=<DivBackward0>)
# 998tensor(9.2633, grad_fn=<DivBackward0>)
# 999tensor(9.4249, grad_fn=<DivBackward0>)

# %%
os.chdir('C:\\Users\\Ji Qi\\Documents\\GitHub\\ST-Aim3')
os.getcwd()
PATH = 'vgae_model_for_simulation.pth'
torch.save(model, PATH)

model = torch.load(PATH)
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder(
#     (conv1): GCNConv(10, 20)
#     (conv_mu): GCNConv(20, 10)
#     (conv_logstd): GCNConv(20, 10)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))

mu_list_reshape = []
logstd_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))
    logstd_list_reshape.append(logstd_list_in_data[i].reshape((out_channels * n_node)))

# %%
mu_list_in_data
# Out:
# [array([[ 1.1469849 ,  0.70561063],
#         [ 1.2261902 ,  0.9413347 ],
#         [ 0.9941276 ,  0.88653105],
#         [ 1.3792328 ,  1.3268385 ],
#         [ 1.056879  ,  0.77060777],
#         [-0.14173836, -0.8374999 ],
#         [ 1.3849291 , -0.59999704],
#         [-0.15066111, -0.7664268 ],
#         [-0.7250092 , -0.7310883 ],
#         [-0.45737866, -0.80446464]], dtype=float32),
#  array([[ 1.1614918 ,  0.7891657 ],
#         [ 1.312118  ,  1.0364691 ],
#         [ 0.9874583 ,  0.9906291 ],
#         [ 1.2742785 ,  0.9592278 ],
#         [ 0.6325973 ,  0.97998446],
#         [-1.1064756 ,  0.09067035],
#         [-0.5280607 , -0.64162046],
#         [ 0.42514223, -0.01992157],
#         [ 0.1593898 , -0.88408536],
#         [-0.8397807 , -0.43799824]], dtype=float32),
#  array([[ 0.9390804 ,  0.67451775],
#         [ 1.2054664 ,  0.67871416],
#         [ 1.0226101 ,  0.7673561 ],
#         [ 1.4836674 ,  1.0177363 ],
#         [ 0.71934813,  0.9566563 ],
#         [-0.04771629, -0.8333735 ],
#         [ 0.10766041, -0.5993127 ],
#         [-0.6734111 , -0.8796259 ],
#         [-0.61245996, -1.0267881 ],
#         [ 0.11036432,  0.12367055]], dtype=float32),
#  array([[ 1.2277092 ,  0.8547084 ],
#         [ 1.0464426 ,  1.1459869 ],
#         [ 1.0023792 ,  0.97500175],
#         [ 1.5292662 ,  1.3607924 ],
#         [ 0.9811912 ,  0.5508294 ],
#         [-0.07211286,  0.05839041],
#         [-0.03266555, -0.4003754 ],
#         [-0.07394788,  0.18741885],
#         [-0.2007314 , -0.69755685],
#         [-1.2416297 , -0.05225757]], dtype=float32),
#  array([[ 1.3053632 ,  0.90551   ],
#         [ 1.0806133 ,  0.71590614],
#         [ 1.0219343 ,  0.8809425 ],
#         [ 1.5931785 ,  0.9162036 ],
#         [ 0.7752034 ,  0.6801968 ],
#         [ 0.22711086, -0.28079674],
#         [-0.32108545, -0.515936  ],
#         [-0.85241556,  0.2887579 ],
#         [-0.5973381 ,  0.60333085],
#         [-1.30741   , -1.1098399 ]], dtype=float32),
#  array([[ 1.4602933 ,  1.1647539 ],
#         [ 1.2502265 ,  1.0161431 ],
#         [ 0.98145664,  0.88877684],
#         [ 1.2519555 ,  1.130273  ],
#         [ 0.99087346,  0.58047384],
#         [-0.43946755, -0.65381694],
#         [-0.7859406 , -2.178748  ],
#         [-1.0965086 ,  1.0969511 ],
#         [-0.4872107 , -0.2307386 ],
#         [ 0.08737403,  0.2083588 ]], dtype=float32),
#  array([[ 1.0489813 ,  1.1514204 ],
#         [ 1.2938126 ,  1.0422927 ],
#         [ 1.0392084 ,  1.0274973 ],
#         [ 1.1144743 ,  1.1495739 ],
#         [ 0.8471828 ,  1.0677907 ],
#         [-0.11584425, -0.3644164 ],
#         [-0.7621788 ,  0.04027188],
#         [-1.2034588 , -0.5448816 ],
#         [-0.6863275 , -0.32231143],
#         [-0.5239757 , -0.71002716]], dtype=float32),
#  array([[ 1.2979952 ,  1.0413412 ],
#         [ 0.8559104 ,  0.9313739 ],
#         [ 1.1354142 ,  0.64650035],
#         [ 1.4885653 ,  1.2196522 ],
#         [ 0.8032026 ,  0.98885787],
#         [-0.74283874, -0.13205373],
#         [-0.27582738, -0.764553  ],
#         [-0.05902079, -0.9439105 ],
#         [-0.49608088, -0.41800654],
#         [-0.5165261 , -0.50804377]], dtype=float32),
#  array([[ 1.0043429 ,  0.7177681 ],
#         [ 1.0947816 ,  0.92978144],
#         [ 1.2923793 ,  0.8588165 ],
#         [ 1.2781479 ,  1.2481238 ],
#         [ 0.76591057,  0.64699125],
#         [-0.37197953, -0.11210847],
#         [ 0.020491  , -0.49121276],
#         [-0.7952676 ,  0.0814068 ],
#         [-0.00716251, -0.32924294],
#         [ 0.36962306, -0.4661648 ]], dtype=float32),
#  array([[ 1.5473778 ,  0.7990307 ],
#         [ 1.2503078 ,  1.0176562 ],
#         [ 1.0243534 ,  0.7422054 ],
#         [ 1.5411906 ,  1.1862574 ],
#         [ 0.6261113 ,  0.7588857 ],
#         [-0.7979324 ,  0.03389591],
#         [-1.0592955 , -0.5595997 ],
#         [ 0.5200105 , -0.27276468],
#         [-0.03976244, -1.3556231 ],
#         [-0.20676047, -0.6256042 ]], dtype=float32),
#  array([[ 1.2570015 ,  0.8651247 ],
#         [ 1.2524061 ,  1.0814773 ],
#         [ 1.0878506 ,  0.6590091 ],
#         [ 1.5976877 ,  1.185074  ],
#         [ 0.43651688,  0.75788414],
#         [-0.13699478, -0.7784947 ],
#         [ 0.32050824, -0.02651536],
#         [-0.85469973,  0.57931674],
#         [-0.75410867, -0.25780916],
#         [-0.8026736 , -1.0052823 ]], dtype=float32),
#  array([[ 1.0881579 ,  0.7651536 ],
#         [ 1.2105225 ,  0.8425792 ],
#         [ 0.86487925,  0.68879956],
#         [ 1.2627032 ,  1.2415252 ],
#         [ 0.6184315 ,  0.8247904 ],
#         [-0.55300826, -0.03979602],
#         [-0.4635811 , -0.80080724],
#         [-0.12725812,  0.15260157],
#         [-1.0912471 ,  0.20889321],
#         [-0.661455  , -0.00624946]], dtype=float32),
#  array([[ 0.971935  ,  1.0261035 ],
#         [ 1.1960021 ,  0.87967414],
#         [ 0.9403265 ,  0.44799405],
#         [ 1.4927697 ,  1.3301528 ],
#         [ 0.7779199 ,  0.89701414],
#         [-0.15982154, -0.49886942],
#         [-0.43620425, -1.2926226 ],
#         [-0.02373224,  0.20955876],
#         [-0.96932244, -0.10537675],
#         [-0.24306567, -0.4403267 ]], dtype=float32),
#  array([[ 1.3617402 ,  0.71323735],
#         [ 1.2062634 ,  1.1152726 ],
#         [ 1.2811974 ,  0.7506373 ],
#         [ 1.2916336 ,  1.3126806 ],
#         [ 0.66381305,  0.8310449 ],
#         [-0.67465353,  0.35113356],
#         [ 0.11669248,  0.43937796],
#         [-0.42574486,  0.06377605],
#         [-0.13358769, -1.8435711 ],
#         [-0.3025186 ,  0.7093648 ]], dtype=float32),
#  array([[ 1.2153076 ,  0.60817873],
#         [ 1.0305481 ,  1.1274318 ],
#         [ 0.7706877 ,  0.76630664],
#         [ 1.4516286 ,  1.2054307 ],
#         [ 0.57525337,  0.7637872 ],
#         [-0.3078307 , -0.11059618],
#         [ 0.5184585 , -0.37141743],
#         [-0.8828972 , -1.239479  ],
#         [-1.3143885 ,  0.71820784],
#         [ 0.06440848, -0.8090435 ]], dtype=float32),
#  array([[ 1.3125917 ,  0.64206374],
#         [ 1.2817212 ,  1.0735475 ],
#         [ 1.4102231 ,  0.4132018 ],
#         [ 1.4084027 ,  1.1409924 ],
#         [ 1.2772228 ,  0.5971092 ],
#         [-0.42655995, -0.51538706],
#         [-0.18950424, -0.9581246 ],
#         [-1.150403  , -0.8688862 ],
#         [-1.2368783 ,  0.6915746 ],
#         [-0.7500494 ,  0.7772968 ]], dtype=float32),
#  array([[ 1.141162  ,  0.61368406],
#         [ 1.2270485 ,  0.9083477 ],
#         [ 1.0524019 ,  0.92534095],
#         [ 1.3814094 ,  1.1052121 ],
#         [ 0.7404766 ,  0.5517674 ],
#         [ 0.5110519 , -0.85455513],
#         [-1.0788577 ,  0.421548  ],
#         [-1.2539332 , -1.4257604 ],
#         [-0.5142839 , -0.29430467],
#         [-0.5553683 , -1.1955897 ]], dtype=float32),
#  array([[ 0.8683047 ,  1.0611153 ],
#         [ 1.2834623 ,  0.8086065 ],
#         [ 1.1125834 ,  0.9800453 ],
#         [ 1.3359414 ,  0.8558266 ],
#         [ 0.79967165,  0.7285547 ],
#         [-0.63786894,  0.2963538 ],
#         [-0.6183957 , -0.3425418 ],
#         [-0.6506099 , -0.09184739],
#         [-0.32603478, -0.36725527],
#         [-0.58219945, -1.0173948 ]], dtype=float32),
#  array([[ 1.1808101 ,  0.8019794 ],
#         [ 1.2996438 ,  0.9749008 ],
#         [ 0.7478794 ,  0.7806634 ],
#         [ 1.4764423 ,  1.1367855 ],
#         [ 0.7527527 ,  0.53687215],
#         [ 0.06726313, -1.5828742 ],
#         [-0.63737607, -1.3007497 ],
#         [-0.18977973, -0.2726606 ],
#         [-0.3726759 , -0.76182187],
#         [ 0.12764603, -0.53578264]], dtype=float32),
#  array([[ 1.2112081 ,  0.8212935 ],
#         [ 1.3190273 ,  1.0925261 ],
#         [ 1.0823499 ,  0.60644174],
#         [ 1.5367147 ,  1.1711501 ],
#         [ 0.93492043,  0.63742703],
#         [-0.6958705 , -0.8258562 ],
#         [-0.16193065, -0.3252383 ],
#         [-0.4712933 , -1.5548935 ],
#         [-0.8982427 , -0.32196695],
#         [-0.7384814 , -0.59627646]], dtype=float32),
#  array([[ 1.231672  ,  1.0670921 ],
#         [ 1.5617216 ,  0.547158  ],
#         [ 1.1121465 ,  0.8239327 ],
#         [ 1.4953957 ,  1.1919181 ],
#         [ 0.940387  ,  0.6620774 ],
#         [-0.390172  ,  0.77394855],
#         [-0.16079548,  0.6090775 ],
#         [ 0.14416277, -0.6474824 ],
#         [-0.94195   , -0.79360163],
#         [-0.7700825 , -1.2021475 ]], dtype=float32),
#  array([[ 1.0962448 ,  0.6960787 ],
#         [ 1.0763602 ,  1.1032485 ],
#         [ 1.3949933 ,  0.6837374 ],
#         [ 1.3306662 ,  1.0968157 ],
#         [ 0.78258896,  0.7313561 ],
#         [-0.62862086, -0.85509956],
#         [-0.74328506, -0.6837434 ],
#         [-1.5345999 , -0.02732912],
#         [-0.5359082 ,  0.6697564 ],
#         [-0.17756402, -0.974658  ]], dtype=float32),
#  array([[ 1.2019849 ,  1.1676687 ],
#         [ 1.0041459 ,  0.9267999 ],
#         [ 0.86689866,  0.70373   ],
#         [ 1.3124225 ,  1.1364727 ],
#         [ 0.6352006 ,  0.6609585 ],
#         [-0.22962803, -0.73711014],
#         [-0.6043471 , -0.52598435],
#         [-0.12352997, -1.222499  ],
#         [-0.05277282, -0.09178436],
#         [-0.78943276,  0.07586041]], dtype=float32),
#  array([[ 1.2610041 ,  1.2225448 ],
#         [ 1.2251832 ,  0.8623867 ],
#         [ 1.0383787 ,  0.8527238 ],
#         [ 1.4113069 ,  1.2520338 ],
#         [ 1.033467  ,  0.8479724 ],
#         [-1.1201673 , -1.0353819 ],
#         [ 0.48044658, -1.0317214 ],
#         [-1.2877176 , -1.1996411 ],
#         [ 0.40178126, -0.37535134],
#         [-1.171746  ,  0.06656942]], dtype=float32),
#  array([[ 1.2361282 ,  0.6896088 ],
#         [ 1.2576673 ,  0.9129412 ],
#         [ 0.7533197 ,  1.0165927 ],
#         [ 1.6019667 ,  1.1728139 ],
#         [ 1.017901  ,  0.7948676 ],
#         [ 0.59389865,  0.34683284],
#         [-2.1277113 , -0.7370898 ],
#         [-1.1841233 , -1.0521786 ],
#         [-0.5060684 ,  0.68117106],
#         [-1.164869  ,  0.40231767]], dtype=float32),
#  array([[ 1.2913809 ,  0.5786304 ],
#         [ 1.2747346 ,  1.0752622 ],
#         [ 0.77137744,  0.5918257 ],
#         [ 1.3356515 ,  1.2161281 ],
#         [ 0.966783  ,  0.8143716 ],
#         [-0.41920298, -0.91469157],
#         [-0.8723494 , -0.82539296],
#         [-0.31419933, -0.8337821 ],
#         [-0.97144455,  0.16720513],
#         [-0.43852052, -0.5197529 ]], dtype=float32),
#  array([[ 1.3746979 ,  0.8307032 ],
#         [ 1.073595  ,  0.8679371 ],
#         [ 1.2979525 ,  0.9472132 ],
#         [ 1.3513492 ,  1.0992109 ],
#         [ 0.98484397,  0.49177018],
#         [-0.86059   , -0.62393963],
#         [-1.0996084 ,  0.77053493],
#         [-0.10642383, -0.6096804 ],
#         [-0.8079115 , -1.2826833 ],
#         [ 0.05162394,  0.6286577 ]], dtype=float32),
#  array([[ 1.1304408 ,  0.82709795],
#         [ 1.4782852 ,  0.97007054],
#         [ 0.56573814,  0.7250197 ],
#         [ 1.5802175 ,  1.1286271 ],
#         [ 0.92793787,  0.8425549 ],
#         [-1.2265024 , -1.7679374 ],
#         [ 0.02276391, -0.47339678],
#         [-1.1764898 , -0.48955637],
#         [-1.3395767 ,  0.19107082],
#         [ 0.15858942, -0.28488386]], dtype=float32),
#  array([[ 1.0108345 ,  0.7390952 ],
#         [ 1.091274  ,  1.1129037 ],
#         [ 0.8539743 ,  0.7905823 ],
#         [ 1.4340092 ,  0.948087  ],
#         [ 0.6413103 ,  1.1116848 ],
#         [-0.56877834, -0.64637566],
#         [-1.3183835 , -0.517272  ],
#         [-1.2239542 , -0.6458228 ],
#         [ 0.159783  , -0.35924366],
#         [-0.9443339 , -0.07057852]], dtype=float32),
#  array([[ 1.1955904 ,  0.8152147 ],
#         [ 1.2030311 ,  1.0462074 ],
#         [ 0.9740093 ,  0.75292224],
#         [ 1.2244425 ,  0.9690678 ],
#         [ 1.0879984 ,  0.63086534],
#         [-0.16856259, -0.6476356 ],
#         [-0.8954481 , -0.213691  ],
#         [ 0.26947016, -0.8184355 ],
#         [-1.5160301 , -0.28356314],
#         [-0.42410302, -0.29727387]], dtype=float32)]

# %%
# input data scatter 
import matplotlib.pyplot as plt
def plot_mu_graph(mu):
    
    n_node = mu.shape[0]
    annotations = [str(i+1) for i in range(n_node)]
    colors = plt.cm.rainbow(np.linspace(0, 1, n_node))
    plt.scatter(mu[:,0],mu[:,1],c=colors, s=100)
    
    for i, label in enumerate(annotations):
        plt.annotate(label, (mu[i,0], mu[i,1]), fontsize=14)

        
plt.subplots(figsize=(20,20))

# import numpy as np
# mu_fake_list = []
# for i in range(30):
#     mu_11 = np.vstack([np.random.normal(0.75, 0.1, size=(3, 1)), np.random.normal(0.9, 0.1, size=(2, 1))])
#     mu_12 = np.vstack([np.random.normal(-1, 0.1, size=(3, 1)), np.random.normal(-1.25, 0.1, size=(2, 1))])
#     mu_fake = np.vstack([np.hstack([mu_11, mu_12]), np.random.normal(0,0.2, size=(5,2))])
#     mu_fake_list.append(np.vstack(mu_fake))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list_in_data[graph_i])

# %%
# original data mu scatter
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*len(mu_list)
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
# original adj matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 5, figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(simu_graph.simu_adj_m()[i], cmap="Greys")

# %%
# original data first 5 vs. last 5
simu_graph = SimuData(n_graph=30)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

colors = ['#3DAE43', '#67E332','#008000', '#006400', '#228B22',
          '#CD5C5C','#C71585', '#FF4500', '#DB7093', '#FF0000']
mu_list = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list.append(np.asarray(mu.detach()))

plt.figure(figsize=(10,10))
for node_i in range(n_node):
    
    node_mu = np.empty((0, 2))
    for graph_i in range(len(mu_list)):
    
        node_mu = np.vstack((node_mu, mu_list[graph_i][node_i, :]))
    
    plt.scatter(node_mu[:,0],node_mu[:,1], c=colors[node_i],alpha=0.8)

plt.show()

# %%
# Gaussian distribution for generating mu
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu, logstd = Encoder(n_node, out_channels)(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))
    logstd_list_in_data.append(np.asarray(logstd.detach()))

mu_list_reshape = []
logstd_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))
    logstd_list_reshape.append(logstd_list_in_data[i].reshape((out_channels * n_node)))
    
import scipy.stats as stats
data_mu = np.zeros((n, out_channels * n_node))
data_logstd = np.zeros((n, out_channels * n_node))
for i in range(n):
    data_mu[i, :] = mu_list_reshape[i]
    data_logstd[i, :] = logstd_list_reshape[i]

from sklearn.mixture import GaussianMixture

gm_mu = GaussianMixture(n_components=1, random_state=0).fit(data_mu)
gm_mu.weights_[0] = 1
# Out:
# C:\Users\Ji Qi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# got mean and cov for mu generating distribution
means_normal = gm_mu.means_
cov_normal = gm_mu.covariances_
means_normal = np.asarray(means_normal.tolist()[0])
cov_normal = np.asarray(cov_normal.tolist()[0])*0.01

# %%
#construct edge index
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
print(means_normal.reshape((n_node,out_channels)))
print(cov_normal)
# Out:
# [[ 0.01673761  0.00790383 -0.01842691  0.0037869   0.023606   -0.01257298
#   -0.01568553  0.01061069 -0.01058234  0.00104946]
#  [ 0.00567145  0.01007921 -0.02593251  0.00481494 -0.00754815 -0.00505986
#   -0.02167961  0.01580778 -0.00207829  0.01977415]
#  [ 0.00718632  0.02139511 -0.03566168 -0.01002756  0.01050212 -0.00102035
#   -0.00613172  0.05270665  0.00618107  0.0266761 ]
#  [ 0.00548944  0.02179075 -0.0173058  -0.00066692  0.00289274 -0.00681778
#   -0.00015875  0.02243168 -0.02291963  0.00743815]
#  [-0.00131841  0.01677275 -0.03005771  0.00243809  0.01838724 -0.0201807
#   -0.01070931  0.0169132  -0.01216554 -0.00434918]
#  [-0.00955434 -0.04215909 -0.01160793  0.00752258 -0.01538937  0.03795458
#    0.01745483  0.00109244 -0.02104536  0.01407931]
#  [-0.00488333  0.0326078   0.01031003  0.0377474  -0.01597427  0.05134169
#   -0.03113178  0.03164112  0.02554771  0.00896824]
#  [-0.01476071  0.05109482  0.00099943 -0.0214377   0.02280485 -0.00649804
#   -0.02174346  0.08317427  0.03433721  0.03956932]
#  [ 0.04293247 -0.03569113 -0.01667072 -0.01167642 -0.00796835 -0.03987035
#   -0.04329942  0.05166803  0.03931397 -0.00496841]
#  [ 0.01316779  0.06125511  0.00777898  0.03366759 -0.10194962  0.05283515
#   -0.00618464  0.0661521   0.0118492   0.06202302]]
# [[ 1.23407130e-04 -1.84253864e-05 -1.96556597e-06 ...  7.30757241e-05
#    5.84611630e-05 -4.43946871e-06]
#  [-1.84253864e-05  1.47004581e-04  5.23332998e-07 ...  1.04403341e-05
#   -4.93334355e-05  4.32879621e-05]
#  [-1.96556597e-06  5.23332998e-07  8.05510405e-05 ... -3.68466138e-05
#   -3.07731358e-05 -3.14988575e-05]
#  ...
#  [ 7.30757241e-05  1.04403341e-05 -3.68466138e-05 ...  2.94378997e-04
#    6.91590522e-05  5.96089218e-05]
#  [ 5.84611630e-05 -4.93334355e-05 -3.07731358e-05 ...  6.91590522e-05
#    5.19900568e-04 -1.55025511e-04]
#  [-4.43946871e-06  4.32879621e-05 -3.14988575e-05 ...  5.96089218e-05
#   -1.55025511e-04  3.86487778e-04]]

# %%
def sample_adj_mat(filter_value=0.75, filter_eye=True):
    model.__mu__ = torch.from_numpy((np.random.multivariate_normal(mean=means_normal,cov=cov_normal)).reshape((n_node,out_channels)))
    z = model.__mu__
    model.decode(z, edge_index)
    adj_mat = np.zeros((n_node, n_node))
    for i in range(n_node*n_node):
        adj_mat[int(edge_index[0, i]), int(edge_index[1, i])] = (model.decode(z, edge_index)[i].detach().numpy()).item()
    adj_mat[adj_mat < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat.shape[0]):
            adj_mat[i,i]=0
    return adj_mat, model.__mu__

# %%
# generate adjacency matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 5, figsize=(10,10))
adj_mat_list = []
mu_list = []
for i in range(25):
    plt.subplot(5, 5, i+1)
    adj_mat, mu_sample = sample_adj_mat(filter_value=0)
    adj_mat_list.append(adj_mat)
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
for i in range(25):
    np.random.normal(0, 1, size=(5, 2))
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*30
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
plt.subplots(figsize=(20,20))

for graph_i in range(25):
    plt.subplot(5, 5, graph_i+1)
    plot_mu_graph(mu_list[graph_i])

# %%
def compute_centrality(mat):
    return (np.sum(mat, axis=0)/mat.shape[0])

# %%
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# adj_list = []

# for i in range(len(dataset)):
#         train_data, val_data, test_data = transform(dataset[i])
#         z = model.encode(train_data.x, train_data.edge_index)
#         adj_mat = np.zeros((n_node, n_node))
#         for j in range(n_node*n_node):
#             adj_mat[int(edge_index[0, j]), int(edge_index[1, j])] = (model.decode(z, edge_index)[j].detach().numpy()).item()
#         adj_list.append(adj_mat)

# %%
def sample_adj_mat_1v1(filter_value=0.75, filter_eye=True, data=train_data):
    model.__mu__ = model.encode(data.x, data.edge_index)
    z = model.__mu__
    adj_mat_temp = np.zeros((n_node, n_node))
    for j in range(n_node*n_node):
        adj_mat_temp[int(edge_index[0, j]), int(edge_index[1, j])] = (model.decode(z, edge_index)[j].detach().numpy()).item()
    adj_mat_temp[adj_mat_temp < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat_temp.shape[0]):
            adj_mat_temp[i,i]=0
    return adj_mat_temp,z

# %%
generated_from_simu = []
generated_simu_centrality = []

for i in range(30):
    train_data, val_data, test_data = transform(dataset[i])
    adj_mat,z = sample_adj_mat_1v1(filter_value=0.7, data=train_data)
    generated_from_simu.append(adj_mat)
    generated_simu_centrality.append(compute_centrality(adj_mat))

# %%
for k in range(30):
    plt.subplot(5,6,k+1)    
    plt.imshow(generated_from_simu[k], cmap="Greys")

# %%
simu_adj_list = []
simu_centrality_list = []
for i in range(30):
    adj_mat = simu_graph.simu_adj_m()[i].detach().numpy()
    simu_adj_list.append(adj_mat)
    simu_centrality_list.append(compute_centrality(adj_mat))

# %%
from scipy import stats
res = stats.ttest_ind(generated_simu_centrality, simu_centrality_list, 
                      equal_var=True, axis=0)

display(res)
# Out:
# Ttest_indResult(statistic=array([10.9626299 ,  7.72221656,  6.83576265, 10.90027879,  7.30782241,
#         5.06947448,  4.67625578,  5.46005156,  4.36472405,  3.67482036]), pvalue=array([9.22560262e-16, 1.79141975e-10, 5.52910643e-09, 1.15476003e-15,
#        8.90699386e-10, 4.36641318e-06, 1.79001177e-05, 1.03786335e-06,
#        5.30676393e-05, 5.21304751e-04]))

# %%
np.mean(np.vstack(generated_simu_centrality), axis=0)
# Out:
# array([0.3608369 , 0.36724798, 0.34949856, 0.37162413, 0.34025561,
#        0.07104433, 0.09292881, 0.09442856, 0.08354401, 0.04944068])

# %%
np.mean(np.vstack(simu_centrality_list), axis=0)
# Out:
# array([0.17999996, 0.19666664, 0.22333333, 0.16999999, 0.19666663,
#        0.        , 0.        , 0.        , 0.        , 0.        ],
#       dtype=float32)
