# %%
import torch
from torch_geometric.utils import (negative_sampling, remove_self_loops,
                                   add_self_loops)
EPS = 1e-15
MAX_LOGSTD = 1

class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""
    def forward(self, z, edge_index, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value


    def forward_all(self, z, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj



class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (Module): The encoder module.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        reset(self.encoder)
        reset(self.decoder)


    def encode(self, *args, **kwargs):
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)


    def decode(self, *args, **kwargs):
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)


    def recon_loss(self, z, pos_edge_index, neg_edge_index=None):
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :oenbj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to train against.
            neg_edge_index (LongTensor, optional): The negative edges to train
                against. If not given, uses negative sampling to calculate
                negative edges. (default: :obj:`None`)
        """

        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()

        # Do not include self-loops in negative samples
        pos_edge_index, _ = remove_self_loops(pos_edge_index)
        pos_edge_index, _ = add_self_loops(pos_edge_index)
        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index, sigmoid=True) +
                              EPS).mean()

        return pos_loss + neg_loss


    def test(self, z, pos_edge_index, neg_edge_index):
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        scores.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to evaluate
                against.
            neg_edge_index (LongTensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import roc_auc_score, average_precision_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)
        
        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)



class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (Module): The encoder module to compute :math:`\mu` and
            :math:`\log\sigma^2`.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(VGAE, self).__init__(encoder, decoder)

    def reparametrize(self, mu, logstd):
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs):
        """"""
        self.__mu__, self.__logstd__ = self.encoder(*args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z

    def kl_loss(self, mu=None, logstd=None):
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (Tensor, optional): The latent space for :math:`\mu`. If set to
                :obj:`None`, uses the last computation of :math:`mu`.
                (default: :obj:`None`)
            logstd (Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`.(default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch
from torch.autograd.grad_mode import F
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges
from torch_geometric.nn import VGAE

import scipy.sparse as sp
import numpy as np
import networkx as nx

class SimuData():
    """Simulate graph data"""
    def __init__(self, p=0.5, n_node=10, n_graph=30):
        self.n_node = n_node
        self.n_graph = n_graph
        self.p = p

    def simu_adj_wgh(self):
        adj_list = []

        for i in range(self.n_graph):
            ## zero matrix
            A = torch.zeros(self.n_node, self.n_node)

            # first five nodes weights: uniform(0,1)A[:5,:5] = W
            W = torch.rand(4,4)

            ## symmetric
            i, j = torch.triu_indices(4, 4)
            W[i, j] = W.T[i, j]
            A[:4,:4] = W
            for i in range(4,7):
                 A[i,i] = 1
            adj_list.append(A)  

        return adj_list

    def simu_adj_diag(self):
        adj_list = []

        for i in range(self.n_graph):
            A = torch.eye(self.n_node)
            adj_list.append(A)  

        return adj_list

    def simu_adj_m(self):
        """generating adjacency matrix"""
        adj_wgh = self.simu_adj_wgh()
        #adj_wgh = self.simu_adj_diag()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>=1-self.p] = 1
            adj[adj<1-self.p] = 0
            adj_m_list.append(adj)    
        return adj_m_list

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.simu_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)

        return dataset

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)


class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=False) 
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=False)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=False)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)


transform = T.Compose([
            T.NormalizeFeatures(),
            T.RandomLinkSplit(num_val=0, num_test=0, is_undirected=True,
                            split_labels=True, add_negative_train_samples=False),])

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix


class LoadData():
    """Load graph data"""
    def __init__(self, file_path, samples, n_node=38):
        self.samples = samples
        self.file_path = file_path
        self.nSample = len(samples)
        self.n_node = n_node

    def get_adj_wgh(self):
        """generating adjacency matrix"""
        adj_orig_list =[]
        for sample in self.samples:
            f_name = self.file_path + ".".join([sample])
            adj   = np.asarray(pd.read_csv(f_name, index_col = 0, iterator = False))
            adj_orig_list.append(adj)    

        return adj_orig_list

    def get_adj_label(self):
        adj_m = self.get_adj_m()
        adj_label_list =[]
        
        for _, adj in enumerate(adj_m):
            adj_label = adj + sp.eye(adj.shape[0])
            adj_label = sparse_to_tuple(sp.coo_matrix(adj_label))
            #adj_label = sparse_to_tuple(adj_label)
            adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T), 
                            torch.FloatTensor(adj_label[1]), 
                            torch.Size(adj_label[2]))
            adj_label_list.append(adj_label)
        return adj_label_list

    def get_adj_norm(self):
        adj_m = self.get_adj_m()
        adj_norm_list =[]

        for _, adj in enumerate(adj_m):
            adj_norm = preprocess_graph(adj)
            adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T), 
                            torch.FloatTensor(adj_norm[1]), 
                            torch.Size(adj_norm[2]))
            adj_norm_list.append(adj_norm)

        return adj_norm_list

    def get_adj_m(self):
        adj_wgh = self.get_adj_wgh()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>0] = 1
            for i in range(38):
                adj[i, i] = 0
            for i in range(38):
                for j in range(38):
                    if adj[i, j] == 1:
                        adj[j, i] = 1
            adj_m_list.append(adj)    
        return adj_m_list

    def get_feature(self):
        """generating feature matrix X"""
        adj_wgh = self.get_adj_wgh()
        x_list = []
        for _, adj in enumerate(adj_wgh):
            x_feature  = adj
            x_feature  = csr_matrix(x_feature)
            x_feature  = sparse_to_tuple(x_feature)
            x_feature  = torch.sparse.FloatTensor(torch.LongTensor(x_feature[0].T), 
                            torch.FloatTensor(x_feature[1]), 
                            torch.Size(x_feature[2]))
            x_list.append(x_feature)
        return x_list

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)   

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.get_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)
        return dataset


def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    
    return sparse_to_tuple(adj_normalized)

from os import walk

def get_filename(mypath):
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        break
    return f

# %%
n_node = 10
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
simu_graph = SimuData(n_graph=30, p=0.5)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

# %%
# original adj matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(10,10))
for i in range(30):
    plt.subplot(5, 6, i+1)
    plt.imshow(simu_graph.simu_adj_m()[i], cmap="Greys")

# %%
out_channels = 2
n_node = 10
num_features = n_node

VGAE_Encoder = Encoder(num_features, out_channels)
model = VGAE(VGAE_Encoder)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
epochs = 5000

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 * model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))
# Out:
# 0tensor(14.3193, grad_fn=<DivBackward0>)
# 1tensor(14.2225, grad_fn=<DivBackward0>)
# 2tensor(15.1838, grad_fn=<DivBackward0>)
# 3tensor(15.5565, grad_fn=<DivBackward0>)
# 4tensor(15.0399, grad_fn=<DivBackward0>)
# 5tensor(16.7606, grad_fn=<DivBackward0>)
# 6tensor(14.3964, grad_fn=<DivBackward0>)
# 7tensor(15.0288, grad_fn=<DivBackward0>)
# 8tensor(14.4796, grad_fn=<DivBackward0>)
# 9tensor(13.7412, grad_fn=<DivBackward0>)
# 10tensor(14.1996, grad_fn=<DivBackward0>)
# 11tensor(13.6008, grad_fn=<DivBackward0>)
# 12tensor(13.7104, grad_fn=<DivBackward0>)
# 13tensor(13.0794, grad_fn=<DivBackward0>)
# 14tensor(14.4545, grad_fn=<DivBackward0>)
# 15tensor(13.2966, grad_fn=<DivBackward0>)
# 16tensor(13.7908, grad_fn=<DivBackward0>)
# 17tensor(13.9344, grad_fn=<DivBackward0>)
# 18tensor(13.7202, grad_fn=<DivBackward0>)
# 19tensor(13.4906, grad_fn=<DivBackward0>)
# 20tensor(13.1427, grad_fn=<DivBackward0>)
# 21tensor(13.3769, grad_fn=<DivBackward0>)
# 22tensor(13.2724, grad_fn=<DivBackward0>)
# 23tensor(12.6642, grad_fn=<DivBackward0>)
# 24tensor(13.5069, grad_fn=<DivBackward0>)
# 25tensor(13.6489, grad_fn=<DivBackward0>)
# 26tensor(12.7702, grad_fn=<DivBackward0>)
# 27tensor(12.9811, grad_fn=<DivBackward0>)
# 28tensor(13.0070, grad_fn=<DivBackward0>)
# 29tensor(12.7313, grad_fn=<DivBackward0>)
# 30tensor(13.7619, grad_fn=<DivBackward0>)
# 31tensor(13.1916, grad_fn=<DivBackward0>)
# 32tensor(12.6741, grad_fn=<DivBackward0>)
# 33tensor(13.2884, grad_fn=<DivBackward0>)
# 34tensor(13.3351, grad_fn=<DivBackward0>)
# 35tensor(12.9165, grad_fn=<DivBackward0>)
# 36tensor(13.2943, grad_fn=<DivBackward0>)
# 37tensor(13.0045, grad_fn=<DivBackward0>)
# 38tensor(13.2609, grad_fn=<DivBackward0>)
# 39tensor(12.8912, grad_fn=<DivBackward0>)
# 40tensor(12.7938, grad_fn=<DivBackward0>)
# 41tensor(12.7842, grad_fn=<DivBackward0>)
# 42tensor(12.9082, grad_fn=<DivBackward0>)
# 43tensor(12.8327, grad_fn=<DivBackward0>)
# 44tensor(13.0543, grad_fn=<DivBackward0>)
# 45tensor(12.5743, grad_fn=<DivBackward0>)
# 46tensor(12.3316, grad_fn=<DivBackward0>)
# 47tensor(12.2994, grad_fn=<DivBackward0>)
# 48tensor(12.6802, grad_fn=<DivBackward0>)
# 49tensor(12.5910, grad_fn=<DivBackward0>)
# 50tensor(12.4920, grad_fn=<DivBackward0>)
# 51tensor(12.6324, grad_fn=<DivBackward0>)
# 52tensor(12.6494, grad_fn=<DivBackward0>)
# 53tensor(12.6317, grad_fn=<DivBackward0>)
# 54tensor(12.0693, grad_fn=<DivBackward0>)
# 55tensor(12.0464, grad_fn=<DivBackward0>)
# 56tensor(11.9229, grad_fn=<DivBackward0>)
# 57tensor(11.8205, grad_fn=<DivBackward0>)
# 58tensor(11.5937, grad_fn=<DivBackward0>)
# 59tensor(11.2469, grad_fn=<DivBackward0>)
# 60tensor(11.2594, grad_fn=<DivBackward0>)
# 61tensor(10.8085, grad_fn=<DivBackward0>)
# 62tensor(10.5964, grad_fn=<DivBackward0>)
# 63tensor(10.2432, grad_fn=<DivBackward0>)
# 64tensor(10.1014, grad_fn=<DivBackward0>)
# 65tensor(10.4596, grad_fn=<DivBackward0>)
# 66tensor(9.9626, grad_fn=<DivBackward0>)
# 67tensor(10.4153, grad_fn=<DivBackward0>)
# 68tensor(9.6383, grad_fn=<DivBackward0>)
# 69tensor(9.9157, grad_fn=<DivBackward0>)
# 70tensor(9.3237, grad_fn=<DivBackward0>)
# 71tensor(9.7635, grad_fn=<DivBackward0>)
# 72tensor(9.3993, grad_fn=<DivBackward0>)
# 73tensor(9.2188, grad_fn=<DivBackward0>)
# 74tensor(9.9448, grad_fn=<DivBackward0>)
# 75tensor(9.4765, grad_fn=<DivBackward0>)
# 76tensor(9.4112, grad_fn=<DivBackward0>)
# 77tensor(9.5053, grad_fn=<DivBackward0>)
# 78tensor(8.8921, grad_fn=<DivBackward0>)
# 79tensor(9.7270, grad_fn=<DivBackward0>)
# 80tensor(8.8446, grad_fn=<DivBackward0>)
# 81tensor(10.0367, grad_fn=<DivBackward0>)
# 82tensor(8.5836, grad_fn=<DivBackward0>)
# 83tensor(9.6613, grad_fn=<DivBackward0>)
# 84tensor(9.3923, grad_fn=<DivBackward0>)
# 85tensor(9.1343, grad_fn=<DivBackward0>)
# 86tensor(8.8879, grad_fn=<DivBackward0>)
# 87tensor(8.7940, grad_fn=<DivBackward0>)
# 88tensor(8.2477, grad_fn=<DivBackward0>)
# 89tensor(9.0085, grad_fn=<DivBackward0>)
# 90tensor(8.1552, grad_fn=<DivBackward0>)
# 91tensor(9.3114, grad_fn=<DivBackward0>)
# 92tensor(8.1179, grad_fn=<DivBackward0>)
# 93tensor(8.0016, grad_fn=<DivBackward0>)
# 94tensor(8.9965, grad_fn=<DivBackward0>)
# 95tensor(8.4948, grad_fn=<DivBackward0>)
# 96tensor(8.4428, grad_fn=<DivBackward0>)
# 97tensor(8.5929, grad_fn=<DivBackward0>)
# 98tensor(8.1807, grad_fn=<DivBackward0>)
# 99tensor(8.5218, grad_fn=<DivBackward0>)
# 100tensor(9.0429, grad_fn=<DivBackward0>)
# 101tensor(8.4212, grad_fn=<DivBackward0>)
# 102tensor(8.3121, grad_fn=<DivBackward0>)
# 103tensor(8.5359, grad_fn=<DivBackward0>)
# 104tensor(8.0720, grad_fn=<DivBackward0>)
# 105tensor(8.3845, grad_fn=<DivBackward0>)
# 106tensor(8.3427, grad_fn=<DivBackward0>)
# 107tensor(8.2509, grad_fn=<DivBackward0>)
# 108tensor(8.8155, grad_fn=<DivBackward0>)
# 109tensor(8.4405, grad_fn=<DivBackward0>)
# 110tensor(8.3938, grad_fn=<DivBackward0>)
# 111tensor(8.1299, grad_fn=<DivBackward0>)
# 112tensor(8.5491, grad_fn=<DivBackward0>)
# 113tensor(9.0987, grad_fn=<DivBackward0>)
# 114tensor(8.4636, grad_fn=<DivBackward0>)
# 115tensor(8.8029, grad_fn=<DivBackward0>)
# 116tensor(8.5704, grad_fn=<DivBackward0>)
# 117tensor(8.9321, grad_fn=<DivBackward0>)
# 118tensor(8.0856, grad_fn=<DivBackward0>)
# 119tensor(8.3143, grad_fn=<DivBackward0>)
# 120tensor(8.4190, grad_fn=<DivBackward0>)
# 121tensor(8.9238, grad_fn=<DivBackward0>)
# 122tensor(8.5303, grad_fn=<DivBackward0>)
# 123tensor(8.2066, grad_fn=<DivBackward0>)
# 124tensor(8.7685, grad_fn=<DivBackward0>)
# 125tensor(8.8798, grad_fn=<DivBackward0>)
# 126tensor(8.3604, grad_fn=<DivBackward0>)
# 127tensor(8.0480, grad_fn=<DivBackward0>)
# 128tensor(8.7472, grad_fn=<DivBackward0>)
# 129tensor(8.1988, grad_fn=<DivBackward0>)
# 130tensor(8.4902, grad_fn=<DivBackward0>)
# 131tensor(8.1590, grad_fn=<DivBackward0>)
# 132tensor(7.9942, grad_fn=<DivBackward0>)
# 133tensor(8.1149, grad_fn=<DivBackward0>)
# 134tensor(8.8190, grad_fn=<DivBackward0>)
# 135tensor(8.0473, grad_fn=<DivBackward0>)
# 136tensor(8.3543, grad_fn=<DivBackward0>)
# 137tensor(8.8106, grad_fn=<DivBackward0>)
# 138tensor(8.7600, grad_fn=<DivBackward0>)
# 139tensor(8.4144, grad_fn=<DivBackward0>)
# 140tensor(8.3788, grad_fn=<DivBackward0>)
# 141tensor(8.5236, grad_fn=<DivBackward0>)
# 142tensor(8.0278, grad_fn=<DivBackward0>)
# 143tensor(7.8913, grad_fn=<DivBackward0>)
# 144tensor(8.9393, grad_fn=<DivBackward0>)
# 145tensor(8.1396, grad_fn=<DivBackward0>)
# 146tensor(8.6736, grad_fn=<DivBackward0>)
# 147tensor(8.2800, grad_fn=<DivBackward0>)
# 148tensor(8.3622, grad_fn=<DivBackward0>)
# 149tensor(7.8593, grad_fn=<DivBackward0>)
# 150tensor(8.2724, grad_fn=<DivBackward0>)
# 151tensor(7.8515, grad_fn=<DivBackward0>)
# 152tensor(8.3178, grad_fn=<DivBackward0>)
# 153tensor(7.9896, grad_fn=<DivBackward0>)
# 154tensor(7.8311, grad_fn=<DivBackward0>)
# 155tensor(9.5648, grad_fn=<DivBackward0>)
# 156tensor(8.2067, grad_fn=<DivBackward0>)
# 157tensor(7.9379, grad_fn=<DivBackward0>)
# 158tensor(8.0872, grad_fn=<DivBackward0>)
# 159tensor(7.8217, grad_fn=<DivBackward0>)
# 160tensor(8.1398, grad_fn=<DivBackward0>)
# 161tensor(8.3725, grad_fn=<DivBackward0>)
# 162tensor(8.5551, grad_fn=<DivBackward0>)
# 163tensor(8.4182, grad_fn=<DivBackward0>)
# 164tensor(8.3642, grad_fn=<DivBackward0>)
# 165tensor(8.4342, grad_fn=<DivBackward0>)
# 166tensor(7.8358, grad_fn=<DivBackward0>)
# 167tensor(8.0389, grad_fn=<DivBackward0>)
# 168tensor(8.5870, grad_fn=<DivBackward0>)
# 169tensor(8.0213, grad_fn=<DivBackward0>)
# 170tensor(7.6952, grad_fn=<DivBackward0>)
# 171tensor(8.4655, grad_fn=<DivBackward0>)
# 172tensor(8.3820, grad_fn=<DivBackward0>)
# 173tensor(8.3156, grad_fn=<DivBackward0>)
# 174tensor(8.5471, grad_fn=<DivBackward0>)
# 175tensor(8.4070, grad_fn=<DivBackward0>)
# 176tensor(8.1054, grad_fn=<DivBackward0>)
# 177tensor(8.6106, grad_fn=<DivBackward0>)
# 178tensor(8.2789, grad_fn=<DivBackward0>)
# 179tensor(8.7544, grad_fn=<DivBackward0>)
# 180tensor(8.0800, grad_fn=<DivBackward0>)
# 181tensor(8.5348, grad_fn=<DivBackward0>)
# 182tensor(8.5076, grad_fn=<DivBackward0>)
# 183tensor(8.0372, grad_fn=<DivBackward0>)
# 184tensor(7.9891, grad_fn=<DivBackward0>)
# 185tensor(7.8379, grad_fn=<DivBackward0>)
# 186tensor(8.3748, grad_fn=<DivBackward0>)
# 187tensor(7.7843, grad_fn=<DivBackward0>)
# 188tensor(7.5381, grad_fn=<DivBackward0>)
# 189tensor(8.5686, grad_fn=<DivBackward0>)
# 190tensor(8.5223, grad_fn=<DivBackward0>)
# 191tensor(7.8136, grad_fn=<DivBackward0>)
# 192tensor(7.7324, grad_fn=<DivBackward0>)
# 193tensor(8.7398, grad_fn=<DivBackward0>)
# 194tensor(8.9070, grad_fn=<DivBackward0>)
# 195tensor(8.0807, grad_fn=<DivBackward0>)
# 196tensor(8.3825, grad_fn=<DivBackward0>)
# 197tensor(7.9490, grad_fn=<DivBackward0>)
# 198tensor(8.0478, grad_fn=<DivBackward0>)
# 199tensor(8.3561, grad_fn=<DivBackward0>)
# 200tensor(8.1018, grad_fn=<DivBackward0>)
# 201tensor(7.8253, grad_fn=<DivBackward0>)
# 202tensor(7.9031, grad_fn=<DivBackward0>)
# 203tensor(8.3649, grad_fn=<DivBackward0>)
# 204tensor(8.2584, grad_fn=<DivBackward0>)
# 205tensor(7.7003, grad_fn=<DivBackward0>)
# 206tensor(8.6124, grad_fn=<DivBackward0>)
# 207tensor(8.5823, grad_fn=<DivBackward0>)
# 208tensor(7.9233, grad_fn=<DivBackward0>)
# 209tensor(8.8700, grad_fn=<DivBackward0>)
# 210tensor(8.7326, grad_fn=<DivBackward0>)
# 211tensor(8.4544, grad_fn=<DivBackward0>)
# 212tensor(8.2068, grad_fn=<DivBackward0>)
# 213tensor(7.5797, grad_fn=<DivBackward0>)
# 214tensor(8.6011, grad_fn=<DivBackward0>)
# 215tensor(8.2943, grad_fn=<DivBackward0>)
# 216tensor(8.0449, grad_fn=<DivBackward0>)
# 217tensor(7.5158, grad_fn=<DivBackward0>)
# 218tensor(8.4017, grad_fn=<DivBackward0>)
# 219tensor(8.5325, grad_fn=<DivBackward0>)
# 220tensor(8.0289, grad_fn=<DivBackward0>)
# 221tensor(7.8562, grad_fn=<DivBackward0>)
# 222tensor(8.6381, grad_fn=<DivBackward0>)
# 223tensor(8.2374, grad_fn=<DivBackward0>)
# 224tensor(8.4115, grad_fn=<DivBackward0>)
# 225tensor(8.2411, grad_fn=<DivBackward0>)
# 226tensor(8.0757, grad_fn=<DivBackward0>)
# 227tensor(8.0128, grad_fn=<DivBackward0>)
# 228tensor(8.2112, grad_fn=<DivBackward0>)
# 229tensor(7.7507, grad_fn=<DivBackward0>)
# 230tensor(8.3680, grad_fn=<DivBackward0>)
# 231tensor(7.6675, grad_fn=<DivBackward0>)
# 232tensor(8.4415, grad_fn=<DivBackward0>)
# 233tensor(7.8769, grad_fn=<DivBackward0>)
# 234tensor(8.5146, grad_fn=<DivBackward0>)
# 235tensor(8.2650, grad_fn=<DivBackward0>)
# 236tensor(7.7338, grad_fn=<DivBackward0>)
# 237tensor(7.9001, grad_fn=<DivBackward0>)
# 238tensor(8.5287, grad_fn=<DivBackward0>)
# 239tensor(8.2225, grad_fn=<DivBackward0>)
# 240tensor(8.3489, grad_fn=<DivBackward0>)
# 241tensor(7.8622, grad_fn=<DivBackward0>)
# 242tensor(8.7454, grad_fn=<DivBackward0>)
# 243tensor(8.1625, grad_fn=<DivBackward0>)
# 244tensor(8.1099, grad_fn=<DivBackward0>)
# 245tensor(8.2225, grad_fn=<DivBackward0>)
# 246tensor(8.2924, grad_fn=<DivBackward0>)
# 247tensor(8.5864, grad_fn=<DivBackward0>)
# 248tensor(7.9902, grad_fn=<DivBackward0>)
# 249tensor(8.4093, grad_fn=<DivBackward0>)
# 250tensor(8.3230, grad_fn=<DivBackward0>)
# 251tensor(8.1542, grad_fn=<DivBackward0>)
# 252tensor(8.1114, grad_fn=<DivBackward0>)
# 253tensor(8.1247, grad_fn=<DivBackward0>)
# 254tensor(8.6997, grad_fn=<DivBackward0>)
# 255tensor(8.1882, grad_fn=<DivBackward0>)
# 256tensor(8.1938, grad_fn=<DivBackward0>)
# 257tensor(8.7714, grad_fn=<DivBackward0>)
# 258tensor(8.2202, grad_fn=<DivBackward0>)
# 259tensor(7.6716, grad_fn=<DivBackward0>)
# 260tensor(8.1477, grad_fn=<DivBackward0>)
# 261tensor(8.1013, grad_fn=<DivBackward0>)
# 262tensor(8.2236, grad_fn=<DivBackward0>)
# 263tensor(8.0634, grad_fn=<DivBackward0>)
# 264tensor(8.2811, grad_fn=<DivBackward0>)
# 265tensor(7.9493, grad_fn=<DivBackward0>)
# 266tensor(8.3100, grad_fn=<DivBackward0>)
# 267tensor(7.7070, grad_fn=<DivBackward0>)
# 268tensor(8.5382, grad_fn=<DivBackward0>)
# 269tensor(7.8716, grad_fn=<DivBackward0>)
# 270tensor(7.9693, grad_fn=<DivBackward0>)
# 271tensor(8.2301, grad_fn=<DivBackward0>)
# 272tensor(8.8295, grad_fn=<DivBackward0>)
# 273tensor(8.1325, grad_fn=<DivBackward0>)
# 274tensor(7.9378, grad_fn=<DivBackward0>)
# 275tensor(7.7068, grad_fn=<DivBackward0>)
# 276tensor(8.1239, grad_fn=<DivBackward0>)
# 277tensor(8.1340, grad_fn=<DivBackward0>)
# 278tensor(7.7856, grad_fn=<DivBackward0>)
# 279tensor(8.3741, grad_fn=<DivBackward0>)
# 280tensor(8.5113, grad_fn=<DivBackward0>)
# 281tensor(7.6622, grad_fn=<DivBackward0>)
# 282tensor(7.4780, grad_fn=<DivBackward0>)
# 283tensor(8.1789, grad_fn=<DivBackward0>)
# 284tensor(7.8462, grad_fn=<DivBackward0>)
# 285tensor(8.2442, grad_fn=<DivBackward0>)
# 286tensor(7.6447, grad_fn=<DivBackward0>)
# 287tensor(7.8689, grad_fn=<DivBackward0>)
# 288tensor(8.3978, grad_fn=<DivBackward0>)
# 289tensor(8.1882, grad_fn=<DivBackward0>)
# 290tensor(7.5294, grad_fn=<DivBackward0>)
# 291tensor(7.6474, grad_fn=<DivBackward0>)
# 292tensor(8.5929, grad_fn=<DivBackward0>)
# 293tensor(8.2651, grad_fn=<DivBackward0>)
# 294tensor(8.1463, grad_fn=<DivBackward0>)
# 295tensor(7.6022, grad_fn=<DivBackward0>)
# 296tensor(8.1158, grad_fn=<DivBackward0>)
# 297tensor(8.0252, grad_fn=<DivBackward0>)
# 298tensor(7.7625, grad_fn=<DivBackward0>)
# 299tensor(8.3329, grad_fn=<DivBackward0>)
# 300tensor(8.2880, grad_fn=<DivBackward0>)
# 301tensor(7.2392, grad_fn=<DivBackward0>)
# 302tensor(7.9959, grad_fn=<DivBackward0>)
# 303tensor(7.7933, grad_fn=<DivBackward0>)
# 304tensor(8.3048, grad_fn=<DivBackward0>)
# 305tensor(7.5528, grad_fn=<DivBackward0>)
# 306tensor(8.3127, grad_fn=<DivBackward0>)
# 307tensor(7.8594, grad_fn=<DivBackward0>)
# 308tensor(8.2353, grad_fn=<DivBackward0>)
# 309tensor(8.0027, grad_fn=<DivBackward0>)
# 310tensor(7.7681, grad_fn=<DivBackward0>)
# 311tensor(8.3993, grad_fn=<DivBackward0>)
# 312tensor(7.4948, grad_fn=<DivBackward0>)
# 313tensor(7.8699, grad_fn=<DivBackward0>)
# 314tensor(8.4249, grad_fn=<DivBackward0>)
# 315tensor(7.9857, grad_fn=<DivBackward0>)
# 316tensor(7.7325, grad_fn=<DivBackward0>)
# 317tensor(8.1082, grad_fn=<DivBackward0>)
# 318tensor(7.3235, grad_fn=<DivBackward0>)
# 319tensor(8.3084, grad_fn=<DivBackward0>)
# 320tensor(8.8169, grad_fn=<DivBackward0>)
# 321tensor(7.8704, grad_fn=<DivBackward0>)
# 322tensor(7.8726, grad_fn=<DivBackward0>)
# 323tensor(7.6998, grad_fn=<DivBackward0>)
# 324tensor(7.9141, grad_fn=<DivBackward0>)
# 325tensor(8.0690, grad_fn=<DivBackward0>)
# 326tensor(8.6255, grad_fn=<DivBackward0>)
# 327tensor(8.0961, grad_fn=<DivBackward0>)
# 328tensor(7.9506, grad_fn=<DivBackward0>)
# 329tensor(8.3352, grad_fn=<DivBackward0>)
# 330tensor(8.0629, grad_fn=<DivBackward0>)
# 331tensor(8.7757, grad_fn=<DivBackward0>)
# 332tensor(7.8542, grad_fn=<DivBackward0>)
# 333tensor(8.1532, grad_fn=<DivBackward0>)
# 334tensor(7.7859, grad_fn=<DivBackward0>)
# 335tensor(7.9751, grad_fn=<DivBackward0>)
# 336tensor(7.8406, grad_fn=<DivBackward0>)
# 337tensor(7.6492, grad_fn=<DivBackward0>)
# 338tensor(8.0147, grad_fn=<DivBackward0>)
# 339tensor(7.8251, grad_fn=<DivBackward0>)
# 340tensor(7.1597, grad_fn=<DivBackward0>)
# 341tensor(7.7230, grad_fn=<DivBackward0>)
# 342tensor(7.7449, grad_fn=<DivBackward0>)
# 343tensor(7.8869, grad_fn=<DivBackward0>)
# 344tensor(7.4809, grad_fn=<DivBackward0>)
# 345tensor(8.7402, grad_fn=<DivBackward0>)
# 346tensor(7.5955, grad_fn=<DivBackward0>)
# 347tensor(7.6839, grad_fn=<DivBackward0>)
# 348tensor(7.7166, grad_fn=<DivBackward0>)
# 349tensor(7.8741, grad_fn=<DivBackward0>)
# 350tensor(7.8055, grad_fn=<DivBackward0>)
# 351tensor(7.9598, grad_fn=<DivBackward0>)
# 352tensor(7.6753, grad_fn=<DivBackward0>)
# 353tensor(8.3370, grad_fn=<DivBackward0>)
# 354tensor(8.1357, grad_fn=<DivBackward0>)
# 355tensor(7.7499, grad_fn=<DivBackward0>)
# 356tensor(7.4008, grad_fn=<DivBackward0>)
# 357tensor(8.0370, grad_fn=<DivBackward0>)
# 358tensor(6.9557, grad_fn=<DivBackward0>)
# 359tensor(8.0751, grad_fn=<DivBackward0>)
# 360tensor(8.1820, grad_fn=<DivBackward0>)
# 361tensor(8.7080, grad_fn=<DivBackward0>)
# 362tensor(8.1772, grad_fn=<DivBackward0>)
# 363tensor(7.7055, grad_fn=<DivBackward0>)
# 364tensor(8.2113, grad_fn=<DivBackward0>)
# 365tensor(8.0035, grad_fn=<DivBackward0>)
# 366tensor(7.9417, grad_fn=<DivBackward0>)
# 367tensor(8.0223, grad_fn=<DivBackward0>)
# 368tensor(8.3005, grad_fn=<DivBackward0>)
# 369tensor(8.2427, grad_fn=<DivBackward0>)
# 370tensor(8.3057, grad_fn=<DivBackward0>)
# 371tensor(8.2060, grad_fn=<DivBackward0>)
# 372tensor(8.3502, grad_fn=<DivBackward0>)
# 373tensor(7.9511, grad_fn=<DivBackward0>)
# 374tensor(7.9413, grad_fn=<DivBackward0>)
# 375tensor(8.6910, grad_fn=<DivBackward0>)
# 376tensor(7.4033, grad_fn=<DivBackward0>)
# 377tensor(7.8060, grad_fn=<DivBackward0>)
# 378tensor(8.7676, grad_fn=<DivBackward0>)
# 379tensor(7.8669, grad_fn=<DivBackward0>)
# 380tensor(7.9953, grad_fn=<DivBackward0>)
# 381tensor(7.8431, grad_fn=<DivBackward0>)
# 382tensor(7.6939, grad_fn=<DivBackward0>)
# 383tensor(8.1047, grad_fn=<DivBackward0>)
# 384tensor(7.8392, grad_fn=<DivBackward0>)
# 385tensor(8.1587, grad_fn=<DivBackward0>)
# 386tensor(8.2306, grad_fn=<DivBackward0>)
# 387tensor(8.2346, grad_fn=<DivBackward0>)
# 388tensor(7.7187, grad_fn=<DivBackward0>)
# 389tensor(8.1358, grad_fn=<DivBackward0>)
# 390tensor(7.4221, grad_fn=<DivBackward0>)
# 391tensor(7.6038, grad_fn=<DivBackward0>)
# 392tensor(8.0226, grad_fn=<DivBackward0>)
# 393tensor(7.7775, grad_fn=<DivBackward0>)
# 394tensor(7.7411, grad_fn=<DivBackward0>)
# 395tensor(7.5036, grad_fn=<DivBackward0>)
# 396tensor(7.8930, grad_fn=<DivBackward0>)
# 397tensor(7.3847, grad_fn=<DivBackward0>)
# 398tensor(7.7316, grad_fn=<DivBackward0>)
# 399tensor(8.1896, grad_fn=<DivBackward0>)
# 400tensor(7.9990, grad_fn=<DivBackward0>)
# 401tensor(7.9138, grad_fn=<DivBackward0>)
# 402tensor(7.9111, grad_fn=<DivBackward0>)
# 403tensor(7.6705, grad_fn=<DivBackward0>)
# 404tensor(7.2157, grad_fn=<DivBackward0>)
# 405tensor(7.5658, grad_fn=<DivBackward0>)
# 406tensor(7.2949, grad_fn=<DivBackward0>)
# 407tensor(8.0897, grad_fn=<DivBackward0>)
# 408tensor(8.0886, grad_fn=<DivBackward0>)
# 409tensor(7.9001, grad_fn=<DivBackward0>)
# 410tensor(7.8938, grad_fn=<DivBackward0>)
# 411tensor(7.9443, grad_fn=<DivBackward0>)
# 412tensor(7.8144, grad_fn=<DivBackward0>)
# 413tensor(7.5007, grad_fn=<DivBackward0>)
# 414tensor(8.3882, grad_fn=<DivBackward0>)
# 415tensor(7.1612, grad_fn=<DivBackward0>)
# 416tensor(7.8017, grad_fn=<DivBackward0>)
# 417tensor(8.5049, grad_fn=<DivBackward0>)
# 418tensor(7.9743, grad_fn=<DivBackward0>)
# 419tensor(7.4614, grad_fn=<DivBackward0>)
# 420tensor(7.4781, grad_fn=<DivBackward0>)
# 421tensor(7.4288, grad_fn=<DivBackward0>)
# 422tensor(7.9302, grad_fn=<DivBackward0>)
# 423tensor(8.1516, grad_fn=<DivBackward0>)
# 424tensor(7.7345, grad_fn=<DivBackward0>)
# 425tensor(8.2871, grad_fn=<DivBackward0>)
# 426tensor(8.0356, grad_fn=<DivBackward0>)
# 427tensor(7.8177, grad_fn=<DivBackward0>)
# 428tensor(7.6824, grad_fn=<DivBackward0>)
# 429tensor(8.3149, grad_fn=<DivBackward0>)
# 430tensor(7.9375, grad_fn=<DivBackward0>)
# 431tensor(7.9864, grad_fn=<DivBackward0>)
# 432tensor(7.5733, grad_fn=<DivBackward0>)
# 433tensor(7.8908, grad_fn=<DivBackward0>)
# 434tensor(7.2303, grad_fn=<DivBackward0>)
# 435tensor(7.8475, grad_fn=<DivBackward0>)
# 436tensor(7.5567, grad_fn=<DivBackward0>)
# 437tensor(7.8580, grad_fn=<DivBackward0>)
# 438tensor(7.4859, grad_fn=<DivBackward0>)
# 439tensor(7.3640, grad_fn=<DivBackward0>)
# 440tensor(8.0677, grad_fn=<DivBackward0>)
# 441tensor(7.7617, grad_fn=<DivBackward0>)
# 442tensor(7.9264, grad_fn=<DivBackward0>)
# 443tensor(7.3091, grad_fn=<DivBackward0>)
# 444tensor(7.3640, grad_fn=<DivBackward0>)
# 445tensor(7.9069, grad_fn=<DivBackward0>)
# 446tensor(6.9779, grad_fn=<DivBackward0>)
# 447tensor(7.1413, grad_fn=<DivBackward0>)
# 448tensor(7.8247, grad_fn=<DivBackward0>)
# 449tensor(7.9502, grad_fn=<DivBackward0>)
# 450tensor(8.5283, grad_fn=<DivBackward0>)
# 451tensor(7.6002, grad_fn=<DivBackward0>)
# 452tensor(7.8423, grad_fn=<DivBackward0>)
# 453tensor(7.9760, grad_fn=<DivBackward0>)
# 454tensor(7.7227, grad_fn=<DivBackward0>)
# 455tensor(7.8016, grad_fn=<DivBackward0>)
# 456tensor(8.0825, grad_fn=<DivBackward0>)
# 457tensor(7.2574, grad_fn=<DivBackward0>)
# 458tensor(8.0483, grad_fn=<DivBackward0>)
# 459tensor(7.9196, grad_fn=<DivBackward0>)
# 460tensor(7.8513, grad_fn=<DivBackward0>)
# 461tensor(7.6551, grad_fn=<DivBackward0>)
# 462tensor(7.8417, grad_fn=<DivBackward0>)
# 463tensor(7.6900, grad_fn=<DivBackward0>)
# 464tensor(7.6063, grad_fn=<DivBackward0>)
# 465tensor(7.6074, grad_fn=<DivBackward0>)
# 466tensor(7.6365, grad_fn=<DivBackward0>)
# 467tensor(8.2386, grad_fn=<DivBackward0>)
# 468tensor(8.1647, grad_fn=<DivBackward0>)
# 469tensor(7.7461, grad_fn=<DivBackward0>)
# 470tensor(7.5824, grad_fn=<DivBackward0>)
# 471tensor(7.4679, grad_fn=<DivBackward0>)
# 472tensor(7.6956, grad_fn=<DivBackward0>)
# 473tensor(7.7505, grad_fn=<DivBackward0>)
# 474tensor(8.3565, grad_fn=<DivBackward0>)
# 475tensor(7.9364, grad_fn=<DivBackward0>)
# 476tensor(7.7161, grad_fn=<DivBackward0>)
# 477tensor(8.6145, grad_fn=<DivBackward0>)
# 478tensor(8.1854, grad_fn=<DivBackward0>)
# 479tensor(7.6622, grad_fn=<DivBackward0>)
# 480tensor(8.1195, grad_fn=<DivBackward0>)
# 481tensor(7.2906, grad_fn=<DivBackward0>)
# 482tensor(7.7569, grad_fn=<DivBackward0>)
# 483tensor(7.3743, grad_fn=<DivBackward0>)
# 484tensor(7.8532, grad_fn=<DivBackward0>)
# 485tensor(7.9837, grad_fn=<DivBackward0>)
# 486tensor(8.1526, grad_fn=<DivBackward0>)
# 487tensor(7.9292, grad_fn=<DivBackward0>)
# 488tensor(7.7319, grad_fn=<DivBackward0>)
# 489tensor(7.9998, grad_fn=<DivBackward0>)
# 490tensor(7.7882, grad_fn=<DivBackward0>)
# 491tensor(7.7244, grad_fn=<DivBackward0>)
# 492tensor(7.4284, grad_fn=<DivBackward0>)
# 493tensor(7.5062, grad_fn=<DivBackward0>)
# 494tensor(7.5094, grad_fn=<DivBackward0>)
# 495tensor(7.6120, grad_fn=<DivBackward0>)
# 496tensor(7.5001, grad_fn=<DivBackward0>)
# 497tensor(7.7983, grad_fn=<DivBackward0>)
# 498tensor(7.8883, grad_fn=<DivBackward0>)
# 499tensor(7.8268, grad_fn=<DivBackward0>)
# 500tensor(8.0667, grad_fn=<DivBackward0>)
# 501tensor(7.7610, grad_fn=<DivBackward0>)
# 502tensor(7.4700, grad_fn=<DivBackward0>)
# 503tensor(7.7450, grad_fn=<DivBackward0>)
# 504tensor(7.7452, grad_fn=<DivBackward0>)
# 505tensor(7.4313, grad_fn=<DivBackward0>)
# 506tensor(8.0557, grad_fn=<DivBackward0>)
# 507tensor(7.9551, grad_fn=<DivBackward0>)
# 508tensor(7.2433, grad_fn=<DivBackward0>)
# 509tensor(8.3083, grad_fn=<DivBackward0>)
# 510tensor(7.5457, grad_fn=<DivBackward0>)
# 511tensor(7.8692, grad_fn=<DivBackward0>)
# 512tensor(7.9449, grad_fn=<DivBackward0>)
# 513tensor(8.5169, grad_fn=<DivBackward0>)
# 514tensor(7.1901, grad_fn=<DivBackward0>)
# 515tensor(7.4699, grad_fn=<DivBackward0>)
# 516tensor(7.7687, grad_fn=<DivBackward0>)
# 517tensor(7.7113, grad_fn=<DivBackward0>)
# 518tensor(8.0882, grad_fn=<DivBackward0>)
# 519tensor(7.9163, grad_fn=<DivBackward0>)
# 520tensor(8.1206, grad_fn=<DivBackward0>)
# 521tensor(7.3593, grad_fn=<DivBackward0>)
# 522tensor(8.1224, grad_fn=<DivBackward0>)
# 523tensor(7.3163, grad_fn=<DivBackward0>)
# 524tensor(7.8729, grad_fn=<DivBackward0>)
# 525tensor(7.4108, grad_fn=<DivBackward0>)
# 526tensor(7.6349, grad_fn=<DivBackward0>)
# 527tensor(8.0391, grad_fn=<DivBackward0>)
# 528tensor(7.5801, grad_fn=<DivBackward0>)
# 529tensor(7.3518, grad_fn=<DivBackward0>)
# 530tensor(7.8815, grad_fn=<DivBackward0>)
# 531tensor(8.2273, grad_fn=<DivBackward0>)
# 532tensor(7.5540, grad_fn=<DivBackward0>)
# 533tensor(7.7962, grad_fn=<DivBackward0>)
# 534tensor(7.6659, grad_fn=<DivBackward0>)
# 535tensor(7.7677, grad_fn=<DivBackward0>)
# 536tensor(7.7076, grad_fn=<DivBackward0>)
# 537tensor(7.2932, grad_fn=<DivBackward0>)
# 538tensor(7.4095, grad_fn=<DivBackward0>)
# 539tensor(7.4621, grad_fn=<DivBackward0>)
# 540tensor(7.4319, grad_fn=<DivBackward0>)
# 541tensor(7.8051, grad_fn=<DivBackward0>)
# 542tensor(7.8191, grad_fn=<DivBackward0>)
# 543tensor(8.4047, grad_fn=<DivBackward0>)
# 544tensor(7.8981, grad_fn=<DivBackward0>)
# 545tensor(7.5921, grad_fn=<DivBackward0>)
# 546tensor(7.3636, grad_fn=<DivBackward0>)
# 547tensor(7.9361, grad_fn=<DivBackward0>)
# 548tensor(7.9636, grad_fn=<DivBackward0>)
# 549tensor(8.2852, grad_fn=<DivBackward0>)
# 550tensor(7.2730, grad_fn=<DivBackward0>)
# 551tensor(7.7607, grad_fn=<DivBackward0>)
# 552tensor(7.9177, grad_fn=<DivBackward0>)
# 553tensor(7.5602, grad_fn=<DivBackward0>)
# 554tensor(7.5710, grad_fn=<DivBackward0>)
# 555tensor(8.1637, grad_fn=<DivBackward0>)
# 556tensor(7.4238, grad_fn=<DivBackward0>)
# 557tensor(8.3063, grad_fn=<DivBackward0>)
# 558tensor(7.7170, grad_fn=<DivBackward0>)
# 559tensor(7.7888, grad_fn=<DivBackward0>)
# 560tensor(6.9943, grad_fn=<DivBackward0>)
# 561tensor(7.2966, grad_fn=<DivBackward0>)
# 562tensor(7.7712, grad_fn=<DivBackward0>)
# 563tensor(7.4360, grad_fn=<DivBackward0>)
# 564tensor(8.2976, grad_fn=<DivBackward0>)
# 565tensor(7.5871, grad_fn=<DivBackward0>)
# 566tensor(8.0187, grad_fn=<DivBackward0>)
# 567tensor(7.2451, grad_fn=<DivBackward0>)
# 568tensor(7.6786, grad_fn=<DivBackward0>)
# 569tensor(7.7140, grad_fn=<DivBackward0>)
# 570tensor(7.5589, grad_fn=<DivBackward0>)
# 571tensor(7.7216, grad_fn=<DivBackward0>)
# 572tensor(7.2712, grad_fn=<DivBackward0>)
# 573tensor(8.2712, grad_fn=<DivBackward0>)
# 574tensor(7.9762, grad_fn=<DivBackward0>)
# 575tensor(7.9528, grad_fn=<DivBackward0>)
# 576tensor(7.1258, grad_fn=<DivBackward0>)
# 577tensor(8.3901, grad_fn=<DivBackward0>)
# 578tensor(7.8931, grad_fn=<DivBackward0>)
# 579tensor(7.7353, grad_fn=<DivBackward0>)
# 580tensor(7.8904, grad_fn=<DivBackward0>)
# 581tensor(7.1038, grad_fn=<DivBackward0>)
# 582tensor(7.1561, grad_fn=<DivBackward0>)
# 583tensor(7.3787, grad_fn=<DivBackward0>)
# 584tensor(7.3591, grad_fn=<DivBackward0>)
# 585tensor(7.9654, grad_fn=<DivBackward0>)
# 586tensor(7.3528, grad_fn=<DivBackward0>)
# 587tensor(7.8723, grad_fn=<DivBackward0>)
# 588tensor(7.1150, grad_fn=<DivBackward0>)
# 589tensor(7.6315, grad_fn=<DivBackward0>)
# 590tensor(7.0024, grad_fn=<DivBackward0>)
# 591tensor(7.9108, grad_fn=<DivBackward0>)
# 592tensor(7.9200, grad_fn=<DivBackward0>)
# 593tensor(7.8730, grad_fn=<DivBackward0>)
# 594tensor(8.0691, grad_fn=<DivBackward0>)
# 595tensor(7.9877, grad_fn=<DivBackward0>)
# 596tensor(7.7343, grad_fn=<DivBackward0>)
# 597tensor(7.6875, grad_fn=<DivBackward0>)
# 598tensor(7.4828, grad_fn=<DivBackward0>)
# 599tensor(7.7136, grad_fn=<DivBackward0>)
# 600tensor(7.0850, grad_fn=<DivBackward0>)
# 601tensor(7.5974, grad_fn=<DivBackward0>)
# 602tensor(7.4838, grad_fn=<DivBackward0>)
# 603tensor(7.5043, grad_fn=<DivBackward0>)
# 604tensor(7.9255, grad_fn=<DivBackward0>)
# 605tensor(7.4194, grad_fn=<DivBackward0>)
# 606tensor(7.3462, grad_fn=<DivBackward0>)
# 607tensor(7.1689, grad_fn=<DivBackward0>)
# 608tensor(7.7945, grad_fn=<DivBackward0>)
# 609tensor(7.5901, grad_fn=<DivBackward0>)
# 610tensor(7.9728, grad_fn=<DivBackward0>)
# 611tensor(7.4734, grad_fn=<DivBackward0>)
# 612tensor(7.1986, grad_fn=<DivBackward0>)
# 613tensor(7.7147, grad_fn=<DivBackward0>)
# 614tensor(8.0499, grad_fn=<DivBackward0>)
# 615tensor(7.4426, grad_fn=<DivBackward0>)
# 616tensor(7.7947, grad_fn=<DivBackward0>)
# 617tensor(7.8650, grad_fn=<DivBackward0>)
# 618tensor(7.3318, grad_fn=<DivBackward0>)
# 619tensor(7.2165, grad_fn=<DivBackward0>)
# 620tensor(7.8131, grad_fn=<DivBackward0>)
# 621tensor(6.9992, grad_fn=<DivBackward0>)
# 622tensor(7.2313, grad_fn=<DivBackward0>)
# 623tensor(7.1753, grad_fn=<DivBackward0>)
# 624tensor(7.7151, grad_fn=<DivBackward0>)
# 625tensor(7.2994, grad_fn=<DivBackward0>)
# 626tensor(7.1345, grad_fn=<DivBackward0>)
# 627tensor(7.2973, grad_fn=<DivBackward0>)
# 628tensor(7.9955, grad_fn=<DivBackward0>)
# 629tensor(7.6750, grad_fn=<DivBackward0>)
# 630tensor(7.7871, grad_fn=<DivBackward0>)
# 631tensor(7.2528, grad_fn=<DivBackward0>)
# 632tensor(7.2121, grad_fn=<DivBackward0>)
# 633tensor(7.6317, grad_fn=<DivBackward0>)
# 634tensor(7.1312, grad_fn=<DivBackward0>)
# 635tensor(7.5798, grad_fn=<DivBackward0>)
# 636tensor(6.7850, grad_fn=<DivBackward0>)
# 637tensor(7.0237, grad_fn=<DivBackward0>)
# 638tensor(7.9478, grad_fn=<DivBackward0>)
# 639tensor(7.3534, grad_fn=<DivBackward0>)
# 640tensor(7.2387, grad_fn=<DivBackward0>)
# 641tensor(7.2881, grad_fn=<DivBackward0>)
# 642tensor(7.4952, grad_fn=<DivBackward0>)
# 643tensor(7.0308, grad_fn=<DivBackward0>)
# 644tensor(7.4010, grad_fn=<DivBackward0>)
# 645tensor(8.0620, grad_fn=<DivBackward0>)
# 646tensor(6.7758, grad_fn=<DivBackward0>)
# 647tensor(7.6700, grad_fn=<DivBackward0>)
# 648tensor(8.1566, grad_fn=<DivBackward0>)
# 649tensor(7.8613, grad_fn=<DivBackward0>)
# 650tensor(7.6300, grad_fn=<DivBackward0>)
# 651tensor(7.7524, grad_fn=<DivBackward0>)
# 652tensor(7.7336, grad_fn=<DivBackward0>)
# 653tensor(7.2781, grad_fn=<DivBackward0>)
# 654tensor(7.8130, grad_fn=<DivBackward0>)
# 655tensor(8.1804, grad_fn=<DivBackward0>)
# 656tensor(7.1201, grad_fn=<DivBackward0>)
# 657tensor(7.7771, grad_fn=<DivBackward0>)
# 658tensor(7.3317, grad_fn=<DivBackward0>)
# 659tensor(7.5060, grad_fn=<DivBackward0>)
# 660tensor(7.1545, grad_fn=<DivBackward0>)
# 661tensor(7.0051, grad_fn=<DivBackward0>)
# 662tensor(7.4949, grad_fn=<DivBackward0>)
# 663tensor(7.4960, grad_fn=<DivBackward0>)
# 664tensor(8.1048, grad_fn=<DivBackward0>)
# 665tensor(7.7896, grad_fn=<DivBackward0>)
# 666tensor(8.1056, grad_fn=<DivBackward0>)
# 667tensor(7.7596, grad_fn=<DivBackward0>)
# 668tensor(7.3136, grad_fn=<DivBackward0>)
# 669tensor(7.7662, grad_fn=<DivBackward0>)
# 670tensor(7.7314, grad_fn=<DivBackward0>)
# 671tensor(7.4193, grad_fn=<DivBackward0>)
# 672tensor(7.5940, grad_fn=<DivBackward0>)
# 673tensor(7.4523, grad_fn=<DivBackward0>)
# 674tensor(7.3779, grad_fn=<DivBackward0>)
# 675tensor(7.3258, grad_fn=<DivBackward0>)
# 676tensor(7.7667, grad_fn=<DivBackward0>)
# 677tensor(7.2732, grad_fn=<DivBackward0>)
# 678tensor(8.1352, grad_fn=<DivBackward0>)
# 679tensor(7.6230, grad_fn=<DivBackward0>)
# 680tensor(7.7639, grad_fn=<DivBackward0>)
# 681tensor(7.6328, grad_fn=<DivBackward0>)
# 682tensor(7.5039, grad_fn=<DivBackward0>)
# 683tensor(7.7960, grad_fn=<DivBackward0>)
# 684tensor(8.1466, grad_fn=<DivBackward0>)
# 685tensor(7.5992, grad_fn=<DivBackward0>)
# 686tensor(7.2573, grad_fn=<DivBackward0>)
# 687tensor(7.6944, grad_fn=<DivBackward0>)
# 688tensor(7.6122, grad_fn=<DivBackward0>)
# 689tensor(7.5637, grad_fn=<DivBackward0>)
# 690tensor(7.5509, grad_fn=<DivBackward0>)
# 691tensor(7.9806, grad_fn=<DivBackward0>)
# 692tensor(7.5695, grad_fn=<DivBackward0>)
# 693tensor(7.7753, grad_fn=<DivBackward0>)
# 694tensor(7.8179, grad_fn=<DivBackward0>)
# 695tensor(7.6853, grad_fn=<DivBackward0>)
# 696tensor(7.5654, grad_fn=<DivBackward0>)
# 697tensor(7.5897, grad_fn=<DivBackward0>)
# 698tensor(6.8980, grad_fn=<DivBackward0>)
# 699tensor(7.6421, grad_fn=<DivBackward0>)
# 700tensor(7.1650, grad_fn=<DivBackward0>)
# 701tensor(7.5445, grad_fn=<DivBackward0>)
# 702tensor(7.7384, grad_fn=<DivBackward0>)
# 703tensor(7.5999, grad_fn=<DivBackward0>)
# 704tensor(7.7911, grad_fn=<DivBackward0>)
# 705tensor(7.6039, grad_fn=<DivBackward0>)
# 706tensor(7.2608, grad_fn=<DivBackward0>)
# 707tensor(7.8599, grad_fn=<DivBackward0>)
# 708tensor(7.9869, grad_fn=<DivBackward0>)
# 709tensor(7.7716, grad_fn=<DivBackward0>)
# 710tensor(7.2679, grad_fn=<DivBackward0>)
# 711tensor(7.4918, grad_fn=<DivBackward0>)
# 712tensor(7.2283, grad_fn=<DivBackward0>)
# 713tensor(7.6774, grad_fn=<DivBackward0>)
# 714tensor(7.2586, grad_fn=<DivBackward0>)
# 715tensor(7.7205, grad_fn=<DivBackward0>)
# 716tensor(7.5310, grad_fn=<DivBackward0>)
# 717tensor(8.2552, grad_fn=<DivBackward0>)
# 718tensor(7.7572, grad_fn=<DivBackward0>)
# 719tensor(7.6751, grad_fn=<DivBackward0>)
# 720tensor(7.3345, grad_fn=<DivBackward0>)
# 721tensor(7.7062, grad_fn=<DivBackward0>)
# 722tensor(7.3698, grad_fn=<DivBackward0>)
# 723tensor(7.9914, grad_fn=<DivBackward0>)
# 724tensor(7.1708, grad_fn=<DivBackward0>)
# 725tensor(7.3889, grad_fn=<DivBackward0>)
# 726tensor(7.2453, grad_fn=<DivBackward0>)
# 727tensor(7.0826, grad_fn=<DivBackward0>)
# 728tensor(7.7508, grad_fn=<DivBackward0>)
# 729tensor(7.4189, grad_fn=<DivBackward0>)
# 730tensor(7.3279, grad_fn=<DivBackward0>)
# 731tensor(7.7319, grad_fn=<DivBackward0>)
# 732tensor(6.7746, grad_fn=<DivBackward0>)
# 733tensor(7.7230, grad_fn=<DivBackward0>)
# 734tensor(7.5972, grad_fn=<DivBackward0>)
# 735tensor(7.3206, grad_fn=<DivBackward0>)
# 736tensor(7.2977, grad_fn=<DivBackward0>)
# 737tensor(7.4775, grad_fn=<DivBackward0>)
# 738tensor(7.6528, grad_fn=<DivBackward0>)
# 739tensor(7.2449, grad_fn=<DivBackward0>)
# 740tensor(6.5832, grad_fn=<DivBackward0>)
# 741tensor(7.6182, grad_fn=<DivBackward0>)
# 742tensor(6.8179, grad_fn=<DivBackward0>)
# 743tensor(7.4197, grad_fn=<DivBackward0>)
# 744tensor(7.8398, grad_fn=<DivBackward0>)
# 745tensor(7.4345, grad_fn=<DivBackward0>)
# 746tensor(7.6172, grad_fn=<DivBackward0>)
# 747tensor(6.8434, grad_fn=<DivBackward0>)
# 748tensor(7.1224, grad_fn=<DivBackward0>)
# 749tensor(7.3643, grad_fn=<DivBackward0>)
# 750tensor(7.5690, grad_fn=<DivBackward0>)
# 751tensor(6.7176, grad_fn=<DivBackward0>)
# 752tensor(7.3316, grad_fn=<DivBackward0>)
# 753tensor(7.3927, grad_fn=<DivBackward0>)
# 754tensor(7.9216, grad_fn=<DivBackward0>)
# 755tensor(7.0442, grad_fn=<DivBackward0>)
# 756tensor(7.4619, grad_fn=<DivBackward0>)
# 757tensor(7.2183, grad_fn=<DivBackward0>)
# 758tensor(6.7853, grad_fn=<DivBackward0>)
# 759tensor(7.7274, grad_fn=<DivBackward0>)
# 760tensor(7.5057, grad_fn=<DivBackward0>)
# 761tensor(7.0190, grad_fn=<DivBackward0>)
# 762tensor(7.6664, grad_fn=<DivBackward0>)
# 763tensor(7.1851, grad_fn=<DivBackward0>)
# 764tensor(7.3759, grad_fn=<DivBackward0>)
# 765tensor(6.9569, grad_fn=<DivBackward0>)
# 766tensor(7.3304, grad_fn=<DivBackward0>)
# 767tensor(7.0098, grad_fn=<DivBackward0>)
# 768tensor(6.8734, grad_fn=<DivBackward0>)
# 769tensor(7.6269, grad_fn=<DivBackward0>)
# 770tensor(7.2519, grad_fn=<DivBackward0>)
# 771tensor(7.6955, grad_fn=<DivBackward0>)
# 772tensor(7.8991, grad_fn=<DivBackward0>)
# 773tensor(7.8884, grad_fn=<DivBackward0>)
# 774tensor(7.1182, grad_fn=<DivBackward0>)
# 775tensor(7.5777, grad_fn=<DivBackward0>)
# 776tensor(7.5396, grad_fn=<DivBackward0>)
# 777tensor(7.9284, grad_fn=<DivBackward0>)
# 778tensor(8.0649, grad_fn=<DivBackward0>)
# 779tensor(7.7082, grad_fn=<DivBackward0>)
# 780tensor(7.0267, grad_fn=<DivBackward0>)
# 781tensor(7.8166, grad_fn=<DivBackward0>)
# 782tensor(7.3641, grad_fn=<DivBackward0>)
# 783tensor(7.3616, grad_fn=<DivBackward0>)
# 784tensor(7.4101, grad_fn=<DivBackward0>)
# 785tensor(7.1971, grad_fn=<DivBackward0>)
# 786tensor(7.6193, grad_fn=<DivBackward0>)
# 787tensor(7.4498, grad_fn=<DivBackward0>)
# 788tensor(7.5638, grad_fn=<DivBackward0>)
# 789tensor(7.9000, grad_fn=<DivBackward0>)
# 790tensor(6.6475, grad_fn=<DivBackward0>)
# 791tensor(7.5616, grad_fn=<DivBackward0>)
# 792tensor(8.0609, grad_fn=<DivBackward0>)
# 793tensor(7.7428, grad_fn=<DivBackward0>)
# 794tensor(7.3594, grad_fn=<DivBackward0>)
# 795tensor(7.4683, grad_fn=<DivBackward0>)
# 796tensor(7.4125, grad_fn=<DivBackward0>)
# 797tensor(7.4351, grad_fn=<DivBackward0>)
# 798tensor(7.5238, grad_fn=<DivBackward0>)
# 799tensor(7.7997, grad_fn=<DivBackward0>)
# 800tensor(6.8595, grad_fn=<DivBackward0>)
# 801tensor(7.4981, grad_fn=<DivBackward0>)
# 802tensor(7.3551, grad_fn=<DivBackward0>)
# 803tensor(7.6046, grad_fn=<DivBackward0>)
# 804tensor(7.5568, grad_fn=<DivBackward0>)
# 805tensor(7.4043, grad_fn=<DivBackward0>)
# 806tensor(7.1699, grad_fn=<DivBackward0>)
# 807tensor(7.9414, grad_fn=<DivBackward0>)
# 808tensor(7.5576, grad_fn=<DivBackward0>)
# 809tensor(8.0302, grad_fn=<DivBackward0>)
# 810tensor(7.4175, grad_fn=<DivBackward0>)
# 811tensor(6.5664, grad_fn=<DivBackward0>)
# 812tensor(7.7936, grad_fn=<DivBackward0>)
# 813tensor(7.3248, grad_fn=<DivBackward0>)
# 814tensor(8.0111, grad_fn=<DivBackward0>)
# 815tensor(7.4500, grad_fn=<DivBackward0>)
# 816tensor(7.2057, grad_fn=<DivBackward0>)
# 817tensor(7.5813, grad_fn=<DivBackward0>)
# 818tensor(7.7756, grad_fn=<DivBackward0>)
# 819tensor(7.3400, grad_fn=<DivBackward0>)
# 820tensor(7.1922, grad_fn=<DivBackward0>)
# 821tensor(7.4750, grad_fn=<DivBackward0>)
# 822tensor(7.3035, grad_fn=<DivBackward0>)
# 823tensor(7.2448, grad_fn=<DivBackward0>)
# 824tensor(7.3558, grad_fn=<DivBackward0>)
# 825tensor(7.6169, grad_fn=<DivBackward0>)
# 826tensor(7.3596, grad_fn=<DivBackward0>)
# 827tensor(7.6707, grad_fn=<DivBackward0>)
# 828tensor(7.9640, grad_fn=<DivBackward0>)
# 829tensor(6.9692, grad_fn=<DivBackward0>)
# 830tensor(7.4853, grad_fn=<DivBackward0>)
# 831tensor(7.8634, grad_fn=<DivBackward0>)
# 832tensor(7.0756, grad_fn=<DivBackward0>)
# 833tensor(7.0496, grad_fn=<DivBackward0>)
# 834tensor(7.2738, grad_fn=<DivBackward0>)
# 835tensor(7.3942, grad_fn=<DivBackward0>)
# 836tensor(7.3687, grad_fn=<DivBackward0>)
# 837tensor(7.4846, grad_fn=<DivBackward0>)
# 838tensor(7.3056, grad_fn=<DivBackward0>)
# 839tensor(7.1763, grad_fn=<DivBackward0>)
# 840tensor(7.7596, grad_fn=<DivBackward0>)
# 841tensor(7.5757, grad_fn=<DivBackward0>)
# 842tensor(7.5087, grad_fn=<DivBackward0>)
# 843tensor(7.0883, grad_fn=<DivBackward0>)
# 844tensor(7.1532, grad_fn=<DivBackward0>)
# 845tensor(7.1706, grad_fn=<DivBackward0>)
# 846tensor(7.4555, grad_fn=<DivBackward0>)
# 847tensor(7.4975, grad_fn=<DivBackward0>)
# 848tensor(6.9956, grad_fn=<DivBackward0>)
# 849tensor(7.4649, grad_fn=<DivBackward0>)
# 850tensor(7.8426, grad_fn=<DivBackward0>)
# 851tensor(7.4670, grad_fn=<DivBackward0>)
# 852tensor(6.4140, grad_fn=<DivBackward0>)
# 853tensor(7.4437, grad_fn=<DivBackward0>)
# 854tensor(7.7346, grad_fn=<DivBackward0>)
# 855tensor(7.6518, grad_fn=<DivBackward0>)
# 856tensor(7.6166, grad_fn=<DivBackward0>)
# 857tensor(7.2887, grad_fn=<DivBackward0>)
# 858tensor(7.1071, grad_fn=<DivBackward0>)
# 859tensor(6.7026, grad_fn=<DivBackward0>)
# 860tensor(7.8278, grad_fn=<DivBackward0>)
# 861tensor(6.9111, grad_fn=<DivBackward0>)
# 862tensor(7.9225, grad_fn=<DivBackward0>)
# 863tensor(7.4438, grad_fn=<DivBackward0>)
# 864tensor(7.1874, grad_fn=<DivBackward0>)
# 865tensor(7.4498, grad_fn=<DivBackward0>)
# 866tensor(7.3797, grad_fn=<DivBackward0>)
# 867tensor(7.7309, grad_fn=<DivBackward0>)
# 868tensor(7.0574, grad_fn=<DivBackward0>)
# 869tensor(7.3704, grad_fn=<DivBackward0>)
# 870tensor(7.3183, grad_fn=<DivBackward0>)
# 871tensor(6.8862, grad_fn=<DivBackward0>)
# 872tensor(7.9490, grad_fn=<DivBackward0>)
# 873tensor(7.6499, grad_fn=<DivBackward0>)
# 874tensor(7.3008, grad_fn=<DivBackward0>)
# 875tensor(7.4371, grad_fn=<DivBackward0>)
# 876tensor(6.9601, grad_fn=<DivBackward0>)
# 877tensor(7.5521, grad_fn=<DivBackward0>)
# 878tensor(7.2572, grad_fn=<DivBackward0>)
# 879tensor(7.8095, grad_fn=<DivBackward0>)
# 880tensor(7.2137, grad_fn=<DivBackward0>)
# 881tensor(7.6412, grad_fn=<DivBackward0>)
# 882tensor(7.4052, grad_fn=<DivBackward0>)
# 883tensor(7.9033, grad_fn=<DivBackward0>)
# 884tensor(7.6452, grad_fn=<DivBackward0>)
# 885tensor(7.2828, grad_fn=<DivBackward0>)
# 886tensor(7.7313, grad_fn=<DivBackward0>)
# 887tensor(7.6661, grad_fn=<DivBackward0>)
# 888tensor(6.9894, grad_fn=<DivBackward0>)
# 889tensor(7.4150, grad_fn=<DivBackward0>)
# 890tensor(7.1270, grad_fn=<DivBackward0>)
# 891tensor(7.5892, grad_fn=<DivBackward0>)
# 892tensor(7.4060, grad_fn=<DivBackward0>)
# 893tensor(7.1704, grad_fn=<DivBackward0>)
# 894tensor(7.2147, grad_fn=<DivBackward0>)
# 895tensor(7.3184, grad_fn=<DivBackward0>)
# 896tensor(7.3083, grad_fn=<DivBackward0>)
# 897tensor(7.5040, grad_fn=<DivBackward0>)
# 898tensor(6.8818, grad_fn=<DivBackward0>)
# 899tensor(7.6237, grad_fn=<DivBackward0>)
# 900tensor(7.5322, grad_fn=<DivBackward0>)
# 901tensor(7.3831, grad_fn=<DivBackward0>)
# 902tensor(6.9814, grad_fn=<DivBackward0>)
# 903tensor(7.3140, grad_fn=<DivBackward0>)
# 904tensor(7.2678, grad_fn=<DivBackward0>)
# 905tensor(7.0632, grad_fn=<DivBackward0>)
# 906tensor(7.5045, grad_fn=<DivBackward0>)
# 907tensor(7.4411, grad_fn=<DivBackward0>)
# 908tensor(7.4504, grad_fn=<DivBackward0>)
# 909tensor(6.8549, grad_fn=<DivBackward0>)
# 910tensor(7.4985, grad_fn=<DivBackward0>)
# 911tensor(7.6098, grad_fn=<DivBackward0>)
# 912tensor(7.5618, grad_fn=<DivBackward0>)
# 913tensor(7.4324, grad_fn=<DivBackward0>)
# 914tensor(7.6577, grad_fn=<DivBackward0>)
# 915tensor(7.0239, grad_fn=<DivBackward0>)
# 916tensor(7.2766, grad_fn=<DivBackward0>)
# 917tensor(7.0615, grad_fn=<DivBackward0>)
# 918tensor(7.4464, grad_fn=<DivBackward0>)
# 919tensor(7.3278, grad_fn=<DivBackward0>)
# 920tensor(6.9764, grad_fn=<DivBackward0>)
# 921tensor(7.5744, grad_fn=<DivBackward0>)
# 922tensor(7.5038, grad_fn=<DivBackward0>)
# 923tensor(7.6073, grad_fn=<DivBackward0>)
# 924tensor(6.7370, grad_fn=<DivBackward0>)
# 925tensor(7.0126, grad_fn=<DivBackward0>)
# 926tensor(7.3439, grad_fn=<DivBackward0>)
# 927tensor(7.1154, grad_fn=<DivBackward0>)
# 928tensor(7.3067, grad_fn=<DivBackward0>)
# 929tensor(7.3810, grad_fn=<DivBackward0>)
# 930tensor(7.4029, grad_fn=<DivBackward0>)
# 931tensor(7.0413, grad_fn=<DivBackward0>)
# 932tensor(7.5558, grad_fn=<DivBackward0>)
# 933tensor(7.0641, grad_fn=<DivBackward0>)
# 934tensor(7.6132, grad_fn=<DivBackward0>)
# 935tensor(7.5801, grad_fn=<DivBackward0>)
# 936tensor(7.5655, grad_fn=<DivBackward0>)
# 937tensor(7.1952, grad_fn=<DivBackward0>)
# 938tensor(7.5569, grad_fn=<DivBackward0>)
# 939tensor(7.4090, grad_fn=<DivBackward0>)
# 940tensor(7.4374, grad_fn=<DivBackward0>)
# 941tensor(7.5430, grad_fn=<DivBackward0>)
# 942tensor(7.3133, grad_fn=<DivBackward0>)
# 943tensor(7.5137, grad_fn=<DivBackward0>)
# 944tensor(6.9747, grad_fn=<DivBackward0>)
# 945tensor(7.5928, grad_fn=<DivBackward0>)
# 946tensor(6.9488, grad_fn=<DivBackward0>)
# 947tensor(7.8725, grad_fn=<DivBackward0>)
# 948tensor(7.5473, grad_fn=<DivBackward0>)
# 949tensor(7.0410, grad_fn=<DivBackward0>)
# 950tensor(7.4951, grad_fn=<DivBackward0>)
# 951tensor(7.4497, grad_fn=<DivBackward0>)
# 952tensor(7.0009, grad_fn=<DivBackward0>)
# 953tensor(6.9118, grad_fn=<DivBackward0>)
# 954tensor(7.6195, grad_fn=<DivBackward0>)
# 955tensor(7.2485, grad_fn=<DivBackward0>)
# 956tensor(7.6415, grad_fn=<DivBackward0>)
# 957tensor(7.3926, grad_fn=<DivBackward0>)
# 958tensor(7.2944, grad_fn=<DivBackward0>)
# 959tensor(7.3020, grad_fn=<DivBackward0>)
# 960tensor(7.0652, grad_fn=<DivBackward0>)
# 961tensor(7.2764, grad_fn=<DivBackward0>)
# 962tensor(7.3380, grad_fn=<DivBackward0>)
# 963tensor(7.2004, grad_fn=<DivBackward0>)
# 964tensor(7.5598, grad_fn=<DivBackward0>)
# 965tensor(7.4710, grad_fn=<DivBackward0>)
# 966tensor(7.4021, grad_fn=<DivBackward0>)
# 967tensor(7.4512, grad_fn=<DivBackward0>)
# 968tensor(7.1691, grad_fn=<DivBackward0>)
# 969tensor(7.1301, grad_fn=<DivBackward0>)
# 970tensor(7.8849, grad_fn=<DivBackward0>)
# 971tensor(7.1600, grad_fn=<DivBackward0>)
# 972tensor(7.0076, grad_fn=<DivBackward0>)
# 973tensor(7.2621, grad_fn=<DivBackward0>)
# 974tensor(7.4903, grad_fn=<DivBackward0>)
# 975tensor(7.2368, grad_fn=<DivBackward0>)
# 976tensor(7.1032, grad_fn=<DivBackward0>)
# 977tensor(7.5504, grad_fn=<DivBackward0>)
# 978tensor(7.4114, grad_fn=<DivBackward0>)
# 979tensor(7.6343, grad_fn=<DivBackward0>)
# 980tensor(7.1344, grad_fn=<DivBackward0>)
# 981tensor(7.7196, grad_fn=<DivBackward0>)
# 982tensor(7.0112, grad_fn=<DivBackward0>)
# 983tensor(7.1123, grad_fn=<DivBackward0>)
# 984tensor(7.5032, grad_fn=<DivBackward0>)
# 985tensor(7.3762, grad_fn=<DivBackward0>)
# 986tensor(7.5144, grad_fn=<DivBackward0>)
# 987tensor(7.3598, grad_fn=<DivBackward0>)
# 988tensor(7.4836, grad_fn=<DivBackward0>)
# 989tensor(7.2869, grad_fn=<DivBackward0>)
# 990tensor(7.0485, grad_fn=<DivBackward0>)
# 991tensor(7.2991, grad_fn=<DivBackward0>)
# 992tensor(6.9351, grad_fn=<DivBackward0>)
# 993tensor(7.1123, grad_fn=<DivBackward0>)
# 994tensor(7.3415, grad_fn=<DivBackward0>)
# 995tensor(7.0222, grad_fn=<DivBackward0>)
# 996tensor(7.2712, grad_fn=<DivBackward0>)
# 997tensor(7.9661, grad_fn=<DivBackward0>)
# 998tensor(7.1602, grad_fn=<DivBackward0>)
# 999tensor(7.1736, grad_fn=<DivBackward0>)
# 1000tensor(6.8922, grad_fn=<DivBackward0>)
# 1001tensor(7.2130, grad_fn=<DivBackward0>)
# 1002tensor(7.3876, grad_fn=<DivBackward0>)
# 1003tensor(7.3353, grad_fn=<DivBackward0>)
# 1004tensor(7.2197, grad_fn=<DivBackward0>)
# 1005tensor(7.0857, grad_fn=<DivBackward0>)
# 1006tensor(7.1018, grad_fn=<DivBackward0>)
# 1007tensor(6.8123, grad_fn=<DivBackward0>)
# 1008tensor(7.4598, grad_fn=<DivBackward0>)
# 1009tensor(7.5901, grad_fn=<DivBackward0>)
# 1010tensor(7.6567, grad_fn=<DivBackward0>)
# 1011tensor(7.2812, grad_fn=<DivBackward0>)
# 1012tensor(7.4222, grad_fn=<DivBackward0>)
# 1013tensor(7.2374, grad_fn=<DivBackward0>)
# 1014tensor(7.1179, grad_fn=<DivBackward0>)
# 1015tensor(7.6908, grad_fn=<DivBackward0>)
# 1016tensor(7.6564, grad_fn=<DivBackward0>)
# 1017tensor(7.3348, grad_fn=<DivBackward0>)
# 1018tensor(7.9086, grad_fn=<DivBackward0>)
# 1019tensor(7.6247, grad_fn=<DivBackward0>)
# 1020tensor(7.1891, grad_fn=<DivBackward0>)
# 1021tensor(7.6620, grad_fn=<DivBackward0>)
# 1022tensor(7.4654, grad_fn=<DivBackward0>)
# 1023tensor(7.2871, grad_fn=<DivBackward0>)
# 1024tensor(7.1800, grad_fn=<DivBackward0>)
# 1025tensor(7.8905, grad_fn=<DivBackward0>)
# 1026tensor(7.3100, grad_fn=<DivBackward0>)
# 1027tensor(7.5505, grad_fn=<DivBackward0>)
# 1028tensor(7.4768, grad_fn=<DivBackward0>)
# 1029tensor(7.8606, grad_fn=<DivBackward0>)
# 1030tensor(7.2415, grad_fn=<DivBackward0>)
# 1031tensor(7.4237, grad_fn=<DivBackward0>)
# 1032tensor(7.4233, grad_fn=<DivBackward0>)
# 1033tensor(7.4999, grad_fn=<DivBackward0>)
# 1034tensor(7.4009, grad_fn=<DivBackward0>)
# 1035tensor(7.1362, grad_fn=<DivBackward0>)
# 1036tensor(7.3620, grad_fn=<DivBackward0>)
# 1037tensor(7.0974, grad_fn=<DivBackward0>)
# 1038tensor(7.3636, grad_fn=<DivBackward0>)
# 1039tensor(7.5011, grad_fn=<DivBackward0>)
# 1040tensor(7.1179, grad_fn=<DivBackward0>)
# 1041tensor(7.1990, grad_fn=<DivBackward0>)
# 1042tensor(7.6455, grad_fn=<DivBackward0>)
# 1043tensor(6.5432, grad_fn=<DivBackward0>)
# 1044tensor(7.3657, grad_fn=<DivBackward0>)
# 1045tensor(7.7592, grad_fn=<DivBackward0>)
# 1046tensor(7.7585, grad_fn=<DivBackward0>)
# 1047tensor(6.8851, grad_fn=<DivBackward0>)
# 1048tensor(7.2403, grad_fn=<DivBackward0>)
# 1049tensor(7.9736, grad_fn=<DivBackward0>)
# 1050tensor(6.7028, grad_fn=<DivBackward0>)
# 1051tensor(7.5153, grad_fn=<DivBackward0>)
# 1052tensor(6.8717, grad_fn=<DivBackward0>)
# 1053tensor(7.6237, grad_fn=<DivBackward0>)
# 1054tensor(6.9878, grad_fn=<DivBackward0>)
# 1055tensor(7.3985, grad_fn=<DivBackward0>)
# 1056tensor(7.2938, grad_fn=<DivBackward0>)
# 1057tensor(7.4457, grad_fn=<DivBackward0>)
# 1058tensor(8.0386, grad_fn=<DivBackward0>)
# 1059tensor(6.7421, grad_fn=<DivBackward0>)
# 1060tensor(7.2772, grad_fn=<DivBackward0>)
# 1061tensor(6.8285, grad_fn=<DivBackward0>)
# 1062tensor(7.1574, grad_fn=<DivBackward0>)
# 1063tensor(7.9166, grad_fn=<DivBackward0>)
# 1064tensor(7.3803, grad_fn=<DivBackward0>)
# 1065tensor(7.5098, grad_fn=<DivBackward0>)
# 1066tensor(7.2332, grad_fn=<DivBackward0>)
# 1067tensor(7.3974, grad_fn=<DivBackward0>)
# 1068tensor(7.4506, grad_fn=<DivBackward0>)
# 1069tensor(7.7038, grad_fn=<DivBackward0>)
# 1070tensor(7.3393, grad_fn=<DivBackward0>)
# 1071tensor(7.4976, grad_fn=<DivBackward0>)
# 1072tensor(8.0401, grad_fn=<DivBackward0>)
# 1073tensor(7.2668, grad_fn=<DivBackward0>)
# 1074tensor(7.3333, grad_fn=<DivBackward0>)
# 1075tensor(7.6431, grad_fn=<DivBackward0>)
# 1076tensor(7.7654, grad_fn=<DivBackward0>)
# 1077tensor(7.0366, grad_fn=<DivBackward0>)
# 1078tensor(7.3760, grad_fn=<DivBackward0>)
# 1079tensor(7.1967, grad_fn=<DivBackward0>)
# 1080tensor(7.8143, grad_fn=<DivBackward0>)
# 1081tensor(7.3138, grad_fn=<DivBackward0>)
# 1082tensor(7.2316, grad_fn=<DivBackward0>)
# 1083tensor(7.4021, grad_fn=<DivBackward0>)
# 1084tensor(7.1418, grad_fn=<DivBackward0>)
# 1085tensor(7.0162, grad_fn=<DivBackward0>)
# 1086tensor(8.0126, grad_fn=<DivBackward0>)
# 1087tensor(7.6903, grad_fn=<DivBackward0>)
# 1088tensor(7.4857, grad_fn=<DivBackward0>)
# 1089tensor(7.3742, grad_fn=<DivBackward0>)
# 1090tensor(7.0234, grad_fn=<DivBackward0>)
# 1091tensor(7.6177, grad_fn=<DivBackward0>)
# 1092tensor(7.1852, grad_fn=<DivBackward0>)
# 1093tensor(7.3021, grad_fn=<DivBackward0>)
# 1094tensor(6.8902, grad_fn=<DivBackward0>)
# 1095tensor(6.9677, grad_fn=<DivBackward0>)
# 1096tensor(7.6212, grad_fn=<DivBackward0>)
# 1097tensor(7.1184, grad_fn=<DivBackward0>)
# 1098tensor(7.9294, grad_fn=<DivBackward0>)
# 1099tensor(7.0258, grad_fn=<DivBackward0>)
# 1100tensor(7.0932, grad_fn=<DivBackward0>)
# 1101tensor(7.3632, grad_fn=<DivBackward0>)
# 1102tensor(7.5680, grad_fn=<DivBackward0>)
# 1103tensor(7.1653, grad_fn=<DivBackward0>)
# 1104tensor(7.5242, grad_fn=<DivBackward0>)
# 1105tensor(7.7411, grad_fn=<DivBackward0>)
# 1106tensor(7.7094, grad_fn=<DivBackward0>)
# 1107tensor(6.9674, grad_fn=<DivBackward0>)
# 1108tensor(7.5111, grad_fn=<DivBackward0>)
# 1109tensor(7.1249, grad_fn=<DivBackward0>)
# 1110tensor(6.9773, grad_fn=<DivBackward0>)
# 1111tensor(7.5227, grad_fn=<DivBackward0>)
# 1112tensor(7.2195, grad_fn=<DivBackward0>)
# 1113tensor(7.7628, grad_fn=<DivBackward0>)
# 1114tensor(7.6168, grad_fn=<DivBackward0>)
# 1115tensor(7.3264, grad_fn=<DivBackward0>)
# 1116tensor(7.5255, grad_fn=<DivBackward0>)
# 1117tensor(7.6030, grad_fn=<DivBackward0>)
# 1118tensor(6.8061, grad_fn=<DivBackward0>)
# 1119tensor(7.5328, grad_fn=<DivBackward0>)
# 1120tensor(7.6840, grad_fn=<DivBackward0>)
# 1121tensor(7.5872, grad_fn=<DivBackward0>)
# 1122tensor(7.6362, grad_fn=<DivBackward0>)
# 1123tensor(7.2013, grad_fn=<DivBackward0>)
# 1124tensor(7.2685, grad_fn=<DivBackward0>)
# 1125tensor(7.2435, grad_fn=<DivBackward0>)
# 1126tensor(7.8716, grad_fn=<DivBackward0>)
# 1127tensor(7.2297, grad_fn=<DivBackward0>)
# 1128tensor(7.4433, grad_fn=<DivBackward0>)
# 1129tensor(6.8773, grad_fn=<DivBackward0>)
# 1130tensor(8.0734, grad_fn=<DivBackward0>)
# 1131tensor(7.2314, grad_fn=<DivBackward0>)
# 1132tensor(7.4355, grad_fn=<DivBackward0>)
# 1133tensor(7.1876, grad_fn=<DivBackward0>)
# 1134tensor(7.1665, grad_fn=<DivBackward0>)
# 1135tensor(7.5753, grad_fn=<DivBackward0>)
# 1136tensor(7.0683, grad_fn=<DivBackward0>)
# 1137tensor(7.2115, grad_fn=<DivBackward0>)
# 1138tensor(7.2152, grad_fn=<DivBackward0>)
# 1139tensor(7.1280, grad_fn=<DivBackward0>)
# ...
# 4628tensor(7.3596, grad_fn=<DivBackward0>)
# 4629tensor(7.0022, grad_fn=<DivBackward0>)
# 4630tensor(7.2901, grad_fn=<DivBackward0>)
# 4631tensor(7.0560, grad_fn=<DivBackward0>)
# 4632tensor(7.0486, grad_fn=<DivBackward0>)
# 4633tensor(7.3218, grad_fn=<DivBackward0>)
# 4634tensor(7.3030, grad_fn=<DivBackward0>)
# 4635tensor(7.7012, grad_fn=<DivBackward0>)
# 4636tensor(7.3208, grad_fn=<DivBackward0>)
# 4637tensor(6.8019, grad_fn=<DivBackward0>)
# 4638tensor(7.6794, grad_fn=<DivBackward0>)
# 4639tensor(7.3734, grad_fn=<DivBackward0>)
# 4640tensor(7.3149, grad_fn=<DivBackward0>)
# 4641tensor(7.2055, grad_fn=<DivBackward0>)
# 4642tensor(6.7347, grad_fn=<DivBackward0>)
# 4643tensor(7.6055, grad_fn=<DivBackward0>)
# 4644tensor(7.4343, grad_fn=<DivBackward0>)
# 4645tensor(7.3315, grad_fn=<DivBackward0>)
# 4646tensor(7.2407, grad_fn=<DivBackward0>)
# 4647tensor(6.9376, grad_fn=<DivBackward0>)
# 4648tensor(6.5224, grad_fn=<DivBackward0>)
# 4649tensor(7.0139, grad_fn=<DivBackward0>)
# 4650tensor(7.0609, grad_fn=<DivBackward0>)
# 4651tensor(7.6325, grad_fn=<DivBackward0>)
# 4652tensor(7.4214, grad_fn=<DivBackward0>)
# 4653tensor(7.4831, grad_fn=<DivBackward0>)
# 4654tensor(7.5368, grad_fn=<DivBackward0>)
# 4655tensor(7.0920, grad_fn=<DivBackward0>)
# 4656tensor(7.0909, grad_fn=<DivBackward0>)
# 4657tensor(7.2877, grad_fn=<DivBackward0>)
# 4658tensor(7.0347, grad_fn=<DivBackward0>)
# 4659tensor(7.2273, grad_fn=<DivBackward0>)
# 4660tensor(8.0199, grad_fn=<DivBackward0>)
# 4661tensor(7.1847, grad_fn=<DivBackward0>)
# 4662tensor(7.2804, grad_fn=<DivBackward0>)
# 4663tensor(7.0319, grad_fn=<DivBackward0>)
# 4664tensor(7.1791, grad_fn=<DivBackward0>)
# 4665tensor(6.9316, grad_fn=<DivBackward0>)
# 4666tensor(7.5539, grad_fn=<DivBackward0>)
# 4667tensor(6.9843, grad_fn=<DivBackward0>)
# 4668tensor(7.1093, grad_fn=<DivBackward0>)
# 4669tensor(7.5703, grad_fn=<DivBackward0>)
# 4670tensor(7.0321, grad_fn=<DivBackward0>)
# 4671tensor(7.6132, grad_fn=<DivBackward0>)
# 4672tensor(7.5016, grad_fn=<DivBackward0>)
# 4673tensor(7.0511, grad_fn=<DivBackward0>)
# 4674tensor(7.3011, grad_fn=<DivBackward0>)
# 4675tensor(6.8634, grad_fn=<DivBackward0>)
# 4676tensor(7.2296, grad_fn=<DivBackward0>)
# 4677tensor(7.6257, grad_fn=<DivBackward0>)
# 4678tensor(7.7026, grad_fn=<DivBackward0>)
# 4679tensor(6.9904, grad_fn=<DivBackward0>)
# 4680tensor(7.5420, grad_fn=<DivBackward0>)
# 4681tensor(7.3350, grad_fn=<DivBackward0>)
# 4682tensor(7.1670, grad_fn=<DivBackward0>)
# 4683tensor(7.3017, grad_fn=<DivBackward0>)
# 4684tensor(7.5538, grad_fn=<DivBackward0>)
# 4685tensor(7.6252, grad_fn=<DivBackward0>)
# 4686tensor(7.1721, grad_fn=<DivBackward0>)
# 4687tensor(7.0851, grad_fn=<DivBackward0>)
# 4688tensor(7.6576, grad_fn=<DivBackward0>)
# 4689tensor(7.8609, grad_fn=<DivBackward0>)
# 4690tensor(7.2261, grad_fn=<DivBackward0>)
# 4691tensor(7.4862, grad_fn=<DivBackward0>)
# 4692tensor(7.0450, grad_fn=<DivBackward0>)
# 4693tensor(6.8726, grad_fn=<DivBackward0>)
# 4694tensor(7.0356, grad_fn=<DivBackward0>)
# 4695tensor(7.2747, grad_fn=<DivBackward0>)
# 4696tensor(6.9904, grad_fn=<DivBackward0>)
# 4697tensor(7.7152, grad_fn=<DivBackward0>)
# 4698tensor(7.3174, grad_fn=<DivBackward0>)
# 4699tensor(7.0906, grad_fn=<DivBackward0>)
# 4700tensor(7.1196, grad_fn=<DivBackward0>)
# 4701tensor(7.6955, grad_fn=<DivBackward0>)
# 4702tensor(6.7137, grad_fn=<DivBackward0>)
# 4703tensor(7.0373, grad_fn=<DivBackward0>)
# 4704tensor(7.2614, grad_fn=<DivBackward0>)
# 4705tensor(7.5305, grad_fn=<DivBackward0>)
# 4706tensor(7.1105, grad_fn=<DivBackward0>)
# 4707tensor(7.6366, grad_fn=<DivBackward0>)
# 4708tensor(6.8503, grad_fn=<DivBackward0>)
# 4709tensor(7.5828, grad_fn=<DivBackward0>)
# 4710tensor(7.7730, grad_fn=<DivBackward0>)
# 4711tensor(6.9404, grad_fn=<DivBackward0>)
# 4712tensor(7.0710, grad_fn=<DivBackward0>)
# 4713tensor(7.3349, grad_fn=<DivBackward0>)
# 4714tensor(8.1851, grad_fn=<DivBackward0>)
# 4715tensor(7.0449, grad_fn=<DivBackward0>)
# 4716tensor(7.4104, grad_fn=<DivBackward0>)
# 4717tensor(7.3226, grad_fn=<DivBackward0>)
# 4718tensor(7.3427, grad_fn=<DivBackward0>)
# 4719tensor(7.1929, grad_fn=<DivBackward0>)
# 4720tensor(7.2660, grad_fn=<DivBackward0>)
# 4721tensor(7.4673, grad_fn=<DivBackward0>)
# 4722tensor(7.5039, grad_fn=<DivBackward0>)
# 4723tensor(6.9995, grad_fn=<DivBackward0>)
# 4724tensor(7.2119, grad_fn=<DivBackward0>)
# 4725tensor(6.5188, grad_fn=<DivBackward0>)
# 4726tensor(7.1702, grad_fn=<DivBackward0>)
# 4727tensor(7.4368, grad_fn=<DivBackward0>)
# 4728tensor(7.4164, grad_fn=<DivBackward0>)
# 4729tensor(7.3623, grad_fn=<DivBackward0>)
# 4730tensor(6.8212, grad_fn=<DivBackward0>)
# 4731tensor(7.0707, grad_fn=<DivBackward0>)
# 4732tensor(7.7662, grad_fn=<DivBackward0>)
# 4733tensor(6.9489, grad_fn=<DivBackward0>)
# 4734tensor(7.0707, grad_fn=<DivBackward0>)
# 4735tensor(6.9194, grad_fn=<DivBackward0>)
# 4736tensor(7.0714, grad_fn=<DivBackward0>)
# 4737tensor(7.4998, grad_fn=<DivBackward0>)
# 4738tensor(7.2944, grad_fn=<DivBackward0>)
# 4739tensor(7.0441, grad_fn=<DivBackward0>)
# 4740tensor(6.8020, grad_fn=<DivBackward0>)
# 4741tensor(7.0705, grad_fn=<DivBackward0>)
# 4742tensor(6.8627, grad_fn=<DivBackward0>)
# 4743tensor(6.9887, grad_fn=<DivBackward0>)
# 4744tensor(7.8371, grad_fn=<DivBackward0>)
# 4745tensor(7.4912, grad_fn=<DivBackward0>)
# 4746tensor(7.9508, grad_fn=<DivBackward0>)
# 4747tensor(7.3071, grad_fn=<DivBackward0>)
# 4748tensor(7.0255, grad_fn=<DivBackward0>)
# 4749tensor(7.4053, grad_fn=<DivBackward0>)
# 4750tensor(7.6118, grad_fn=<DivBackward0>)
# 4751tensor(7.2132, grad_fn=<DivBackward0>)
# 4752tensor(7.0495, grad_fn=<DivBackward0>)
# 4753tensor(7.6428, grad_fn=<DivBackward0>)
# 4754tensor(7.2410, grad_fn=<DivBackward0>)
# 4755tensor(6.9575, grad_fn=<DivBackward0>)
# 4756tensor(7.2559, grad_fn=<DivBackward0>)
# 4757tensor(7.0914, grad_fn=<DivBackward0>)
# 4758tensor(7.3727, grad_fn=<DivBackward0>)
# 4759tensor(7.4276, grad_fn=<DivBackward0>)
# 4760tensor(7.1333, grad_fn=<DivBackward0>)
# 4761tensor(7.2556, grad_fn=<DivBackward0>)
# 4762tensor(7.0902, grad_fn=<DivBackward0>)
# 4763tensor(6.8422, grad_fn=<DivBackward0>)
# 4764tensor(7.0438, grad_fn=<DivBackward0>)
# 4765tensor(7.4522, grad_fn=<DivBackward0>)
# 4766tensor(7.2984, grad_fn=<DivBackward0>)
# 4767tensor(7.6349, grad_fn=<DivBackward0>)
# 4768tensor(7.7368, grad_fn=<DivBackward0>)
# 4769tensor(7.4402, grad_fn=<DivBackward0>)
# 4770tensor(7.5247, grad_fn=<DivBackward0>)
# 4771tensor(7.4794, grad_fn=<DivBackward0>)
# 4772tensor(7.4978, grad_fn=<DivBackward0>)
# 4773tensor(6.7236, grad_fn=<DivBackward0>)
# 4774tensor(7.3060, grad_fn=<DivBackward0>)
# 4775tensor(7.5322, grad_fn=<DivBackward0>)
# 4776tensor(6.9112, grad_fn=<DivBackward0>)
# 4777tensor(7.3487, grad_fn=<DivBackward0>)
# 4778tensor(6.8075, grad_fn=<DivBackward0>)
# 4779tensor(7.0734, grad_fn=<DivBackward0>)
# 4780tensor(7.2753, grad_fn=<DivBackward0>)
# 4781tensor(6.7924, grad_fn=<DivBackward0>)
# 4782tensor(7.5665, grad_fn=<DivBackward0>)
# 4783tensor(7.2492, grad_fn=<DivBackward0>)
# 4784tensor(7.5176, grad_fn=<DivBackward0>)
# 4785tensor(7.6942, grad_fn=<DivBackward0>)
# 4786tensor(6.8175, grad_fn=<DivBackward0>)
# 4787tensor(6.9743, grad_fn=<DivBackward0>)
# 4788tensor(7.2757, grad_fn=<DivBackward0>)
# 4789tensor(7.4646, grad_fn=<DivBackward0>)
# 4790tensor(7.2013, grad_fn=<DivBackward0>)
# 4791tensor(7.3013, grad_fn=<DivBackward0>)
# 4792tensor(7.4040, grad_fn=<DivBackward0>)
# 4793tensor(7.5525, grad_fn=<DivBackward0>)
# 4794tensor(7.2595, grad_fn=<DivBackward0>)
# 4795tensor(6.9353, grad_fn=<DivBackward0>)
# 4796tensor(7.5897, grad_fn=<DivBackward0>)
# 4797tensor(7.3638, grad_fn=<DivBackward0>)
# 4798tensor(6.8397, grad_fn=<DivBackward0>)
# 4799tensor(7.6044, grad_fn=<DivBackward0>)
# 4800tensor(7.2865, grad_fn=<DivBackward0>)
# 4801tensor(7.3098, grad_fn=<DivBackward0>)
# 4802tensor(7.1203, grad_fn=<DivBackward0>)
# 4803tensor(7.5730, grad_fn=<DivBackward0>)
# 4804tensor(7.3013, grad_fn=<DivBackward0>)
# 4805tensor(7.9616, grad_fn=<DivBackward0>)
# 4806tensor(7.1688, grad_fn=<DivBackward0>)
# 4807tensor(7.3661, grad_fn=<DivBackward0>)
# 4808tensor(7.5215, grad_fn=<DivBackward0>)
# 4809tensor(7.3380, grad_fn=<DivBackward0>)
# 4810tensor(7.3145, grad_fn=<DivBackward0>)
# 4811tensor(6.8799, grad_fn=<DivBackward0>)
# 4812tensor(7.7576, grad_fn=<DivBackward0>)
# 4813tensor(7.2463, grad_fn=<DivBackward0>)
# 4814tensor(6.9084, grad_fn=<DivBackward0>)
# 4815tensor(7.2803, grad_fn=<DivBackward0>)
# 4816tensor(7.3376, grad_fn=<DivBackward0>)
# 4817tensor(6.9398, grad_fn=<DivBackward0>)
# 4818tensor(7.4286, grad_fn=<DivBackward0>)
# 4819tensor(7.0256, grad_fn=<DivBackward0>)
# 4820tensor(7.5737, grad_fn=<DivBackward0>)
# 4821tensor(7.3198, grad_fn=<DivBackward0>)
# 4822tensor(7.2122, grad_fn=<DivBackward0>)
# 4823tensor(7.2162, grad_fn=<DivBackward0>)
# 4824tensor(7.2600, grad_fn=<DivBackward0>)
# 4825tensor(7.4506, grad_fn=<DivBackward0>)
# 4826tensor(7.4580, grad_fn=<DivBackward0>)
# 4827tensor(7.5505, grad_fn=<DivBackward0>)
# 4828tensor(7.2801, grad_fn=<DivBackward0>)
# 4829tensor(7.3758, grad_fn=<DivBackward0>)
# 4830tensor(7.0614, grad_fn=<DivBackward0>)
# 4831tensor(7.3204, grad_fn=<DivBackward0>)
# 4832tensor(7.3276, grad_fn=<DivBackward0>)
# 4833tensor(7.0665, grad_fn=<DivBackward0>)
# 4834tensor(7.3572, grad_fn=<DivBackward0>)
# 4835tensor(7.9427, grad_fn=<DivBackward0>)
# 4836tensor(7.0083, grad_fn=<DivBackward0>)
# 4837tensor(6.9750, grad_fn=<DivBackward0>)
# 4838tensor(7.4131, grad_fn=<DivBackward0>)
# 4839tensor(7.0303, grad_fn=<DivBackward0>)
# 4840tensor(7.0887, grad_fn=<DivBackward0>)
# 4841tensor(6.9186, grad_fn=<DivBackward0>)
# 4842tensor(7.4416, grad_fn=<DivBackward0>)
# 4843tensor(7.5697, grad_fn=<DivBackward0>)
# 4844tensor(7.8426, grad_fn=<DivBackward0>)
# 4845tensor(7.3367, grad_fn=<DivBackward0>)
# 4846tensor(7.4396, grad_fn=<DivBackward0>)
# 4847tensor(7.1735, grad_fn=<DivBackward0>)
# 4848tensor(7.2917, grad_fn=<DivBackward0>)
# 4849tensor(7.6436, grad_fn=<DivBackward0>)
# 4850tensor(7.1235, grad_fn=<DivBackward0>)
# 4851tensor(7.7834, grad_fn=<DivBackward0>)
# 4852tensor(7.2832, grad_fn=<DivBackward0>)
# 4853tensor(7.1360, grad_fn=<DivBackward0>)
# 4854tensor(6.8741, grad_fn=<DivBackward0>)
# 4855tensor(7.5755, grad_fn=<DivBackward0>)
# 4856tensor(7.2668, grad_fn=<DivBackward0>)
# 4857tensor(7.2483, grad_fn=<DivBackward0>)
# 4858tensor(7.7907, grad_fn=<DivBackward0>)
# 4859tensor(6.9393, grad_fn=<DivBackward0>)
# 4860tensor(7.1733, grad_fn=<DivBackward0>)
# 4861tensor(7.7515, grad_fn=<DivBackward0>)
# 4862tensor(7.4371, grad_fn=<DivBackward0>)
# 4863tensor(6.9880, grad_fn=<DivBackward0>)
# 4864tensor(7.5177, grad_fn=<DivBackward0>)
# 4865tensor(7.7874, grad_fn=<DivBackward0>)
# 4866tensor(7.6680, grad_fn=<DivBackward0>)
# 4867tensor(7.3634, grad_fn=<DivBackward0>)
# 4868tensor(7.4805, grad_fn=<DivBackward0>)
# 4869tensor(6.8707, grad_fn=<DivBackward0>)
# 4870tensor(7.4426, grad_fn=<DivBackward0>)
# 4871tensor(7.4824, grad_fn=<DivBackward0>)
# 4872tensor(7.1829, grad_fn=<DivBackward0>)
# 4873tensor(7.6609, grad_fn=<DivBackward0>)
# 4874tensor(7.4753, grad_fn=<DivBackward0>)
# 4875tensor(7.5414, grad_fn=<DivBackward0>)
# 4876tensor(7.2121, grad_fn=<DivBackward0>)
# 4877tensor(7.6030, grad_fn=<DivBackward0>)
# 4878tensor(7.5782, grad_fn=<DivBackward0>)
# 4879tensor(7.1694, grad_fn=<DivBackward0>)
# 4880tensor(7.1704, grad_fn=<DivBackward0>)
# 4881tensor(7.3654, grad_fn=<DivBackward0>)
# 4882tensor(7.5141, grad_fn=<DivBackward0>)
# 4883tensor(7.2294, grad_fn=<DivBackward0>)
# 4884tensor(6.8014, grad_fn=<DivBackward0>)
# 4885tensor(6.7597, grad_fn=<DivBackward0>)
# 4886tensor(7.3116, grad_fn=<DivBackward0>)
# 4887tensor(7.3496, grad_fn=<DivBackward0>)
# 4888tensor(6.8689, grad_fn=<DivBackward0>)
# 4889tensor(7.2669, grad_fn=<DivBackward0>)
# 4890tensor(7.4320, grad_fn=<DivBackward0>)
# 4891tensor(7.4619, grad_fn=<DivBackward0>)
# 4892tensor(7.7212, grad_fn=<DivBackward0>)
# 4893tensor(7.0403, grad_fn=<DivBackward0>)
# 4894tensor(7.2290, grad_fn=<DivBackward0>)
# 4895tensor(6.8154, grad_fn=<DivBackward0>)
# 4896tensor(7.7439, grad_fn=<DivBackward0>)
# 4897tensor(6.8599, grad_fn=<DivBackward0>)
# 4898tensor(6.9908, grad_fn=<DivBackward0>)
# 4899tensor(7.4171, grad_fn=<DivBackward0>)
# 4900tensor(7.2553, grad_fn=<DivBackward0>)
# 4901tensor(7.0975, grad_fn=<DivBackward0>)
# 4902tensor(7.8682, grad_fn=<DivBackward0>)
# 4903tensor(7.3340, grad_fn=<DivBackward0>)
# 4904tensor(6.7850, grad_fn=<DivBackward0>)
# 4905tensor(7.2924, grad_fn=<DivBackward0>)
# 4906tensor(7.1392, grad_fn=<DivBackward0>)
# 4907tensor(7.2703, grad_fn=<DivBackward0>)
# 4908tensor(7.5337, grad_fn=<DivBackward0>)
# 4909tensor(7.3293, grad_fn=<DivBackward0>)
# 4910tensor(6.8688, grad_fn=<DivBackward0>)
# 4911tensor(7.3676, grad_fn=<DivBackward0>)
# 4912tensor(6.7701, grad_fn=<DivBackward0>)
# 4913tensor(6.8752, grad_fn=<DivBackward0>)
# 4914tensor(7.4810, grad_fn=<DivBackward0>)
# 4915tensor(6.7476, grad_fn=<DivBackward0>)
# 4916tensor(7.8847, grad_fn=<DivBackward0>)
# 4917tensor(7.1888, grad_fn=<DivBackward0>)
# 4918tensor(7.5141, grad_fn=<DivBackward0>)
# 4919tensor(7.1378, grad_fn=<DivBackward0>)
# 4920tensor(7.2673, grad_fn=<DivBackward0>)
# 4921tensor(7.8986, grad_fn=<DivBackward0>)
# 4922tensor(7.4538, grad_fn=<DivBackward0>)
# 4923tensor(7.4990, grad_fn=<DivBackward0>)
# 4924tensor(7.1595, grad_fn=<DivBackward0>)
# 4925tensor(7.2646, grad_fn=<DivBackward0>)
# 4926tensor(7.6849, grad_fn=<DivBackward0>)
# 4927tensor(7.3944, grad_fn=<DivBackward0>)
# 4928tensor(7.3383, grad_fn=<DivBackward0>)
# 4929tensor(7.0222, grad_fn=<DivBackward0>)
# 4930tensor(7.3451, grad_fn=<DivBackward0>)
# 4931tensor(7.1259, grad_fn=<DivBackward0>)
# 4932tensor(6.8540, grad_fn=<DivBackward0>)
# 4933tensor(7.4572, grad_fn=<DivBackward0>)
# 4934tensor(7.1745, grad_fn=<DivBackward0>)
# 4935tensor(7.0696, grad_fn=<DivBackward0>)
# 4936tensor(7.2011, grad_fn=<DivBackward0>)
# 4937tensor(7.3073, grad_fn=<DivBackward0>)
# 4938tensor(7.2226, grad_fn=<DivBackward0>)
# 4939tensor(6.9596, grad_fn=<DivBackward0>)
# 4940tensor(6.7559, grad_fn=<DivBackward0>)
# 4941tensor(7.4580, grad_fn=<DivBackward0>)
# 4942tensor(7.7641, grad_fn=<DivBackward0>)
# 4943tensor(7.5003, grad_fn=<DivBackward0>)
# 4944tensor(7.5332, grad_fn=<DivBackward0>)
# 4945tensor(7.5221, grad_fn=<DivBackward0>)
# 4946tensor(7.5628, grad_fn=<DivBackward0>)
# 4947tensor(7.0765, grad_fn=<DivBackward0>)
# 4948tensor(7.4521, grad_fn=<DivBackward0>)
# 4949tensor(6.7823, grad_fn=<DivBackward0>)
# 4950tensor(6.8071, grad_fn=<DivBackward0>)
# 4951tensor(7.2032, grad_fn=<DivBackward0>)
# 4952tensor(7.5468, grad_fn=<DivBackward0>)
# 4953tensor(7.1611, grad_fn=<DivBackward0>)
# 4954tensor(7.3195, grad_fn=<DivBackward0>)
# 4955tensor(7.7535, grad_fn=<DivBackward0>)
# 4956tensor(7.5887, grad_fn=<DivBackward0>)
# 4957tensor(7.6742, grad_fn=<DivBackward0>)
# 4958tensor(7.6252, grad_fn=<DivBackward0>)
# 4959tensor(7.6497, grad_fn=<DivBackward0>)
# 4960tensor(7.2026, grad_fn=<DivBackward0>)
# 4961tensor(7.0156, grad_fn=<DivBackward0>)
# 4962tensor(7.5969, grad_fn=<DivBackward0>)
# 4963tensor(7.3267, grad_fn=<DivBackward0>)
# 4964tensor(7.1707, grad_fn=<DivBackward0>)
# 4965tensor(7.1117, grad_fn=<DivBackward0>)
# 4966tensor(7.2079, grad_fn=<DivBackward0>)
# 4967tensor(7.4889, grad_fn=<DivBackward0>)
# 4968tensor(8.1551, grad_fn=<DivBackward0>)
# 4969tensor(7.4900, grad_fn=<DivBackward0>)
# 4970tensor(7.4337, grad_fn=<DivBackward0>)
# 4971tensor(7.5296, grad_fn=<DivBackward0>)
# 4972tensor(7.1300, grad_fn=<DivBackward0>)
# 4973tensor(7.1081, grad_fn=<DivBackward0>)
# 4974tensor(7.9365, grad_fn=<DivBackward0>)
# 4975tensor(7.7232, grad_fn=<DivBackward0>)
# 4976tensor(7.4643, grad_fn=<DivBackward0>)
# 4977tensor(7.6384, grad_fn=<DivBackward0>)
# 4978tensor(7.3641, grad_fn=<DivBackward0>)
# 4979tensor(7.0796, grad_fn=<DivBackward0>)
# 4980tensor(7.0552, grad_fn=<DivBackward0>)
# 4981tensor(7.7484, grad_fn=<DivBackward0>)
# 4982tensor(6.8632, grad_fn=<DivBackward0>)
# 4983tensor(7.2420, grad_fn=<DivBackward0>)
# 4984tensor(7.3742, grad_fn=<DivBackward0>)
# 4985tensor(6.9162, grad_fn=<DivBackward0>)
# 4986tensor(7.1553, grad_fn=<DivBackward0>)
# 4987tensor(7.3674, grad_fn=<DivBackward0>)
# 4988tensor(7.6675, grad_fn=<DivBackward0>)
# 4989tensor(7.2721, grad_fn=<DivBackward0>)
# 4990tensor(7.5506, grad_fn=<DivBackward0>)
# 4991tensor(7.5935, grad_fn=<DivBackward0>)
# 4992tensor(7.1121, grad_fn=<DivBackward0>)
# 4993tensor(7.6193, grad_fn=<DivBackward0>)
# 4994tensor(7.2656, grad_fn=<DivBackward0>)
# 4995tensor(7.2006, grad_fn=<DivBackward0>)
# 4996tensor(7.7194, grad_fn=<DivBackward0>)
# 4997tensor(7.5293, grad_fn=<DivBackward0>)
# 4998tensor(7.3096, grad_fn=<DivBackward0>)
# 4999tensor(7.2574, grad_fn=<DivBackward0>)

# %%
os.chdir('C:\\Users\\Ji Qi\\Documents\\GitHub\\ST-Aim3')
os.getcwd()
PATH = 'vgae_model_for_simulation_0.25.pth'
torch.save(model, PATH)

model = torch.load(PATH)
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder(
#     (conv1): GCNConv(10, 4)
#     (conv_mu): GCNConv(4, 2)
#     (conv_logstd): GCNConv(4, 2)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
for i in range(len(dataset)):
    train_data = dataset[i]
    print(VGAE_Encoder(train_data.x, train_data.edge_index))
# Out:
# (tensor([[-0.4474,  1.5786],
#         [-1.7984,  1.8212],
#         [-0.7990,  1.6466],
#         [-2.5891,  0.2752],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1463, -1.8447],
#         [-2.1733, -1.8095],
#         [-2.1523, -1.8294],
#         [-1.9268, -1.7014],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-0.5906,  1.0200],
#         [ 0.2821, -0.0934],
#         [ 0.4367,  0.0597],
#         [-2.5121,  0.6412],
#         [-1.8193,  1.2096],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.0581, -1.8099],
#         [-1.9352, -1.9408],
#         [-2.1329, -1.5230],
#         [-1.9722, -1.6791],
#         [-2.0697, -1.7467],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [ 0.2821, -0.0934],
#         [ 0.4367,  0.0597],
#         [-3.1139,  0.5643],
#         [-3.1139,  0.5643],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-1.9352, -1.9408],
#         [-2.1329, -1.5230],
#         [-1.9517, -1.6402],
#         [-1.9517, -1.6402],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-1.1357,  1.4105],
#         [ 0.2821, -0.0934],
#         [-2.3708,  0.7326],
#         [-2.6327,  1.0121],
#         [-0.4220,  0.9181],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1105, -1.7963],
#         [-1.9352, -1.9408],
#         [-2.0322, -1.6281],
#         [-2.0635, -1.6376],
#         [-2.0448, -1.8150],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-1.1533,  1.7029],
#         [-0.5590,  1.5786],
#         [ 0.4367,  0.0597],
#         [-2.4798,  1.0690],
#         [-2.1288,  0.5381],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1553, -1.8091],
#         [-2.1447, -1.8381],
#         [-2.1329, -1.5230],
#         [-2.0386, -1.7012],
#         [-1.9618, -1.6968],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [ 0.2031,  1.4518],
#         [-2.5011,  1.0749],
#         [-3.0648,  0.3894],
#         [-0.8908,  1.6293],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-2.1360, -1.8769],
#         [-2.0674, -1.6649],
#         [-1.9600, -1.5915],
#         [-2.1477, -1.8210],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-1.5474,  1.2062],
#         [-0.9839,  1.5209],
#         [-1.7634,  0.8132],
#         [-2.6927,  1.4644],
#         [-0.6466,  0.9886],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.0731, -1.7625],
#         [-2.1297, -1.8104],
#         [-2.0523, -1.6691],
#         [-2.1268, -1.6634],
#         [-2.0525, -1.8051],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-0.5906,  1.0200],
#         [ 0.2821, -0.0934],
#         [ 0.4367,  0.0597],
#         [-2.5121,  0.6412],
#         [-1.8193,  1.2096],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.0581, -1.8099],
#         [-1.9352, -1.9408],
#         [-2.1329, -1.5230],
#         [-1.9722, -1.6791],
#         [-2.0697, -1.7467],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [-2.5294,  0.7405],
#         [-2.5294,  0.7405],
#         [-2.5294,  0.7405],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-2.0000, -1.7294],
#         [-2.0000, -1.7294],
#         [-2.0000, -1.7294],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-0.1589,  1.3637],
#         [-1.5654,  1.3465],
#         [-1.3246,  1.9245],
#         [-1.7793,  0.9255],
#         [-0.8962,  1.2710],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1173, -1.8515],
#         [-2.0980, -1.7810],
#         [-2.1902, -1.8210],
#         [-2.0306, -1.7505],
#         [-2.0924, -1.8038],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.6444,  1.4417],
#         [ 0.2821, -0.0934],
#         [ 0.2902,  1.5492],
#         [-4.9905, -0.2905],
#         [ 0.4688,  1.9510],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1408, -1.9023],
#         [-1.9352, -1.9408],
#         [-2.1523, -1.8866],
#         [-1.8171, -1.5772],
#         [-2.2168, -1.9160],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-2.0705,  1.4314],
#         [-0.5920,  1.6109],
#         [ 0.4367,  0.0597],
#         [-2.7403,  0.9331],
#         [ 0.4210,  1.2721],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1003, -1.7424],
#         [-2.1492, -1.8377],
#         [-2.1329, -1.5230],
#         [-2.0139, -1.6795],
#         [-2.1115, -1.8812],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [-1.2155,  0.9596],
#         [-2.5859,  0.9561],
#         [-3.0649,  0.1952],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-2.0516, -1.8131],
#         [-2.0574, -1.6892],
#         [-1.9374, -1.6091],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [ 0.2821, -0.0934],
#         [-3.6405,  0.0901],
#         [-3.6405,  0.0901],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-1.9352, -1.9408],
#         [-1.9635, -1.4582],
#         [-1.9635, -1.4582],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [-3.6307, -0.8466],
#         [ 0.4367,  0.0597],
#         [-3.6307, -0.8466],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-1.7570, -1.6531],
#         [-2.1329, -1.5230],
#         [-1.7570, -1.6531],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-0.4984,  1.6107],
#         [-0.7411,  1.3447],
#         [-1.8303,  1.9197],
#         [-2.6145,  0.6673],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1505, -1.8432],
#         [-2.1109, -1.8341],
#         [-2.2020, -1.7703],
#         [-2.0023, -1.6436],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.4725,  1.8935],
#         [ 0.3555,  1.9157],
#         [ 0.3151,  1.9413],
#         [-4.9905, -0.2905],
#         [ 0.3921,  1.7396],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2080, -1.9135],
#         [-2.2097, -1.9077],
#         [-2.2131, -1.9066],
#         [-1.8171, -1.5772],
#         [-2.1831, -1.9016],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.6480,  1.6786],
#         [ 0.5583,  2.0382],
#         [ 0.4367,  0.0597],
#         [-4.9905, -0.2905],
#         [ 0.4670,  1.3324],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1774, -1.9137],
#         [-2.2315, -1.9254],
#         [-2.1329, -1.5230],
#         [-1.8171, -1.5772],
#         [-2.1214, -1.8867],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-0.6023,  1.6414],
#         [ 0.2821, -0.0934],
#         [-1.3461,  1.8019],
#         [-2.6513,  1.1373],
#         [-2.3215,  0.5966],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1537, -1.8385],
#         [-1.9352, -1.9408],
#         [-2.1678, -1.8024],
#         [-2.0467, -1.6944],
#         [-1.9681, -1.6882],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [-0.9826,  1.8294],
#         [ 0.0411,  1.7282],
#         [-2.7013,  0.6082],
#         [-2.2134,  1.2593],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-2.1787, -1.8302],
#         [-2.1780, -1.8867],
#         [-1.9644, -1.6665],
#         [-2.0718, -1.7259],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-2.1123,  1.1983],
#         [ 0.2821, -0.0934],
#         [-2.3248,  0.7929],
#         [-3.0169,  1.2142],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.0638, -1.7289],
#         [-1.9352, -1.9408],
#         [-2.0422, -1.6336],
#         [-2.0891, -1.6245],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.4738,  2.2761],
#         [ 0.2821, -0.0934],
#         [ 0.4738,  2.2761],
#         [-4.9905, -0.2905],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2670, -1.9317],
#         [-1.9352, -1.9408],
#         [-2.2670, -1.9317],
#         [-1.8171, -1.5772],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.4738,  2.2761],
#         [ 0.2821, -0.0934],
#         [ 0.4738,  2.2761],
#         [-3.1139,  0.5643],
#         [-3.1139,  0.5643],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2670, -1.9317],
#         [-1.9352, -1.9408],
#         [-2.2670, -1.9317],
#         [-1.9517, -1.6402],
#         [-1.9517, -1.6402],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-2.1514,  1.4825],
#         [ 0.2821, -0.0934],
#         [-0.7335,  1.7002],
#         [-2.7898,  0.9643],
#         [ 0.2972,  1.3502],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1070, -1.7400],
#         [-1.9352, -1.9408],
#         [-2.1609, -1.8336],
#         [-2.0180, -1.6781],
#         [-2.1217, -1.8776],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.8201,  1.3687],
#         [-1.2155,  0.9596],
#         [-2.5859,  0.9561],
#         [-3.0649,  0.1952],
#         [ 0.8201,  1.3687],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1321, -1.9092],
#         [-2.0516, -1.8131],
#         [-2.0574, -1.6892],
#         [-1.9374, -1.6091],
#         [-2.1321, -1.9092],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.6558,  2.1613],
#         [ 0.6558,  2.1613],
#         [ 0.1118,  1.5837],
#         [-4.9905, -0.2905],
#         [ 0.1118,  1.5837],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2519, -1.9370],
#         [-2.2519, -1.9370],
#         [-2.1551, -1.8777],
#         [-1.8171, -1.5772],
#         [-2.1551, -1.8777],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[-0.5792,  1.8426],
#         [ 0.2821, -0.0934],
#         [ 0.3920,  1.7716],
#         [-2.5580,  0.5809],
#         [-1.9795,  1.2147],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.1851, -1.8494],
#         [-1.9352, -1.9408],
#         [-2.1881, -1.9031],
#         [-1.9623, -1.6736],
#         [-2.0682, -1.7375],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 0.4694,  2.0209],
#         [ 0.2247,  1.7860],
#         [ 0.2998,  2.4468],
#         [-4.9905, -0.2905],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2276, -1.9194],
#         [-2.1923, -1.9099],
#         [-2.2944, -1.9426],
#         [-1.8171, -1.5772],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [-0.0223,  1.9107],
#         [-0.0223,  1.9107],
#         [-4.9905, -0.2905],
#         [ 0.4582,  0.6762],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-2.2107, -1.9114],
#         [-2.2107, -1.9114],
#         [-1.8171, -1.5772],
#         [-2.0201, -1.8553],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))
# (tensor([[ 1.1821,  2.0611],
#         [ 0.2821, -0.0934],
#         [ 0.4367,  0.0597],
#         [-3.1139,  0.5643],
#         [-3.1139,  0.5643],
#         [ 0.2062, -0.4674],
#         [ 0.4110, -0.4184],
#         [ 0.3098, -0.4368],
#         [ 0.3285, -0.6642],
#         [ 0.3285, -0.6642]], grad_fn=<AddBackward0>), tensor([[-2.2440, -1.9631],
#         [-1.9352, -1.9408],
#         [-2.1329, -1.5230],
#         [-1.9517, -1.6402],
#         [-1.9517, -1.6402],
#         [-1.8402, -1.7865],
#         [-1.8625, -1.8438],
#         [-1.8464, -1.7940],
#         [-1.8117, -1.7844],
#         [-1.8117, -1.7844]], grad_fn=<AddBackward0>))

# %%
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))

mu_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))

# input data scatter 
import matplotlib.pyplot as plt
def plot_mu_graph(mu):
    
    n_node = mu.shape[0]
    annotations = [str(i+1) for i in range(n_node)]
    colors = plt.cm.rainbow(np.linspace(0, 1, n_node))
    plt.scatter(mu[:,0],mu[:,1],c=colors, s=100)
    
    for i, label in enumerate(annotations):
        plt.annotate(label, (mu[i,0], mu[i,1]), fontsize=14)

        
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list_in_data[graph_i])

# %%
# original data mu scatter
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*len(mu_list)
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
# original data first 5 vs. last 5
simu_graph = SimuData(n_graph=30)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

colors = ['#3DAE43', '#67E332','#008000', '#006400', '#228B22',
          '#CD5C5C','#C71585', '#FF4500', '#DB7093', '#FF0000']
mu_list = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list.append(np.asarray(mu.detach()))

plt.figure(figsize=(10,10))
for node_i in range(n_node):
    
    node_mu = np.empty((0, 2))
    for graph_i in range(len(mu_list)):
    
        node_mu = np.vstack((node_mu, mu_list[graph_i][node_i, :]))
    
    plt.scatter(node_mu[:,0],node_mu[:,1], c=colors[node_i],alpha=0.8)

plt.show()

# %%
# Gaussian distribution for generating mu

import scipy.stats as stats
data_mu = np.zeros((n, out_channels * n_node))
for i in range(n):
    data_mu[i, :] = mu_list_reshape[i]

from sklearn.mixture import GaussianMixture

gm_mu = GaussianMixture(n_components=1, random_state=0).fit(data_mu)
gm_mu.weights_[0] = 1
# Out:
# C:\Users\Ji Qi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# got mean and cov for mu generating distribution
means_normal = gm_mu.means_
cov_normal = gm_mu.covariances_
means_normal = np.asarray(means_normal.tolist()[0])
cov_normal = np.asarray(cov_normal.tolist()[0])

# %%
def compute_centrality(mat):
    return (np.sum(mat, axis=0)/mat.shape[0])

# %%
def sample_adj_mat(filter_value=0.75, filter_eye=True):
    model.__mu__ = torch.from_numpy((np.random.multivariate_normal(mean=means_normal,cov=cov_normal)).reshape((n_node,out_channels)))
    z = model.__mu__
    model.decode(z, edge_index)
    adj_mat = np.zeros((n_node, n_node))
    for i in range(n_node*n_node):
        adj_mat[int(edge_index[0, i]), int(edge_index[1, i])] = (model.decode(z, edge_index)[i].detach().numpy()).item()
    adj_mat[adj_mat < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat.shape[0]):
            adj_mat[i,i]=0
    return adj_mat, model.__mu__

# %%
# generate adjacency matrices

generated_from_simu = []
generated_simu_centrality = []

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(20,10))
adj_mat_list = []
mu_list = []
for i in range(30):
    plt.subplot(5, 6, i+1)
    adj_mat, mu_sample = sample_adj_mat(filter_value=0, filter_eye=False)
    generated_from_simu.append(adj_mat)
    generated_simu_centrality.append(compute_centrality(adj_mat))
    adj_mat_list.append(adj_mat)
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list[graph_i])

# %%
plot_scatter_for_mu(mu_list)

# %%
simu_adj_list = []
simu_centrality_list = []
for i in range(30):
    adj_mat = simu_graph.simu_adj_m()[i].detach().numpy()
    simu_adj_list.append(adj_mat)
    simu_centrality_list.append(compute_centrality(adj_mat))

# %%
from scipy import stats
res = stats.ttest_ind(generated_simu_centrality, simu_centrality_list, 
                      equal_var=True, axis=0)

display(res)
# Out:
# Ttest_indResult(statistic=array([ 15.56312932,  14.77535086,  15.22146813,  16.30160427,
#         13.75254761,  34.44894362,  84.77932551,  93.16993486,
#        158.86641132,  55.21630421]), pvalue=array([2.27663940e-22, 2.54963240e-21, 6.43099792e-22, 2.53095908e-23,
#        6.58696606e-20, 2.57393683e-40, 1.64972381e-62, 7.19940785e-65,
#        2.94765680e-78, 7.66428733e-52]))

# %%
np.mean(np.vstack(generated_simu_centrality), axis=0)
# Out:
# array([0.05018621, 0.09384497, 0.13722942, 0.0680849 , 0.08649408,
#        0.00312617, 0.        , 0.        , 0.00312617, 0.        ])

# %%
np.mean(np.vstack(simu_centrality_list), axis=0)
# Out:
# array([0.21      , 0.24      , 0.19333334, 0.16999997, 0.19333333,
#        0.        , 0.        , 0.        , 0.        , 0.        ],
#       dtype=float32)
