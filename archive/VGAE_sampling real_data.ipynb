# %%
import torch
from torch_geometric.utils import (negative_sampling, remove_self_loops,
                                   add_self_loops)
EPS = 1e-15
MAX_LOGSTD = 1

class InnerProductDecoder(torch.nn.Module):
    r"""The inner product decoder from the `"Variational Graph Auto-Encoders"
    <https://arxiv.org/abs/1611.07308>`_ paper

    .. math::
        \sigma(\mathbf{Z}\mathbf{Z}^{\top})

    where :math:`\mathbf{Z} \in \mathbb{R}^{N \times d}` denotes the latent
    space produced by the encoder."""
    def forward(self, z, edge_index, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into edge probabilities for
        the given node-pairs :obj:`edge_index`.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        value = (z[edge_index[0]] * z[edge_index[1]]).sum(dim=1)
        return torch.sigmoid(value) if sigmoid else value


    def forward_all(self, z, sigmoid=True):
        r"""Decodes the latent variables :obj:`z` into a probabilistic dense
        adjacency matrix.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            sigmoid (bool, optional): If set to :obj:`False`, does not apply
                the logistic sigmoid function to the output.
                (default: :obj:`True`)
        """
        adj = torch.matmul(z, z.t())
        return torch.sigmoid(adj) if sigmoid else adj



class GAE(torch.nn.Module):
    r"""The Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper based on user-defined encoder and decoder models.

    Args:
        encoder (Module): The encoder module.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(GAE, self).__init__()
        self.encoder = encoder
        self.decoder = InnerProductDecoder() if decoder is None else decoder
        GAE.reset_parameters(self)

    def reset_parameters(self):
        reset(self.encoder)
        reset(self.decoder)


    def encode(self, *args, **kwargs):
        r"""Runs the encoder and computes node-wise latent variables."""
        return self.encoder(*args, **kwargs)


    def decode(self, *args, **kwargs):
        r"""Runs the decoder and computes edge probabilities."""
        return self.decoder(*args, **kwargs)


    def recon_loss(self, z, pos_edge_index, neg_edge_index=None):
        r"""Given latent variables :obj:`z`, computes the binary cross
        entropy loss for positive edges :oenbj:`pos_edge_index` and negative
        sampled edges.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to train against.
            neg_edge_index (LongTensor, optional): The negative edges to train
                against. If not given, uses negative sampling to calculate
                negative edges. (default: :obj:`None`)
        """

        pos_loss = -torch.log(
            self.decoder(z, pos_edge_index, sigmoid=True) + EPS).mean()

        # Do not include self-loops in negative samples
        pos_edge_index, _ = remove_self_loops(pos_edge_index)
        pos_edge_index, _ = add_self_loops(pos_edge_index)
        if neg_edge_index is None:
            neg_edge_index = negative_sampling(pos_edge_index, z.size(0))
        neg_loss = -torch.log(1 -
                              self.decoder(z, neg_edge_index, sigmoid=True) +
                              EPS).mean()

        return pos_loss + neg_loss


    def test(self, z, pos_edge_index, neg_edge_index):
        r"""Given latent variables :obj:`z`, positive edges
        :obj:`pos_edge_index` and negative edges :obj:`neg_edge_index`,
        computes area under the ROC curve (AUC) and average precision (AP)
        scores.

        Args:
            z (Tensor): The latent space :math:`\mathbf{Z}`.
            pos_edge_index (LongTensor): The positive edges to evaluate
                against.
            neg_edge_index (LongTensor): The negative edges to evaluate
                against.
        """
        from sklearn.metrics import roc_auc_score, average_precision_score

        pos_y = z.new_ones(pos_edge_index.size(1))
        neg_y = z.new_zeros(neg_edge_index.size(1))
        y = torch.cat([pos_y, neg_y], dim=0)

        pos_pred = self.decoder(z, pos_edge_index, sigmoid=True)
        neg_pred = self.decoder(z, neg_edge_index, sigmoid=True)
        pred = torch.cat([pos_pred, neg_pred], dim=0)
        
        y, pred = y.detach().cpu().numpy(), pred.detach().cpu().numpy()

        return roc_auc_score(y, pred), average_precision_score(y, pred)



class VGAE(GAE):
    r"""The Variational Graph Auto-Encoder model from the
    `"Variational Graph Auto-Encoders" <https://arxiv.org/abs/1611.07308>`_
    paper.

    Args:
        encoder (Module): The encoder module to compute :math:`\mu` and
            :math:`\log\sigma^2`.
        decoder (Module, optional): The decoder module. If set to :obj:`None`,
            will default to the
            :class:`torch_geometric.nn.models.InnerProductDecoder`.
            (default: :obj:`None`)
    """
    def __init__(self, encoder, decoder=None):
        super(VGAE, self).__init__(encoder, decoder)

    def reparametrize(self, mu, logstd):
        if self.training:
            return mu + torch.randn_like(logstd) * torch.exp(logstd)
        else:
            return mu
    
    def encode(self, *args, **kwargs):
        """"""
        self.__mu__, self.__logstd__ = self.encoder(*args, **kwargs)
        self.__logstd__ = self.__logstd__.clamp(max=MAX_LOGSTD)
        z = self.reparametrize(self.__mu__, self.__logstd__)
        return z

    def kl_loss(self, mu=None, logstd=None):
        r"""Computes the KL loss, either for the passed arguments :obj:`mu`
        and :obj:`logstd`, or based on latent variables from last encoding.

        Args:
            mu (Tensor, optional): The latent space for :math:`\mu`. If set to
                :obj:`None`, uses the last computation of :math:`mu`.
                (default: :obj:`None`)
            logstd (Tensor, optional): The latent space for
                :math:`\log\sigma`.  If set to :obj:`None`, uses the last
                computation of :math:`\log\sigma^2`.(default: :obj:`None`)
        """
        mu = self.__mu__ if mu is None else mu
        logstd = self.__logstd__ if logstd is None else logstd.clamp(
            max=MAX_LOGSTD)
        return -0.5 * torch.mean(
            torch.sum(1 + 2 * logstd - mu**2 - logstd.exp()**2, dim=1))

# %%
import torch
from torch.autograd.grad_mode import F
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges
from torch_geometric.nn import VGAE

import scipy.sparse as sp
import numpy as np
import networkx as nx

class SimuData():
    """Simulate graph data"""
    def __init__(self, p=0.5, n_node=10, n_graph=30):
        self.n_node = n_node
        self.n_graph = n_graph
        self.p = p

    def simu_adj_wgh(self):
        adj_list = []

        for i in range(self.n_graph):
            ## zero matrix
            A = torch.zeros(self.n_node, self.n_node)
            # first five nodes weights: uniform(0,1)A[:5,:5] = W
            W = torch.rand(5, 5)
            ## symmetric
            i, j = torch.triu_indices(5, 5)
            W[i, j] = W.T[i, j]
            A[:5, :5] = W
            adj_list.append(A)  

        return adj_list

    def simu_adj_diag(self):
        adj_list = []

        for i in range(self.n_graph):
            A = torch.eye(self.n_node)
            adj_list.append(A)  

        return adj_list

    def simu_adj_m(self):
        """generating adjacency matrix"""
        adj_wgh = self.simu_adj_wgh()
        #adj_wgh = self.simu_adj_diag()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>=1-self.p] = 1
            adj[adj<1-self.p] = 0
            adj_m_list.append(adj)    
        return adj_m_list

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.simu_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)

        return dataset

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)


class Encoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=False) 
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=False)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=False)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)


transform = T.Compose([
            T.NormalizeFeatures(),
            T.RandomLinkSplit(num_val=0, num_test=0, is_undirected=True,
                            split_labels=True, add_negative_train_samples=False),])

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix


class LoadData():
    """Load graph data"""
    def __init__(self, file_path, samples, n_node=38):
        self.samples = samples
        self.file_path = file_path
        self.nSample = len(samples)
        self.n_node = n_node

    def get_adj_wgh(self):
        """generating adjacency matrix"""
        adj_orig_list =[]
        for sample in self.samples:
            f_name = self.file_path + ".".join([sample])
            adj   = np.asarray(pd.read_csv(f_name, index_col = 0, iterator = False))
            adj_orig_list.append(adj)    

        return adj_orig_list

    def get_adj_label(self):
        adj_m = self.get_adj_m()
        adj_label_list =[]
        
        for _, adj in enumerate(adj_m):
            adj_label = adj + sp.eye(adj.shape[0])
            adj_label = sparse_to_tuple(sp.coo_matrix(adj_label))
            #adj_label = sparse_to_tuple(adj_label)
            adj_label = torch.sparse.FloatTensor(torch.LongTensor(adj_label[0].T), 
                            torch.FloatTensor(adj_label[1]), 
                            torch.Size(adj_label[2]))
            adj_label_list.append(adj_label)
        return adj_label_list

    def get_adj_norm(self):
        adj_m = self.get_adj_m()
        adj_norm_list =[]

        for _, adj in enumerate(adj_m):
            adj_norm = preprocess_graph(adj)
            adj_norm = torch.sparse.FloatTensor(torch.LongTensor(adj_norm[0].T), 
                            torch.FloatTensor(adj_norm[1]), 
                            torch.Size(adj_norm[2]))
            adj_norm_list.append(adj_norm)

        return adj_norm_list

    def get_adj_m(self):
        adj_wgh = self.get_adj_wgh()
        adj_m_list =[]
        for _, adj in enumerate(adj_wgh):
            adj[adj>0] = 1
            for i in range(38):
                adj[i, i] = 0
            for i in range(38):
                for j in range(38):
                    if adj[i, j] == 1:
                        adj[j, i] = 1
            adj_m_list.append(adj)    
        return adj_m_list

    def get_feature(self):
        """generating feature matrix X"""
        adj_wgh = self.get_adj_wgh()
        x_list = []
        for _, adj in enumerate(adj_wgh):
            x_feature  = adj
            x_feature  = csr_matrix(x_feature)
            x_feature  = sparse_to_tuple(x_feature)
            x_feature  = torch.sparse.FloatTensor(torch.LongTensor(x_feature[0].T), 
                            torch.FloatTensor(x_feature[1]), 
                            torch.Size(x_feature[2]))
            x_list.append(x_feature)
        return x_list

    def get_x_feature(self):
        x = torch.arange(self.n_node)
        x_onehot = torch.eye(self.n_node)[x,:] 

        return torch.FloatTensor(x_onehot)   

    def graph_dataset(self):
        dataset =[]
        simu_adj = self.get_adj_m()

        for _, adj in enumerate(simu_adj):
            edge_index_temp = sp.coo_matrix(adj)
            indices = np.vstack((edge_index_temp.row, edge_index_temp.col))
            edge_index_A = torch.LongTensor(indices) 
            x = self.get_x_feature()
            data = Data(x=x, edge_index=edge_index_A)
            dataset.append(data)
        return dataset


def sparse_to_tuple(sparse_mx):
    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

def preprocess_graph(adj):
    adj = sp.coo_matrix(adj)
    adj_ = adj + sp.eye(adj.shape[0])
    rowsum = np.array(adj_.sum(1))
    degree_mat_inv_sqrt = sp.diags(np.power(rowsum, -0.5).flatten())
    adj_normalized = adj_.dot(degree_mat_inv_sqrt).transpose().dot(degree_mat_inv_sqrt).tocoo()
    
    return sparse_to_tuple(adj_normalized)

from os import walk

def get_filename(mypath):
    f = []
    for (dirpath, dirnames, filenames) in walk(mypath):
        f.extend(filenames)
        break
    return f

# %%
n_node = 10
temp = np.zeros((2, n_node * n_node))
for i in range(n_node):
    for j in range(n_node):
        temp[0, j + n_node*i] = j
for i in range(n_node):
    for j in range(n_node):
        temp[1, j + n_node*i] = i
edge_index = temp

# %%
simu_graph = SimuData(n_graph=30, p=0.5)
dataset = simu_graph.graph_dataset()
n_node = simu_graph.n_node

# %%
# original adj matrices

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(10,10))
for i in range(30):
    plt.subplot(5, 6, i+1)
    plt.imshow(simu_graph.simu_adj_m()[i], cmap="Greys")

# %%
out_channels = 10
n_node = 10
num_features = n_node

VGAE_Encoder = Encoder(num_features, out_channels)
model = VGAE(VGAE_Encoder)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
epochs = 5000

for epoch in range(epochs):
    loss_total = 0
    optimizer.zero_grad()
    
    for i in range(len(dataset)):
        train_data, val_data, test_data = transform(dataset[i])
        z = model.encode(train_data.x, train_data.edge_index)
        loss =10 * model.recon_loss(z, train_data.edge_index)
        loss = loss + (1 /num_features) * model.kl_loss()
        loss_total += loss

    loss_avg = loss_total/len(dataset)
    loss_avg.backward()
    optimizer.step()
    print(str(epoch)+str(loss_avg))
# Out:
# 0tensor(26.5482, grad_fn=<DivBackward0>)
# 1tensor(27.4671, grad_fn=<DivBackward0>)
# 2tensor(24.4267, grad_fn=<DivBackward0>)
# 3tensor(20.9738, grad_fn=<DivBackward0>)
# 4tensor(23.1447, grad_fn=<DivBackward0>)
# 5tensor(19.7326, grad_fn=<DivBackward0>)
# 6tensor(21.4164, grad_fn=<DivBackward0>)
# 7tensor(21.2615, grad_fn=<DivBackward0>)
# 8tensor(18.8159, grad_fn=<DivBackward0>)
# 9tensor(16.8883, grad_fn=<DivBackward0>)
# 10tensor(16.5753, grad_fn=<DivBackward0>)
# 11tensor(16.8118, grad_fn=<DivBackward0>)
# 12tensor(16.4125, grad_fn=<DivBackward0>)
# 13tensor(15.6680, grad_fn=<DivBackward0>)
# 14tensor(14.5467, grad_fn=<DivBackward0>)
# 15tensor(14.7616, grad_fn=<DivBackward0>)
# 16tensor(13.8965, grad_fn=<DivBackward0>)
# 17tensor(12.5942, grad_fn=<DivBackward0>)
# 18tensor(12.2407, grad_fn=<DivBackward0>)
# 19tensor(11.9453, grad_fn=<DivBackward0>)
# 20tensor(11.4865, grad_fn=<DivBackward0>)
# 21tensor(10.6299, grad_fn=<DivBackward0>)
# 22tensor(10.2074, grad_fn=<DivBackward0>)
# 23tensor(10.7453, grad_fn=<DivBackward0>)
# 24tensor(9.8130, grad_fn=<DivBackward0>)
# 25tensor(9.7808, grad_fn=<DivBackward0>)
# 26tensor(9.7360, grad_fn=<DivBackward0>)
# 27tensor(9.2944, grad_fn=<DivBackward0>)
# 28tensor(9.5886, grad_fn=<DivBackward0>)
# 29tensor(9.5424, grad_fn=<DivBackward0>)
# 30tensor(9.1744, grad_fn=<DivBackward0>)
# 31tensor(9.7917, grad_fn=<DivBackward0>)
# 32tensor(9.3917, grad_fn=<DivBackward0>)
# 33tensor(9.8067, grad_fn=<DivBackward0>)
# 34tensor(9.4183, grad_fn=<DivBackward0>)
# 35tensor(8.9316, grad_fn=<DivBackward0>)
# 36tensor(9.5372, grad_fn=<DivBackward0>)
# 37tensor(9.1594, grad_fn=<DivBackward0>)
# 38tensor(9.3106, grad_fn=<DivBackward0>)
# 39tensor(9.0488, grad_fn=<DivBackward0>)
# 40tensor(9.6123, grad_fn=<DivBackward0>)
# 41tensor(8.6860, grad_fn=<DivBackward0>)
# 42tensor(8.8213, grad_fn=<DivBackward0>)
# 43tensor(8.9367, grad_fn=<DivBackward0>)
# 44tensor(8.9499, grad_fn=<DivBackward0>)
# 45tensor(8.9812, grad_fn=<DivBackward0>)
# 46tensor(9.3429, grad_fn=<DivBackward0>)
# 47tensor(8.5740, grad_fn=<DivBackward0>)
# 48tensor(8.9877, grad_fn=<DivBackward0>)
# 49tensor(8.8282, grad_fn=<DivBackward0>)
# 50tensor(9.2180, grad_fn=<DivBackward0>)
# 51tensor(8.7122, grad_fn=<DivBackward0>)
# 52tensor(8.7962, grad_fn=<DivBackward0>)
# 53tensor(8.4763, grad_fn=<DivBackward0>)
# 54tensor(8.4241, grad_fn=<DivBackward0>)
# 55tensor(9.2952, grad_fn=<DivBackward0>)
# 56tensor(8.9485, grad_fn=<DivBackward0>)
# 57tensor(8.6392, grad_fn=<DivBackward0>)
# 58tensor(8.2120, grad_fn=<DivBackward0>)
# 59tensor(9.1866, grad_fn=<DivBackward0>)
# 60tensor(8.5736, grad_fn=<DivBackward0>)
# 61tensor(8.9196, grad_fn=<DivBackward0>)
# 62tensor(8.8270, grad_fn=<DivBackward0>)
# 63tensor(8.3268, grad_fn=<DivBackward0>)
# 64tensor(8.6486, grad_fn=<DivBackward0>)
# 65tensor(8.6002, grad_fn=<DivBackward0>)
# 66tensor(8.5412, grad_fn=<DivBackward0>)
# 67tensor(8.6930, grad_fn=<DivBackward0>)
# 68tensor(8.2528, grad_fn=<DivBackward0>)
# 69tensor(8.1793, grad_fn=<DivBackward0>)
# 70tensor(8.1448, grad_fn=<DivBackward0>)
# 71tensor(8.7078, grad_fn=<DivBackward0>)
# 72tensor(8.4253, grad_fn=<DivBackward0>)
# 73tensor(8.9463, grad_fn=<DivBackward0>)
# 74tensor(8.6782, grad_fn=<DivBackward0>)
# 75tensor(8.7331, grad_fn=<DivBackward0>)
# 76tensor(8.4688, grad_fn=<DivBackward0>)
# 77tensor(8.3208, grad_fn=<DivBackward0>)
# 78tensor(9.0385, grad_fn=<DivBackward0>)
# 79tensor(8.7678, grad_fn=<DivBackward0>)
# 80tensor(8.3729, grad_fn=<DivBackward0>)
# 81tensor(8.3749, grad_fn=<DivBackward0>)
# 82tensor(8.5279, grad_fn=<DivBackward0>)
# 83tensor(8.1625, grad_fn=<DivBackward0>)
# 84tensor(8.2512, grad_fn=<DivBackward0>)
# 85tensor(8.5729, grad_fn=<DivBackward0>)
# 86tensor(8.3246, grad_fn=<DivBackward0>)
# 87tensor(8.2821, grad_fn=<DivBackward0>)
# 88tensor(8.4486, grad_fn=<DivBackward0>)
# 89tensor(8.1271, grad_fn=<DivBackward0>)
# 90tensor(8.1990, grad_fn=<DivBackward0>)
# 91tensor(8.4406, grad_fn=<DivBackward0>)
# 92tensor(8.4585, grad_fn=<DivBackward0>)
# 93tensor(8.2118, grad_fn=<DivBackward0>)
# 94tensor(8.5030, grad_fn=<DivBackward0>)
# 95tensor(8.1904, grad_fn=<DivBackward0>)
# 96tensor(8.4230, grad_fn=<DivBackward0>)
# 97tensor(8.4032, grad_fn=<DivBackward0>)
# 98tensor(8.7720, grad_fn=<DivBackward0>)
# 99tensor(7.8135, grad_fn=<DivBackward0>)
# 100tensor(8.1750, grad_fn=<DivBackward0>)
# 101tensor(8.1241, grad_fn=<DivBackward0>)
# 102tensor(7.9308, grad_fn=<DivBackward0>)
# 103tensor(8.1807, grad_fn=<DivBackward0>)
# 104tensor(7.8475, grad_fn=<DivBackward0>)
# 105tensor(7.7893, grad_fn=<DivBackward0>)
# 106tensor(7.9570, grad_fn=<DivBackward0>)
# 107tensor(7.7664, grad_fn=<DivBackward0>)
# 108tensor(8.5812, grad_fn=<DivBackward0>)
# 109tensor(7.8704, grad_fn=<DivBackward0>)
# 110tensor(8.4690, grad_fn=<DivBackward0>)
# 111tensor(8.5581, grad_fn=<DivBackward0>)
# 112tensor(8.1001, grad_fn=<DivBackward0>)
# 113tensor(7.7223, grad_fn=<DivBackward0>)
# 114tensor(8.6871, grad_fn=<DivBackward0>)
# 115tensor(8.1832, grad_fn=<DivBackward0>)
# 116tensor(8.0558, grad_fn=<DivBackward0>)
# 117tensor(8.1820, grad_fn=<DivBackward0>)
# 118tensor(7.8274, grad_fn=<DivBackward0>)
# 119tensor(7.5956, grad_fn=<DivBackward0>)
# 120tensor(8.4153, grad_fn=<DivBackward0>)
# 121tensor(7.7249, grad_fn=<DivBackward0>)
# 122tensor(8.0792, grad_fn=<DivBackward0>)
# 123tensor(7.9503, grad_fn=<DivBackward0>)
# 124tensor(8.0090, grad_fn=<DivBackward0>)
# 125tensor(8.2181, grad_fn=<DivBackward0>)
# 126tensor(7.9019, grad_fn=<DivBackward0>)
# 127tensor(8.0919, grad_fn=<DivBackward0>)
# 128tensor(8.7089, grad_fn=<DivBackward0>)
# 129tensor(7.6880, grad_fn=<DivBackward0>)
# 130tensor(8.2192, grad_fn=<DivBackward0>)
# 131tensor(7.5847, grad_fn=<DivBackward0>)
# 132tensor(7.6645, grad_fn=<DivBackward0>)
# 133tensor(7.6866, grad_fn=<DivBackward0>)
# 134tensor(7.5292, grad_fn=<DivBackward0>)
# 135tensor(8.4172, grad_fn=<DivBackward0>)
# 136tensor(8.1667, grad_fn=<DivBackward0>)
# 137tensor(7.5821, grad_fn=<DivBackward0>)
# 138tensor(7.9485, grad_fn=<DivBackward0>)
# 139tensor(8.1358, grad_fn=<DivBackward0>)
# 140tensor(7.8542, grad_fn=<DivBackward0>)
# 141tensor(8.1411, grad_fn=<DivBackward0>)
# 142tensor(7.2706, grad_fn=<DivBackward0>)
# 143tensor(7.9365, grad_fn=<DivBackward0>)
# 144tensor(8.0948, grad_fn=<DivBackward0>)
# 145tensor(8.1171, grad_fn=<DivBackward0>)
# 146tensor(7.2774, grad_fn=<DivBackward0>)
# 147tensor(7.8037, grad_fn=<DivBackward0>)
# 148tensor(7.9670, grad_fn=<DivBackward0>)
# 149tensor(8.1193, grad_fn=<DivBackward0>)
# 150tensor(7.6647, grad_fn=<DivBackward0>)
# 151tensor(7.8657, grad_fn=<DivBackward0>)
# 152tensor(7.4170, grad_fn=<DivBackward0>)
# 153tensor(7.2460, grad_fn=<DivBackward0>)
# 154tensor(7.3683, grad_fn=<DivBackward0>)
# 155tensor(7.3789, grad_fn=<DivBackward0>)
# 156tensor(8.0026, grad_fn=<DivBackward0>)
# 157tensor(7.6886, grad_fn=<DivBackward0>)
# 158tensor(7.1546, grad_fn=<DivBackward0>)
# 159tensor(7.4157, grad_fn=<DivBackward0>)
# 160tensor(7.4625, grad_fn=<DivBackward0>)
# 161tensor(7.5052, grad_fn=<DivBackward0>)
# 162tensor(7.0711, grad_fn=<DivBackward0>)
# 163tensor(7.7274, grad_fn=<DivBackward0>)
# 164tensor(7.1513, grad_fn=<DivBackward0>)
# 165tensor(7.2670, grad_fn=<DivBackward0>)
# 166tensor(7.4144, grad_fn=<DivBackward0>)
# 167tensor(7.4119, grad_fn=<DivBackward0>)
# 168tensor(7.2295, grad_fn=<DivBackward0>)
# 169tensor(7.1205, grad_fn=<DivBackward0>)
# 170tensor(6.8100, grad_fn=<DivBackward0>)
# 171tensor(7.6149, grad_fn=<DivBackward0>)
# 172tensor(7.6157, grad_fn=<DivBackward0>)
# 173tensor(7.8520, grad_fn=<DivBackward0>)
# 174tensor(7.2938, grad_fn=<DivBackward0>)
# 175tensor(7.3095, grad_fn=<DivBackward0>)
# 176tensor(6.8010, grad_fn=<DivBackward0>)
# 177tensor(7.1747, grad_fn=<DivBackward0>)
# 178tensor(6.6799, grad_fn=<DivBackward0>)
# 179tensor(7.6472, grad_fn=<DivBackward0>)
# 180tensor(7.5168, grad_fn=<DivBackward0>)
# 181tensor(7.5793, grad_fn=<DivBackward0>)
# 182tensor(7.4790, grad_fn=<DivBackward0>)
# 183tensor(7.7863, grad_fn=<DivBackward0>)
# 184tensor(7.5520, grad_fn=<DivBackward0>)
# 185tensor(7.3082, grad_fn=<DivBackward0>)
# 186tensor(7.7196, grad_fn=<DivBackward0>)
# 187tensor(7.6211, grad_fn=<DivBackward0>)
# 188tensor(7.4404, grad_fn=<DivBackward0>)
# 189tensor(7.5860, grad_fn=<DivBackward0>)
# 190tensor(7.1747, grad_fn=<DivBackward0>)
# 191tensor(7.3011, grad_fn=<DivBackward0>)
# 192tensor(7.5979, grad_fn=<DivBackward0>)
# 193tensor(6.9004, grad_fn=<DivBackward0>)
# 194tensor(7.5573, grad_fn=<DivBackward0>)
# 195tensor(7.1231, grad_fn=<DivBackward0>)
# 196tensor(7.1759, grad_fn=<DivBackward0>)
# 197tensor(7.0510, grad_fn=<DivBackward0>)
# 198tensor(7.3418, grad_fn=<DivBackward0>)
# 199tensor(7.7238, grad_fn=<DivBackward0>)
# 200tensor(7.4402, grad_fn=<DivBackward0>)
# 201tensor(6.9678, grad_fn=<DivBackward0>)
# 202tensor(7.1677, grad_fn=<DivBackward0>)
# 203tensor(7.2338, grad_fn=<DivBackward0>)
# 204tensor(7.1654, grad_fn=<DivBackward0>)
# 205tensor(6.8790, grad_fn=<DivBackward0>)
# 206tensor(7.0916, grad_fn=<DivBackward0>)
# 207tensor(7.0307, grad_fn=<DivBackward0>)
# 208tensor(6.7481, grad_fn=<DivBackward0>)
# 209tensor(6.8862, grad_fn=<DivBackward0>)
# 210tensor(7.5205, grad_fn=<DivBackward0>)
# 211tensor(7.3685, grad_fn=<DivBackward0>)
# 212tensor(7.2995, grad_fn=<DivBackward0>)
# 213tensor(6.8528, grad_fn=<DivBackward0>)
# 214tensor(6.4984, grad_fn=<DivBackward0>)
# 215tensor(6.7470, grad_fn=<DivBackward0>)
# 216tensor(6.5349, grad_fn=<DivBackward0>)
# 217tensor(7.1033, grad_fn=<DivBackward0>)
# 218tensor(6.9841, grad_fn=<DivBackward0>)
# 219tensor(6.2440, grad_fn=<DivBackward0>)
# 220tensor(6.7342, grad_fn=<DivBackward0>)
# 221tensor(7.2335, grad_fn=<DivBackward0>)
# 222tensor(6.8674, grad_fn=<DivBackward0>)
# 223tensor(6.4934, grad_fn=<DivBackward0>)
# 224tensor(6.7047, grad_fn=<DivBackward0>)
# 225tensor(6.4996, grad_fn=<DivBackward0>)
# 226tensor(6.3715, grad_fn=<DivBackward0>)
# 227tensor(6.2990, grad_fn=<DivBackward0>)
# 228tensor(7.2584, grad_fn=<DivBackward0>)
# 229tensor(6.5583, grad_fn=<DivBackward0>)
# 230tensor(6.5692, grad_fn=<DivBackward0>)
# 231tensor(6.6497, grad_fn=<DivBackward0>)
# 232tensor(6.5347, grad_fn=<DivBackward0>)
# 233tensor(6.3433, grad_fn=<DivBackward0>)
# 234tensor(6.3639, grad_fn=<DivBackward0>)
# 235tensor(6.6458, grad_fn=<DivBackward0>)
# 236tensor(6.5921, grad_fn=<DivBackward0>)
# 237tensor(6.6135, grad_fn=<DivBackward0>)
# 238tensor(6.3526, grad_fn=<DivBackward0>)
# 239tensor(6.3810, grad_fn=<DivBackward0>)
# 240tensor(6.0054, grad_fn=<DivBackward0>)
# 241tensor(6.7762, grad_fn=<DivBackward0>)
# 242tensor(5.8509, grad_fn=<DivBackward0>)
# 243tensor(6.4776, grad_fn=<DivBackward0>)
# 244tensor(5.8966, grad_fn=<DivBackward0>)
# 245tensor(6.3915, grad_fn=<DivBackward0>)
# 246tensor(6.5271, grad_fn=<DivBackward0>)
# 247tensor(6.2190, grad_fn=<DivBackward0>)
# 248tensor(6.4261, grad_fn=<DivBackward0>)
# 249tensor(5.8834, grad_fn=<DivBackward0>)
# 250tensor(6.0115, grad_fn=<DivBackward0>)
# 251tensor(6.4240, grad_fn=<DivBackward0>)
# 252tensor(5.9852, grad_fn=<DivBackward0>)
# 253tensor(6.5456, grad_fn=<DivBackward0>)
# 254tensor(5.7511, grad_fn=<DivBackward0>)
# 255tensor(6.0236, grad_fn=<DivBackward0>)
# 256tensor(6.4684, grad_fn=<DivBackward0>)
# 257tensor(5.5451, grad_fn=<DivBackward0>)
# 258tensor(6.0848, grad_fn=<DivBackward0>)
# 259tensor(5.7934, grad_fn=<DivBackward0>)
# 260tensor(5.8944, grad_fn=<DivBackward0>)
# 261tensor(6.0733, grad_fn=<DivBackward0>)
# 262tensor(6.0986, grad_fn=<DivBackward0>)
# 263tensor(5.7004, grad_fn=<DivBackward0>)
# 264tensor(5.6801, grad_fn=<DivBackward0>)
# 265tensor(5.7081, grad_fn=<DivBackward0>)
# 266tensor(5.8627, grad_fn=<DivBackward0>)
# 267tensor(5.9450, grad_fn=<DivBackward0>)
# 268tensor(5.7899, grad_fn=<DivBackward0>)
# 269tensor(5.9834, grad_fn=<DivBackward0>)
# 270tensor(5.4223, grad_fn=<DivBackward0>)
# 271tensor(6.0487, grad_fn=<DivBackward0>)
# 272tensor(6.0221, grad_fn=<DivBackward0>)
# 273tensor(5.4025, grad_fn=<DivBackward0>)
# 274tensor(6.0122, grad_fn=<DivBackward0>)
# 275tensor(5.6314, grad_fn=<DivBackward0>)
# 276tensor(6.4601, grad_fn=<DivBackward0>)
# 277tensor(6.0599, grad_fn=<DivBackward0>)
# 278tensor(5.8321, grad_fn=<DivBackward0>)
# 279tensor(5.4178, grad_fn=<DivBackward0>)
# 280tensor(6.1116, grad_fn=<DivBackward0>)
# 281tensor(5.9965, grad_fn=<DivBackward0>)
# 282tensor(5.7584, grad_fn=<DivBackward0>)
# 283tensor(5.9319, grad_fn=<DivBackward0>)
# 284tensor(5.3846, grad_fn=<DivBackward0>)
# 285tensor(5.7762, grad_fn=<DivBackward0>)
# 286tensor(5.0873, grad_fn=<DivBackward0>)
# 287tensor(6.3490, grad_fn=<DivBackward0>)
# 288tensor(5.9597, grad_fn=<DivBackward0>)
# 289tensor(5.3514, grad_fn=<DivBackward0>)
# 290tensor(5.4222, grad_fn=<DivBackward0>)
# 291tensor(5.9826, grad_fn=<DivBackward0>)
# 292tensor(5.6295, grad_fn=<DivBackward0>)
# 293tensor(6.6784, grad_fn=<DivBackward0>)
# 294tensor(5.2010, grad_fn=<DivBackward0>)
# 295tensor(5.7567, grad_fn=<DivBackward0>)
# 296tensor(6.2636, grad_fn=<DivBackward0>)
# 297tensor(5.2637, grad_fn=<DivBackward0>)
# 298tensor(5.9828, grad_fn=<DivBackward0>)
# 299tensor(5.7441, grad_fn=<DivBackward0>)
# 300tensor(5.6807, grad_fn=<DivBackward0>)
# 301tensor(5.8642, grad_fn=<DivBackward0>)
# 302tensor(5.6630, grad_fn=<DivBackward0>)
# 303tensor(5.9851, grad_fn=<DivBackward0>)
# 304tensor(5.4555, grad_fn=<DivBackward0>)
# 305tensor(6.4895, grad_fn=<DivBackward0>)
# 306tensor(5.2915, grad_fn=<DivBackward0>)
# 307tensor(5.4601, grad_fn=<DivBackward0>)
# 308tensor(5.5459, grad_fn=<DivBackward0>)
# 309tensor(5.7007, grad_fn=<DivBackward0>)
# 310tensor(5.5086, grad_fn=<DivBackward0>)
# 311tensor(5.3962, grad_fn=<DivBackward0>)
# 312tensor(5.7367, grad_fn=<DivBackward0>)
# 313tensor(5.8065, grad_fn=<DivBackward0>)
# 314tensor(5.2740, grad_fn=<DivBackward0>)
# 315tensor(5.7500, grad_fn=<DivBackward0>)
# 316tensor(5.3701, grad_fn=<DivBackward0>)
# 317tensor(5.6977, grad_fn=<DivBackward0>)
# 318tensor(5.1383, grad_fn=<DivBackward0>)
# 319tensor(5.5204, grad_fn=<DivBackward0>)
# 320tensor(5.3667, grad_fn=<DivBackward0>)
# 321tensor(5.4067, grad_fn=<DivBackward0>)
# 322tensor(5.4599, grad_fn=<DivBackward0>)
# 323tensor(6.0178, grad_fn=<DivBackward0>)
# 324tensor(5.1038, grad_fn=<DivBackward0>)
# 325tensor(5.7470, grad_fn=<DivBackward0>)
# 326tensor(5.3988, grad_fn=<DivBackward0>)
# 327tensor(5.8898, grad_fn=<DivBackward0>)
# 328tensor(5.4010, grad_fn=<DivBackward0>)
# 329tensor(5.4397, grad_fn=<DivBackward0>)
# 330tensor(5.3692, grad_fn=<DivBackward0>)
# 331tensor(5.2174, grad_fn=<DivBackward0>)
# 332tensor(5.7671, grad_fn=<DivBackward0>)
# 333tensor(5.5756, grad_fn=<DivBackward0>)
# 334tensor(5.6711, grad_fn=<DivBackward0>)
# 335tensor(5.2581, grad_fn=<DivBackward0>)
# 336tensor(5.8371, grad_fn=<DivBackward0>)
# 337tensor(5.3839, grad_fn=<DivBackward0>)
# 338tensor(5.7919, grad_fn=<DivBackward0>)
# 339tensor(5.1423, grad_fn=<DivBackward0>)
# 340tensor(5.1401, grad_fn=<DivBackward0>)
# 341tensor(5.1519, grad_fn=<DivBackward0>)
# 342tensor(5.5905, grad_fn=<DivBackward0>)
# 343tensor(4.9814, grad_fn=<DivBackward0>)
# 344tensor(5.3122, grad_fn=<DivBackward0>)
# 345tensor(5.2150, grad_fn=<DivBackward0>)
# 346tensor(5.3197, grad_fn=<DivBackward0>)
# 347tensor(5.5902, grad_fn=<DivBackward0>)
# 348tensor(5.1856, grad_fn=<DivBackward0>)
# 349tensor(5.1709, grad_fn=<DivBackward0>)
# 350tensor(5.1114, grad_fn=<DivBackward0>)
# 351tensor(5.6631, grad_fn=<DivBackward0>)
# 352tensor(4.6620, grad_fn=<DivBackward0>)
# 353tensor(5.5629, grad_fn=<DivBackward0>)
# 354tensor(5.2167, grad_fn=<DivBackward0>)
# 355tensor(5.3367, grad_fn=<DivBackward0>)
# 356tensor(5.4504, grad_fn=<DivBackward0>)
# 357tensor(5.4448, grad_fn=<DivBackward0>)
# 358tensor(5.4959, grad_fn=<DivBackward0>)
# 359tensor(4.9984, grad_fn=<DivBackward0>)
# 360tensor(4.9175, grad_fn=<DivBackward0>)
# 361tensor(4.9077, grad_fn=<DivBackward0>)
# 362tensor(5.4647, grad_fn=<DivBackward0>)
# 363tensor(6.0947, grad_fn=<DivBackward0>)
# 364tensor(5.4584, grad_fn=<DivBackward0>)
# 365tensor(5.3164, grad_fn=<DivBackward0>)
# 366tensor(6.0139, grad_fn=<DivBackward0>)
# 367tensor(5.5653, grad_fn=<DivBackward0>)
# 368tensor(4.9094, grad_fn=<DivBackward0>)
# 369tensor(5.5430, grad_fn=<DivBackward0>)
# 370tensor(5.0235, grad_fn=<DivBackward0>)
# 371tensor(5.6797, grad_fn=<DivBackward0>)
# 372tensor(5.0480, grad_fn=<DivBackward0>)
# 373tensor(5.6730, grad_fn=<DivBackward0>)
# 374tensor(5.8619, grad_fn=<DivBackward0>)
# 375tensor(5.9651, grad_fn=<DivBackward0>)
# 376tensor(4.9348, grad_fn=<DivBackward0>)
# 377tensor(5.0619, grad_fn=<DivBackward0>)
# 378tensor(5.5876, grad_fn=<DivBackward0>)
# 379tensor(6.0435, grad_fn=<DivBackward0>)
# 380tensor(5.1440, grad_fn=<DivBackward0>)
# 381tensor(4.8507, grad_fn=<DivBackward0>)
# 382tensor(5.4951, grad_fn=<DivBackward0>)
# 383tensor(5.3197, grad_fn=<DivBackward0>)
# 384tensor(4.9416, grad_fn=<DivBackward0>)
# 385tensor(5.0839, grad_fn=<DivBackward0>)
# 386tensor(5.5581, grad_fn=<DivBackward0>)
# 387tensor(5.3521, grad_fn=<DivBackward0>)
# 388tensor(5.1271, grad_fn=<DivBackward0>)
# 389tensor(5.5537, grad_fn=<DivBackward0>)
# 390tensor(5.2700, grad_fn=<DivBackward0>)
# 391tensor(5.1099, grad_fn=<DivBackward0>)
# 392tensor(5.5816, grad_fn=<DivBackward0>)
# 393tensor(5.2096, grad_fn=<DivBackward0>)
# 394tensor(5.2796, grad_fn=<DivBackward0>)
# 395tensor(5.0661, grad_fn=<DivBackward0>)
# 396tensor(5.2938, grad_fn=<DivBackward0>)
# 397tensor(5.4368, grad_fn=<DivBackward0>)
# 398tensor(5.5360, grad_fn=<DivBackward0>)
# 399tensor(5.3525, grad_fn=<DivBackward0>)
# 400tensor(5.4991, grad_fn=<DivBackward0>)
# 401tensor(4.6730, grad_fn=<DivBackward0>)
# 402tensor(5.2523, grad_fn=<DivBackward0>)
# 403tensor(4.9000, grad_fn=<DivBackward0>)
# 404tensor(5.6454, grad_fn=<DivBackward0>)
# 405tensor(5.2937, grad_fn=<DivBackward0>)
# 406tensor(4.9625, grad_fn=<DivBackward0>)
# 407tensor(4.8104, grad_fn=<DivBackward0>)
# 408tensor(4.7036, grad_fn=<DivBackward0>)
# 409tensor(5.1314, grad_fn=<DivBackward0>)
# 410tensor(4.9937, grad_fn=<DivBackward0>)
# 411tensor(5.1816, grad_fn=<DivBackward0>)
# 412tensor(5.3332, grad_fn=<DivBackward0>)
# 413tensor(5.0140, grad_fn=<DivBackward0>)
# 414tensor(5.2385, grad_fn=<DivBackward0>)
# 415tensor(4.9668, grad_fn=<DivBackward0>)
# 416tensor(5.0071, grad_fn=<DivBackward0>)
# 417tensor(4.9812, grad_fn=<DivBackward0>)
# 418tensor(5.1515, grad_fn=<DivBackward0>)
# 419tensor(5.4141, grad_fn=<DivBackward0>)
# 420tensor(5.0531, grad_fn=<DivBackward0>)
# 421tensor(4.7718, grad_fn=<DivBackward0>)
# 422tensor(5.3085, grad_fn=<DivBackward0>)
# 423tensor(4.6863, grad_fn=<DivBackward0>)
# 424tensor(5.4244, grad_fn=<DivBackward0>)
# 425tensor(5.4826, grad_fn=<DivBackward0>)
# 426tensor(5.2914, grad_fn=<DivBackward0>)
# 427tensor(5.0817, grad_fn=<DivBackward0>)
# 428tensor(5.0412, grad_fn=<DivBackward0>)
# 429tensor(4.8686, grad_fn=<DivBackward0>)
# 430tensor(5.1482, grad_fn=<DivBackward0>)
# 431tensor(4.6246, grad_fn=<DivBackward0>)
# 432tensor(4.6760, grad_fn=<DivBackward0>)
# 433tensor(5.3266, grad_fn=<DivBackward0>)
# 434tensor(4.9009, grad_fn=<DivBackward0>)
# 435tensor(5.2721, grad_fn=<DivBackward0>)
# 436tensor(4.7943, grad_fn=<DivBackward0>)
# 437tensor(4.8103, grad_fn=<DivBackward0>)
# 438tensor(5.2087, grad_fn=<DivBackward0>)
# 439tensor(4.7567, grad_fn=<DivBackward0>)
# 440tensor(4.6332, grad_fn=<DivBackward0>)
# 441tensor(5.2890, grad_fn=<DivBackward0>)
# 442tensor(4.6119, grad_fn=<DivBackward0>)
# 443tensor(5.3716, grad_fn=<DivBackward0>)
# 444tensor(5.4647, grad_fn=<DivBackward0>)
# 445tensor(5.1434, grad_fn=<DivBackward0>)
# 446tensor(4.7606, grad_fn=<DivBackward0>)
# 447tensor(4.6302, grad_fn=<DivBackward0>)
# 448tensor(4.7072, grad_fn=<DivBackward0>)
# 449tensor(4.5350, grad_fn=<DivBackward0>)
# 450tensor(4.9675, grad_fn=<DivBackward0>)
# 451tensor(5.1703, grad_fn=<DivBackward0>)
# 452tensor(4.9604, grad_fn=<DivBackward0>)
# 453tensor(5.1206, grad_fn=<DivBackward0>)
# 454tensor(4.9593, grad_fn=<DivBackward0>)
# 455tensor(4.8923, grad_fn=<DivBackward0>)
# 456tensor(5.2138, grad_fn=<DivBackward0>)
# 457tensor(5.1972, grad_fn=<DivBackward0>)
# 458tensor(4.6713, grad_fn=<DivBackward0>)
# 459tensor(4.8338, grad_fn=<DivBackward0>)
# 460tensor(5.0898, grad_fn=<DivBackward0>)
# 461tensor(5.4485, grad_fn=<DivBackward0>)
# 462tensor(5.3362, grad_fn=<DivBackward0>)
# 463tensor(5.1237, grad_fn=<DivBackward0>)
# 464tensor(4.6661, grad_fn=<DivBackward0>)
# 465tensor(4.8441, grad_fn=<DivBackward0>)
# 466tensor(5.2099, grad_fn=<DivBackward0>)
# 467tensor(4.6156, grad_fn=<DivBackward0>)
# 468tensor(5.7134, grad_fn=<DivBackward0>)
# 469tensor(5.1283, grad_fn=<DivBackward0>)
# 470tensor(4.5924, grad_fn=<DivBackward0>)
# 471tensor(4.6832, grad_fn=<DivBackward0>)
# 472tensor(5.1541, grad_fn=<DivBackward0>)
# 473tensor(5.1279, grad_fn=<DivBackward0>)
# 474tensor(4.7455, grad_fn=<DivBackward0>)
# 475tensor(5.0056, grad_fn=<DivBackward0>)
# 476tensor(4.7303, grad_fn=<DivBackward0>)
# 477tensor(5.3982, grad_fn=<DivBackward0>)
# 478tensor(5.0388, grad_fn=<DivBackward0>)
# 479tensor(5.1895, grad_fn=<DivBackward0>)
# 480tensor(5.0629, grad_fn=<DivBackward0>)
# 481tensor(5.0488, grad_fn=<DivBackward0>)
# 482tensor(4.9397, grad_fn=<DivBackward0>)
# 483tensor(4.7755, grad_fn=<DivBackward0>)
# 484tensor(5.0460, grad_fn=<DivBackward0>)
# 485tensor(4.3898, grad_fn=<DivBackward0>)
# 486tensor(4.8937, grad_fn=<DivBackward0>)
# 487tensor(4.7612, grad_fn=<DivBackward0>)
# 488tensor(4.6618, grad_fn=<DivBackward0>)
# 489tensor(4.6165, grad_fn=<DivBackward0>)
# 490tensor(5.0369, grad_fn=<DivBackward0>)
# 491tensor(4.9434, grad_fn=<DivBackward0>)
# 492tensor(5.2422, grad_fn=<DivBackward0>)
# 493tensor(4.9805, grad_fn=<DivBackward0>)
# 494tensor(5.0872, grad_fn=<DivBackward0>)
# 495tensor(5.0859, grad_fn=<DivBackward0>)
# 496tensor(5.4263, grad_fn=<DivBackward0>)
# 497tensor(4.8439, grad_fn=<DivBackward0>)
# 498tensor(5.3058, grad_fn=<DivBackward0>)
# 499tensor(4.5753, grad_fn=<DivBackward0>)
# 500tensor(5.3654, grad_fn=<DivBackward0>)
# 501tensor(4.7409, grad_fn=<DivBackward0>)
# 502tensor(5.1051, grad_fn=<DivBackward0>)
# 503tensor(5.0103, grad_fn=<DivBackward0>)
# 504tensor(4.8684, grad_fn=<DivBackward0>)
# 505tensor(4.3087, grad_fn=<DivBackward0>)
# 506tensor(4.8070, grad_fn=<DivBackward0>)
# 507tensor(5.0557, grad_fn=<DivBackward0>)
# 508tensor(4.8498, grad_fn=<DivBackward0>)
# 509tensor(5.1693, grad_fn=<DivBackward0>)
# 510tensor(5.1243, grad_fn=<DivBackward0>)
# 511tensor(5.1734, grad_fn=<DivBackward0>)
# 512tensor(4.6323, grad_fn=<DivBackward0>)
# 513tensor(4.7428, grad_fn=<DivBackward0>)
# 514tensor(4.4043, grad_fn=<DivBackward0>)
# 515tensor(4.4379, grad_fn=<DivBackward0>)
# 516tensor(4.9897, grad_fn=<DivBackward0>)
# 517tensor(5.4196, grad_fn=<DivBackward0>)
# 518tensor(5.0764, grad_fn=<DivBackward0>)
# 519tensor(4.8565, grad_fn=<DivBackward0>)
# 520tensor(5.0121, grad_fn=<DivBackward0>)
# 521tensor(5.2619, grad_fn=<DivBackward0>)
# 522tensor(4.7387, grad_fn=<DivBackward0>)
# 523tensor(5.6652, grad_fn=<DivBackward0>)
# 524tensor(5.0664, grad_fn=<DivBackward0>)
# 525tensor(5.0153, grad_fn=<DivBackward0>)
# 526tensor(5.0277, grad_fn=<DivBackward0>)
# 527tensor(4.4995, grad_fn=<DivBackward0>)
# 528tensor(4.9469, grad_fn=<DivBackward0>)
# 529tensor(4.4081, grad_fn=<DivBackward0>)
# 530tensor(5.0883, grad_fn=<DivBackward0>)
# 531tensor(4.8521, grad_fn=<DivBackward0>)
# 532tensor(4.5193, grad_fn=<DivBackward0>)
# 533tensor(4.9547, grad_fn=<DivBackward0>)
# 534tensor(5.5063, grad_fn=<DivBackward0>)
# 535tensor(4.9215, grad_fn=<DivBackward0>)
# 536tensor(4.9191, grad_fn=<DivBackward0>)
# 537tensor(5.0266, grad_fn=<DivBackward0>)
# 538tensor(4.9093, grad_fn=<DivBackward0>)
# 539tensor(5.1115, grad_fn=<DivBackward0>)
# 540tensor(5.4483, grad_fn=<DivBackward0>)
# 541tensor(4.8589, grad_fn=<DivBackward0>)
# 542tensor(4.9182, grad_fn=<DivBackward0>)
# 543tensor(4.8335, grad_fn=<DivBackward0>)
# 544tensor(5.0795, grad_fn=<DivBackward0>)
# 545tensor(4.9723, grad_fn=<DivBackward0>)
# 546tensor(4.6945, grad_fn=<DivBackward0>)
# 547tensor(5.0952, grad_fn=<DivBackward0>)
# 548tensor(4.5393, grad_fn=<DivBackward0>)
# 549tensor(5.4825, grad_fn=<DivBackward0>)
# 550tensor(4.9294, grad_fn=<DivBackward0>)
# 551tensor(4.8044, grad_fn=<DivBackward0>)
# 552tensor(4.9056, grad_fn=<DivBackward0>)
# 553tensor(4.6816, grad_fn=<DivBackward0>)
# 554tensor(4.9151, grad_fn=<DivBackward0>)
# 555tensor(5.0282, grad_fn=<DivBackward0>)
# 556tensor(5.1711, grad_fn=<DivBackward0>)
# 557tensor(4.6924, grad_fn=<DivBackward0>)
# 558tensor(5.1229, grad_fn=<DivBackward0>)
# 559tensor(4.4168, grad_fn=<DivBackward0>)
# 560tensor(4.8471, grad_fn=<DivBackward0>)
# 561tensor(4.9825, grad_fn=<DivBackward0>)
# 562tensor(4.8971, grad_fn=<DivBackward0>)
# 563tensor(5.0687, grad_fn=<DivBackward0>)
# 564tensor(5.2671, grad_fn=<DivBackward0>)
# 565tensor(4.7928, grad_fn=<DivBackward0>)
# 566tensor(4.6395, grad_fn=<DivBackward0>)
# 567tensor(4.6901, grad_fn=<DivBackward0>)
# 568tensor(4.6996, grad_fn=<DivBackward0>)
# 569tensor(4.6064, grad_fn=<DivBackward0>)
# 570tensor(4.3300, grad_fn=<DivBackward0>)
# 571tensor(4.8021, grad_fn=<DivBackward0>)
# 572tensor(5.4831, grad_fn=<DivBackward0>)
# 573tensor(5.0685, grad_fn=<DivBackward0>)
# 574tensor(5.1809, grad_fn=<DivBackward0>)
# 575tensor(4.7656, grad_fn=<DivBackward0>)
# 576tensor(4.7377, grad_fn=<DivBackward0>)
# 577tensor(4.9296, grad_fn=<DivBackward0>)
# 578tensor(4.5732, grad_fn=<DivBackward0>)
# 579tensor(4.8629, grad_fn=<DivBackward0>)
# 580tensor(4.7986, grad_fn=<DivBackward0>)
# 581tensor(4.4353, grad_fn=<DivBackward0>)
# 582tensor(4.8323, grad_fn=<DivBackward0>)
# 583tensor(4.5942, grad_fn=<DivBackward0>)
# 584tensor(4.6755, grad_fn=<DivBackward0>)
# 585tensor(4.5380, grad_fn=<DivBackward0>)
# 586tensor(4.6907, grad_fn=<DivBackward0>)
# 587tensor(4.4001, grad_fn=<DivBackward0>)
# 588tensor(4.6778, grad_fn=<DivBackward0>)
# 589tensor(4.8397, grad_fn=<DivBackward0>)
# 590tensor(4.7751, grad_fn=<DivBackward0>)
# 591tensor(4.9020, grad_fn=<DivBackward0>)
# 592tensor(4.8924, grad_fn=<DivBackward0>)
# 593tensor(5.3921, grad_fn=<DivBackward0>)
# 594tensor(4.6544, grad_fn=<DivBackward0>)
# 595tensor(4.7891, grad_fn=<DivBackward0>)
# 596tensor(4.9099, grad_fn=<DivBackward0>)
# 597tensor(4.3914, grad_fn=<DivBackward0>)
# 598tensor(4.5751, grad_fn=<DivBackward0>)
# 599tensor(5.1517, grad_fn=<DivBackward0>)
# 600tensor(4.8910, grad_fn=<DivBackward0>)
# 601tensor(5.1561, grad_fn=<DivBackward0>)
# 602tensor(4.5473, grad_fn=<DivBackward0>)
# 603tensor(4.6821, grad_fn=<DivBackward0>)
# 604tensor(4.8143, grad_fn=<DivBackward0>)
# 605tensor(4.8452, grad_fn=<DivBackward0>)
# 606tensor(4.9186, grad_fn=<DivBackward0>)
# 607tensor(4.6852, grad_fn=<DivBackward0>)
# 608tensor(4.9887, grad_fn=<DivBackward0>)
# 609tensor(4.4729, grad_fn=<DivBackward0>)
# 610tensor(4.6311, grad_fn=<DivBackward0>)
# 611tensor(4.6455, grad_fn=<DivBackward0>)
# 612tensor(4.7953, grad_fn=<DivBackward0>)
# 613tensor(4.2792, grad_fn=<DivBackward0>)
# 614tensor(4.6597, grad_fn=<DivBackward0>)
# 615tensor(4.5613, grad_fn=<DivBackward0>)
# 616tensor(4.5723, grad_fn=<DivBackward0>)
# 617tensor(4.4705, grad_fn=<DivBackward0>)
# 618tensor(3.9498, grad_fn=<DivBackward0>)
# 619tensor(4.8710, grad_fn=<DivBackward0>)
# 620tensor(4.9626, grad_fn=<DivBackward0>)
# 621tensor(4.6714, grad_fn=<DivBackward0>)
# 622tensor(4.7155, grad_fn=<DivBackward0>)
# 623tensor(4.8693, grad_fn=<DivBackward0>)
# 624tensor(4.7765, grad_fn=<DivBackward0>)
# 625tensor(4.8975, grad_fn=<DivBackward0>)
# 626tensor(4.7422, grad_fn=<DivBackward0>)
# 627tensor(4.5911, grad_fn=<DivBackward0>)
# 628tensor(4.3584, grad_fn=<DivBackward0>)
# 629tensor(5.1569, grad_fn=<DivBackward0>)
# 630tensor(4.3366, grad_fn=<DivBackward0>)
# 631tensor(5.0988, grad_fn=<DivBackward0>)
# 632tensor(4.5061, grad_fn=<DivBackward0>)
# 633tensor(4.6414, grad_fn=<DivBackward0>)
# 634tensor(4.9136, grad_fn=<DivBackward0>)
# 635tensor(4.7935, grad_fn=<DivBackward0>)
# 636tensor(4.2895, grad_fn=<DivBackward0>)
# 637tensor(5.2115, grad_fn=<DivBackward0>)
# 638tensor(3.9877, grad_fn=<DivBackward0>)
# 639tensor(4.6272, grad_fn=<DivBackward0>)
# 640tensor(4.6278, grad_fn=<DivBackward0>)
# 641tensor(5.0034, grad_fn=<DivBackward0>)
# 642tensor(4.7418, grad_fn=<DivBackward0>)
# 643tensor(4.3248, grad_fn=<DivBackward0>)
# 644tensor(4.1948, grad_fn=<DivBackward0>)
# 645tensor(5.1990, grad_fn=<DivBackward0>)
# 646tensor(4.6634, grad_fn=<DivBackward0>)
# 647tensor(4.7505, grad_fn=<DivBackward0>)
# 648tensor(5.2740, grad_fn=<DivBackward0>)
# 649tensor(4.6981, grad_fn=<DivBackward0>)
# 650tensor(4.6743, grad_fn=<DivBackward0>)
# 651tensor(4.6737, grad_fn=<DivBackward0>)
# 652tensor(4.4972, grad_fn=<DivBackward0>)
# 653tensor(4.7913, grad_fn=<DivBackward0>)
# 654tensor(4.9558, grad_fn=<DivBackward0>)
# 655tensor(5.0730, grad_fn=<DivBackward0>)
# 656tensor(4.9036, grad_fn=<DivBackward0>)
# 657tensor(4.0185, grad_fn=<DivBackward0>)
# 658tensor(4.9221, grad_fn=<DivBackward0>)
# 659tensor(4.4909, grad_fn=<DivBackward0>)
# 660tensor(4.8784, grad_fn=<DivBackward0>)
# 661tensor(5.0330, grad_fn=<DivBackward0>)
# 662tensor(4.3766, grad_fn=<DivBackward0>)
# 663tensor(4.4505, grad_fn=<DivBackward0>)
# 664tensor(5.4185, grad_fn=<DivBackward0>)
# 665tensor(5.1101, grad_fn=<DivBackward0>)
# 666tensor(4.4648, grad_fn=<DivBackward0>)
# 667tensor(4.5692, grad_fn=<DivBackward0>)
# 668tensor(4.6120, grad_fn=<DivBackward0>)
# 669tensor(5.6363, grad_fn=<DivBackward0>)
# 670tensor(4.5329, grad_fn=<DivBackward0>)
# 671tensor(4.2678, grad_fn=<DivBackward0>)
# 672tensor(4.5825, grad_fn=<DivBackward0>)
# 673tensor(5.3830, grad_fn=<DivBackward0>)
# 674tensor(5.0187, grad_fn=<DivBackward0>)
# 675tensor(4.7633, grad_fn=<DivBackward0>)
# 676tensor(4.6165, grad_fn=<DivBackward0>)
# 677tensor(4.7931, grad_fn=<DivBackward0>)
# 678tensor(4.5986, grad_fn=<DivBackward0>)
# 679tensor(4.1568, grad_fn=<DivBackward0>)
# 680tensor(5.9589, grad_fn=<DivBackward0>)
# 681tensor(4.6376, grad_fn=<DivBackward0>)
# 682tensor(4.5333, grad_fn=<DivBackward0>)
# 683tensor(4.5016, grad_fn=<DivBackward0>)
# 684tensor(4.7020, grad_fn=<DivBackward0>)
# 685tensor(5.0476, grad_fn=<DivBackward0>)
# 686tensor(4.8755, grad_fn=<DivBackward0>)
# 687tensor(4.8103, grad_fn=<DivBackward0>)
# 688tensor(4.3642, grad_fn=<DivBackward0>)
# 689tensor(4.9536, grad_fn=<DivBackward0>)
# 690tensor(4.2736, grad_fn=<DivBackward0>)
# 691tensor(4.8342, grad_fn=<DivBackward0>)
# 692tensor(4.5575, grad_fn=<DivBackward0>)
# 693tensor(4.6361, grad_fn=<DivBackward0>)
# 694tensor(4.5532, grad_fn=<DivBackward0>)
# 695tensor(5.0699, grad_fn=<DivBackward0>)
# 696tensor(4.3314, grad_fn=<DivBackward0>)
# 697tensor(4.3364, grad_fn=<DivBackward0>)
# 698tensor(4.7509, grad_fn=<DivBackward0>)
# 699tensor(4.5077, grad_fn=<DivBackward0>)
# 700tensor(4.4781, grad_fn=<DivBackward0>)
# 701tensor(4.8268, grad_fn=<DivBackward0>)
# 702tensor(5.1898, grad_fn=<DivBackward0>)
# 703tensor(5.0803, grad_fn=<DivBackward0>)
# 704tensor(5.0812, grad_fn=<DivBackward0>)
# 705tensor(4.5197, grad_fn=<DivBackward0>)
# 706tensor(4.3888, grad_fn=<DivBackward0>)
# 707tensor(4.5110, grad_fn=<DivBackward0>)
# 708tensor(4.7063, grad_fn=<DivBackward0>)
# 709tensor(4.6460, grad_fn=<DivBackward0>)
# 710tensor(4.3433, grad_fn=<DivBackward0>)
# 711tensor(4.2291, grad_fn=<DivBackward0>)
# 712tensor(4.6970, grad_fn=<DivBackward0>)
# 713tensor(4.9370, grad_fn=<DivBackward0>)
# 714tensor(4.6672, grad_fn=<DivBackward0>)
# 715tensor(5.4071, grad_fn=<DivBackward0>)
# 716tensor(5.3795, grad_fn=<DivBackward0>)
# 717tensor(4.6850, grad_fn=<DivBackward0>)
# 718tensor(4.3207, grad_fn=<DivBackward0>)
# 719tensor(4.5180, grad_fn=<DivBackward0>)
# 720tensor(4.5806, grad_fn=<DivBackward0>)
# 721tensor(5.6871, grad_fn=<DivBackward0>)
# 722tensor(4.4253, grad_fn=<DivBackward0>)
# 723tensor(4.6590, grad_fn=<DivBackward0>)
# 724tensor(4.5773, grad_fn=<DivBackward0>)
# 725tensor(4.7949, grad_fn=<DivBackward0>)
# 726tensor(4.4518, grad_fn=<DivBackward0>)
# 727tensor(4.2584, grad_fn=<DivBackward0>)
# 728tensor(4.3453, grad_fn=<DivBackward0>)
# 729tensor(4.6674, grad_fn=<DivBackward0>)
# 730tensor(4.9860, grad_fn=<DivBackward0>)
# 731tensor(4.3767, grad_fn=<DivBackward0>)
# 732tensor(4.7306, grad_fn=<DivBackward0>)
# 733tensor(4.9269, grad_fn=<DivBackward0>)
# 734tensor(4.2355, grad_fn=<DivBackward0>)
# 735tensor(4.4957, grad_fn=<DivBackward0>)
# 736tensor(4.4781, grad_fn=<DivBackward0>)
# 737tensor(4.7718, grad_fn=<DivBackward0>)
# 738tensor(5.1752, grad_fn=<DivBackward0>)
# 739tensor(5.0949, grad_fn=<DivBackward0>)
# 740tensor(5.0834, grad_fn=<DivBackward0>)
# 741tensor(5.0941, grad_fn=<DivBackward0>)
# 742tensor(4.7646, grad_fn=<DivBackward0>)
# 743tensor(4.9621, grad_fn=<DivBackward0>)
# 744tensor(5.1315, grad_fn=<DivBackward0>)
# 745tensor(4.1936, grad_fn=<DivBackward0>)
# 746tensor(4.6548, grad_fn=<DivBackward0>)
# 747tensor(4.5395, grad_fn=<DivBackward0>)
# 748tensor(4.7616, grad_fn=<DivBackward0>)
# 749tensor(4.5388, grad_fn=<DivBackward0>)
# 750tensor(5.3245, grad_fn=<DivBackward0>)
# 751tensor(4.5771, grad_fn=<DivBackward0>)
# 752tensor(4.4901, grad_fn=<DivBackward0>)
# 753tensor(4.8779, grad_fn=<DivBackward0>)
# 754tensor(4.4588, grad_fn=<DivBackward0>)
# 755tensor(4.8139, grad_fn=<DivBackward0>)
# 756tensor(4.7817, grad_fn=<DivBackward0>)
# 757tensor(4.5317, grad_fn=<DivBackward0>)
# 758tensor(4.6451, grad_fn=<DivBackward0>)
# 759tensor(4.4848, grad_fn=<DivBackward0>)
# 760tensor(4.1172, grad_fn=<DivBackward0>)
# 761tensor(4.9474, grad_fn=<DivBackward0>)
# 762tensor(4.4436, grad_fn=<DivBackward0>)
# 763tensor(4.5145, grad_fn=<DivBackward0>)
# 764tensor(4.8299, grad_fn=<DivBackward0>)
# 765tensor(4.5489, grad_fn=<DivBackward0>)
# 766tensor(4.2125, grad_fn=<DivBackward0>)
# 767tensor(5.0528, grad_fn=<DivBackward0>)
# 768tensor(4.9621, grad_fn=<DivBackward0>)
# 769tensor(4.9044, grad_fn=<DivBackward0>)
# 770tensor(4.5181, grad_fn=<DivBackward0>)
# 771tensor(4.9679, grad_fn=<DivBackward0>)
# 772tensor(4.5501, grad_fn=<DivBackward0>)
# 773tensor(5.0195, grad_fn=<DivBackward0>)
# 774tensor(4.3157, grad_fn=<DivBackward0>)
# 775tensor(4.7846, grad_fn=<DivBackward0>)
# 776tensor(4.5750, grad_fn=<DivBackward0>)
# 777tensor(5.2583, grad_fn=<DivBackward0>)
# 778tensor(4.7993, grad_fn=<DivBackward0>)
# 779tensor(4.7495, grad_fn=<DivBackward0>)
# 780tensor(4.7248, grad_fn=<DivBackward0>)
# 781tensor(5.5039, grad_fn=<DivBackward0>)
# 782tensor(4.4456, grad_fn=<DivBackward0>)
# 783tensor(4.9145, grad_fn=<DivBackward0>)
# 784tensor(5.0715, grad_fn=<DivBackward0>)
# 785tensor(4.4468, grad_fn=<DivBackward0>)
# 786tensor(4.1973, grad_fn=<DivBackward0>)
# 787tensor(5.1520, grad_fn=<DivBackward0>)
# 788tensor(4.7238, grad_fn=<DivBackward0>)
# 789tensor(4.6756, grad_fn=<DivBackward0>)
# 790tensor(4.5796, grad_fn=<DivBackward0>)
# 791tensor(4.6503, grad_fn=<DivBackward0>)
# 792tensor(4.5629, grad_fn=<DivBackward0>)
# 793tensor(4.5523, grad_fn=<DivBackward0>)
# 794tensor(4.4541, grad_fn=<DivBackward0>)
# 795tensor(4.5229, grad_fn=<DivBackward0>)
# 796tensor(4.8824, grad_fn=<DivBackward0>)
# 797tensor(4.5103, grad_fn=<DivBackward0>)
# 798tensor(4.6863, grad_fn=<DivBackward0>)
# 799tensor(4.8358, grad_fn=<DivBackward0>)
# 800tensor(4.5306, grad_fn=<DivBackward0>)
# 801tensor(4.9095, grad_fn=<DivBackward0>)
# 802tensor(4.6376, grad_fn=<DivBackward0>)
# 803tensor(5.0596, grad_fn=<DivBackward0>)
# 804tensor(4.4896, grad_fn=<DivBackward0>)
# 805tensor(4.8890, grad_fn=<DivBackward0>)
# 806tensor(4.8348, grad_fn=<DivBackward0>)
# 807tensor(4.3975, grad_fn=<DivBackward0>)
# 808tensor(4.6747, grad_fn=<DivBackward0>)
# 809tensor(5.0404, grad_fn=<DivBackward0>)
# 810tensor(4.5423, grad_fn=<DivBackward0>)
# 811tensor(4.5569, grad_fn=<DivBackward0>)
# 812tensor(4.5737, grad_fn=<DivBackward0>)
# 813tensor(4.8429, grad_fn=<DivBackward0>)
# 814tensor(4.5583, grad_fn=<DivBackward0>)
# 815tensor(4.4903, grad_fn=<DivBackward0>)
# 816tensor(4.5693, grad_fn=<DivBackward0>)
# 817tensor(4.4193, grad_fn=<DivBackward0>)
# 818tensor(4.8316, grad_fn=<DivBackward0>)
# 819tensor(4.6766, grad_fn=<DivBackward0>)
# 820tensor(4.5969, grad_fn=<DivBackward0>)
# 821tensor(4.5260, grad_fn=<DivBackward0>)
# 822tensor(4.5047, grad_fn=<DivBackward0>)
# 823tensor(4.9423, grad_fn=<DivBackward0>)
# 824tensor(4.9662, grad_fn=<DivBackward0>)
# 825tensor(4.6033, grad_fn=<DivBackward0>)
# 826tensor(5.0423, grad_fn=<DivBackward0>)
# 827tensor(4.5251, grad_fn=<DivBackward0>)
# 828tensor(4.6403, grad_fn=<DivBackward0>)
# 829tensor(5.1074, grad_fn=<DivBackward0>)
# 830tensor(4.4390, grad_fn=<DivBackward0>)
# 831tensor(4.9158, grad_fn=<DivBackward0>)
# 832tensor(4.5139, grad_fn=<DivBackward0>)
# 833tensor(4.3895, grad_fn=<DivBackward0>)
# 834tensor(4.5857, grad_fn=<DivBackward0>)
# 835tensor(4.4877, grad_fn=<DivBackward0>)
# 836tensor(4.6300, grad_fn=<DivBackward0>)
# 837tensor(4.6633, grad_fn=<DivBackward0>)
# 838tensor(4.4448, grad_fn=<DivBackward0>)
# 839tensor(4.6139, grad_fn=<DivBackward0>)
# 840tensor(5.2743, grad_fn=<DivBackward0>)
# 841tensor(4.9571, grad_fn=<DivBackward0>)
# 842tensor(4.8038, grad_fn=<DivBackward0>)
# 843tensor(4.8952, grad_fn=<DivBackward0>)
# 844tensor(4.5756, grad_fn=<DivBackward0>)
# 845tensor(5.2804, grad_fn=<DivBackward0>)
# 846tensor(4.5703, grad_fn=<DivBackward0>)
# 847tensor(4.2977, grad_fn=<DivBackward0>)
# 848tensor(4.9592, grad_fn=<DivBackward0>)
# 849tensor(4.4837, grad_fn=<DivBackward0>)
# 850tensor(4.6689, grad_fn=<DivBackward0>)
# 851tensor(4.9585, grad_fn=<DivBackward0>)
# 852tensor(3.9343, grad_fn=<DivBackward0>)
# 853tensor(4.2659, grad_fn=<DivBackward0>)
# 854tensor(5.0018, grad_fn=<DivBackward0>)
# 855tensor(4.3762, grad_fn=<DivBackward0>)
# 856tensor(5.0532, grad_fn=<DivBackward0>)
# 857tensor(4.2133, grad_fn=<DivBackward0>)
# 858tensor(4.5113, grad_fn=<DivBackward0>)
# 859tensor(4.2783, grad_fn=<DivBackward0>)
# 860tensor(4.1424, grad_fn=<DivBackward0>)
# 861tensor(4.6274, grad_fn=<DivBackward0>)
# 862tensor(4.8904, grad_fn=<DivBackward0>)
# 863tensor(4.9699, grad_fn=<DivBackward0>)
# 864tensor(4.6063, grad_fn=<DivBackward0>)
# 865tensor(4.9245, grad_fn=<DivBackward0>)
# 866tensor(4.4309, grad_fn=<DivBackward0>)
# 867tensor(5.2136, grad_fn=<DivBackward0>)
# 868tensor(4.7209, grad_fn=<DivBackward0>)
# 869tensor(4.3173, grad_fn=<DivBackward0>)
# 870tensor(4.7993, grad_fn=<DivBackward0>)
# 871tensor(4.2151, grad_fn=<DivBackward0>)
# 872tensor(5.3233, grad_fn=<DivBackward0>)
# 873tensor(4.4633, grad_fn=<DivBackward0>)
# 874tensor(4.7070, grad_fn=<DivBackward0>)
# 875tensor(4.0003, grad_fn=<DivBackward0>)
# 876tensor(5.1069, grad_fn=<DivBackward0>)
# 877tensor(4.8145, grad_fn=<DivBackward0>)
# 878tensor(4.9476, grad_fn=<DivBackward0>)
# 879tensor(5.0923, grad_fn=<DivBackward0>)
# 880tensor(4.5524, grad_fn=<DivBackward0>)
# 881tensor(4.8190, grad_fn=<DivBackward0>)
# 882tensor(4.9391, grad_fn=<DivBackward0>)
# 883tensor(4.8411, grad_fn=<DivBackward0>)
# 884tensor(5.0597, grad_fn=<DivBackward0>)
# 885tensor(4.4755, grad_fn=<DivBackward0>)
# 886tensor(4.8405, grad_fn=<DivBackward0>)
# 887tensor(4.6320, grad_fn=<DivBackward0>)
# 888tensor(4.6685, grad_fn=<DivBackward0>)
# 889tensor(5.0967, grad_fn=<DivBackward0>)
# 890tensor(4.7031, grad_fn=<DivBackward0>)
# 891tensor(4.5418, grad_fn=<DivBackward0>)
# 892tensor(4.9296, grad_fn=<DivBackward0>)
# 893tensor(4.5201, grad_fn=<DivBackward0>)
# 894tensor(4.8346, grad_fn=<DivBackward0>)
# 895tensor(4.9902, grad_fn=<DivBackward0>)
# 896tensor(4.7233, grad_fn=<DivBackward0>)
# 897tensor(4.3790, grad_fn=<DivBackward0>)
# 898tensor(4.7631, grad_fn=<DivBackward0>)
# 899tensor(4.5012, grad_fn=<DivBackward0>)
# 900tensor(4.7441, grad_fn=<DivBackward0>)
# 901tensor(4.7308, grad_fn=<DivBackward0>)
# 902tensor(4.6562, grad_fn=<DivBackward0>)
# 903tensor(4.6954, grad_fn=<DivBackward0>)
# 904tensor(4.5932, grad_fn=<DivBackward0>)
# 905tensor(4.5694, grad_fn=<DivBackward0>)
# 906tensor(4.6307, grad_fn=<DivBackward0>)
# 907tensor(4.1757, grad_fn=<DivBackward0>)
# 908tensor(4.6055, grad_fn=<DivBackward0>)
# 909tensor(4.3809, grad_fn=<DivBackward0>)
# 910tensor(5.4480, grad_fn=<DivBackward0>)
# 911tensor(4.8566, grad_fn=<DivBackward0>)
# 912tensor(4.5213, grad_fn=<DivBackward0>)
# 913tensor(4.5339, grad_fn=<DivBackward0>)
# 914tensor(4.4407, grad_fn=<DivBackward0>)
# 915tensor(4.2125, grad_fn=<DivBackward0>)
# 916tensor(4.6970, grad_fn=<DivBackward0>)
# 917tensor(4.2892, grad_fn=<DivBackward0>)
# 918tensor(5.0712, grad_fn=<DivBackward0>)
# 919tensor(4.8337, grad_fn=<DivBackward0>)
# 920tensor(4.4271, grad_fn=<DivBackward0>)
# 921tensor(4.4945, grad_fn=<DivBackward0>)
# 922tensor(4.8644, grad_fn=<DivBackward0>)
# 923tensor(5.1170, grad_fn=<DivBackward0>)
# 924tensor(4.5548, grad_fn=<DivBackward0>)
# 925tensor(4.5968, grad_fn=<DivBackward0>)
# 926tensor(4.7397, grad_fn=<DivBackward0>)
# 927tensor(4.2917, grad_fn=<DivBackward0>)
# 928tensor(5.2642, grad_fn=<DivBackward0>)
# 929tensor(5.0746, grad_fn=<DivBackward0>)
# 930tensor(4.6550, grad_fn=<DivBackward0>)
# 931tensor(4.6953, grad_fn=<DivBackward0>)
# 932tensor(4.7533, grad_fn=<DivBackward0>)
# 933tensor(5.3572, grad_fn=<DivBackward0>)
# 934tensor(5.2409, grad_fn=<DivBackward0>)
# 935tensor(4.7530, grad_fn=<DivBackward0>)
# 936tensor(4.7075, grad_fn=<DivBackward0>)
# 937tensor(4.8864, grad_fn=<DivBackward0>)
# 938tensor(4.6782, grad_fn=<DivBackward0>)
# 939tensor(4.9681, grad_fn=<DivBackward0>)
# 940tensor(4.8516, grad_fn=<DivBackward0>)
# 941tensor(5.0937, grad_fn=<DivBackward0>)
# 942tensor(4.7238, grad_fn=<DivBackward0>)
# 943tensor(4.0170, grad_fn=<DivBackward0>)
# 944tensor(4.2485, grad_fn=<DivBackward0>)
# 945tensor(4.7891, grad_fn=<DivBackward0>)
# 946tensor(4.4040, grad_fn=<DivBackward0>)
# 947tensor(4.7371, grad_fn=<DivBackward0>)
# 948tensor(4.2222, grad_fn=<DivBackward0>)
# 949tensor(4.9631, grad_fn=<DivBackward0>)
# 950tensor(4.1305, grad_fn=<DivBackward0>)
# 951tensor(4.2306, grad_fn=<DivBackward0>)
# 952tensor(4.5648, grad_fn=<DivBackward0>)
# 953tensor(4.2345, grad_fn=<DivBackward0>)
# 954tensor(4.9946, grad_fn=<DivBackward0>)
# 955tensor(5.0084, grad_fn=<DivBackward0>)
# 956tensor(4.5408, grad_fn=<DivBackward0>)
# 957tensor(5.0181, grad_fn=<DivBackward0>)
# 958tensor(5.1463, grad_fn=<DivBackward0>)
# 959tensor(4.5122, grad_fn=<DivBackward0>)
# 960tensor(4.7575, grad_fn=<DivBackward0>)
# 961tensor(4.2848, grad_fn=<DivBackward0>)
# 962tensor(4.5894, grad_fn=<DivBackward0>)
# 963tensor(4.6788, grad_fn=<DivBackward0>)
# 964tensor(4.8566, grad_fn=<DivBackward0>)
# 965tensor(4.7435, grad_fn=<DivBackward0>)
# 966tensor(4.2222, grad_fn=<DivBackward0>)
# 967tensor(4.5833, grad_fn=<DivBackward0>)
# 968tensor(4.5356, grad_fn=<DivBackward0>)
# 969tensor(4.3364, grad_fn=<DivBackward0>)
# 970tensor(4.8535, grad_fn=<DivBackward0>)
# 971tensor(4.8399, grad_fn=<DivBackward0>)
# 972tensor(5.0026, grad_fn=<DivBackward0>)
# 973tensor(4.7540, grad_fn=<DivBackward0>)
# 974tensor(4.7840, grad_fn=<DivBackward0>)
# 975tensor(4.3809, grad_fn=<DivBackward0>)
# 976tensor(4.9522, grad_fn=<DivBackward0>)
# 977tensor(4.5092, grad_fn=<DivBackward0>)
# 978tensor(4.4195, grad_fn=<DivBackward0>)
# 979tensor(4.5043, grad_fn=<DivBackward0>)
# 980tensor(4.4090, grad_fn=<DivBackward0>)
# 981tensor(4.6491, grad_fn=<DivBackward0>)
# 982tensor(4.5221, grad_fn=<DivBackward0>)
# 983tensor(4.5095, grad_fn=<DivBackward0>)
# 984tensor(4.5913, grad_fn=<DivBackward0>)
# 985tensor(4.6424, grad_fn=<DivBackward0>)
# 986tensor(4.5669, grad_fn=<DivBackward0>)
# 987tensor(5.1038, grad_fn=<DivBackward0>)
# 988tensor(4.7111, grad_fn=<DivBackward0>)
# 989tensor(4.6962, grad_fn=<DivBackward0>)
# 990tensor(4.9463, grad_fn=<DivBackward0>)
# 991tensor(5.1408, grad_fn=<DivBackward0>)
# 992tensor(5.1114, grad_fn=<DivBackward0>)
# 993tensor(4.9053, grad_fn=<DivBackward0>)
# 994tensor(4.2089, grad_fn=<DivBackward0>)
# 995tensor(4.9786, grad_fn=<DivBackward0>)
# 996tensor(4.9507, grad_fn=<DivBackward0>)
# 997tensor(4.5355, grad_fn=<DivBackward0>)
# 998tensor(4.8532, grad_fn=<DivBackward0>)
# 999tensor(5.0202, grad_fn=<DivBackward0>)
# 1000tensor(4.8799, grad_fn=<DivBackward0>)
# 1001tensor(4.8300, grad_fn=<DivBackward0>)
# 1002tensor(4.8673, grad_fn=<DivBackward0>)
# 1003tensor(4.6006, grad_fn=<DivBackward0>)
# 1004tensor(4.6301, grad_fn=<DivBackward0>)
# 1005tensor(4.6853, grad_fn=<DivBackward0>)
# 1006tensor(4.9533, grad_fn=<DivBackward0>)
# 1007tensor(4.0474, grad_fn=<DivBackward0>)
# 1008tensor(4.5490, grad_fn=<DivBackward0>)
# 1009tensor(4.5979, grad_fn=<DivBackward0>)
# 1010tensor(4.7512, grad_fn=<DivBackward0>)
# 1011tensor(4.5478, grad_fn=<DivBackward0>)
# 1012tensor(4.7955, grad_fn=<DivBackward0>)
# 1013tensor(4.9063, grad_fn=<DivBackward0>)
# 1014tensor(4.3130, grad_fn=<DivBackward0>)
# 1015tensor(4.5786, grad_fn=<DivBackward0>)
# 1016tensor(4.7185, grad_fn=<DivBackward0>)
# 1017tensor(4.7516, grad_fn=<DivBackward0>)
# 1018tensor(4.4261, grad_fn=<DivBackward0>)
# 1019tensor(4.8034, grad_fn=<DivBackward0>)
# 1020tensor(4.6498, grad_fn=<DivBackward0>)
# 1021tensor(4.1325, grad_fn=<DivBackward0>)
# 1022tensor(4.9295, grad_fn=<DivBackward0>)
# 1023tensor(5.0061, grad_fn=<DivBackward0>)
# 1024tensor(5.1066, grad_fn=<DivBackward0>)
# 1025tensor(4.3637, grad_fn=<DivBackward0>)
# 1026tensor(4.8292, grad_fn=<DivBackward0>)
# 1027tensor(4.6966, grad_fn=<DivBackward0>)
# 1028tensor(4.8621, grad_fn=<DivBackward0>)
# 1029tensor(4.7517, grad_fn=<DivBackward0>)
# 1030tensor(4.6051, grad_fn=<DivBackward0>)
# 1031tensor(4.5915, grad_fn=<DivBackward0>)
# 1032tensor(4.6560, grad_fn=<DivBackward0>)
# 1033tensor(4.7871, grad_fn=<DivBackward0>)
# 1034tensor(4.7815, grad_fn=<DivBackward0>)
# 1035tensor(4.6129, grad_fn=<DivBackward0>)
# 1036tensor(3.9349, grad_fn=<DivBackward0>)
# 1037tensor(4.4929, grad_fn=<DivBackward0>)
# 1038tensor(4.4150, grad_fn=<DivBackward0>)
# 1039tensor(4.2815, grad_fn=<DivBackward0>)
# 1040tensor(4.7212, grad_fn=<DivBackward0>)
# 1041tensor(4.7413, grad_fn=<DivBackward0>)
# 1042tensor(4.0134, grad_fn=<DivBackward0>)
# 1043tensor(4.4605, grad_fn=<DivBackward0>)
# 1044tensor(4.3444, grad_fn=<DivBackward0>)
# 1045tensor(4.6176, grad_fn=<DivBackward0>)
# 1046tensor(4.4771, grad_fn=<DivBackward0>)
# 1047tensor(4.8500, grad_fn=<DivBackward0>)
# 1048tensor(4.7296, grad_fn=<DivBackward0>)
# 1049tensor(5.1683, grad_fn=<DivBackward0>)
# 1050tensor(4.3239, grad_fn=<DivBackward0>)
# 1051tensor(4.3645, grad_fn=<DivBackward0>)
# 1052tensor(4.7579, grad_fn=<DivBackward0>)
# 1053tensor(4.5049, grad_fn=<DivBackward0>)
# 1054tensor(4.4584, grad_fn=<DivBackward0>)
# 1055tensor(4.4092, grad_fn=<DivBackward0>)
# 1056tensor(4.3547, grad_fn=<DivBackward0>)
# 1057tensor(4.3858, grad_fn=<DivBackward0>)
# 1058tensor(4.2382, grad_fn=<DivBackward0>)
# 1059tensor(4.5624, grad_fn=<DivBackward0>)
# 1060tensor(4.1198, grad_fn=<DivBackward0>)
# 1061tensor(4.9132, grad_fn=<DivBackward0>)
# 1062tensor(5.5724, grad_fn=<DivBackward0>)
# 1063tensor(5.5500, grad_fn=<DivBackward0>)
# 1064tensor(4.5351, grad_fn=<DivBackward0>)
# 1065tensor(4.4213, grad_fn=<DivBackward0>)
# 1066tensor(4.6348, grad_fn=<DivBackward0>)
# 1067tensor(4.7634, grad_fn=<DivBackward0>)
# 1068tensor(5.0794, grad_fn=<DivBackward0>)
# 1069tensor(4.4659, grad_fn=<DivBackward0>)
# 1070tensor(4.8145, grad_fn=<DivBackward0>)
# 1071tensor(4.3089, grad_fn=<DivBackward0>)
# 1072tensor(4.5927, grad_fn=<DivBackward0>)
# 1073tensor(4.5075, grad_fn=<DivBackward0>)
# 1074tensor(4.2437, grad_fn=<DivBackward0>)
# 1075tensor(4.8254, grad_fn=<DivBackward0>)
# 1076tensor(4.1949, grad_fn=<DivBackward0>)
# 1077tensor(4.6647, grad_fn=<DivBackward0>)
# 1078tensor(4.5031, grad_fn=<DivBackward0>)
# 1079tensor(4.2937, grad_fn=<DivBackward0>)
# 1080tensor(4.5227, grad_fn=<DivBackward0>)
# 1081tensor(5.3382, grad_fn=<DivBackward0>)
# 1082tensor(4.5181, grad_fn=<DivBackward0>)
# 1083tensor(4.3293, grad_fn=<DivBackward0>)
# 1084tensor(4.5959, grad_fn=<DivBackward0>)
# 1085tensor(4.4679, grad_fn=<DivBackward0>)
# 1086tensor(4.6609, grad_fn=<DivBackward0>)
# 1087tensor(4.4181, grad_fn=<DivBackward0>)
# 1088tensor(4.2600, grad_fn=<DivBackward0>)
# 1089tensor(4.6732, grad_fn=<DivBackward0>)
# 1090tensor(4.7169, grad_fn=<DivBackward0>)
# 1091tensor(4.2950, grad_fn=<DivBackward0>)
# 1092tensor(4.8574, grad_fn=<DivBackward0>)
# 1093tensor(4.8615, grad_fn=<DivBackward0>)
# 1094tensor(4.4101, grad_fn=<DivBackward0>)
# 1095tensor(4.1853, grad_fn=<DivBackward0>)
# 1096tensor(4.4301, grad_fn=<DivBackward0>)
# 1097tensor(4.2230, grad_fn=<DivBackward0>)
# 1098tensor(4.6582, grad_fn=<DivBackward0>)
# 1099tensor(5.1760, grad_fn=<DivBackward0>)
# 1100tensor(4.3476, grad_fn=<DivBackward0>)
# 1101tensor(4.4583, grad_fn=<DivBackward0>)
# 1102tensor(4.7626, grad_fn=<DivBackward0>)
# 1103tensor(4.7341, grad_fn=<DivBackward0>)
# 1104tensor(4.8824, grad_fn=<DivBackward0>)
# 1105tensor(4.6008, grad_fn=<DivBackward0>)
# 1106tensor(4.8821, grad_fn=<DivBackward0>)
# 1107tensor(4.4814, grad_fn=<DivBackward0>)
# 1108tensor(4.5542, grad_fn=<DivBackward0>)
# 1109tensor(4.5749, grad_fn=<DivBackward0>)
# 1110tensor(4.6395, grad_fn=<DivBackward0>)
# 1111tensor(4.4281, grad_fn=<DivBackward0>)
# 1112tensor(4.6413, grad_fn=<DivBackward0>)
# 1113tensor(4.9894, grad_fn=<DivBackward0>)
# 1114tensor(5.1792, grad_fn=<DivBackward0>)
# 1115tensor(4.5530, grad_fn=<DivBackward0>)
# 1116tensor(4.4317, grad_fn=<DivBackward0>)
# 1117tensor(4.9018, grad_fn=<DivBackward0>)
# 1118tensor(4.1741, grad_fn=<DivBackward0>)
# 1119tensor(4.5664, grad_fn=<DivBackward0>)
# 1120tensor(5.3190, grad_fn=<DivBackward0>)
# 1121tensor(4.7165, grad_fn=<DivBackward0>)
# 1122tensor(4.5581, grad_fn=<DivBackward0>)
# 1123tensor(4.5600, grad_fn=<DivBackward0>)
# 1124tensor(4.7968, grad_fn=<DivBackward0>)
# 1125tensor(4.8707, grad_fn=<DivBackward0>)
# 1126tensor(4.4668, grad_fn=<DivBackward0>)
# 1127tensor(5.3611, grad_fn=<DivBackward0>)
# 1128tensor(4.6266, grad_fn=<DivBackward0>)
# 1129tensor(4.4563, grad_fn=<DivBackward0>)
# 1130tensor(4.7858, grad_fn=<DivBackward0>)
# 1131tensor(4.3000, grad_fn=<DivBackward0>)
# 1132tensor(4.5409, grad_fn=<DivBackward0>)
# 1133tensor(4.5989, grad_fn=<DivBackward0>)
# 1134tensor(4.4111, grad_fn=<DivBackward0>)
# 1135tensor(4.9322, grad_fn=<DivBackward0>)
# 1136tensor(4.5532, grad_fn=<DivBackward0>)
# 1137tensor(5.3069, grad_fn=<DivBackward0>)
# 1138tensor(5.0644, grad_fn=<DivBackward0>)
# 1139tensor(4.5163, grad_fn=<DivBackward0>)
# 1140tensor(4.2692, grad_fn=<DivBackward0>)
# ...
# 4628tensor(4.5166, grad_fn=<DivBackward0>)
# 4629tensor(4.0483, grad_fn=<DivBackward0>)
# 4630tensor(4.7072, grad_fn=<DivBackward0>)
# 4631tensor(4.1343, grad_fn=<DivBackward0>)
# 4632tensor(4.0826, grad_fn=<DivBackward0>)
# 4633tensor(4.3096, grad_fn=<DivBackward0>)
# 4634tensor(4.2801, grad_fn=<DivBackward0>)
# 4635tensor(4.2740, grad_fn=<DivBackward0>)
# 4636tensor(4.3138, grad_fn=<DivBackward0>)
# 4637tensor(4.1286, grad_fn=<DivBackward0>)
# 4638tensor(4.4045, grad_fn=<DivBackward0>)
# 4639tensor(4.0112, grad_fn=<DivBackward0>)
# 4640tensor(4.7107, grad_fn=<DivBackward0>)
# 4641tensor(4.2466, grad_fn=<DivBackward0>)
# 4642tensor(4.3574, grad_fn=<DivBackward0>)
# 4643tensor(3.8395, grad_fn=<DivBackward0>)
# 4644tensor(4.3417, grad_fn=<DivBackward0>)
# 4645tensor(4.3359, grad_fn=<DivBackward0>)
# 4646tensor(4.4292, grad_fn=<DivBackward0>)
# 4647tensor(4.8678, grad_fn=<DivBackward0>)
# 4648tensor(3.8070, grad_fn=<DivBackward0>)
# 4649tensor(3.9255, grad_fn=<DivBackward0>)
# 4650tensor(4.3330, grad_fn=<DivBackward0>)
# 4651tensor(4.4173, grad_fn=<DivBackward0>)
# 4652tensor(4.2637, grad_fn=<DivBackward0>)
# 4653tensor(4.1687, grad_fn=<DivBackward0>)
# 4654tensor(4.3392, grad_fn=<DivBackward0>)
# 4655tensor(4.4580, grad_fn=<DivBackward0>)
# 4656tensor(4.0488, grad_fn=<DivBackward0>)
# 4657tensor(4.2456, grad_fn=<DivBackward0>)
# 4658tensor(4.2111, grad_fn=<DivBackward0>)
# 4659tensor(4.1872, grad_fn=<DivBackward0>)
# 4660tensor(4.5495, grad_fn=<DivBackward0>)
# 4661tensor(3.9602, grad_fn=<DivBackward0>)
# 4662tensor(4.1485, grad_fn=<DivBackward0>)
# 4663tensor(4.5214, grad_fn=<DivBackward0>)
# 4664tensor(4.4593, grad_fn=<DivBackward0>)
# 4665tensor(4.1786, grad_fn=<DivBackward0>)
# 4666tensor(3.9601, grad_fn=<DivBackward0>)
# 4667tensor(4.6390, grad_fn=<DivBackward0>)
# 4668tensor(4.6508, grad_fn=<DivBackward0>)
# 4669tensor(4.3756, grad_fn=<DivBackward0>)
# 4670tensor(4.6684, grad_fn=<DivBackward0>)
# 4671tensor(3.7850, grad_fn=<DivBackward0>)
# 4672tensor(4.3614, grad_fn=<DivBackward0>)
# 4673tensor(4.1997, grad_fn=<DivBackward0>)
# 4674tensor(4.4142, grad_fn=<DivBackward0>)
# 4675tensor(4.0421, grad_fn=<DivBackward0>)
# 4676tensor(5.0382, grad_fn=<DivBackward0>)
# 4677tensor(3.9575, grad_fn=<DivBackward0>)
# 4678tensor(3.9470, grad_fn=<DivBackward0>)
# 4679tensor(4.2327, grad_fn=<DivBackward0>)
# 4680tensor(4.2045, grad_fn=<DivBackward0>)
# 4681tensor(4.2671, grad_fn=<DivBackward0>)
# 4682tensor(4.7510, grad_fn=<DivBackward0>)
# 4683tensor(4.3979, grad_fn=<DivBackward0>)
# 4684tensor(4.1920, grad_fn=<DivBackward0>)
# 4685tensor(4.4699, grad_fn=<DivBackward0>)
# 4686tensor(4.7737, grad_fn=<DivBackward0>)
# 4687tensor(4.0546, grad_fn=<DivBackward0>)
# 4688tensor(4.6432, grad_fn=<DivBackward0>)
# 4689tensor(3.8975, grad_fn=<DivBackward0>)
# 4690tensor(4.2842, grad_fn=<DivBackward0>)
# 4691tensor(4.3940, grad_fn=<DivBackward0>)
# 4692tensor(4.3868, grad_fn=<DivBackward0>)
# 4693tensor(4.3606, grad_fn=<DivBackward0>)
# 4694tensor(4.2464, grad_fn=<DivBackward0>)
# 4695tensor(4.3858, grad_fn=<DivBackward0>)
# 4696tensor(4.5692, grad_fn=<DivBackward0>)
# 4697tensor(4.4485, grad_fn=<DivBackward0>)
# 4698tensor(4.6397, grad_fn=<DivBackward0>)
# 4699tensor(4.3844, grad_fn=<DivBackward0>)
# 4700tensor(4.5582, grad_fn=<DivBackward0>)
# 4701tensor(4.2245, grad_fn=<DivBackward0>)
# 4702tensor(4.3407, grad_fn=<DivBackward0>)
# 4703tensor(4.2157, grad_fn=<DivBackward0>)
# 4704tensor(4.8953, grad_fn=<DivBackward0>)
# 4705tensor(4.3660, grad_fn=<DivBackward0>)
# 4706tensor(4.2556, grad_fn=<DivBackward0>)
# 4707tensor(4.5542, grad_fn=<DivBackward0>)
# 4708tensor(4.4259, grad_fn=<DivBackward0>)
# 4709tensor(4.5515, grad_fn=<DivBackward0>)
# 4710tensor(4.6874, grad_fn=<DivBackward0>)
# 4711tensor(4.3080, grad_fn=<DivBackward0>)
# 4712tensor(4.1539, grad_fn=<DivBackward0>)
# 4713tensor(4.1930, grad_fn=<DivBackward0>)
# 4714tensor(4.0483, grad_fn=<DivBackward0>)
# 4715tensor(4.0666, grad_fn=<DivBackward0>)
# 4716tensor(4.4516, grad_fn=<DivBackward0>)
# 4717tensor(3.9498, grad_fn=<DivBackward0>)
# 4718tensor(4.3118, grad_fn=<DivBackward0>)
# 4719tensor(4.6366, grad_fn=<DivBackward0>)
# 4720tensor(4.8931, grad_fn=<DivBackward0>)
# 4721tensor(4.5142, grad_fn=<DivBackward0>)
# 4722tensor(4.4310, grad_fn=<DivBackward0>)
# 4723tensor(3.8699, grad_fn=<DivBackward0>)
# 4724tensor(4.3607, grad_fn=<DivBackward0>)
# 4725tensor(4.3686, grad_fn=<DivBackward0>)
# 4726tensor(4.2742, grad_fn=<DivBackward0>)
# 4727tensor(4.3882, grad_fn=<DivBackward0>)
# 4728tensor(4.3710, grad_fn=<DivBackward0>)
# 4729tensor(4.7871, grad_fn=<DivBackward0>)
# 4730tensor(3.9149, grad_fn=<DivBackward0>)
# 4731tensor(4.9713, grad_fn=<DivBackward0>)
# 4732tensor(4.3212, grad_fn=<DivBackward0>)
# 4733tensor(4.0585, grad_fn=<DivBackward0>)
# 4734tensor(5.0463, grad_fn=<DivBackward0>)
# 4735tensor(3.9540, grad_fn=<DivBackward0>)
# 4736tensor(4.3812, grad_fn=<DivBackward0>)
# 4737tensor(4.5607, grad_fn=<DivBackward0>)
# 4738tensor(4.2307, grad_fn=<DivBackward0>)
# 4739tensor(4.5921, grad_fn=<DivBackward0>)
# 4740tensor(4.3410, grad_fn=<DivBackward0>)
# 4741tensor(4.2318, grad_fn=<DivBackward0>)
# 4742tensor(3.9970, grad_fn=<DivBackward0>)
# 4743tensor(4.3880, grad_fn=<DivBackward0>)
# 4744tensor(4.0197, grad_fn=<DivBackward0>)
# 4745tensor(4.4590, grad_fn=<DivBackward0>)
# 4746tensor(4.2586, grad_fn=<DivBackward0>)
# 4747tensor(4.3929, grad_fn=<DivBackward0>)
# 4748tensor(4.5487, grad_fn=<DivBackward0>)
# 4749tensor(4.9045, grad_fn=<DivBackward0>)
# 4750tensor(3.7650, grad_fn=<DivBackward0>)
# 4751tensor(4.5882, grad_fn=<DivBackward0>)
# 4752tensor(4.2677, grad_fn=<DivBackward0>)
# 4753tensor(4.1573, grad_fn=<DivBackward0>)
# 4754tensor(4.1332, grad_fn=<DivBackward0>)
# 4755tensor(4.6254, grad_fn=<DivBackward0>)
# 4756tensor(4.0640, grad_fn=<DivBackward0>)
# 4757tensor(4.2036, grad_fn=<DivBackward0>)
# 4758tensor(4.8093, grad_fn=<DivBackward0>)
# 4759tensor(3.8190, grad_fn=<DivBackward0>)
# 4760tensor(3.9898, grad_fn=<DivBackward0>)
# 4761tensor(4.5278, grad_fn=<DivBackward0>)
# 4762tensor(4.1559, grad_fn=<DivBackward0>)
# 4763tensor(4.0596, grad_fn=<DivBackward0>)
# 4764tensor(4.6023, grad_fn=<DivBackward0>)
# 4765tensor(4.5547, grad_fn=<DivBackward0>)
# 4766tensor(4.3260, grad_fn=<DivBackward0>)
# 4767tensor(4.5000, grad_fn=<DivBackward0>)
# 4768tensor(4.2391, grad_fn=<DivBackward0>)
# 4769tensor(4.7127, grad_fn=<DivBackward0>)
# 4770tensor(4.7888, grad_fn=<DivBackward0>)
# 4771tensor(4.3673, grad_fn=<DivBackward0>)
# 4772tensor(4.4197, grad_fn=<DivBackward0>)
# 4773tensor(4.3204, grad_fn=<DivBackward0>)
# 4774tensor(4.1192, grad_fn=<DivBackward0>)
# 4775tensor(4.3654, grad_fn=<DivBackward0>)
# 4776tensor(4.3681, grad_fn=<DivBackward0>)
# 4777tensor(4.2002, grad_fn=<DivBackward0>)
# 4778tensor(4.0072, grad_fn=<DivBackward0>)
# 4779tensor(4.2712, grad_fn=<DivBackward0>)
# 4780tensor(4.2906, grad_fn=<DivBackward0>)
# 4781tensor(4.5354, grad_fn=<DivBackward0>)
# 4782tensor(4.6729, grad_fn=<DivBackward0>)
# 4783tensor(4.5853, grad_fn=<DivBackward0>)
# 4784tensor(4.0209, grad_fn=<DivBackward0>)
# 4785tensor(4.8644, grad_fn=<DivBackward0>)
# 4786tensor(4.6147, grad_fn=<DivBackward0>)
# 4787tensor(4.1263, grad_fn=<DivBackward0>)
# 4788tensor(4.6194, grad_fn=<DivBackward0>)
# 4789tensor(4.1078, grad_fn=<DivBackward0>)
# 4790tensor(4.3167, grad_fn=<DivBackward0>)
# 4791tensor(4.7678, grad_fn=<DivBackward0>)
# 4792tensor(4.8677, grad_fn=<DivBackward0>)
# 4793tensor(4.6245, grad_fn=<DivBackward0>)
# 4794tensor(4.6557, grad_fn=<DivBackward0>)
# 4795tensor(4.4340, grad_fn=<DivBackward0>)
# 4796tensor(4.3507, grad_fn=<DivBackward0>)
# 4797tensor(3.9028, grad_fn=<DivBackward0>)
# 4798tensor(4.2868, grad_fn=<DivBackward0>)
# 4799tensor(4.2409, grad_fn=<DivBackward0>)
# 4800tensor(4.3931, grad_fn=<DivBackward0>)
# 4801tensor(4.4010, grad_fn=<DivBackward0>)
# 4802tensor(4.5164, grad_fn=<DivBackward0>)
# 4803tensor(4.6241, grad_fn=<DivBackward0>)
# 4804tensor(4.3784, grad_fn=<DivBackward0>)
# 4805tensor(4.2140, grad_fn=<DivBackward0>)
# 4806tensor(4.3774, grad_fn=<DivBackward0>)
# 4807tensor(3.7163, grad_fn=<DivBackward0>)
# 4808tensor(3.9877, grad_fn=<DivBackward0>)
# 4809tensor(4.0523, grad_fn=<DivBackward0>)
# 4810tensor(4.6302, grad_fn=<DivBackward0>)
# 4811tensor(3.9488, grad_fn=<DivBackward0>)
# 4812tensor(4.4692, grad_fn=<DivBackward0>)
# 4813tensor(4.4242, grad_fn=<DivBackward0>)
# 4814tensor(4.3720, grad_fn=<DivBackward0>)
# 4815tensor(5.1120, grad_fn=<DivBackward0>)
# 4816tensor(4.4210, grad_fn=<DivBackward0>)
# 4817tensor(4.5791, grad_fn=<DivBackward0>)
# 4818tensor(4.0409, grad_fn=<DivBackward0>)
# 4819tensor(4.0974, grad_fn=<DivBackward0>)
# 4820tensor(4.2174, grad_fn=<DivBackward0>)
# 4821tensor(4.3602, grad_fn=<DivBackward0>)
# 4822tensor(4.7767, grad_fn=<DivBackward0>)
# 4823tensor(3.6877, grad_fn=<DivBackward0>)
# 4824tensor(4.6722, grad_fn=<DivBackward0>)
# 4825tensor(3.6507, grad_fn=<DivBackward0>)
# 4826tensor(4.3243, grad_fn=<DivBackward0>)
# 4827tensor(4.0953, grad_fn=<DivBackward0>)
# 4828tensor(4.4725, grad_fn=<DivBackward0>)
# 4829tensor(4.0181, grad_fn=<DivBackward0>)
# 4830tensor(4.4873, grad_fn=<DivBackward0>)
# 4831tensor(4.9678, grad_fn=<DivBackward0>)
# 4832tensor(3.9196, grad_fn=<DivBackward0>)
# 4833tensor(4.4316, grad_fn=<DivBackward0>)
# 4834tensor(4.0050, grad_fn=<DivBackward0>)
# 4835tensor(4.4072, grad_fn=<DivBackward0>)
# 4836tensor(4.4236, grad_fn=<DivBackward0>)
# 4837tensor(4.2450, grad_fn=<DivBackward0>)
# 4838tensor(4.4709, grad_fn=<DivBackward0>)
# 4839tensor(4.0523, grad_fn=<DivBackward0>)
# 4840tensor(4.2142, grad_fn=<DivBackward0>)
# 4841tensor(3.9956, grad_fn=<DivBackward0>)
# 4842tensor(4.1215, grad_fn=<DivBackward0>)
# 4843tensor(4.2126, grad_fn=<DivBackward0>)
# 4844tensor(4.1351, grad_fn=<DivBackward0>)
# 4845tensor(4.2514, grad_fn=<DivBackward0>)
# 4846tensor(4.0380, grad_fn=<DivBackward0>)
# 4847tensor(4.1664, grad_fn=<DivBackward0>)
# 4848tensor(4.5931, grad_fn=<DivBackward0>)
# 4849tensor(4.4670, grad_fn=<DivBackward0>)
# 4850tensor(4.2038, grad_fn=<DivBackward0>)
# 4851tensor(4.1153, grad_fn=<DivBackward0>)
# 4852tensor(3.6690, grad_fn=<DivBackward0>)
# 4853tensor(3.7186, grad_fn=<DivBackward0>)
# 4854tensor(4.2769, grad_fn=<DivBackward0>)
# 4855tensor(3.8176, grad_fn=<DivBackward0>)
# 4856tensor(4.0582, grad_fn=<DivBackward0>)
# 4857tensor(4.5409, grad_fn=<DivBackward0>)
# 4858tensor(3.9767, grad_fn=<DivBackward0>)
# 4859tensor(4.1708, grad_fn=<DivBackward0>)
# 4860tensor(3.7352, grad_fn=<DivBackward0>)
# 4861tensor(4.7376, grad_fn=<DivBackward0>)
# 4862tensor(4.4636, grad_fn=<DivBackward0>)
# 4863tensor(4.9694, grad_fn=<DivBackward0>)
# 4864tensor(4.6774, grad_fn=<DivBackward0>)
# 4865tensor(4.4154, grad_fn=<DivBackward0>)
# 4866tensor(4.1737, grad_fn=<DivBackward0>)
# 4867tensor(4.6411, grad_fn=<DivBackward0>)
# 4868tensor(4.3610, grad_fn=<DivBackward0>)
# 4869tensor(4.5007, grad_fn=<DivBackward0>)
# 4870tensor(4.3503, grad_fn=<DivBackward0>)
# 4871tensor(4.2742, grad_fn=<DivBackward0>)
# 4872tensor(4.6764, grad_fn=<DivBackward0>)
# 4873tensor(4.2939, grad_fn=<DivBackward0>)
# 4874tensor(4.0500, grad_fn=<DivBackward0>)
# 4875tensor(4.5929, grad_fn=<DivBackward0>)
# 4876tensor(3.9300, grad_fn=<DivBackward0>)
# 4877tensor(3.9736, grad_fn=<DivBackward0>)
# 4878tensor(4.3698, grad_fn=<DivBackward0>)
# 4879tensor(4.7319, grad_fn=<DivBackward0>)
# 4880tensor(3.9592, grad_fn=<DivBackward0>)
# 4881tensor(4.5727, grad_fn=<DivBackward0>)
# 4882tensor(4.6420, grad_fn=<DivBackward0>)
# 4883tensor(4.5271, grad_fn=<DivBackward0>)
# 4884tensor(4.1877, grad_fn=<DivBackward0>)
# 4885tensor(4.0954, grad_fn=<DivBackward0>)
# 4886tensor(4.1958, grad_fn=<DivBackward0>)
# 4887tensor(4.0785, grad_fn=<DivBackward0>)
# 4888tensor(3.7998, grad_fn=<DivBackward0>)
# 4889tensor(4.1757, grad_fn=<DivBackward0>)
# 4890tensor(4.0712, grad_fn=<DivBackward0>)
# 4891tensor(4.3299, grad_fn=<DivBackward0>)
# 4892tensor(4.6142, grad_fn=<DivBackward0>)
# 4893tensor(3.9699, grad_fn=<DivBackward0>)
# 4894tensor(4.2308, grad_fn=<DivBackward0>)
# 4895tensor(4.3140, grad_fn=<DivBackward0>)
# 4896tensor(4.1752, grad_fn=<DivBackward0>)
# 4897tensor(4.2422, grad_fn=<DivBackward0>)
# 4898tensor(4.5151, grad_fn=<DivBackward0>)
# 4899tensor(4.1680, grad_fn=<DivBackward0>)
# 4900tensor(3.7461, grad_fn=<DivBackward0>)
# 4901tensor(3.9698, grad_fn=<DivBackward0>)
# 4902tensor(4.3713, grad_fn=<DivBackward0>)
# 4903tensor(4.2665, grad_fn=<DivBackward0>)
# 4904tensor(4.8302, grad_fn=<DivBackward0>)
# 4905tensor(3.8840, grad_fn=<DivBackward0>)
# 4906tensor(4.3488, grad_fn=<DivBackward0>)
# 4907tensor(4.5350, grad_fn=<DivBackward0>)
# 4908tensor(4.1160, grad_fn=<DivBackward0>)
# 4909tensor(4.2594, grad_fn=<DivBackward0>)
# 4910tensor(4.2972, grad_fn=<DivBackward0>)
# 4911tensor(3.9830, grad_fn=<DivBackward0>)
# 4912tensor(4.0172, grad_fn=<DivBackward0>)
# 4913tensor(4.4679, grad_fn=<DivBackward0>)
# 4914tensor(4.4686, grad_fn=<DivBackward0>)
# 4915tensor(4.4438, grad_fn=<DivBackward0>)
# 4916tensor(4.4869, grad_fn=<DivBackward0>)
# 4917tensor(4.2972, grad_fn=<DivBackward0>)
# 4918tensor(4.4449, grad_fn=<DivBackward0>)
# 4919tensor(3.9487, grad_fn=<DivBackward0>)
# 4920tensor(3.9509, grad_fn=<DivBackward0>)
# 4921tensor(4.2540, grad_fn=<DivBackward0>)
# 4922tensor(4.0914, grad_fn=<DivBackward0>)
# 4923tensor(4.2485, grad_fn=<DivBackward0>)
# 4924tensor(4.2506, grad_fn=<DivBackward0>)
# 4925tensor(3.9745, grad_fn=<DivBackward0>)
# 4926tensor(4.1979, grad_fn=<DivBackward0>)
# 4927tensor(3.9089, grad_fn=<DivBackward0>)
# 4928tensor(4.1005, grad_fn=<DivBackward0>)
# 4929tensor(4.4570, grad_fn=<DivBackward0>)
# 4930tensor(4.2811, grad_fn=<DivBackward0>)
# 4931tensor(4.0970, grad_fn=<DivBackward0>)
# 4932tensor(4.2468, grad_fn=<DivBackward0>)
# 4933tensor(4.2662, grad_fn=<DivBackward0>)
# 4934tensor(4.5273, grad_fn=<DivBackward0>)
# 4935tensor(4.2628, grad_fn=<DivBackward0>)
# 4936tensor(4.1621, grad_fn=<DivBackward0>)
# 4937tensor(3.9331, grad_fn=<DivBackward0>)
# 4938tensor(4.4346, grad_fn=<DivBackward0>)
# 4939tensor(4.5687, grad_fn=<DivBackward0>)
# 4940tensor(4.3245, grad_fn=<DivBackward0>)
# 4941tensor(4.4832, grad_fn=<DivBackward0>)
# 4942tensor(4.3521, grad_fn=<DivBackward0>)
# 4943tensor(4.3833, grad_fn=<DivBackward0>)
# 4944tensor(4.2030, grad_fn=<DivBackward0>)
# 4945tensor(4.6034, grad_fn=<DivBackward0>)
# 4946tensor(5.2549, grad_fn=<DivBackward0>)
# 4947tensor(3.8922, grad_fn=<DivBackward0>)
# 4948tensor(4.3617, grad_fn=<DivBackward0>)
# 4949tensor(3.9099, grad_fn=<DivBackward0>)
# 4950tensor(4.8063, grad_fn=<DivBackward0>)
# 4951tensor(4.4449, grad_fn=<DivBackward0>)
# 4952tensor(4.3757, grad_fn=<DivBackward0>)
# 4953tensor(4.9487, grad_fn=<DivBackward0>)
# 4954tensor(4.5674, grad_fn=<DivBackward0>)
# 4955tensor(3.6385, grad_fn=<DivBackward0>)
# 4956tensor(4.3447, grad_fn=<DivBackward0>)
# 4957tensor(4.6357, grad_fn=<DivBackward0>)
# 4958tensor(4.3317, grad_fn=<DivBackward0>)
# 4959tensor(4.6879, grad_fn=<DivBackward0>)
# 4960tensor(3.8922, grad_fn=<DivBackward0>)
# 4961tensor(4.3033, grad_fn=<DivBackward0>)
# 4962tensor(4.1370, grad_fn=<DivBackward0>)
# 4963tensor(4.4223, grad_fn=<DivBackward0>)
# 4964tensor(3.9595, grad_fn=<DivBackward0>)
# 4965tensor(4.3819, grad_fn=<DivBackward0>)
# 4966tensor(4.3048, grad_fn=<DivBackward0>)
# 4967tensor(4.0522, grad_fn=<DivBackward0>)
# 4968tensor(4.4223, grad_fn=<DivBackward0>)
# 4969tensor(4.8654, grad_fn=<DivBackward0>)
# 4970tensor(4.6683, grad_fn=<DivBackward0>)
# 4971tensor(4.2477, grad_fn=<DivBackward0>)
# 4972tensor(3.9569, grad_fn=<DivBackward0>)
# 4973tensor(4.4406, grad_fn=<DivBackward0>)
# 4974tensor(4.4165, grad_fn=<DivBackward0>)
# 4975tensor(3.8118, grad_fn=<DivBackward0>)
# 4976tensor(4.0033, grad_fn=<DivBackward0>)
# 4977tensor(4.2133, grad_fn=<DivBackward0>)
# 4978tensor(4.4921, grad_fn=<DivBackward0>)
# 4979tensor(4.1663, grad_fn=<DivBackward0>)
# 4980tensor(4.0946, grad_fn=<DivBackward0>)
# 4981tensor(4.2131, grad_fn=<DivBackward0>)
# 4982tensor(4.2547, grad_fn=<DivBackward0>)
# 4983tensor(4.8472, grad_fn=<DivBackward0>)
# 4984tensor(4.2560, grad_fn=<DivBackward0>)
# 4985tensor(4.4337, grad_fn=<DivBackward0>)
# 4986tensor(4.0400, grad_fn=<DivBackward0>)
# 4987tensor(4.7176, grad_fn=<DivBackward0>)
# 4988tensor(4.2245, grad_fn=<DivBackward0>)
# 4989tensor(3.8980, grad_fn=<DivBackward0>)
# 4990tensor(4.4442, grad_fn=<DivBackward0>)
# 4991tensor(3.9332, grad_fn=<DivBackward0>)
# 4992tensor(4.8963, grad_fn=<DivBackward0>)
# 4993tensor(4.4682, grad_fn=<DivBackward0>)
# 4994tensor(3.8698, grad_fn=<DivBackward0>)
# 4995tensor(3.9321, grad_fn=<DivBackward0>)
# 4996tensor(3.9415, grad_fn=<DivBackward0>)
# 4997tensor(4.8052, grad_fn=<DivBackward0>)
# 4998tensor(3.9351, grad_fn=<DivBackward0>)
# 4999tensor(4.2051, grad_fn=<DivBackward0>)

# %%
os.chdir('C:\\Users\\Ji Qi\\Documents\\GitHub\\ST-Aim3')
os.getcwd()
PATH = 'vgae_model_for_simulation.pth'
torch.save(model, PATH)

model = torch.load(PATH)
model.eval()
# Out:
# VGAE(
#   (encoder): Encoder(
#     (conv1): GCNConv(10, 20)
#     (conv_mu): GCNConv(20, 10)
#     (conv_logstd): GCNConv(20, 10)
#   )
#   (decoder): InnerProductDecoder()
# )

# %%
# get mu and logstd 

mu_list_in_data = []
logstd_list_in_data = []
for i in range(len(dataset)):
    train_data = dataset[i]
    mu = model.encode(train_data.x, train_data.edge_index)
    mu_list_in_data.append(np.asarray(mu.detach()))

mu_list_reshape = []
n = len(dataset)
for i in range(n):
    mu_list_reshape.append(mu_list_in_data[i].reshape((out_channels * n_node)))

# input data scatter 
import matplotlib.pyplot as plt
def plot_mu_graph(mu):
    
    n_node = mu.shape[0]
    annotations = [str(i+1) for i in range(n_node)]
    colors = plt.cm.rainbow(np.linspace(0, 1, n_node))
    plt.scatter(mu[:,0],mu[:,1],c=colors, s=100)
    
    for i, label in enumerate(annotations):
        plt.annotate(label, (mu[i,0], mu[i,1]), fontsize=14)

        
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list_in_data[graph_i])

# %%
# original data mu scatter
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
def plot_scatter_for_mu(mu_list):
    column_names = ["x", "y"]
    mu_for_plot = pd.DataFrame(columns = column_names, data=np.vstack(mu_list))
    mu_for_plot["label"] = list(range(10))*len(mu_list)
    x = mu_for_plot["x"]
    y = mu_for_plot["y"]
    c = mu_for_plot["label"]
    fig, ax = plt.subplots(figsize=(10,10))
    scatter = ax.scatter(x, y, c=c)

    # produce a legend with the unique colors from the scatter
    legend1 = ax.legend(*scatter.legend_elements(),
                        loc="lower left", title="Classes")
    ax.add_artist(legend1)

    plt.grid()
    plt.show()

plot_scatter_for_mu(mu_list_in_data)

# %%
# Gaussian distribution for generating mu

import scipy.stats as stats
data_mu = np.zeros((n, out_channels * n_node))
for i in range(n):
    data_mu[i, :] = mu_list_reshape[i]

from sklearn.mixture import GaussianMixture

gm_mu = GaussianMixture(n_components=1, random_state=0).fit(data_mu)
gm_mu.weights_[0] = 1
# Out:
# C:\Users\Ji Qi\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# got mean and cov for mu generating distribution
means_normal = gm_mu.means_
cov_normal = gm_mu.covariances_
means_normal = np.asarray(means_normal.tolist()[0])
cov_normal = np.asarray(cov_normal.tolist()[0])

# %%
def compute_centrality(mat):
    return (np.sum(mat, axis=0)/mat.shape[0])

# %%
def sample_adj_mat(filter_value=0.75, filter_eye=True):
    model.__mu__ = torch.from_numpy((np.random.multivariate_normal(mean=means_normal,cov=cov_normal)).reshape((n_node,out_channels)))
    z = model.__mu__
    model.decode(z, edge_index)
    adj_mat = np.zeros((n_node, n_node))
    for i in range(n_node*n_node):
        adj_mat[int(edge_index[0, i]), int(edge_index[1, i])] = (model.decode(z, edge_index)[i].detach().numpy()).item()
    adj_mat[adj_mat < filter_value] = 0
    if filter_eye:
        for i in range(adj_mat.shape[0]):
            adj_mat[i,i]=0
    return adj_mat, model.__mu__

# %%
# generate adjacency matrices

generated_from_simu = []
generated_simu_centrality = []

import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 6, figsize=(20,10))
adj_mat_list = []
mu_list = []
for i in range(30):
    plt.subplot(5, 6, i+1)
    adj_mat, mu_sample = sample_adj_mat(filter_value=0, filter_eye=False)
    generated_from_simu.append(adj_mat)
    generated_simu_centrality.append(compute_centrality(adj_mat))
    adj_mat_list.append(adj_mat)
    mu_list.append(mu_sample.detach().numpy())
    plt.imshow(adj_mat, cmap="Greys")

# %%
plt.subplots(figsize=(20,20))

for graph_i in range(30):
    plt.subplot(5, 6, graph_i+1)
    plot_mu_graph(mu_list[graph_i])

# %%
plot_scatter_for_mu(mu_list)

# %%
simu_adj_list = []
simu_centrality_list = []
for i in range(30):
    adj_mat = simu_graph.simu_adj_m()[i].detach().numpy()
    simu_adj_list.append(adj_mat)
    simu_centrality_list.append(compute_centrality(adj_mat))

# %%
from scipy import stats
res = stats.ttest_ind(generated_simu_centrality, simu_centrality_list, 
                      equal_var=True, axis=0)
display(res)
# Out:
# Ttest_indResult(statistic=array([ 14.16128597,  14.27910879,   8.00585641,  10.87603324,
#         12.50602862, 319.61246725, 375.9456942 , 342.71001422,
#        399.62060884, 402.41175989]), pvalue=array([1.76789386e-020, 1.21478786e-020, 5.98782420e-011, 1.26025447e-015,
#        4.15003227e-018, 7.63064019e-096, 6.24349936e-100, 1.33628026e-097,
#        1.81005594e-101, 1.20901733e-101]))

# %%
np.mean(np.vstack(generated_simu_centrality), axis=0)
# Out:
# array([0.53758528, 0.53261797, 0.44517827, 0.53892192, 0.54468259,
#        0.42887293, 0.43343869, 0.4303677 , 0.4362384 , 0.43682127])

# %%
np.mean(np.vstack(simu_centrality_list), axis=0)
# Out:
# array([0.24333334, 0.24333332, 0.26000002, 0.25333336, 0.22000003,
#        0.        , 0.        , 0.        , 0.        , 0.        ],
#       dtype=float32)
